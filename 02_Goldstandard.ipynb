# %% [markdown]
# # Load data

# %%
import json
import pandas as pd

# %%
! ls daten_goldstandard/
# Out:
# master.json slave.json  unique.json

# %%
records_master = []
records_slave = []
records_unique = []
for line in open('./daten_goldstandard/master.json', 'r'):
    records_master.append(json.loads(line))
for line in open('./daten_goldstandard/slave.json', 'r'):
    records_slave.append(json.loads(line))
for line in open('./daten_goldstandard/unique.json', 'r'):
    records_unique.append(json.loads(line))

len(records_master), len(records_slave), len(records_unique)
# Out:
# (159, 435, 596)

# %%
df_m = pd.DataFrame(records_master)
df_s = pd.DataFrame(records_slave)
df_u = pd.DataFrame(records_unique)

len(df_m.columns), len(df_s.columns), len(df_u.columns)
# Out:
# (23, 23, 23)

# %%
# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(df_m.columns)

df_m.head()
# Out:
#                                             035liste century coordinate  \
# 0         [(IDSBB)002447452, (ALEX)9912923344101791]    2000         []
# 1               [(IDSBB)000369647, (NEBIS)005609528]    1978         []
# 2  [(IDSLU)001293605, (IDSBB)006725532, (NEBIS)01...    2017         []
# 3  [(NATIONALLICENCE)oxford-10.1093/cid/ciu795, (...    2015         []
# 4  [(NATIONALLICENCE)oxford-10.1093/ndt/gft319, (...    2013         []
#
#   corporate decade      docid                   doi edition exactDate  \
# 0        []   2000  264853032                    []          2000
# 1        []   1978  264853288                    []          1978
# 2        []   2017  264853539                    []          2017
# 3        []   2015  264853784  [10.1093/cid/ciu795]          20150201
# 4        []   2013  264854039  [10.1093/ndt/gft319]          201310
#
#                  format             isbn                  ismn musicid  \
# 0  [BK020000, BK020800]  [0-87834-101-3]                    []
# 1            [BK020000]               []                    []
# 2            [BK010000]               []                    []
# 3            [BK010053]               []  [10.1093/cid/ciu795]
# 4            [BK010053]               []  [10.1093/ndt/gft319]
#
#          pages                         part  \
# 0     [319 S.]          [Vol. 26, 26, 2000]
# 1     [252 S.]                  [33001/680]
# 2  [74 Seiten]      [Nr. 313 (August 2017)]
# 3           []  [60/3(2015-02-01), 432-437]
# 4           []  [28/10(2013-10), 2421-2431]
#
#                                               person pubinit pubword  \
# 0  [[ChuC.Y. Cyrus, LeeRonald Demos(DE-588)157411...      []      []
# 1  [[SchikanederEmanuel1751-1812(DE-588)11860757X...      []      []
# 2  [[SchneiderReto U.1963-(DE-588)115417206Verfas...      []      []
# 3  [[RozotVirginieDivision of Immunology and Alle...      []      []
# 4  [[BonnyOlivierDepartment of Pharmacology and T...      []      []
#
#     pubyear scale                                            ttlfull  \
# 0  2000                [Population and economic change in East Asia]
# 1  1978                                            [Die Zauberflöte]
# 2  2017            [Alles Wissen dieser Welt, warum Bibliotheken ...
# 3  20150201        [Combined Use of Mycobacterium tuberculosis-Sp...
# 4  201310          [Molecular bases of circadian rhythmicity in r...
#
#                                              ttlpart      volumes
# 0      [Population and economic change in East Asia]     [319 S.]
# 1                                  [Die Zauberflöte]     [252 S.]
# 2  [Alles Wissen dieser Welt, warum Bibliotheken ...  [74 Seiten]
# 3  [Combined Use of Mycobacterium tuberculosis-Sp...           []
# 4  [Molecular bases of circadian rhythmicity in r...           []

# %%
df_s.head()
# Out:
#                              035liste century coordinate  \
# 0  [(OCoLC)731635279, (ABN)000539983]    2009         []
# 1  [(OCoLC)808324878, (ABN)000155059]    2000         []
# 2  [(OCoLC)231772550, (ABN)000096920]    1999         []
# 3  [(OCoLC)887157168, (ABN)000223912]    uuuu         []
# 4  [(OCoLC)887324690, (ABN)000548154]    2008         []
#
#                                            corporate decade      docid doi  \
# 0                                                 []   2009  000311049  []
# 1  [Metropolitan Opera Orchestra, Metropolitan Op...   2000  00130724X  []
# 2                                                 []   1999  001817272  []
# 3                                                 []   uuuu  00236865X  []
# 4                                                 []   2008  00351031X  []
#
#   edition exactDate      format                 isbn ismn musicid  \
# 0          2009      [BK020000]  [978-3-15-020008-7]   []
# 1          2000      [VM010300]                   []   []
# 2          1999      [BK020000]      [3-495-47879-5]   []
# 3          uuuuuuuu  [BK020000]                   []   []
# 4          2008      [BK020000]  [978-1-4058-8214-9]   []
#
#                                           pages     part  \
# 0                                      [600 S.]  [20008]
# 1  [1 DVD-Video, DVD Region 0, 169 Min., farb.]       []
# 2                                      [316 S.]       []
# 3                                      [412 S.]       []
# 4                                       [64 S.]       []
#
#                                               person                pubinit  \
# 0  [[GraweChristian, GraweUrsula], [Jane Austen ;...          [Reclam jun.]
# 1  [[MozartWolfgang Amadeus, LevineJames, Schikan...  [Deutsche Grammophon]
# 2                                  [[Andreas Flury]]                [Alber]
# 3                                               [[]]      [Ernst Eulenburg]
# 4  [[StrangeJoanna], [Jane Austen ; retold by Joa...    [Pearson Education]
#
#                  pubword   pubyear scale  \
# 0          [Reclam jun.]  2009
# 1  [Deutsche Grammophon]  2000
# 2                [Alber]  1999
# 3      [Ernst Eulenburg]  uuuuuuuu
# 4    [Pearson Education]  2008
#
#                                              ttlfull  \
# 0                                      [Emma, Roman]
# 1           [Die Zauberflöte, Oper in zwei Aufzügen]
# 2  [Der moralische Status der Tiere, Henry Salt, ...
# 3                                  [Die Zauberflöte]
# 4                                             [Emma]
#
#                                              ttlpart  \
# 0                                      [Emma, Roman]
# 1           [Die Zauberflöte, Oper in zwei Aufzügen]
# 2  [Der moralische Status der Tiere, Henry Salt, ...
# 3                                  [Die Zauberflöte]
# 4                                             [Emma]
#
#                                         volumes
# 0                                      [600 S.]
# 1  [1 DVD-Video, DVD Region 0, 169 Min., farb.]
# 2                                      [316 S.]
# 3                                      [412 S.]
# 4                                       [64 S.]

# %%
df_u.head()
# Out:
#                              035liste century coordinate  \
# 0  [(OCoLC)362722306, (ABN)000551177]    2009         []
# 1  [(OCoLC)886929897, (ABN)000223034]    2004         []
# 2  [(OCoLC)778386601, (ABN)000433604]    1793         []
# 3  [(OCoLC)778561839, (ABN)000238844]    2000         []
# 4  [(OCoLC)777853583, (ABN)000243260]    1990         []
#
#                  corporate decade      docid doi edition exactDate  \
# 0                       []   2009  000143235  []          2009
# 1  [Wiener Philharmoniker]   2004  00044801X  []          2004
# 2                       []   1793  000996009  []          17931797
# 3                       []   2000  00239538X  []          2000
# 4                       []   1990  002410559  []          1990
#
#        format                 isbn ismn musicid  \
# 0  [BK020000]  [978-3-7466-6120-9]   []
# 1  [MU040100]                   []   []
# 2  [MU010000]                   []   []
# 3  [BK020047]      [3-932992-42-3]   []
# 4  [BK020000]      [0-19-282756-1]   []
#
#                                                pages    part  \
# 0                                           [575 S.]  [6120]
# 1                                             [2 CD]      []
# 2                                           [202 S.]      []
# 3  [1 CD-Rom in Box, mit Notizbuchfunktion für Re...      []
# 4                                           [445 p.]      []
#
#                                               person  \
# 0                                    [[Jane Austen]]
# 1                         [[KarajanHerbert von], []]
# 2                        [[Wolfgang Amadeus Mozart]]
# 3  [[FrischMax1911-1991(DE-588)118536109], [Max F...
# 4                                    [[Jane Austen]]
#
#                      pubinit                    pubword   pubyear scale  \
# 0       [Aufbau Taschenbuch]       [Aufbau Taschenbuch]  2009
# 1                  [Membran]                  [Membran]  2004
# 2          [Komm. Breitkopf]          [Komm. Breitkopf]  17931797
# 3                   [Terzio]                   [Terzio]  2000
# 4  [Oxford University Press]  [Oxford University Press]  1990
#
#                                              ttlfull  \
# 0                                      [Emma, Roman]
# 1                                  [Die Zauberflöte]
# 2  [Die Zauberflöte, eine grosse Oper in zwey Auf...
# 3  [Homo faber, Originaltext, Interpretation, Bio...
# 4                                             [Emma]
#
#                                              ttlpart  \
# 0                                      [Emma, Roman]
# 1                                  [Die Zauberflöte]
# 2  [Die Zauberflöte, eine grosse Oper in zwey Auf...
# 3  [Homo faber, Originaltext, Interpretation, Bio...
# 4                                             [Emma]
#
#                                              volumes
# 0                                           [575 S.]
# 1                                             [2 CD]
# 2                                           [202 S.]
# 3  [1 CD-Rom in Box, mit Notizbuchfunktion für Re...
# 4                                           [445 p.]

# %% [markdown]
# ## Transform list columns to string columns

# %%
def transform_list_to_string(df, column):
    df[column] = [', '.join(map(str, list_element)) for list_element in df[column]]
    
    return df

# %%
list_columns = ['coordinate', 'corporate', 'pages', 'part', 'pubword',
                'ttlfull', 'ttlpart']
array_of_strings_columns = ['person']

for list_col in list_columns:
    df_m = transform_list_to_string(df_m, list_col)
    df_s = transform_list_to_string(df_s, list_col)
    df_u = transform_list_to_string(df_u, list_col)

for aos_col in array_of_strings_columns:
    df_m = transform_list_to_string(df_m, aos_col)
    df_s = transform_list_to_string(df_s, aos_col)
    df_u = transform_list_to_string(df_u, aos_col)
    
# Additional
df_s = transform_list_to_string(df_s, '035liste')
df_u = transform_list_to_string(df_u, '035liste')

# %%
df_m.head()
# Out:
#                                             035liste century coordinate  \
# 0         [(IDSBB)002447452, (ALEX)9912923344101791]    2000
# 1               [(IDSBB)000369647, (NEBIS)005609528]    1978
# 2  [(IDSLU)001293605, (IDSBB)006725532, (NEBIS)01...    2017
# 3  [(NATIONALLICENCE)oxford-10.1093/cid/ciu795, (...    2015
# 4  [(NATIONALLICENCE)oxford-10.1093/ndt/gft319, (...    2013
#
#   corporate decade      docid                   doi edition exactDate  \
# 0             2000  264853032                    []          2000
# 1             1978  264853288                    []          1978
# 2             2017  264853539                    []          2017
# 3             2015  264853784  [10.1093/cid/ciu795]          20150201
# 4             2013  264854039  [10.1093/ndt/gft319]          201310
#
#                  format             isbn                  ismn musicid  \
# 0  [BK020000, BK020800]  [0-87834-101-3]                    []
# 1            [BK020000]               []                    []
# 2            [BK010000]               []                    []
# 3            [BK010053]               []  [10.1093/cid/ciu795]
# 4            [BK010053]               []  [10.1093/ndt/gft319]
#
#        pages                       part  \
# 0     319 S.          Vol. 26, 26, 2000
# 1     252 S.                  33001/680
# 2  74 Seiten      Nr. 313 (August 2017)
# 3             60/3(2015-02-01), 432-437
# 4             28/10(2013-10), 2421-2431
#
#                                               person pubinit pubword  \
# 0  ['ChuC.Y. Cyrus', 'LeeRonald Demos(DE-588)1574...      []
# 1  ['SchikanederEmanuel1751-1812(DE-588)11860757X...      []
# 2  ['SchneiderReto U.1963-(DE-588)115417206Verfas...      []
# 3  ['RozotVirginieDivision of Immunology and Alle...      []
# 4  ['BonnyOlivierDepartment of Pharmacology and T...      []
#
#     pubyear scale                                            ttlfull  \
# 0  2000                  Population and economic change in East Asia
# 1  1978                                              Die Zauberflöte
# 2  2017            Alles Wissen dieser Welt, warum Bibliotheken n...
# 3  20150201        Combined Use of Mycobacterium tuberculosis-Spe...
# 4  201310          Molecular bases of circadian rhythmicity in re...
#
#                                              ttlpart      volumes
# 0        Population and economic change in East Asia     [319 S.]
# 1                                    Die Zauberflöte     [252 S.]
# 2  Alles Wissen dieser Welt, warum Bibliotheken n...  [74 Seiten]
# 3  Combined Use of Mycobacterium tuberculosis-Spe...           []
# 4  Molecular bases of circadian rhythmicity in re...           []

# %%
comp_str = 'Biblio'

df_m[df_m.ttlfull.str.contains(comp_str)]
# Out:
#                                               035liste century coordinate  \
# 2    [(IDSLU)001293605, (IDSBB)006725532, (NEBIS)01...    2017
# 148                 [(SBT)000781193, (RERO)R008489733]    2015
#
#     corporate decade      docid doi edition exactDate      format  \
# 2               2017  264853539  []          2017      [BK010000]
# 148             2015  504390775  []          20151475  [BK020000]
#
#                     isbn ismn musicid      pages                   part  \
# 2                     []   []          74 Seiten  Nr. 313 (August 2017)
# 148  [978-88-7922-121-4]   []             2 vol.                n. 1, 1
#
#                                                 person  \
# 2    ['SchneiderReto U.1963-(DE-588)115417206Verfas...
# 148  ['LapiniBernardo'], ['Francesco Petrarca ; com...
#
#                                    pubinit  \
# 2                                       []
# 148  [ADV, Biblioteca cantonale di Lugano]
#
#                                  pubword   pubyear scale  \
# 2                                         2017
# 148  ADV, Biblioteca cantonale di Lugano  20151475
#
#                                                ttlfull  \
# 2    Alles Wissen dieser Welt, warum Bibliotheken n...
# 148  Trionfi, riedizione accurata dell'incunabolo c...
#
#                                                ttlpart      volumes
# 2    Alles Wissen dieser Welt, warum Bibliotheken n...  [74 Seiten]
# 148  Trionfi, riedizione accurata dell'incunabolo c...     [2 vol.]

# %%
# Python RegEx library for string compare
import re

def master_slaves_compare(masters, slaves, i, j):
    search_string = re.sub(r'\(', '\(', masters['035liste'].loc[i][j])
    search_string = re.sub(r'\)', '\)', search_string)
    print('\nmaster index {:d}, slave relation {:d}, {:s}'.format(i, j, search_string))
    
    slave_index = slaves[slaves['035liste'].str.contains(search_string)].index
    
    return slave_index

# %%
for i in range(len(df_m)):
    for j in range(len(df_m['035liste'].loc[i])):
        slave_index = master_slaves_compare(df_m, df_u, i, j)

        df_united = pd.concat([df_m.loc[[i]], df_u.iloc[slave_index]], axis=0)
        print(df_united.drop(columns=['035liste', 'docid']).duplicated())
# Out:
# master index 0, slave relation 0, \(IDSBB\)002447452
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-41830de133d4> in <module>
#       4
#       5         df_united = pd.concat([df_m.loc[[i]], df_u.iloc[slave_index]], axis=0)
# ----> 6         print(df_united.drop(columns=['035liste', 'docid']).duplicated())
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4383         vals = (col.values for name, col in self.iteritems()
#    4384                 if name in subset)
# -> 4385         labels, shape = map(list, zip(*map(f, vals)))
#    4386
#    4387         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in f(vals)
#    4364         def f(vals):
#    4365             labels, shape = algorithms.factorize(
# -> 4366                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT))
#    4367             return labels.astype('i8', copy=False), len(shape)
#    4368
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     628                                            na_sentinel=na_sentinel,
#     629                                            size_hint=size_hint,
# --> 630                                            na_value=na_value)
#     631
#     632     if sort and len(uniques) > 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     474     uniques = vec_klass()
#     475     labels = table.get_labels(values, uniques, 0, na_sentinel,
# --> 476                               na_value=na_value)
#     477
#     478     labels = _ensure_platform_int(labels)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# TypeError: unhashable type: 'list'

# %%
# Look at sample cases
df_m.loc[0], df_u.loc[107]

# %%
# Look at sample cases, manually
master_index = 2

slave_index = master_slaves_compare(df_m, df_u, master_index, 0)

df_united = pd.concat([df_m.loc[[master_index]], df_u.iloc[slave_index]], axis=0)
df_united

# %% [markdown]
# ## Find duplicates

# %%
def find_duplicates(df):
    df_duplicates = df[df.drop(columns=['035liste', 'docid']).duplicated(keep=False)].sort_values(by='ttlfull')
    
    return df_duplicates

# %%
find_duplicates(df_u)

# %%
df_m.loc[90]

# %%
df_u.loc[367], df_u.loc[61]

# %%
print(df_m.decade.unique())

df_m_d_sd = df_m.decade.sort_values()
for i in range(len(df_m_d_sd)):
    print(df_m_d_sd[i])

# %%
print(df_m.exactDate.unique())

df_m_d_sd = df_m.exactDate.sort_values()
for i in range(len(df_m_d_sd)):
    print(df_m_d_sd[i])

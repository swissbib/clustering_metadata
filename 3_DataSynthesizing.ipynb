# %%
oversampling = 5
modification_ratio = 0.2
strip_number_digits = True

# %% [markdown]
# # Data Synthesizing

# %% [markdown]
# Chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb) brings a fraction of duplicate records out of Swissbib's goldstandard of below 0.6%. The explicit full amount will be sufficient for training and performance testing of a machine learning model. The fraction by itself is a low value, though. This chapter will focus on increasing the amount of duplicate pair rows in order to have a more balanced set for training and testing models at hand. This is done, generating artifical data pairs of duplicates.

# %% [markdown]
# ## Table of Contents
#
# - [Metadata Takeover](#Metadata-Takeover)
# - [Loading and Duplicating the Base Data](#Loading-and-Duplicating-the-Base-Data)
# - [Modifying the Base Data](#Modifying-the-Base-Data)
#     - [coordinate](#coordinate)
#     - [corporate](#corporate)
#     - [doi](#doi)
#     - [edition](#edition)
#     - [exactDate](#exactDate)
#     - [format](#format)
#     - [isbn](#isbn)
#     - [ismn](#ismn)
#     - [musicid](#musicid)
#     - [part](#part)
#     - [person](#person)
#     - [pubinit](#pubinit)
#     - [scale](#scale)
#     - [ttlfull](#ttlfull)
#     - [volumes](#volumes)
# - [Data Pairing for Duplicates](#Data-Pairing-for-Duplicates)
# - [Removing One Side of an Attribute Pair](#Removing-One-Side-of-an-Attribute-Pair)
# - [Append Synthetic Duplicates to Feature Base](#Append-Synthetic-Duplicates-to-Feature-Base)
# - [Summary](#Summary)
#     - [Goldstandard DataFrame Handover](#Goldstandard-DataFrame-Handover)

# %% [markdown]
# ## Metadata Takeover

# %% [markdown]
# Two artefacts have arisen from the previous chapters, the metadata dictionary and a DataFrame that will be the basis for the feature matrix for the models. Both artefact must be loaded as the first step of this chapter.

# %%
import os
import pickle as pk
import pandas as pd
import bz2
import _pickle as cPickle

path_goldstandard = './daten_goldstandard'

# Restore metadata so far
with open(os.path.join(path_goldstandard, 'columns_metadata.pkl'), 'rb') as handle:
    columns_metadata_dict = pk.load(handle)
    
# Restore DataFrame with features from compressed pickle file
with bz2.BZ2File((os.path.join(
    path_goldstandard, 'feature_base_df.pkl')), 'rb') as file:
    df_feature_base = cPickle.load(file)

# %%
for k in columns_metadata_dict.keys():
    print(k, '\n', columns_metadata_dict[k], '\n')
# Out:
# data_analysis_columns
#  ['coordinate_E', 'coordinate_N', 'corporate_full', 'doi', 'edition', 'exactDate', 'format_prefix', 'format_postfix', 'isbn', 'ismn', 'musicid', 'part', 'person_100', 'person_700', 'person_245c', 'pubinit', 'scale', 'ttlfull_245', 'ttlfull_246', 'volumes']
#
# columns_to_use
#  ['duplicates', 'coordinate_E_x', 'coordinate_E_y', 'coordinate_N_x', 'coordinate_N_y', 'corporate_full_x', 'corporate_full_y', 'doi_x', 'doi_y', 'edition_x', 'edition_y', 'exactDate_x', 'exactDate_y', 'format_prefix_x', 'format_prefix_y', 'format_postfix_x', 'format_postfix_y', 'isbn_x', 'isbn_y', 'ismn_x', 'ismn_y', 'musicid_x', 'musicid_y', 'part_x', 'part_y', 'person_100_x', 'person_100_y', 'person_700_x', 'person_700_y', 'person_245c_x', 'person_245c_y', 'pubinit_x', 'pubinit_y', 'scale_x', 'scale_y', 'ttlfull_245_x', 'ttlfull_245_y', 'ttlfull_246_x', 'ttlfull_246_y', 'volumes_x', 'volumes_y']
#
# similarity_metrics
#  {'coordinate_E': LCSStr({'qval': 1, 'external': True}), 'coordinate_N': LCSStr({'qval': 1, 'external': True}), 'corporate_full': LCSStr({'qval': 1, 'external': True}), 'doi': Identity({'qval': 1, 'external': True}), 'edition': Jaccard({'qval': 1, 'as_set': False, 'external': True}), 'exactDate': Hamming({'qval': 1, 'test_func': <function Base._ident at 0x11620d378>, 'truncate': False, 'external': True}), 'format_prefix': Identity({'qval': 1, 'external': True}), 'format_postfix': Jaccard({'qval': 2, 'as_set': False, 'external': True}), 'isbn': Identity({'qval': 1, 'external': True}), 'ismn': Identity({'qval': 1, 'external': True}), 'musicid': LCSStr({'qval': 1, 'external': True}), 'part': StrCmp95({'long_strings': False, 'external': True}), 'person_100': StrCmp95({'long_strings': False, 'external': True}), 'person_700': StrCmp95({'long_strings': False, 'external': True}), 'person_245c': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'pubinit': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'scale': Jaccard({'qval': 1, 'as_set': False, 'external': True}), 'ttlfull_245': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'ttlfull_246': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'volumes': StrCmp95({'long_strings': False, 'external': True})}
#
# features
#  ['coordinate_E_delta', 'coordinate_N_delta', 'corporate_full_delta', 'doi_delta', 'edition_delta', 'exactDate_delta', 'format_prefix_delta', 'format_postfix_delta', 'isbn_delta', 'ismn_delta', 'musicid_delta', 'part_delta', 'person_100_delta', 'person_700_delta', 'person_245c_delta', 'pubinit_delta', 'scale_delta', 'ttlfull_245_delta', 'ttlfull_246_delta', 'volumes_delta', 'duplicates']

# %%
# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(df_feature_base.columns)

df_feature_base.head()
# Out:
#                              035liste_x                            035liste_y  \
# 0    [(OCoLC)731635279, (ABN)000539983]    [(OCoLC)731635279, (ABN)000539983]
# 1    [(OCoLC)731635279, (ABN)000539983]  [(OCoLC)731635279, (NEBIS)009587153]
# 2    [(OCoLC)731635279, (ABN)000539983]  [(OCoLC)731635279, (LIBIB)000315536]
# 3  [(OCoLC)731635279, (NEBIS)009587153]    [(OCoLC)731635279, (ABN)000539983]
# 4  [(OCoLC)731635279, (NEBIS)009587153]  [(OCoLC)731635279, (NEBIS)009587153]
#
#   century_x century_y coordinate_E_x coordinate_E_y coordinate_N_x  \
# 0      2009      2009
# 1      2009      2009
# 2      2009      2009
# 3      2009      2009
# 4      2009      2009
#
#   coordinate_N_y coordinate_x coordinate_y corporate_110_x corporate_110_y  \
# 0                          []           []
# 1                          []           []
# 2                          []           []
# 3                          []           []
# 4                          []           []
#
#   corporate_710_x corporate_710_y corporate_full_x corporate_full_y decade_x  \
# 0                                                                       2009
# 1                                                                       2009
# 2                                                                       2009
# 3                                                                       2009
# 4                                                                       2009
#
#   decade_y    docid_x    docid_y doi_x doi_y  duplicates edition_x edition_y  \
# 0     2009  000311049  000311049                       1
# 1     2009  000311049  196506476                       1
# 2     2009  000311049  323173349                       1
# 3     2009  196506476  000311049                       1
# 4     2009  196506476  196506476                       1
#
#   exactDate_x exactDate_y format_postfix_x format_postfix_y format_prefix_x  \
# 0    2009uuuu    2009uuuu           020000           020000              bk
# 1    2009uuuu    2009uuuu           020000           020000              bk
# 2    2009uuuu    2009uuuu           020000           020000              bk
# 3    2009uuuu    2009uuuu           020000           020000              bk
# 4    2009uuuu    2009uuuu           020000           020000              bk
#
#   format_prefix_y               isbn_x               isbn_y ismn_x ismn_y  \
# 0              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 1              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 2              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 3              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 4              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
#
#   masters_docid musicid_x musicid_y   pages_x   pages_y part_x part_y  \
# 0     504389793                      [600 S.]  [600 S.]  20008  20008
# 1     504389793                      [600 S.]  [600 S.]  20008  20008
# 2     504389793                      [600 S.]  [600 S.]  20008  20008
# 3     504389793                      [600 S.]  [600 S.]  20008  20008
# 4     504389793                      [600 S.]  [600 S.]  20008  20008
#
#   person_100_x person_100_y  \
# 0   austenjane   austenjane
# 1   austenjane   austenjane
# 2   austenjane   austenjane
# 3   austenjane   austenjane
# 4   austenjane   austenjane
#
#                                        person_245c_x  \
# 0  jane austen ; aus dem englischen übersetzt von...
# 1  jane austen ; aus dem englischen übersetzt von...
# 2  jane austen ; aus dem englischen übersetzt von...
# 3  jane austen ; aus dem engl. übers. von ursula ...
# 4  jane austen ; aus dem engl. übers. von ursula ...
#
#                                        person_245c_y  \
# 0  jane austen ; aus dem englischen übersetzt von...
# 1  jane austen ; aus dem engl. übers. von ursula ...
# 2                                        jane austen
# 3  jane austen ; aus dem englischen übersetzt von...
# 4  jane austen ; aus dem engl. übers. von ursula ...
#
#                   person_700_x                 person_700_y    pubinit_x  \
# 0  grawechristian, graweursula  grawechristian, graweursula  reclam jun.
# 1  grawechristian, graweursula                               reclam jun.
# 2  grawechristian, graweursula                               reclam jun.
# 3                               grawechristian, graweursula       reclam
# 4                                                                 reclam
#
#      pubinit_y      pubword_x      pubword_y pubyear_x pubyear_y scale_x  \
# 0  reclam jun.  [Reclam jun.]  [Reclam jun.]  2009      2009
# 1       reclam  [Reclam jun.]       [Reclam]  2009      2009
# 2       reclam  [Reclam jun.]       [Reclam]  2009      2009
# 3  reclam jun.       [Reclam]  [Reclam jun.]  2009      2009
# 4       reclam       [Reclam]       [Reclam]  2009      2009
#
#   scale_y ttlfull_245_x ttlfull_245_y ttlfull_246_x ttlfull_246_y  \
# 0           emma, roman   emma, roman
# 1           emma, roman          emma
# 2           emma, roman   emma, roman
# 3                  emma   emma, roman
# 4                  emma          emma
#
#                     ttlpart_x                   ttlpart_y volumes_x volumes_y
# 0  {'245': ['Emma', 'Roman']}  {'245': ['Emma', 'Roman']}       600       600
# 1  {'245': ['Emma', 'Roman']}           {'245': ['Emma']}       600       600
# 2  {'245': ['Emma', 'Roman']}  {'245': ['Emma', 'Roman']}       600       600
# 3           {'245': ['Emma']}  {'245': ['Emma', 'Roman']}       600       600
# 4           {'245': ['Emma']}           {'245': ['Emma']}       600       600

# %% [markdown]
# ## Loading and Duplicating the Base Data

# %% [markdown]
# For generating artificial pairs of duplicates, Swissbib's goldstandard file of uniques and masters will be taken as a basis. The files will be loaded into a DataFrame which will be duplicated for pairing after manipulating the data of the second, the duplicated DataFrame.

# %%
import json

records_master, records_unique = [], []
file_master, file_unique = 'master.json', 'unique.json'

for line in open(os.path.join(path_goldstandard, file_master), 'r'):
    records_master.append(json.loads(line))
for line in open(os.path.join(path_goldstandard, file_unique), 'r'):
    records_unique.append(json.loads(line))

print('Number of records in data file {:s}\t{:d}'.format(file_master, len(records_master)))
print('Number of records in data file {:s}\t{:d}'.format(file_unique, len(records_unique)))

records_unique.extend(records_master)
print('Number of total records \t\t\t{:d}'.format(len(records_unique)))
# Out:
# Number of records in data file master.json	159
# Number of records in data file unique.json	596
# Number of total records 			755

# %%
goldstandard_uniques = {}

goldstandard_uniques['original'] = pd.DataFrame(records_unique)
goldstandard_uniques['modified'] = pd.DataFrame(records_unique)
# Multiply oversampling data
number_of_oversampling_loop = round((oversampling*len(df_feature_base))/(
    (1-oversampling/100)*100*len(goldstandard_uniques['original'])))

for i in range(number_of_oversampling_loop) :
    goldstandard_uniques['modified'] = pd.concat(
        [goldstandard_uniques['modified'], pd.DataFrame(records_unique)], sort=True)

# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(goldstandard_uniques['original'].columns)

goldstandard_uniques['modified'].reset_index(drop=True, inplace=True)
if oversampling > 0:
    print('Omitting the goldstandard training data, with {:,d} iterations in the for-loop, ...'.format(
        number_of_oversampling_loop))
    print('... oversampling will generate a ratio of {:.1f}% of synthetic duplicates in the full trainig data.'.format(
        100*len(goldstandard_uniques['modified'])/(len(df_feature_base)+len(goldstandard_uniques['modified']))))
else :
    print('The goldstandard will not be increased with synthetic data.')
goldstandard_uniques['modified'].head()
# Out:
# Omitting the goldstandard training data, with 18 iterations in the for-loop, ...
# ... oversampling will generate a ratio of 5.2% of synthetic duplicates in the full trainig data.
#                              035liste century coordinate  \
# 0  [(OCoLC)362722306, (ABN)000551177]    2009         []
# 1  [(OCoLC)886929897, (ABN)000223034]    2004         []
# 2  [(OCoLC)778386601, (ABN)000433604]    1793         []
# 3  [(OCoLC)778561839, (ABN)000238844]    2000         []
# 4  [(OCoLC)777853583, (ABN)000243260]    1990         []
#
#                                            corporate decade      docid doi  \
# 0                  {'110': [], '710': [], '810': []}   2009  000143235  []
# 1  {'110': [], '710': ['Wiener Philharmoniker'], ...   2004  00044801X  []
# 2                  {'110': [], '710': [], '810': []}   1793  000996009  []
# 3                  {'110': [], '710': [], '810': []}   2000  00239538X  []
# 4                  {'110': [], '710': [], '810': []}   1990  002410559  []
#
#   edition exactDate      format                 isbn ismn musicid  \
# 0          2009      [BK020000]  [978-3-7466-6120-9]   []
# 1          2004      [MU040100]                   []   []
# 2          17931797  [MU010000]                   []   []
# 3          2000      [BK020047]      [3-932992-42-3]   []
# 4          1990      [BK020000]      [0-19-282756-1]   []
#
#                                                pages    part  \
# 0                                           [575 S.]  [6120]
# 1                                             [2 CD]      []
# 2                                           [202 S.]      []
# 3  [1 CD-Rom in Box, mit Notizbuchfunktion für Re...      []
# 4                                           [445 p.]      []
#
#                                               person  \
# 0  {'100': ['AustenJane'], '700': [], '800': [], ...
# 1  {'100': ['MozartWolfgang Amadeus'], '700': ['K...
# 2  {'100': ['MozartWolfgang Amadeus'], '700': [],...
# 3  {'100': [], '700': ['FrischMax'], '800': [], '...
# 4  {'100': ['AustenJane'], '700': [], '800': [], ...
#
#                      pubinit                    pubword   pubyear scale  \
# 0       [Aufbau Taschenbuch]       [Aufbau Taschenbuch]  2009
# 1                  [Membran]                  [Membran]  2004
# 2          [Komm. Breitkopf]          [Komm. Breitkopf]  17931797
# 3                   [Terzio]                   [Terzio]  2000
# 4  [Oxford University Press]  [Oxford University Press]  1990
#
#                                              ttlfull  \
# 0                         {'245': ['Emma', 'Roman']}
# 1                       {'245': ['Die Zauberflöte']}
# 2  {'245': ['Die Zauberflöte', 'eine grosse Oper ...
# 3  {'245': ['Homo faber', 'Originaltext, Interpre...
# 4                                  {'245': ['Emma']}
#
#                                              ttlpart  \
# 0                         {'245': ['Emma', 'Roman']}
# 1                       {'245': ['Die Zauberflöte']}
# 2  {'245': ['Die Zauberflöte', 'eine grosse Oper ...
# 3  {'245': ['Homo faber', 'Originaltext, Interpre...
# 4                                  {'245': ['Emma']}
#
#                                              volumes
# 0                                           [575 S.]
# 1                                             [2 CD]
# 2                                           [202 S.]
# 3  [1 CD-Rom in Box, mit Notizbuchfunktion für Re...
# 4                                           [445 p.]

# %% [markdown]
# The goldstandard data must be preprocessed the same way as in chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb), see section [Transform Attributes for Similarity Comparison](./2_GoldstandardDataPreparation.ipynb#Transform-Attributes-for-Similarity-Comparison) there.

# %%
import data_preparation_funcs as dpf

for i in ['original', 'modified']:
    goldstandard_uniques[i] = dpf.attribute_preprocessing(
        goldstandard_uniques[i],
        columns_metadata_dict['data_analysis_columns'], strip_number_digits)

# %%
columns_metadata_dict['data_analysis_columns']
# Out:
# ['coordinate_E',
#  'coordinate_N',
#  'corporate_full',
#  'doi',
#  'edition',
#  'exactDate',
#  'format_prefix',
#  'format_postfix',
#  'isbn',
#  'ismn',
#  'musicid',
#  'part',
#  'person_100',
#  'person_700',
#  'person_245c',
#  'pubinit',
#  'scale',
#  'ttlfull_245',
#  'ttlfull_246',
#  'volumes']

# %% [markdown]
# The following section of this chapter will modify the data of the above listed columns with the goal to produce pairs of duplicates after joining the DataFrame $\texttt{goldstandard}\_\texttt{uniques}[\texttt{'original'}]$ with $\texttt{goldstandard}\_\texttt{uniques}[\texttt{'modified'}]$. These pairs of duplicates are to consist of pairs that are not necessarily equal but may show similarity, instead. This will be achieved by modifying the attributes of $\texttt{goldstandard}\_\texttt{uniques}[\texttt{'modified'}]$.

# %% [markdown]
# ## Modifying the Base Data

# %% [markdown]
# For each attribute, a function has been implemented that modifies its value in a manner that may be expected in Swissbib's data reality. The function has been implemented in a Python library [modify_data_funcs.py](./modify_data_funcs.py).

# %%
import modify_data_funcs as mdf

# %% [markdown]
# All functions below expect a parameter named $\texttt{modification}\_\texttt{ratio}$. This parameter determines the fraction of sample rows that will be modified. The parameter is set to its value all above, in the first code cell of this chapter. Besides the $\texttt{modification}\_\texttt{ratio}$, the functions are called with four additional parameters which have the effect of modifying the attribute value. All four of these parameters can be set separately. All four of these parameters simulate the effect of mistyping during data entry of a bibliographical unit.
#
# - $\texttt{number}\_\texttt{of}\_\texttt{delete}$ : This parameter controls the effect of removing characters. Its value determines the amount of characters to be removed in the string chosen randomly.
# - $\texttt{number}\_\texttt{of}\_\texttt{switch}$ : This parameter controls the effect of switching two adjacent characters. Its value determines the amount of character pairs to be switched in the string chosen randomly. The effect of switching two characters simulates a typo, e.g. in the title of a bibliographical unit.
# - $\texttt{number}\_\texttt{of}\_\texttt{replace}$ : This parameter controls the effect of replacing a character at a randomly chosen position in the string with a randomly chosen new character. Its value determines the amount of characters to be replaced in the string chosen randomly.
# - $\texttt{number}\_\texttt{of}\_\texttt{add}$ : This parameter controls the effect of adding characters. This is the opposite transaction to the effect of removing characters. Its value determines the amount of characters to be removed in the string chosen randomly.
#
# In the following subsecions below, each attribute will be discussed and eventually handled separately.

# %% [markdown]
# ### coordinate

# %% [markdown]
# For attribute $\texttt{coordinate}$, typos of switching two adjacent characters can be imagined. This will be the only kind of manipulation foreseen for this attribute.

# %%
number_of_delete = 0
number_of_switch = 1
number_of_replace = 0
number_of_add = 0

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'coordinate_E', modification_ratio,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'coordinate_N', modification_ratio,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 194 samples two characters of attribute coordinate_E switched.
# In 194 samples two characters of attribute coordinate_N switched.

# %% [markdown]
# ### corporate

# %% [markdown]
# For attribute $\texttt{corporate}$, which is a string of free text all kinds of typos can be imagined. All four parameters for manipulation will be set to a value greater than 0, therefore.

# %%
number_of_delete = 1
number_of_switch = 1
number_of_replace = 1
number_of_add = 1

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'corporate_full', modification_ratio,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 616 samples one character of attribute corporate_full removed.
# In 616 samples two characters of attribute corporate_full switched.
# In 616 samples one character of attribute corporate_full replaced.
# In 616 samples one character of attribute corporate_full added.

# %% [markdown]
# ### doi

# %% [markdown]
# Attribute $\texttt{doi}$ will be compared on identity of the string in chapter [Feature Matrix Generation](./3_FeatureMatrixGeneration.ipynb). Reason is that the value of the attribute is expected to be processed fully electronically without any additional human or manual manipulation in Swissbib's data sources. Therefore, the attribute's values are expected to originate with a very high quality in their sources and this expectation is to be expressed in the training data. Leaving the attribute's values unmodified, will make it a a strong indicator of duplicate bibliographical units, if present.

# %% [markdown]
# ### edition

# %% [markdown]
# This attribute holds numbers. Wrongly entered data are hard to simulate and the manipulation of this attribute shall be ommitted for it.

# %% [markdown]
# ### exactDate

# %% [markdown]
# This attribute has a fixed length of eight characters. It can hold number digits or markers for unknown data. A typo of switching two adjacent digits can be imagined for this attribute as well as a mistyping of a number digit. The corresponding parameters will be set for data manipulation.

# %%
number_of_delete = 0
number_of_switch = 1
number_of_replace = 1
number_of_add = 0

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'exactDate', modification_ratio/2,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 1434 samples two characters of attribute exactDate switched.
# In 1434 samples one character of attribute exactDate replaced.

# %% [markdown]
# ### format

# %% [markdown]
# Attribute $\texttt{format}\_\texttt{prefix}$ is a code where character modification would produce unknown codes. This need not be expected by the deduplication model. With $\texttt{format}\_\texttt{postfix}$, a number switch may be possible, though.

# %%
number_of_delete = 0
number_of_switch = 1
number_of_replace = 0
number_of_add = 0

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'format_postfix', modification_ratio/4,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 717 samples two characters of attribute format_postfix switched.

# %% [markdown]
# ### isbn

# %% [markdown]
# Attribute $\texttt{isbn}$ will be compared on identity of the string. Therefore, this attribute will not be modified to remain a strong indicator of duplicate bibliographical units.

# %% [markdown]
# ### ismn

# %% [markdown]
# The same statement as for attribute $\texttt{isbn}$ holds for attribute $\texttt{ismn}$. The attribute will not be modified.

# %% [markdown]
# ### musicid

# %% [markdown]
# For this attribute, a missing character or an additional character may be possible for a pair of duplicates. This will be simulated here, all aditionally thinkable manipulations will be omitted.

# %%
number_of_delete = 1
number_of_switch = 0
number_of_replace = 0
number_of_add = 1

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'musicid', modification_ratio/4,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 75 samples one character of attribute musicid removed.
# In 73 samples one character of attribute musicid added.

# %% [markdown]
# ### part

# %% [markdown]
# Like attribute $\texttt{edition}$, this attribute holds numbers and is hard to manipulate is a good way. Wrongly entered data shall not be simulated with this attribute.

# %% [markdown]
# ### person

# %% [markdown]
# The $\texttt{person}$ attribute is a typical attribute of manually entered data, prone to typos. For this reason, it will be manipulated in all four possible kinds described.

# %%
number_of_delete = 1
number_of_switch = 1
number_of_replace = 1
number_of_add = 1

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'person_100', modification_ratio,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'person_700', modification_ratio,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'person_245c', modification_ratio,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 1775 samples one character of attribute person_100 removed.
# In 1775 samples two characters of attribute person_100 switched.
# In 1775 samples one character of attribute person_100 replaced.
# In 1775 samples one character of attribute person_100 added.
# In 1733 samples one character of attribute person_700 removed.
# In 1733 samples two characters of attribute person_700 switched.
# In 1733 samples one character of attribute person_700 replaced.
# In 1733 samples one character of attribute person_700 added.
# In 2592 samples one character of attribute person_245c removed.
# In 2592 samples two characters of attribute person_245c switched.
# In 2592 samples one character of attribute person_245c replaced.
# In 2592 samples one character of attribute person_245c added.

# %% [markdown]
# ### pubinit

# %% [markdown]
# This attribute holds names. It will be treated the same way as the $\texttt{person}$ attributes.

# %%
number_of_delete = 1
number_of_switch = 1
number_of_replace = 1
number_of_add = 1

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'pubinit', modification_ratio,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 1866 samples one character of attribute pubinit removed.
# In 1862 samples two characters of attribute pubinit switched.
# In 1862 samples one character of attribute pubinit replaced.
# In 1862 samples one character of attribute pubinit added.

# %% [markdown]
# ### scale

# %% [markdown]
# This attribute is used for scaling information of maps. It is sparsely filled and digit 0 is the predominant one. As it is hard to modify the attribute in a good way, no modification will be similated on it.

# %% [markdown]
# ### ttlfull

# %% [markdown]
# Both $\texttt{ttlfull}$ attributes can hold longer string sequences and are prototypical for typos. Both of them will be treated the same way as the $\texttt{person}$ attributes.

# %%
number_of_delete = 1
number_of_switch = 1
number_of_replace = 1
number_of_add = 1

goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'ttlfull_245', modification_ratio*2,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
goldstandard_uniques['modified'] = mdf.modify_character_string(
    goldstandard_uniques['modified'], 'ttlfull_246', modification_ratio*2,
    number_of_delete, number_of_switch, number_of_replace, number_of_add)
# Out:
# In 5738 samples one character of attribute ttlfull_245 removed.
# In 5618 samples two characters of attribute ttlfull_245 switched.
# In 5618 samples one character of attribute ttlfull_245 replaced.
# In 5618 samples one character of attribute ttlfull_245 added.
# In 646 samples one character of attribute ttlfull_246 removed.
# In 646 samples two characters of attribute ttlfull_246 switched.
# In 646 samples one character of attribute ttlfull_246 replaced.
# In 646 samples one character of attribute ttlfull_246 added.

# %% [markdown]
# ### volumes

# %% [markdown]
# For the same reason as for attributes $\texttt{edition}$ and $\texttt{part}$, no modification will be similated on attribute $\texttt{volumes}$.

# %% [markdown]
# ## Data Pairing for Duplicates

# %% [markdown]
# In chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb), the records pairing for generating pairs of duplicates was accomplished with the help of attribute $\texttt{035liste}$. For the synthetic data of this chapter, attribute $\texttt{docid}$ is the right key for joining. The reason for this choice is that attribute $\texttt{docid}$ identifies a record in an unambiguous way. It acts like a primary key for a record in the base data. Joining a record with itself on this unique identifier guarantees the generation of a pair of duplicates.

# %%
duplicates = pd.merge(left=goldstandard_uniques['original'], right=goldstandard_uniques['modified'], how='inner',
                  left_on='docid', right_on='docid')
# Mark all as duplicates for target vector
duplicates['duplicates'] = 1

print('Number of new duplicate pairs {:,d}'.format(len(duplicates)))

# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(duplicates)

duplicates.sample(n=5)
# Out:
# Number of new duplicate pairs 14,345
#            docid                                         035liste_x  \
# 4043   198041713               [(OCoLC)891402158, (NEBIS)007601601]
# 13802  504390333  [(IDSLU)000503700, (NEBIS)005540513, (RERO)R00...
# 666    029450969               [(OCoLC)180154028, (IDSLU)000515896]
# 3954   196396425  [(OCoLC)249303373, (NEBIS)009541789, (OCoLC)24...
# 8537   360836143  [(OCoLC)669269893, (IDSBB)006498535, (OCoLC)66...
#
#                                                   isbn_x  \
# 4043                                                  []
# 13802                                    [3-7655-8593-9]
# 666                                  [978-3-7815-1513-0]
# 3954   [3-15-002620-2 (kart.), 978-3-15-002620-5 (kar...
# 8537                                 [978-3-11-024767-1]
#
#                                                ttlpart_x pubyear_x decade_x  \
# 4043   {'245': ['Homo Faber', 'nach dem Roman von Max...  20111991     2011
# 13802                {'245': ['Die Reise der Pinguine']}  2005         2005
# 666    {'245': ['Lernprozesse dokumentieren, reflekti...  2007         2007
# 3954   {'245': ['Die Zauberflöte', 'KV 620 : eine gro...  2008         2008
# 8537   {'245': ['Lebenswissenschaft Praktische Theolo...  2011         2011
#
#       century_x exactDate_x edition_x part_x                      pages_x  \
# 4043       2011    20111991                1     [1 DVD-Video (117 Min.)]
# 13802      2005    2005uuuu                   [1 DVD-Video (ca. 82 Min.)]
# 666        2007    2007uuuu                                      [304 S.]
# 3954       2008    2008uuuu             2620                       [90 S]
# 8537       2011    2011uuuu                9           [Online-Ressource]
#
#       volumes_x pubinit_x   pubword_x scale_x coordinate_x doi_x ismn_x  \
# 4043      1 117  suhrkamp  [Suhrkamp]                   []
# 13802      1 82                    []                   []
# 666         304                    []                   []
# 3954         90    reclam    [Reclam]                   []
# 8537                               []                   []
#
#       musicid_x coordinate_E_x coordinate_N_x corporate_110_x corporate_710_x  \
# 4043
# 13802     99036
# 666
# 3954
# 8537
#
#       corporate_full_x format_prefix_x format_postfix_x  \
# 4043                                vm           010300
# 13802                               vm           010300
# 666                                 bk           020000
# 3954                                bk           020000
# 8537                                bk           020053
#
#                  person_100_x  \
# 4043
# 13802
# 666
# 3954   mozartwolfgang amadeus
# 8537
#
#                                             person_700_x  \
# 4043   schlöndorffvolker, frischmax, shepardsam, delp...
# 13802                                         jacquetluc
# 666
# 3954               kochhans-albrecht, schikanederemanuel
# 8537   kliethomas, kumlehnmartina, kunzralph, schlagt...
#
#                                            person_245c_x  \
# 4043                                  volker schlöndorff
# 13802                           ein film von luc jacquet
# 666        hrsg. von michaela gläser-zikuda ... [et al.]
# 3954   wolfgang amadeus mozart ; libretto von emanuel...
# 8537   hrsg. von thomas klie, martina kumlehn, ralph ...
#
#                                            ttlfull_245_x  \
# 4043           homo faber, nach dem roman von max frisch
# 13802                             die reise der pinguine
# 666    lernprozesse dokumentieren, reflektieren und b...
# 3954   die zauberflöte, kv 620 : eine große oper in z...
# 8537           lebenswissenschaft praktische theologie?!
#
#                                      ttlfull_246_x  \
# 4043
# 13802  the emperor's journey, marche de l'empereur
# 666
# 3954
# 8537
#
#                                               035liste_y century_y  \
# 4043                [(OCoLC)891402158, (NEBIS)007601601]      2011
# 13802  [(IDSLU)000503700, (NEBIS)005540513, (RERO)R00...      2005
# 666                 [(OCoLC)180154028, (IDSLU)000515896]      2007
# 3954   [(OCoLC)249303373, (NEBIS)009541789, (OCoLC)24...      2008
# 8537   [(OCoLC)669269893, (IDSBB)006498535, (OCoLC)66...      2011
#
#       coordinate_y decade_y doi_y edition_y exactDate_y  \
# 4043            []     2011                    20111991
# 13802           []     2005                    2005uuuu
# 666             []     2007                    2007uuuu
# 3954            []     2008                    2008uuuu
# 8537            []     2011                    2011uuuu
#
#                                                   isbn_y ismn_y musicid_y  \
# 4043                                                  []
# 13802                                    [3-7655-8593-9]            99036
# 666                                  [978-3-7815-1513-0]
# 3954   [3-15-002620-2 (kart.), 978-3-15-002620-5 (kar...
# 8537                                 [978-3-11-024767-1]
#
#                            pages_y part_y pubinit_y   pubword_y pubyear_y  \
# 4043      [1 DVD-Video (117 Min.)]      1  suhrkamp  [Suhrkamp]  20111991
# 13802  [1 DVD-Video (ca. 82 Min.)]                           []  2005
# 666                       [304 S.]                           []  2007
# 3954                        [90 S]   2620     crlam    [Reclam]  2008
# 8537            [Online-Ressource]      9                    []  2011
#
#       scale_y                                          ttlpart_y volumes_y  \
# 4043           {'245': ['Homo Faber', 'nach dem Roman von Max...     1 117
# 13802                        {'245': ['Die Reise der Pinguine']}      1 82
# 666            {'245': ['Lernprozesse dokumentieren, reflekti...       304
# 3954           {'245': ['Die Zauberflöte', 'KV 620 : eine gro...        90
# 8537           {'245': ['Lebenswissenschaft Praktische Theolo...
#
#       coordinate_E_y coordinate_N_y corporate_110_y corporate_710_y  \
# 4043
# 13802
# 666
# 3954
# 8537
#
#       corporate_full_y format_prefix_y format_postfix_y  \
# 4043                                vm           010300
# 13802                               vm           010300
# 666                                 bk           020000
# 3954                                bk           020000
# 8537                                bk           020053
#
#                   person_100_y  \
# 4043
# 13802
# 666
# 3954   mozartwolfgang amadeuas
# 8537
#
#                                             person_700_y  \
# 4043   sclöndorffvolker, frischmax, shepardsam, delpy...
# 13802                                         acyquetulc
# 666
# 3954                kochhans-albrect, schikanedreemanuel
# 8537   kliethomas, kumlehnmartina, kunzralph, chlagth...
#
#                                            person_245c_y  \
# 4043                                 volker qschlöndorff
# 13802                           ein film von luc jacquet
# 666         hrsg. von michaela glser-pikuda ... [et al.]
# 3954   wolfgang amadeus mozart ; libretto von eunuel ...
# 8537   hrsg. von thomas klie, martina kumlehn, ralph ...
#
#                                            ttlfull_245_y  \
# 4043          homo faber,g nach dem roman von max frishc
# 13802                              ie reise der pinguine
# 666    lernprozesse dokumentieren, reflektieren und b...
# 3954   die zauberflöte, kv 620 : eiye große operin zw...
# 8537           lebenswsisrenschaf praktische theologie?!
#
#                                     ttlfull_246_y  duplicates
# 4043                                                        1
# 13802  the emperor's jorney, marche de l'empereur           1
# 666                                                         1
# 3954                                                        1
# 8537                                                        1

# %% [markdown]
# Some sample records of the new synthetic pairs of duplicates are shown above.

# %% [markdown]
# ## Removing One Side of an Attribute Pair

# %% [markdown]
# One additional scenario of data differences of a pair of duplicates can be observed in Swissbib's raw data and has not been covered, yet. The scenario of an empty value in one attribute of a pair. To cover this scenario and in order to synthetise more reatlistic training data, a function has been implemented which removes attributes randomly from a pair. This function will be applyed to the columns only, that will be relevant for the final feature matrix.

# %%
duplicates_columns = columns_metadata_dict['columns_to_use'][:] # Copy list by value, not by reference!
# This attribute is always filled
duplicates_columns.remove('exactDate_x')
duplicates_columns.remove('exactDate_y')
# These attributes are mostly filled
duplicates_columns.remove('format_prefix_x')
duplicates_columns.remove('format_prefix_y')
duplicates_columns.remove('format_postfix_x')
duplicates_columns.remove('format_postfix_y')
# Title is the most important attribute that is hardly missing
duplicates_columns.remove('ttlfull_245_x')
duplicates_columns.remove('ttlfull_245_y')
duplicates_columns.remove('ttlfull_246_x')
duplicates_columns.remove('ttlfull_246_y')
# Target vector is needed
duplicates_columns.remove('duplicates')

duplicates = mdf.remove_one_side_of_attribute_pair(duplicates, duplicates_columns, modification_ratio/5)

# %% [markdown]
# ## Append Synthetic Duplicates to Feature Base

# %% [markdown]
# To be able to append the synthesised pairs of duplicates to the feature base of chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb), attributes $\texttt{docid}\_\texttt{x}$ and $\texttt{docid}\_\texttt{y}$ have to be added with the goal to receive a DataFrame with the same columns like the feature base DataFrame, loaded in the beginning of this chapter.

# %%
duplicates.rename(columns={'docid' : 'docid_x'}, inplace=True)
duplicates['docid_y'] = duplicates['docid_x']
duplicates.sample(n=5)
# Out:
#          docid_x                                         035liste_x  \
# 14019  504390465  [(RERO)R274430160, (VAUD)991019979819702852, (...
# 9434   435476378  [(VAUD)991004106199702852, (RNV)005698815-41bc...
# 9332   431142637  [(VAUD)991001903549702853, (RNV)006145308-41bc...
# 4859   224844571                                 [(RERO)R279244260]
# 6113   251750868                                 [(RERO)R007030108]
#
#                 isbn_x                                          ttlpart_x  \
# 14019  [0-7294-0744-6]  {'245': ['The complete works of Voltaire', 'Tr...
# 9434                []  {'245': ['Bonne chance !', 'cours de langue fr...
# 9332                []  {'245': ['Bonne chance !', 'cours de langue fr...
# 4859   [3-906721-44-2]  {'245': ['Bonne chance!', 'cours de langue fra...
# 6113                []  {'245': ['Bonne chance!', 'cours de langue fra...
#
#       pubyear_x decade_x century_x exactDate_x edition_x part_x  \
# 14019  2000         2000      2000    2000uuuu               56
# 9434   19941995     1994      1994    19941995
# 9332   1987         1987      1987    1987uuuu
# 4859   1999         1999      1999    1999uuuu         2
# 6113   1994         1994      1994    1994uuuu                1
#
#                     pages_x volumes_x                           pubinit_x  \
# 14019      [XXVIII, 365 p.]       365                 voltaire foundation
# 9434   [2 disques compacts]         2  berner lehrmittel- und medienverl.
# 9332               [145 p.]       145        staatlicher lehrmittelverlag
# 4859               [171 S.]       171        staatlicher lehrmittelverlag
# 6113                [93 S.]        93      [staatlicher lehrmittelverlag]
#
#                                   pubword_x scale_x coordinate_x doi_x ismn_x  \
# 14019                 [Voltaire Foundation]                   []
# 9434   [Berner Lehrmittel- und Medienverl.]                   []
# 9332         [Staatlicher Lehrmittelverlag]                   []
# 4859         [Staatlicher Lehrmittelverlag]                   []
# 6113       [[Staatlicher Lehrmittelverlag]]                   []
#
#       musicid_x coordinate_E_x coordinate_N_x corporate_110_x  \
# 14019
# 9434
# 9332
# 4859
# 6113
#
#                                          corporate_710_x  \
# 14019
# 9434   interkantonale lehrmittelzentrale (rapperswil,...
# 9332
# 4859   interkantonale lehrmittelzentrale (rapperswil,...
# 6113
#
#                                         corporate_full_x format_prefix_x  \
# 14019                                                                 bk
# 9434   interkantonale lehrmittelzentrale (rapperswil,...              mu
# 9332                                                                  bk
# 4859   interkantonale lehrmittelzentrale (rapperswil,...              bk
# 6113                                                                  vm
#
#       format_postfix_x person_100_x   person_700_x  \
# 14019           020000     voltaire    renwickjohn
# 9434            030000
# 9332            020000                 binderheidy
# 4859            020000               kesslersigrid
# 6113            030000
#
#                                            person_245c_x  \
# 14019  critical ed. by john renwick = [les oeuvres co...
# 9434   [hrsg.] interkantonale lehrmittelzentrale rapp...
# 9332                            heidy binder... [et al.]
# 4859   sigrid kessler... [et al.] ; [hrsg.:] interkan...
# 6113   [sigrid kessler... et al.] ; [hrsg. interkanto...
#
#                                            ttlfull_245_x ttlfull_246_x  \
# 14019  the complete works of voltaire, traité sur la ...
# 9434         bonne chance !, cours de langue française 1
# 9332   bonne chance !, cours de langue française prem...
# 4859   bonne chance!, cours de langue française, 3, l...
# 6113   bonne chance!, cours de langue française, 1, d...
#
#                                               035liste_y century_y  \
# 14019  [(RERO)R274430160, (VAUD)991019979819702852, (...      2000
# 9434   [(VAUD)991004106199702852, (RNV)005698815-41bc...      1994
# 9332   [(VAUD)991001903549702853, (RNV)006145308-41bc...      1987
# 4859                                  [(RERO)R279244260]      1999
# 6113                                  [(RERO)R007030108]      1994
#
#       coordinate_y decade_y doi_y edition_y exactDate_y           isbn_y  \
# 14019           []     2000                    2010uuuu  [0-7294-0744-6]
# 9434            []     1994                    19941995               []
# 9332            []     1987                    1987uuuu               []
# 4859            []     1999               2    1999uuuu  [3-906721-44-2]
# 6113            []     1994                    1994uuuu               []
#
#       ismn_y musicid_y               pages_y part_y  \
# 14019                       [XXVIII, 365 p.]     56
# 9434                    [2 disques compacts]
# 9332                                [145 p.]
# 4859                                [171 S.]
# 6113                                 [93 S.]      1
#
#                                pubinit_y  \
# 14019                voltaire foundation
# 9434   berner lehmittel- und medienverl.
# 9332        staatlicher lehrmittelverlag
# 4859         staatlicher lhrmittelverlag
# 6113      [staatlicher lehrmttelverlzag]
#
#                                   pubword_y pubyear_y scale_y  \
# 14019                 [Voltaire Foundation]  2000
# 9434   [Berner Lehrmittel- und Medienverl.]  19941995
# 9332         [Staatlicher Lehrmittelverlag]  1987
# 4859         [Staatlicher Lehrmittelverlag]  1999
# 6113       [[Staatlicher Lehrmittelverlag]]  1994
#
#                                                ttlpart_y volumes_y  \
# 14019  {'245': ['The complete works of Voltaire', 'Tr...
# 9434   {'245': ['Bonne chance !', 'cours de langue fr...         2
# 9332   {'245': ['Bonne chance !', 'cours de langue fr...       145
# 4859   {'245': ['Bonne chance!', 'cours de langue fra...       171
# 6113   {'245': ['Bonne chance!', 'cours de langue fra...        93
#
#       coordinate_E_y coordinate_N_y corporate_110_y  \
# 14019
# 9434
# 9332
# 4859
# 6113
#
#                                          corporate_710_y  \
# 14019
# 9434   interkantonale lehrmittelzentrale (rapperswil,...
# 9332
# 4859   interkantonale lehrmittelzentrale (rapperswil,...
# 6113
#
#                                         corporate_full_y format_prefix_y  \
# 14019                                                                 bk
# 9434   interkantonale lehrmittelzentrale r(apperswil,...              mu
# 9332                                                                  bk
# 4859   interkantonale lehrmittelzentrale (rapperswil,...              bk
# 6113                                                                  vm
#
#       format_postfix_y person_100_y   person_700_y  \
# 14019           020000     voltaire    renwickjohn
# 9434            030000
# 9332            020000                 binderheidy
# 4859            020000               kesslersigrid
# 6113            030000
#
#                                            person_245c_y  \
# 14019  critical ed. by john renwick = [les oeuvres co...
# 9434   [hrsg.] interkantonale lehrmittelzentrale rapp...
# 9332                             heidy binde... [et al.]
# 4859   sigrid kessler... [et al. ]; [hrsg.:] interkan...
# 6113   [sigrid kessler... et al.] ; [hrsg. interkanto...
#
#                                            ttlfull_245_y ttlfull_246_y  \
# 14019  the complete works of voltaire, traité surmla ...
# 9434          bonne chance !, cours delangue française 1
# 9332   bnne chance !, cours de langue française premi...
# 4859   bonne chandce!, cours de langue française, 3, ...
# 6113   bonne chance!, cours de langume française, 1, ...
#
#        duplicates    docid_y
# 14019           1  504390465
# 9434            1  435476378
# 9332            1  431142637
# 4859            1  224844571
# 6113            1  251750868

# %% [markdown]
# Now, the synthetic records of pairs of duplicates is ready and can be appended to the feature base of chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb).

# %%
if oversampling > 0 :
    frames = [df_feature_base, duplicates]

    df_feature_base = pd.concat(frames, sort=True)
    # Set unique values on index
    df_feature_base.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## Summary

# %% [markdown]
# The amount of duplicate records that are generated out of Swissbib's goldstandard, is low with a fraction of below 0.6%. This raises the requirement for increasing this amount. This chapter increases the amount of duplicates with artifical records. The basic records from Swissbib's goldstandard have been loaded, manipulated slightly, and by the end joined to generate a desired amount of synthetic data records for training and performance testing.

# %%
print('Number of rows in training set :', len(df_feature_base))
print('Number of rows with pairs of duplicates in training set :', len(df_feature_base[df_feature_base.duplicates==1]))
print('Ratio : {:.2f}%'.format(100*len(df_feature_base[df_feature_base.duplicates==1])/len(df_feature_base)))
# Out:
# Number of rows in training set : 273773
# Number of rows with pairs of duplicates in training set : 15818
# Ratio : 5.78%

# %% [markdown]
# ### Goldstandard DataFrame Handover

# %% [markdown]
# The DataFrame for the feature base has been extended with additional rows in this chapter. The result is saved into a pickle file. This is done to hand over the data to the next chapters. The data will be read in the next chapter [Feature Matrix Generation](./4_FeatureMatrixGeneration.ipynb) as input file. The metadata dictionary has not been modified in this chapter. Therefore it is not needed to be stored again.

# %%
# Store into compressed intermediary file
with bz2.BZ2File(os.path.join(path_goldstandard, 'feature_base_df.pkl'),
                 'w') as df_output_file:
    pk.dump(df_feature_base, df_output_file)

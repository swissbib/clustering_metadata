# %%
execution_mode = 'full'
strip_number_digits = True

# %% [markdown]
# # Goldstandard and Data Preparation

# %% [markdown]
# Swissbib's goldstandard is a set of pre-defined records being used for testing their implemented logic of identifying duplicate and unique records, see [[JudACaps](./A_References.ipynb#judacaps)]. The Swissbib project team has processed the goldstandard data into a data extract with the help of a scala implementation [[ScalRepo](./A_References.ipynb#scala_repo)]. This chapter of the capstone project loads the data records of the goldstandard and processes it with the goal to make it ready for its transformation into the feature matrix for the machine learning models.

# %% [markdown]
# The goal of this chapter will be achieved, when having a DataFrame with rows of pairs of records of the goldstandard that represent pairs of duplicates or pairs of uniques, respectively. Each row has to be marked with a flag indicating whether the row is a pair of duplicates or a pair of uniques. This flag will be separated to the target for training and performance testing of the machine learning models. See [[JudACaps](./A_References.ipynb#judacaps)] for the basic explanation of the process.

# %% [markdown]
# ## Table of Contents
#
# - [Metadata Takeover](#Metadata-Takeover)
# - [Description of Swissbib's Goldstandard](#Description-of-Swissbib's-Goldstandard)
#     - [Sample Records of a Goldstandard Example](#Sample-Records-of-a-Goldstandard-Example)
#     - [Generating Pairs of Duplicates](#Generating-Pairs-of-Duplicates)
#     - [Generating Pairs of Uniques](#Generating-Pairs-of-Uniques)
# - [Transform Attributes for Similarity Comparison](#Transform-Attributes-for-Similarity-Comparison)
#     - [ismn](#ismn)
# - [Build Pairs of Duplicates](#Build-Pairs-of-Duplicates)
#     - [Slaves Masters Relationships](#Slaves-Masters-Relationships)
#     - [Duplicates Rows Generation](#Duplicates-Rows-Generation)
# - [Build Pairs of Uniques](#Build-Pairs-of-Uniques)
#     - [Masters Uniques Relationships](#Masters-Uniques-Relationships)
#     - [Uniqes Rows Generation](#Uniqes-Rows-Generation)
# - [Build Feature Base](#Build-Feature-Base)
# - [Summary](#Summary)
#     - [Goldstandard DataFrame Handover](#Goldstandard-DataFrame-Handover)

# %% [markdown]
# ## Metadata Takeover

# %% [markdown]
# The analysis of Swissbib's raw data has led to a decision on each attribute, whether to process it into the feature matrix. The decision has been consolidated into a dictionary of metadata as a result of chapter [Data Analysis](./1_DataAnalysis.ipynb). This metadata is needed for processing the goldstandard and must be loaded as a first step.

# %%
import os
import pickle as pk

path_goldstandard = './daten_goldstandard'

# Restore metadata so far
with open(os.path.join(path_goldstandard, 'columns_metadata.pkl'), 'rb') as handle:
    columns_metadata_dict = pk.load(handle)

# %%
for k in columns_metadata_dict.keys():
    print(k, '\n', columns_metadata_dict[k], '\n')
# Out:
# data_analysis_columns
#  ['coordinate_E', 'coordinate_N', 'corporate_full', 'doi', 'edition', 'exactDate', 'format_prefix', 'format_postfix', 'isbn', 'ismn', 'musicid', 'part', 'person_100', 'person_700', 'person_245c', 'pubinit', 'scale', 'ttlfull_245', 'ttlfull_246', 'volumes']

# %% [markdown]
# ## Description of Swissbib's Goldstandard

# %% [markdown]
# Swissbib's goldstandard is a fix set of pre-defined data that has been processed into three distinct .json files [[ScalRepo](./A_References.ipynb#scala_repo)].
#
# - $\texttt{slave.json}$ - This data file holds the original duplicated records that are being merged into a master record.
# - $\texttt{master.json}$ - This data file holds the unique master records that are formed out of its records in file $\texttt{slave.json}$.
# - $\texttt{unique.json}$ - This data file holds records with similar data as in $\texttt{slave.json}$ and $\texttt{master.json}$, but records that are correctly being identified as unique records and not as a duplicate record of any record in $\texttt{slave.json}$.
#
# This section starts with loading the goldstandard data into a separate DataFrame for each set. Afterwards, the data will be analysed and explained.

# %%
import json

records_slave, records_master, records_unique = [], [], []
file_slave, file_master, file_unique = 'slave.json', 'master.json', 'unique.json'

for line in open(os.path.join(path_goldstandard, file_slave), 'r'):
    records_slave.append(json.loads(line))
for line in open(os.path.join(path_goldstandard, file_master), 'r'):
    records_master.append(json.loads(line))
for line in open(os.path.join(path_goldstandard, file_unique), 'r'):
    records_unique.append(json.loads(line))

print('Number of records in data file {:s}\t{:d}'.format(file_slave, len(records_slave)))
print('Number of records in data file {:s}\t{:d}'.format(file_master, len(records_master)))
print('Number of records in data file {:s}\t{:d}'.format(file_unique, len(records_unique)))
# Out:
# Number of records in data file slave.json	435
# Number of records in data file master.json	159
# Number of records in data file unique.json	596

# %%
import pandas as pd

goldstandard = {}

goldstandard['slaves'] = pd.DataFrame(records_slave)
goldstandard['masters'] = pd.DataFrame(records_master)
goldstandard['uniques'] = pd.DataFrame(records_unique)

# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(goldstandard['slaves'].columns)

goldstandard['slaves'].head()
# Out:
#        docid                            035liste                 isbn  \
# 0  000311049  [(OCoLC)731635279, (ABN)000539983]  [978-3-15-020008-7]
# 1  00130724X  [(OCoLC)808324878, (ABN)000155059]                   []
# 2  001817272  [(OCoLC)231772550, (ABN)000096920]      [3-495-47879-5]
# 3  00236865X  [(OCoLC)887157168, (ABN)000223912]                   []
# 4  00351031X  [(OCoLC)887324690, (ABN)000548154]  [978-1-4058-8214-9]
#
#                                              ttlfull  \
# 0                         {'245': ['Emma', 'Roman']}
# 1  {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# 2  {'245': ['Der moralische Status der Tiere', 'H...
# 3                       {'245': ['Die Zauberflöte']}
# 4                                  {'245': ['Emma']}
#
#                                              ttlpart  \
# 0                         {'245': ['Emma', 'Roman']}
# 1  {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# 2  {'245': ['Der moralische Status der Tiere', 'H...
# 3                       {'245': ['Die Zauberflöte']}
# 4                                  {'245': ['Emma']}
#
#                                               person  \
# 0  {'100': ['AustenJane'], '700': ['GraweChristia...
# 1  {'100': ['LevineJamesDir.'], '700': ['MozartWo...
# 2  {'100': ['FluryAndreas'], '700': [], '800': []...
# 3  {'100': ['MozartWolfgang Amadeus'], '700': [],...
# 4  {'100': ['AustenJane'], '700': ['StrangeJoanna...
#
#                                            corporate   pubyear decade century  \
# 0                  {'110': [], '710': [], '810': []}  2009       2009    2009
# 1  {'110': [], '710': ['Metropolitan Opera Orches...  2000       2000    2000
# 2                  {'110': [], '710': [], '810': []}  1999       1999    1999
# 3                  {'110': [], '710': [], '810': []}  uuuuuuuu   uuuu    uuuu
# 4                  {'110': [], '710': [], '810': []}  2008       2008    2008
#
#   exactDate edition     part                                         pages  \
# 0  2009              [20008]                                      [600 S.]
# 1  2000                   []  [1 DVD-Video, DVD Region 0, 169 Min., farb.]
# 2  1999                   []                                      [316 S.]
# 3  uuuuuuuu               []                                      [412 S.]
# 4  2008                   []                                       [64 S.]
#
#                                         volumes                pubinit  \
# 0                                      [600 S.]          [Reclam jun.]
# 1  [1 DVD-Video, DVD Region 0, 169 Min., farb.]  [Deutsche Grammophon]
# 2                                      [316 S.]                [Alber]
# 3                                      [412 S.]      [Ernst Eulenburg]
# 4                                       [64 S.]    [Pearson Education]
#
#                  pubword scale coordinate doi ismn musicid      format
# 0          [Reclam jun.]               []  []   []          [BK020000]
# 1  [Deutsche Grammophon]               []  []   []          [VM010300]
# 2                [Alber]               []  []   []          [BK020000]
# 3      [Ernst Eulenburg]               []  []   []          [BK020000]
# 4    [Pearson Education]               []  []   []          [BK020000]

# %% [markdown]
# The three files of the goldstandard will be used for training and testing the performance of the machine learning models of the capstone project. Combining the records of file $\texttt{slave.json}$ into pairs will generate a set of duplicate training data, while combining the records of file $\texttt{slave.json}$ with file $\texttt{unique.json}$ will generate a set of unique pair records for the training data.

# %% [markdown]
# ### Sample Records of a Goldstandard Example

# %% [markdown]
# Let's have a rough look at an example in the goldstandard data. All records of all three .json files will be chosen with string 'Emma' in attribute $\texttt{ttlfull}$ shall be taken as example.

# %%
goldstandard['slaves'][
    goldstandard['slaves'].ttlfull.apply(lambda x : x['245'][0]).str.contains('Emma')
]
# Out:
#          docid                                           035liste  \
# 0    000311049                 [(OCoLC)731635279, (ABN)000539983]
# 4    00351031X                 [(OCoLC)887324690, (ABN)000548154]
# 17   017959411                 [(OCoLC)636062037, (BGR)000409509]
# 19   020155182                 [(OCoLC)218626148, (BGR)000463276]
# 29   022315098               [(OCoLC)218626148, (IDSLU)000449481]
# 51   035554215               [(OCoLC)218626148, (IDSSG)000338145]
# 77   055836801  [(OCoLC)495204467, (SGBN)001068279, (OCoLC)495...
# 109  103342699               [(OCoLC)263554860, (IDSBB)001470548]
# 130  117574562               [(OCoLC)218626148, (IDSBB)003781869]
# 160  161169244               [(OCoLC)218626148, (NEBIS)004930649]
# 170  167723502               [(OCoLC)636062037, (NEBIS)005724810]
# 179  190194553               [(OCoLC)632335304, (NEBIS)008647887]
# 187  196506476               [(OCoLC)731635279, (NEBIS)009587153]
# 229  233497366                                 [(RERO)R003971490]
# 276  323173349               [(OCoLC)731635279, (LIBIB)000315536]
# 311  356992772                                  [(SGBN)001344510]
# 373  414925408  [(VAUD)991010949619702852, (RNV)003971490-41bc...
# 378  415447542  [(VAUD)991001434509702852, (RNV)003104061-41bc...
#
#                                                   isbn  \
# 0                                  [978-3-15-020008-7]
# 4                                  [978-1-4058-8214-9]
# 17   [978-1-4058-7953-8 (CD Pack), 978-1-4058-8214-...
# 19                  [978-0-521-82437-8, 0-521-82437-0]
# 29                                     [0-521-82437-0]
# 51                  [978-0-521-82437-8, 0-521-82437-0]
# 77        [978-1-4058-8214-9 (br), 1-4058-8214-X (br)]
# 109                                                 []
# 130                                    [0-521-82437-0]
# 160                 [978-0-521-82437-8, 0-521-82437-0]
# 170                                [978-1-4058-8214-9]
# 179                                    [0-375-75742-2]
# 187                                [978-3-15-020008-7]
# 229                                    [0-521-82437-0]
# 276                                [978-3-15-020008-7]
# 311                                                 []
# 373                                    [0-521-82437-0]
# 378                                    [0-375-75742-2]
#
#                         ttlfull                     ttlpart  \
# 0    {'245': ['Emma', 'Roman']}  {'245': ['Emma', 'Roman']}
# 4             {'245': ['Emma']}           {'245': ['Emma']}
# 17            {'245': ['Emma']}           {'245': ['Emma']}
# 19            {'245': ['Emma']}           {'245': ['Emma']}
# 29            {'245': ['Emma']}           {'245': ['Emma']}
# 51            {'245': ['Emma']}           {'245': ['Emma']}
# 77            {'245': ['Emma']}           {'245': ['Emma']}
# 109           {'245': ['Emma']}           {'245': ['Emma']}
# 130           {'245': ['Emma']}           {'245': ['Emma']}
# 160           {'245': ['Emma']}           {'245': ['Emma']}
# 170           {'245': ['Emma']}           {'245': ['Emma']}
# 179           {'245': ['Emma']}           {'245': ['Emma']}
# 187           {'245': ['Emma']}           {'245': ['Emma']}
# 229           {'245': ['Emma']}           {'245': ['Emma']}
# 276  {'245': ['Emma', 'Roman']}  {'245': ['Emma', 'Roman']}
# 311           {'245': ['Emma']}           {'245': ['Emma']}
# 373           {'245': ['Emma']}           {'245': ['Emma']}
# 378           {'245': ['Emma']}           {'245': ['Emma']}
#
#                                                 person  \
# 0    {'100': ['AustenJane'], '700': ['GraweChristia...
# 4    {'100': ['AustenJane'], '700': ['StrangeJoanna...
# 17   {'100': ['AustenJane'], '700': ['BarnesAnnette...
# 19   {'100': ['AustenJane'], '700': ['CroninRichard...
# 29   {'100': ['AustenJane'], '700': [], '800': [], ...
# 51   {'100': ['AustenJane'], '700': ['CroninRichard...
# 77   {'100': ['AustenJane'], '700': ['BarnesAnnette...
# 109  {'100': ['AustenJane'], '700': [], '800': [], ...
# 130  {'100': ['AustenJane'], '700': ['CroninRichard...
# 160  {'100': ['AustenJane'], '700': ['CroninRichard...
# 170  {'100': [], '700': ['AustenJane', 'BarnesAnnet...
# 179  {'100': ['AustenJane'], '700': [], '800': [], ...
# 187  {'100': ['AustenJane'], '700': [], '800': [], ...
# 229  {'100': ['AustenJane'], '700': ['CroninRichard...
# 276  {'100': ['AustenJane'], '700': [], '800': [], ...
# 311  {'100': ['AustenJane'], '700': [], '800': [], ...
# 373  {'100': ['AustenJane'], '700': ['CroninRichard...
# 378  {'100': ['AustenJane'], '700': [], '800': [], ...
#
#                              corporate   pubyear decade century exactDate  \
# 0    {'110': [], '710': [], '810': []}  2009       2009    2009  2009
# 4    {'110': [], '710': [], '810': []}  2008       2008    2008  2008
# 17   {'110': [], '710': [], '810': []}  2008       2008    2008  2008
# 19   {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 29   {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 51   {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 77   {'110': [], '710': [], '810': []}  2008       2008    2008  2008
# 109  {'110': [], '710': [], '810': []}  1979       1979    1979  1979
# 130  {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 160  {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 170  {'110': [], '710': [], '810': []}  2008       2008    2008  2008
# 179  {'110': [], '710': [], '810': []}  2001       2001    2001  2001
# 187  {'110': [], '710': [], '810': []}  2009       2009    2009  2009
# 229  {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 276  {'110': [], '710': [], '810': []}  2009       2009    2009  2009
# 311  {'110': [], '710': [], '810': []}  1979       1979    1979  1979
# 373  {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 378  {'110': [], '710': [], '810': []}  2001       2001    2001  2001
#
#     edition     part             pages           volumes  \
# 0            [20008]          [600 S.]          [600 S.]
# 4                 []           [64 S.]           [64 S.]
# 17                []           [64 S.]           [64 S.]
# 19                []          [600 S.]          [600 S.]
# 29                []          [599 S.]          [599 S.]
# 51                []          [600 S.]          [600 S.]
# 77                []           [64 S.]           [64 S.]
# 109               []          [549 S.]          [549 S.]
# 130               []          [600 S.]          [600 S.]
# 160               []          [600 S.]          [600 S.]
# 170               []           [64 S.]           [64 S.]
# 179               []          [359 S.]          [359 S.]
# 187          [20008]          [600 S.]          [600 S.]
# 229               []  [LXXVII, 600 p.]  [LXXVII, 600 p.]
# 276          [20008]          [600 S.]          [600 S.]
# 311               []          [549 S.]          [549 S.]
# 373               []  [LXXVII, 600 p.]  [LXXVII, 600 p.]
# 378               []    [XXII, 359 p.]    [XXII, 359 p.]
#
#                           pubinit                       pubword scale  \
# 0                   [Reclam jun.]                 [Reclam jun.]
# 4             [Pearson Education]           [Pearson Education]
# 17       [Pearson Education Ltd.]      [Pearson Education Ltd.]
# 19   [Cambridge University Press]  [Cambridge University Press]
# 29                             []                            []
# 51                             []                            []
# 77            [Pearson Education]           [Pearson Education]
# 109                            []                            []
# 130                            []                            []
# 160  [Cambridge University Press]  [Cambridge University Press]
# 170           [Pearson Education]           [Pearson Education]
# 179              [Modern Library]              [Modern Library]
# 187                      [Reclam]                      [Reclam]
# 229       [Cambridge Univ. Press]       [Cambridge Univ. Press]
# 276                      [Reclam]                      [Reclam]
# 311                [Insel Verlag]                [Insel Verlag]
# 373       [Cambridge Univ. Press]       [Cambridge Univ. Press]
# 378          [The Modern Library]          [The Modern Library]
#
#     coordinate doi ismn musicid      format
# 0           []  []   []          [BK020000]
# 4           []  []   []          [BK020000]
# 17          []  []   []          [BK020000]
# 19          []  []   []          [BK020000]
# 29          []  []   []          [BK020000]
# 51          []  []   []          [BK020000]
# 77          []  []   []          [BK020000]
# 109         []  []   []          [BK020000]
# 130         []  []   []          [BK020000]
# 160         []  []   []          [BK020000]
# 170         []  []   []          [BK020000]
# 179         []  []   []          [BK020000]
# 187         []  []   []          [BK020000]
# 229         []  []   []          [BK020000]
# 276         []  []   []          [BK020000]
# 311         []  []   []          [BK020000]
# 373         []  []   []          [BK020000]
# 378         []  []   []          [BK020000]

# %%
print('Number of records in slave.json with string \'Emma\' :', len(
    goldstandard['slaves'][
        goldstandard['slaves'].ttlfull.apply(lambda x : x['245'][0]).str.contains('Emma')])
     )
# Out:
# Number of records in slave.json with string 'Emma' : 18

# %% [markdown]
# A number of 18 records in $\texttt{slave.json}$ contain the string 'Emma' in attribute $\texttt{ttlfull}$. Some of these records are duplicates. File $\texttt{master.json}$ knows the amount of uniques out of the 18 records.

# %%
goldstandard['masters'][
    goldstandard['masters'].ttlfull.apply(lambda x : x['245'][0]).str.contains('Emma')
]
# Out:
#         docid                                           035liste  \
# 85  504389793  [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# 86  504389807  [(NEBIS)008647887, (VAUD)991001434509702852, (...
# 87  504389815  [(IDSLU)000449481, (IDSBB)003781869, (NEBIS)00...
# 88  504389823  [(SGBN)001068279, (ABN)000548154, (BGR)0004095...
# 89  504389831                [(IDSBB)001470548, (SGBN)001344510]
#
#                                             isbn            ttlfull  \
# 85                           [978-3-15-020008-7]  {'245': ['Emma']}
# 86                               [0-375-75742-2]  {'245': ['Emma']}
# 87                               [0-521-82437-0]  {'245': ['Emma']}
# 88  [978-1-4058-8214-9 (br), 1-4058-8214-X (br)]  {'245': ['Emma']}
# 89                                            []  {'245': ['Emma']}
#
#               ttlpart                                             person  \
# 85  {'245': ['Emma']}  {'100': ['AustenJane'], '700': [], '800': [], ...
# 86  {'245': ['Emma']}  {'100': ['AustenJane'], '700': [], '800': [], ...
# 87  {'245': ['Emma']}  {'100': ['AustenJane'], '700': [], '800': ['Au...
# 88  {'245': ['Emma']}  {'100': ['AustenJane'], '700': ['BarnesAnnette...
# 89  {'245': ['Emma']}  {'100': ['AustenJane'], '700': [], '800': [], ...
#
#                             corporate   pubyear decade century exactDate  \
# 85  {'110': [], '710': [], '810': []}  2009       2009    2009  2009
# 86  {'110': [], '710': [], '810': []}  2001       2001    2001  2001
# 87  {'110': [], '710': [], '810': []}  2005       2005    2005  2005
# 88  {'110': [], '710': [], '810': []}  2008       2008    2008  2008
# 89  {'110': [], '710': [], '810': []}  1979       1979    1979  1979
#
#    edition     part     pages   volumes              pubinit  \
# 85          [20008]  [600 S.]  [600 S.]             [Reclam]
# 86               []  [359 S.]  [359 S.]     [Modern Library]
# 87               []  [599 S.]  [599 S.]                   []
# 88               []   [64 S.]   [64 S.]  [Pearson Education]
# 89               []  [549 S.]  [549 S.]                   []
#
#                 pubword scale coordinate doi ismn musicid      format
# 85             [Reclam]               []  []   []          [BK020000]
# 86     [Modern Library]               []  []   []          [BK020000]
# 87                   []               []  []   []          [BK020000]
# 88  [Pearson Education]               []  []   []          [BK020000]
# 89                   []               []  []   []          [BK020000]

# %%
print('Number of records in master.json with string \'Emma\' :', len(
    goldstandard['masters'][
        goldstandard['masters'].ttlfull.apply(lambda x : x['245'][0]).str.contains('Emma')])
     )
# Out:
# Number of records in master.json with string 'Emma' : 5

# %% [markdown]
# The number of deduplicated records of file $\texttt{slave.json}$ containing string 'Emma' is 5. This is the number of unique records that are built in Swissbib's deduplication step out of the original 18 records above.
#
# There may be some minor differences in some fields of the deduplicated master file records compared to their original data in the duplicated original slave file records. Nevertheless, it is possible to identify the slave file records as duplicates of their associated master file records, looking at the details of the values of each attribute.
#
# In a final step, let's have a look at the 'Emma' string data of $\texttt{unique.json}$.

# %%
goldstandard['uniques'][
    goldstandard['uniques'].ttlfull.apply(lambda x : x['245'][0]).str.contains('Emma')
]
# Out:
#          docid                                           035liste  \
# 0    000143235                 [(OCoLC)362722306, (ABN)000551177]
# 4    002410559                 [(OCoLC)777853583, (ABN)000243260]
# 8    004130235                 [(OCoLC)887396789, (ABN)000628911]
# 13   017204097                 [(OCoLC)759250730, (BGR)000090407]
# 16   017738490                  [(OCoLC)76214484, (BGR)000281870]
# 20   01843486X                 [(OCoLC)759471685, (BGR)000212474]
# 26   021868816               [(OCoLC)610677900, (IDSLU)000093923]
# 42   038872498                 [(OCoLC)614721683, (SBT)000133903]
# 53   043085075                 [(OCoLC)882111340, (SBT)000463076]
# 62   051168871                [(OCoLC)759052846, (SGBN)001050098]
# 64   051572184                [(OCoLC)759058296, (SGBN)001060390]
# 68   053149580                [(OCoLC)759082968, (SGBN)001121235]
# 75   055275540                [(OCoLC)196459920, (SGBN)001234498]
# 78   055721753                [(OCoLC)732622324, (SGBN)001210208]
# 79   055836534                [(OCoLC)758069343, (SGBN)000458718]
# 103  077891678               [(OCoLC)605624983, (IDSBB)002184876]
# 115  09251703X               [(OCoLC)601005765, (IDSBB)004397615]
# 119  096258241               [(OCoLC)256364940, (IDSBB)001122030]
# 123  099169584               [(OCoLC)602806516, (IDSBB)004856135]
# 150  118839071               [(OCoLC)884533340, (IDSBB)000869415]
# 164  13863632X               [(OCoLC)636864378, (NEBIS)001455894]
# 181  160959055               [(OCoLC)635958140, (NEBIS)004952065]
# 190  169215628               [(OCoLC)729952995, (NEBIS)005884357]
# 192  183110714  [(OCoLC)800585351, (NEBIS)007344139, (OCoLC)80...
# 219  215675983                                    [(RERO)1878056]
# 220  216012872                                    [(RERO)1918154]
# 312  250735768                                 [(RERO)R006432641]
# 313  250896974                                 [(RERO)R006450838]
# 348  315048913                                 [(RERO)R005339099]
# 349  315858133  [(OCoLC)887524935, (ABN)000748108, (ZDB-22-CAN...
# 383  32197798X               [(OCoLC)237893744, (LIBIB)000188548]
# 384  322647916               [(OCoLC)836605224, (LIBIB)000224043]
# 385  322663563               [(OCoLC)759250730, (LIBIB)000224988]
# 392  337635617               [(OCoLC)919233036, (IDSLU)001203491]
# 393  337918651                 [(OCoLC)918992241, (ABN)000777750]
# 396  339410671                [(OCoLC)922663046, (SGBN)001329749]
# 440  353526452  [(OCoLC)912508004, (NEBIS)010476406, (OCoLC)91...
# 444  357508726                                 [(RERO)R008372350]
# 448  360500676  [(OCoLC)823820017, (SGBN)001341883, (OCoLC)823...
# 479  414025806  [(VAUD)991009408689702852, (RNV)000183309-41bc...
# 482  418402930  [(VAUD)991000009909702852, (RNV)000000022-41bc...
# 489  42968391X  [(VAUD)991000934389702853, (RNV)008255353-41bc...
# 590  502974850  [(VAUD)991021133696002852, (EXLNZ-41BCULAUSA_N...
# 591  503037281  [(OCoLC)190777025, (ABN)000816378, (OCoLC)1907...
#
#                                                   isbn  \
# 0                                  [978-3-7466-6120-9]
# 4                                      [0-19-282756-1]
# 8                                  [978-0-307-38684-7]
# 13                                     [3-596-22191-9]
# 16                                     [3-7466-5105-0]
# 20                                     [0-582-41794-5]
# 26                                                  []
# 42                                     [0-14-043010-5]
# 53                                                  []
# 62                                                  []
# 64                                 [978-3-491-96266-8]
# 68                                 [978-3-596-90041-1]
# 75                                 [978-3-15-020008-7]
# 78                                 [978-0-14-062010-8]
# 79                                     [0-582-41794-5]
# 103                                                 []
# 115                                                 []
# 119                     [3-15-007633-1, 3-15-027633-0]
# 123                                    [3-15-027633-0]
# 150                                                 []
# 164                                                 []
# 181                                    [1-904633-00-5]
# 190                                                 []
# 192                 [978-3-596-51207-2, 3-596-51207-7]
# 219                                    [0-19-254704-6]
# 220                                    [0-14-043010-5]
# 312                                                 []
# 313                                                 []
# 348                                [978-2-253-15933-9]
# 349  [3-95418-379-X, 978-3-95418-379-1, 3-95418-379...
# 383                                    [0-14-062010-9]
# 384                                    [0-14-043010-5]
# 385                                    [3-596-22191-9]
# 392                                [978-1-4058-8214-9]
# 393                                [978-3-526-52644-5]
# 396                                [978-3-15-010955-7]
# 440  [978-0-14-310771-2 (paperback), 0-14-310771-2 ...
# 444                                [978-1-107-62046-9]
# 448                 [978-0-14-119952-8, 0-14-119952-0]
# 479                                                 []
# 482                                                 []
# 489                                                 []
# 590                 [978-1-63106-070-0, 1-63106-070-8]
# 591                 [978-0-19-953552-1, 0-19-953552-3]
#
#                                                ttlfull  \
# 0                           {'245': ['Emma', 'Roman']}
# 4                                    {'245': ['Emma']}
# 8                                    {'245': ['Emma']}
# 13                          {'245': ['Emma', 'Roman']}
# 16                                   {'245': ['Emma']}
# 20                                   {'245': ['Emma']}
# 26                                   {'245': ['Emma']}
# 42                                   {'245': ['Emma']}
# 53                        {'245': ['Emma', 'mobbing']}
# 62                                   {'245': ['Emma']}
# 64                                   {'245': ['Emma']}
# 68                          {'245': ['Emma', 'Roman']}
# 75                          {'245': ['Emma', 'Roman']}
# 78                                   {'245': ['Emma']}
# 79                                   {'245': ['Emma']}
# 103                               {'245': ['An Emma']}
# 115                                  {'245': ['Emma']}
# 119                                  {'245': ['Emma']}
# 123                                  {'245': ['Emma']}
# 150                                  {'245': ['Emma']}
# 164                                  {'245': ['Emma']}
# 181                                  {'245': ['Emma']}
# 190                                  {'245': ['Emma']}
# 192                         {'245': ['Emma', 'Roman']}
# 219                                  {'245': ['Emma']}
# 220                                  {'245': ['Emma']}
# 312                                  {'245': ['Emma']}
# 313                                  {'245': ['Emma']}
# 348                                  {'245': ['Emma']}
# 349          {'245': ['Emma', 'Vollständige Fassung']}
# 383                                  {'245': ['Emma']}
# 384                                  {'245': ['Emma']}
# 385                                  {'245': ['Emma']}
# 392                                  {'245': ['Emma']}
# 393                                  {'245': ['Emma']}
# 396                         {'245': ['Emma', 'Roman']}
# 440  {'245': ['Emma', '200th-anniversary annotated ...
# 444                                  {'245': ['Emma']}
# 448                                  {'245': ['Emma']}
# 479                                  {'245': ['Emma']}
# 482                                  {'245': ['Emma']}
# 489                                  {'245': ['Emma']}
# 590                                  {'245': ['Emma']}
# 591                                  {'245': ['Emma']}
#
#                                                ttlpart  \
# 0                           {'245': ['Emma', 'Roman']}
# 4                                    {'245': ['Emma']}
# 8                                    {'245': ['Emma']}
# 13                          {'245': ['Emma', 'Roman']}
# 16                                   {'245': ['Emma']}
# 20                                   {'245': ['Emma']}
# 26                                   {'245': ['Emma']}
# 42                                   {'245': ['Emma']}
# 53                        {'245': ['Emma', 'mobbing']}
# 62                                   {'245': ['Emma']}
# 64                                   {'245': ['Emma']}
# 68                          {'245': ['Emma', 'Roman']}
# 75                          {'245': ['Emma', 'Roman']}
# 78                                   {'245': ['Emma']}
# 79                                   {'245': ['Emma']}
# 103                               {'245': ['An Emma']}
# 115                                  {'245': ['Emma']}
# 119                                  {'245': ['Emma']}
# 123                                  {'245': ['Emma']}
# 150                                  {'245': ['Emma']}
# 164                                  {'245': ['Emma']}
# 181                                  {'245': ['Emma']}
# 190                                  {'245': ['Emma']}
# 192                         {'245': ['Emma', 'Roman']}
# 219                                  {'245': ['Emma']}
# 220                                  {'245': ['Emma']}
# 312                                  {'245': ['Emma']}
# 313                                  {'245': ['Emma']}
# 348                                  {'245': ['Emma']}
# 349          {'245': ['Emma', 'Vollständige Fassung']}
# 383                                  {'245': ['Emma']}
# 384                                  {'245': ['Emma']}
# 385                                  {'245': ['Emma']}
# 392                                  {'245': ['Emma']}
# 393                                  {'245': ['Emma']}
# 396                         {'245': ['Emma', 'Roman']}
# 440  {'245': ['Emma', '200th-anniversary annotated ...
# 444                                  {'245': ['Emma']}
# 448                                  {'245': ['Emma']}
# 479                                  {'245': ['Emma']}
# 482                                  {'245': ['Emma']}
# 489                                  {'245': ['Emma']}
# 590                                  {'245': ['Emma']}
# 591                                  {'245': ['Emma']}
#
#                                                 person  \
# 0    {'100': ['AustenJane'], '700': [], '800': [], ...
# 4    {'100': ['AustenJane'], '700': [], '800': [], ...
# 8    {'100': ['AustenJane'], '700': [], '800': [], ...
# 13   {'100': ['AustenJane'], '700': [], '800': [], ...
# 16   {'100': ['AustenJane'], '700': [], '800': [], ...
# 20   {'100': ['AustenJane'], '700': ['BarnesAnnette...
# 26   {'100': ['AustenJane'], '700': [], '800': [], ...
# 42   {'100': ['AustenJane'], '700': ['BlytheRonald'...
# 53   {'100': [], '700': [], '800': [], '245c': ['Ca...
# 62   {'100': ['AustenJane'], '700': [], '800': [], ...
# 64   {'100': ['AustenJane'], '700': [], '800': [], ...
# 68   {'100': ['AustenJane'], '700': [], '800': [], ...
# 75   {'100': ['AustenJane'], '700': ['GraweChristia...
# 78   {'100': ['AustenJane'], '700': [], '800': [], ...
# 79   {'100': ['AustenJane'], '700': ['BarnesAnnette...
# 103  {'100': ['SchubertFranz'], '700': [], '800': [...
# 115  {'100': ['AustenJane'], '700': [], '800': [], ...
# 119  {'100': ['AustenJane'], '700': [], '800': [], ...
# 123  {'100': ['AustenJane'], '700': ['AustenJane'],...
# 150  {'100': ['AustenJane'], '700': [], '800': [], ...
# 164  {'100': ['AustenJane'], '700': [], '800': [], ...
# 181  {'100': ['AustenJane'], '700': [], '800': [], ...
# 190  {'100': ['AustenJane'], '700': [], '800': [], ...
# 192  {'100': ['AustenJane'], '700': ['HenzeHelene']...
# 219  {'100': ['AustenJane'], '700': [], '800': ['Au...
# 220  {'100': ['AustenJane'], '700': ['BlytheRonald'...
# 312  {'100': ['AustenJane'], '700': [], '800': [], ...
# 313  {'100': ['AustenJane'], '700': [], '800': [], ...
# 348  {'100': ['AustenJane'], '700': [], '800': [], ...
# 349  {'100': ['AustenJane'], '700': ['SchulzeJürgen...
# 383  {'100': ['AustenJane'], '700': [], '800': [], ...
# 384  {'100': [], '700': ['AustenJane'], '800': [], ...
# 385  {'100': [], '700': ['AustenJane'], '800': [], ...
# 392  {'100': ['AustenJane'], '700': [], '800': [], ...
# 393  {'100': ['AustenJane'], '700': [], '800': [], ...
# 396  {'100': ['AustenJane'], '700': [], '800': [], ...
# 440  {'100': ['AustenJane'], '700': ['WellsJuliette...
# 444  {'100': ['AustenJane'], '700': ['CroninRichard...
# 448  {'100': ['AustenJane'], '700': [], '800': [], ...
# 479  {'100': ['AustenJane'], '700': [], '800': [], ...
# 482  {'100': ['AustenJane'], '700': [], '800': ['Au...
# 489  {'100': ['AustenJane'], '700': [], '800': [], ...
# 590  {'100': ['AustenJane'], '700': [], '800': [], ...
# 591  {'100': ['AustenJane'], '700': [], '800': [], ...
#
#                                              corporate   pubyear decade  \
# 0                    {'110': [], '710': [], '810': []}  2009       2009
# 4                    {'110': [], '710': [], '810': []}  1990       1990
# 8                    {'110': [], '710': [], '810': []}  2007       2007
# 13                   {'110': [], '710': [], '810': []}  1996       1996
# 16                   {'110': [], '710': [], '810': []}  2001       2001
# 20                   {'110': [], '710': [], '810': []}  2000       2000
# 26                   {'110': [], '710': [], '810': []}  1996       1996
# 42                   {'110': [], '710': [], '810': []}  1983       1983
# 53   {'110': [], '710': ['Caritas (Ticino)'], '810'...  2002       2002
# 62                   {'110': [], '710': [], '810': []}  1953       1953
# 64                   {'110': [], '710': [], '810': []}  2009       2009
# 68                   {'110': [], '710': [], '810': []}  2009       2009
# 75                   {'110': [], '710': [], '810': []}  2007       2007
# 78                   {'110': [], '710': [], '810': []}  200u       200u
# 79                   {'110': [], '710': [], '810': []}  1999       1999
# 103                  {'110': [], '710': [], '810': []}  uuuuuuuu   uuuu
# 115                  {'110': [], '710': [], '810': []}  1955       1955
# 119                  {'110': [], '710': [], '810': []}  1985       1985
# 123                  {'110': [], '710': [], '810': []}  1980       1980
# 150                  {'110': [], '710': [], '810': []}  1988       1988
# 164                  {'110': [], '710': [], '810': []}  1994       1994
# 181                  {'110': [], '710': [], '810': []}  2003       2003
# 190                  {'110': [], '710': [], '810': []}  1963       1963
# 192                  {'110': [], '710': [], '810': []}  2012       2012
# 219                  {'110': [], '710': [], '810': []}  1988       1988
# 220                  {'110': [], '710': [], '810': []}  1975       1975
# 312                  {'110': [], '710': [], '810': []}  1931       1931
# 313                  {'110': [], '710': [], '810': []}  1960       1960
# 348                  {'110': [], '710': [], '810': []}  2012       2012
# 349                  {'110': [], '710': [], '810': []}  2013       2013
# 383                  {'110': [], '710': [], '810': []}  1994       1994
# 384                  {'110': [], '710': [], '810': []}  1985       1985
# 385                  {'110': [], '710': [], '810': []}  1996       1996
# 392                  {'110': [], '710': [], '810': []}  1996       1996
# 393                  {'110': [], '710': [], '810': []}  2010       2010
# 396                  {'110': [], '710': [], '810': []}  2015       2015
# 440                  {'110': [], '710': [], '810': []}  2015       2015
# 444                  {'110': [], '710': [], '810': []}  2013       2013
# 448                  {'110': [], '710': [], '810': []}  2012       2012
# 479                  {'110': [], '710': [], '810': []}  1901       1901
# 482                  {'110': [], '710': [], '810': []}  1922       1922
# 489                  {'110': [], '710': [], '810': []}  2005       2005
# 590                  {'110': [], '710': [], '810': []}  2015       2015
# 591                  {'110': [], '710': [], '810': []}  2008       2008
#
#     century exactDate                      edition         part  \
# 0      2009  2009                                        [6120]
# 4      1990  1990                                            []
# 8      2007  2007                                            []
# 13     1996  1996                   [87.-88. Tsd.]       [2191]
# 16     2001  2001                          3. Aufl       [5105]
# 20     2000  2000        [new ed., 2nd impression]           []
# 26     1996  1996                                         [[1]]
# 42     1983  1983                                            []
# 53     2002  2002                                            []
# 62     1953  1953                                            []
# 64     2009  2009                                            []
# 68     2009  2009      Ungekürzte Ausgabe, 2. Aufl      [90041]
# 75     2007  2007                                   [Nr. 20008]
# 78     200u  200u                                            []
# 79     1999  1999                         6th impr           []
# 103    uuuu  uuuuuuuu                                        []
# 115    1955  1955                                         [129]
# 119    1985  1985                                    [Nr. 7633]
# 123    1980  1980                                    [Nr. 7633]
# 150    1988  1988                [11th impression]           []
# 164    1994  1994                        [Reprint]           []
# 181    2003  2003                                            []
# 190    1963  1963                                            []
# 192    2012  2012                                            []
# 219    1988  1988                     3rd ed. repr     [vol. 4]
# 220    1975  1975                          [Repr.]           []
# 312    1931  1931                                          [24]
# 313    1960  1960                                            []
# 348    2012  2012                                            []
# 349    2013  2013                          1. Aufl           []
# 383    1994  1994                                            []
# 384    1985  1985                                            []
# 385    1996  1996                                        [2191]
# 392    1996  1996                                            []
# 393    2010  2010                                            []
# 396    2015  2015            Durchgesehene Ausgabe           []
# 440    2015  2015                                            []
# 444    2013  2013                         Pbk. ed.           []
# 448    2012  2012                                            []
# 479    1901  1901                                            []
# 482    1922  1922                                            []
# 489    2005  2005                                            []
# 590    2015  2015                                            []
# 591    2008  2008                         Reissued           []
#
#                                   pages                             volumes  \
# 0                              [575 S.]                            [575 S.]
# 4                              [445 p.]                            [445 p.]
# 8                              [495 S.]                            [495 S.]
# 13                             [414 S.]                            [414 S.]
# 16                             [553 S.]                            [553 S.]
# 20                              [59 S.]                             [59 S.]
# 26                             [560 S.]                            [560 S.]
# 42                             [471 p.]                            [471 p.]
# 53                    [1 Videocassetta]                   [1 Videocassetta]
# 62                             [377 S.]                            [377 S.]
# 64                             [450 S.]                            [450 S.]
# 68                             [509 S.]                            [509 S.]
# 75                             [600 S.]                            [600 S.]
# 78                             [367 S.]                            [367 S.]
# 79                              [59 S.]                             [59 S.]
# 103                                  []                                  []
# 115                       [XIV, 432 S.]                       [XIV, 432 S.]
# 119                            [560 S.]                            [560 S.]
# 123                            [560 S.]                            [560 S.]
# 150                            [367 S.]                            [367 S.]
# 164                            [3 vol.]                            [3 vol.]
# 181                            [590 S.]                            [590 S.]
# 190                            [127 p.]                            [127 p.]
# 192                            [735 S.]                            [735 S.]
# 219                        [XI, 521 p.]                        [XI, 521 p.]
# 220                            [471 p.]                            [471 p.]
# 312                            [395 p.]                            [395 p.]
# 313                            [521 p.]                            [521 p.]
# 348     [1 livre électronique (e-book)]     [1 livre électronique (e-book)]
# 349                  [Online Ressource]                  [Online Ressource]
# 383                            [367 S.]                            [367 S.]
# 384                            [471 S.]                            [471 S.]
# 385                            [414 S.]                            [414 S.]
# 392                             [64 S.]                             [64 S.]
# 393                            [144 S.]                            [144 S.]
# 396                            [600 S.]                            [600 S.]
# 440                            [459 p.]                            [459 p.]
# 444                            [600 p.]                            [600 p.]
# 448                             [485 S]                             [485 S]
# 479                     [XVIII, 436 p.]                     [XVIII, 436 p.]
# 482                         [V, 395 p.]                         [V, 395 p.]
# 489  [3 disque compact ( env. 213 min)]  [3 disque compact ( env. 213 min)]
# 590                            [448 p.]                            [448 p.]
# 591                        [402 Seiten]                        [402 Seiten]
#
#                           pubinit                       pubword scale  \
# 0            [Aufbau Taschenbuch]          [Aufbau Taschenbuch]
# 4       [Oxford University Press]     [Oxford University Press]
# 8                 [Vintage Books]               [Vintage Books]
# 13   [Fischer-Taschenbuch-Verlag]  [Fischer-Taschenbuch-Verlag]
# 16    [Aufbau Taschenbuch-Verlag]   [Aufbau Taschenbuch-Verlag]
# 20        [Pearson Education Ltd]       [Pearson Education Ltd]
# 26                             []                            []
# 42                [Penguin Books]               [Penguin Books]
# 53               [Caritas Ticino]              [Caritas Ticino]
# 62                      [Collins]                     [Collins]
# 64                     [Albatros]                    [Albatros]
# 68   [Fischer-Taschenbuch-Verlag]  [Fischer-Taschenbuch-Verlag]
# 75                       [Reclam]                      [Reclam]
# 78                [Penguin Books]               [Penguin Books]
# 79                      [Pearson]                     [Pearson]
# 103                            []                            []
# 115                            []                            []
# 119                            []                            []
# 123                            []                            []
# 150                            []                            []
# 164    [Routledge/Thoemmes Press]    [Routledge/Thoemmes Press]
# 181                         [CRW]                         [CRW]
# 190             [Peninsula press]             [Peninsula press]
# 192   [Fischer Taschenbuch Verl.]   [Fischer Taschenbuch Verl.]
# 219     [Oxford University Press]     [Oxford University Press]
# 220               [Penguin Books]               [Penguin Books]
# 312          [J.M. Dent and Sons]          [J.M. Dent and Sons]
# 313     [Oxford University Press]     [Oxford University Press]
# 348           [Le Livre de Poche]           [Le Livre de Poche]
# 349          [Null Papier Verlag]          [Null Papier Verlag]
# 383                     [Penguin]                     [Penguin]
# 384                     [Penguin]                     [Penguin]
# 385                     [Fischer]                     [Fischer]
# 392                            []                            []
# 393        [Black Cat Publishing]        [Black Cat Publishing]
# 396                      [Reclam]                      [Reclam]
# 440               [Penguin Books]               [Penguin Books]
# 444  [Cambridge University Press]  [Cambridge University Press]
# 448                     [Penguin]                     [Penguin]
# 479                   [Macmillan]                   [Macmillan]
# 482          [J.M. Dent and sons]          [J.M. Dent and sons]
# 489                   [Macmilian]                   [Macmilian]
# 590       [Race Point Publishing]       [Race Point Publishing]
# 591                            []                            []
#
#     coordinate doi ismn musicid      format
# 0           []  []   []          [BK020000]
# 4           []  []   []          [BK020000]
# 8           []  []   []          [BK020000]
# 13          []  []   []          [BK020000]
# 16          []  []   []          [BK020000]
# 20          []  []   []          [BK020000]
# 26          []  []   []          [BK020000]
# 42          []  []   []          [BK020000]
# 53          []  []   []          [VM010200]
# 62          []  []   []          [BK020000]
# 64          []  []   []          [BK020000]
# 68          []  []   []          [BK020000]
# 75          []  []   []          [BK020000]
# 78          []  []   []          [BK020000]
# 79          []  []   []          [BK020000]
# 103         []  []   []          [MU040100]
# 115         []  []   []          [BK020000]
# 119         []  []   []          [BK020000]
# 123         []  []   []          [BK020000]
# 150         []  []   []          [BK020000]
# 164         []  []   []          [BK020000]
# 181         []  []   []          [BK020000]
# 190         []  []   []          [BK020000]
# 192         []  []   []          [BK020000]
# 219         []  []   []          [BK020000]
# 220         []  []   []          [BK020000]
# 312         []  []   []          [BK020000]
# 313         []  []   []          [BK020000]
# 348         []  []   []          [BK020053]
# 349         []  []   []          [BK020053]
# 383         []  []   []          [BK020000]
# 384         []  []   []          [BK020000]
# 385         []  []   []          [BK020000]
# 392         []  []   []          [BK020000]
# 393         []  []   []          [BK020000]
# 396         []  []   []          [BK020000]
# 440         []  []   []          [BK020000]
# 444         []  []   []          [BK020000]
# 448         []  []   []          [BK020000]
# 479         []  []   []          [BK020000]
# 482         []  []   []          [BK020000]
# 489         []  []   []          [MU040000]
# 590         []  []   []          [BK020000]
# 591         []  []   []          [BK020000]

# %%
print('Number of records in unique.json with string \'Emma\' :', len(
    goldstandard['uniques'][
        goldstandard['uniques'].ttlfull.apply(lambda x : x['245'][0]).str.contains('Emma')])
     )
# Out:
# Number of records in unique.json with string 'Emma' : 44

# %% [markdown]
# The number of unique records of file $\texttt{unique.json}$ is 44. The data of the records reveal that none of them can be associated as duplicate of a record in $\texttt{master.json}$. These unique records are excellent training data for deduplication as they can be used for training of similar but non-duplicate, thus unique, record pairs.

# %% [markdown]
# The goal of generating training and test data with the help of the goldstandard is to generate two categories of training data.
#
# - The first category consists of records of pairs of the original records out of file $\texttt{slave.json}$ that have a label 'duplicates'. This will be accomplished with the help of the records of file $\texttt{master.json}$, see subsection [Generating Pairs of Duplicates](#Generating-Pairs-of-Duplicates).
# - The second category consists of records of pairs of the original records out of files $\texttt{slave.json}$ and $\texttt{unique.json}$ that have a label 'uniques', see subsection [Generating Pairs of Uniques](#Generating-Pairs-of-Uniques).

# %% [markdown]
# To calculate the number of possible duplicate pairs the formula
#
# $
# \begin{align}
# Tot_{duplicate\ pairs} = \sum_{i=1}^{M} \frac{1}{2}S_i \cdot \left(S_i-1\right)
# \end{align}
# $
#
# where $M$ is the number of records in file $\texttt{master.json}$ and $S_i$ are the number of records in file $\texttt{slave.json}$ that are associated with master record $m_i$. As the number of slave records must be counted for each master record and as this number can only be deduced out of the goldstandard data, it is not possible to calculate the number of expected duplicate pair records in advance.

# %% [markdown]
# ### Generating Pairs of Duplicates

# %% [markdown]
# The central attribute for retrieving duplicates in the goldstandard data is attribute $\texttt{035liste}$, see chapter [Data Analysis](./1_DataAnalysis.ipynb). It helps to identify the associated master record for a given record of file $\texttt{slave.json}$. The process implemented below parses the list of identifiers in attribute $\texttt{035liste}$ of each record in file $\texttt{slave.json}$ and searches the value of the identifier in the attribute $\texttt{035liste}$ of all records of file $\texttt{master.json}$. When the identifier is found in file $\texttt{master.json}$, the master record's attribute $\texttt{docid}$ is stored as a new column in the slave DataFrame, see figure [Slave/master relationship](#slave_master_relationship). The new attribute in the slave record has the meaning of a foreign key to the related master record. This process is repeated for each list element of one slave record and for each record in the data file $\texttt{slave.json}$.

# %% [markdown]
# <center>
#     <b>Figure</b><a id='slave_master_relationship'></a> Slave/master relationship.
#     <img src="./documentation/training_data.png" style="width: 600px;"/></p>
# </center>

# %% [markdown]
# As will be shown below, the relationship of a slave record to its master record is unique. Even if there is more than one entry in the list of attribute $\texttt{035liste}$ of a slave record it will be shown that all distinct entries of a $\texttt{035liste}$ attribute list of one slave record point to one and the same master record.

# %% [markdown]
# Attribute $\texttt{035liste}$ will not be used in training nore in perfomance testing of the models. The column will be removed before model training.

# %% [markdown]
# ### Generating Pairs of Uniques

# %% [markdown]
# File $\texttt{unique.json}$ holds data of unique records. For training and testing purposes, pairs of records could be generated exclusively with the records out of this file. This would generate record pairs with label 'uniques' which can be clearly distinguished and therefore clearly be recognized as non-duplicate pairs. A more interesting pairing of records can be generated with records out of $\texttt{slave.json}$ and records out of $\texttt{unique.json}$. Pairs of records that are produced in a mixture of both sources, may reveal similarities in their attributes pairing that makes these pairs more difficult for classifying clearly as uniques.
#
# A mixture of both pairing sources will be implemented for the generation of training and testing data. The pairing combinations of all available unique records with all available slave records is done with a Cartesian product and its number calculates to the following value.

# %%
print('Total expected number of pairs of uniques for training and testing : {:,d}'.format(
    len(goldstandard['uniques'])*len(goldstandard['slaves'])))
# Out:
# Total expected number of pairs of uniques for training and testing : 259,260

# %% [markdown]
# Of course, this estimated amount only holds true, if the records of slaves do not have any duplicates in the records of uniques. Whether this is the case in the goldstandard data, will be investigated below.

# %% [markdown]
# ## Transform Attributes for Similarity Comparison

# %% [markdown]
# Before pairing the records into a DataFrame that will be used for the feature matrix, the attributes of the goldstandard data will be processed into their form to be used for generating the similarity matrix. This step could be done after the pairing step. Doing it before building pairs, avoids transformation of the same attributes several times and reduces the amount of transformation to the amount of raw data in the goldstandard instead of the multiplyed data of the paired records.

# %% [markdown]
# As the data preparation of the attributes will be reused in chapter [Data Synthesizing](./3_DataSynthesizing.ipynb), it has been encapsulated into a separate function of library [data_preparation_funcs.py](./data_preparation_funcs.py), which handles the processing of all relevant attributes. This function will be called below.

# %%
import data_preparation_funcs as dpf

for i in ['slaves', 'masters', 'uniques']:
    goldstandard[i] = dpf.attribute_preprocessing(
        goldstandard[i],
        columns_metadata_dict['data_analysis_columns'], strip_number_digits)

# %% [markdown]
# ### ismn

# %%
for i in ['slaves', 'masters', 'uniques']:
    display(goldstandard[i].ismn[goldstandard[i].ismn.apply(lambda x : len(x)>0)])
# Out:
# 31                                  m006450510
# 132                                 m006546756
# 164                                 m006546749
# 171                                 m006450510
# 191    m006546756 (kritischer bericht, leinen)
# 225                                 m006450510
# 228                                 m006204687
# 418                              9790006450510
# 419                                 m200205343
# 420                                 m006204687
# 429    m006546756 (kritischer bericht, leinen)
# Name: ismn, dtype: object
# 35                                  m200205343
# 37                                  m006450510
# 123    m006546756 (kritischer bericht, leinen)
# 149                                 m006204687
# 150                                 m006450510
# 157                                 m006546749
# Name: ismn, dtype: object
# 34        m700241001
# 151    9790200207781
# 193    9790006450510
# 282       m006450510
# 340       m008060205
# 342       m006450510
# 388    9790006201334
# 498    9790006201334
# 589    9790006450510
# Name: ismn, dtype: object

# %% [markdown]
# A vanishingly small number of rows with real ismn identifyers had been found in the data of chapter [Data Analysis](./1_DataAnalysis.ipynb). In the goldstandard data, the amount of real ismn identifyers found is fair. As there will be training data with filled attribute $\texttt{ismn}$, the attribute will be kept for the feature matrix.

# %%
#columns_metadata_dict['data_analysis_columns'].remove('ismn')
#columns_metadata_dict['columns_to_use'].remove('ismn_x')
#columns_metadata_dict['columns_to_use'].remove('ismn_y')

# %% [markdown]
# ## Build Pairs of Duplicates

# %% [markdown]
# As a first step, the relationship between slaves records and masters records is investigated. Thereafter, the records of pairs of duplicates will be generated.

# %%
for i in range(len(goldstandard['slaves'])):
    if len(goldstandard['masters'][goldstandard['masters'].docid == goldstandard['slaves'].docid.loc[i]]) > 0 :
        print('STOP!')
        break

# %% [markdown]
# The silence of the code cell above shows that there is no record in file $\texttt{slaves.json}$ that has the same $\texttt{docid}$ like any record in file $\texttt{masters.json}$. Attribute $\texttt{docid}$ is irrelevant for identifying pairs of duplicates.

# %% [markdown]
# ### Slaves Masters Relationships

# %% [markdown]
# To understand, how to build pairs of duplicates, let's have a look at some sample data.

# %%
for i in ['slaves', 'masters', 'uniques']:
    print(f'\n{i}')
    print(goldstandard[i]['035liste'].sample(n=5))
# Out:
# slaves
# 276    [(OCoLC)731635279, (LIBIB)000315536]
# 9        [(OCoLC)780137741, (ABN)000669941]
# 4        [(OCoLC)887324690, (ABN)000548154]
# 330    [(OCoLC)884694486, (IDSBB)006000910]
# 262     [(SNL)vtls001719167, (Sz)001719167]
# Name: 035liste, dtype: object
#
# masters
# 81    [(IDSBB)006726594, (NEBIS)011045420, (OCoLC)10...
# 69    [(RERO)1245069, (VAUD)991018231439702852, (RNV...
# 74    [(IDSBB)006503313, (IDSBB)006491015, (SNL)vtls...
# 71                 [(RERO)R006172599, (RERO)R275502460]
# 49                 [(RERO)R006132598, (RERO)R275508860]
# Name: 035liste, dtype: object
#
# uniques
# 394                      [(RERO)R008249818]
# 203    [(OCoLC)611244100, (NEBIS)009374474]
# 279                      [(RERO)R003945582]
# 252                      [(RERO)R278018360]
# 141    [(OCoLC)884457936, (IDSBB)004819890]
# Name: 035liste, dtype: object

# %%
for i in range(len(goldstandard['slaves'])):
    if i < 4:
        for j in range(len(goldstandard['slaves']['035liste'][i])):
            for k in range(len(goldstandard['masters'])):
                if goldstandard['slaves']['035liste'][i][j] in goldstandard['masters']['035liste'][k]:
                    print('slaves record', i, 'holds in 035liste position', j, 'a reference to masters record', k)
print('etc.')
# Out:
# slaves record 0 holds in 035liste position 1 a reference to masters record 85
# slaves record 1 holds in 035liste position 1 a reference to masters record 145
# slaves record 2 holds in 035liste position 1 a reference to masters record 119
# slaves record 3 holds in 035liste position 1 a reference to masters record 57
# etc.

# %% [markdown]
# The code above shows a relationship between records out of $\texttt{slaves.json}$ and records out of $\texttt{masters.json}$. This relationship is established with the entries in attribute $\texttt{035liste}$. The next step is to look at record pairs that have this relationship.

# %%
sample_pair_1 = [0, 85]
sample_pair_2 = [1, 145]
sample_pair_3 = [2, 119]
sample_pair_4 = [3, 57]

print('Example pair 1')
print('slaves record', goldstandard['slaves']['035liste'][sample_pair_1[0]], '\nmasters record', goldstandard['masters']['035liste'][sample_pair_1[1]])
print('\nExample pair 2')
print('slaves record', goldstandard['slaves']['035liste'][sample_pair_2[0]], '\nmasters record', goldstandard['masters']['035liste'][sample_pair_2[1]])
print('\nExample pair 3')
print('slaves record', goldstandard['slaves']['035liste'][sample_pair_3[0]], '\nmasters record', goldstandard['masters']['035liste'][sample_pair_3[1]])
print('\nExample pair 4')
print('slaves record', goldstandard['slaves']['035liste'][sample_pair_4[0]], '\nmasters record', goldstandard['masters']['035liste'][sample_pair_4[1]])
# Out:
# Example pair 1
# slaves record ['(OCoLC)731635279', '(ABN)000539983']
# masters record ['(NEBIS)009587153', '(LIBIB)000315536', '(ABN)000539983']
#
# Example pair 2
# slaves record ['(OCoLC)808324878', '(ABN)000155059']
# masters record ['(IDSBB)003690925', '(NEBIS)005645758', '(RERO)R003034172', '(ABN)000155059']
#
# Example pair 3
# slaves record ['(OCoLC)231772550', '(ABN)000096920']
# masters record ['(IDSBB)001651899', '(NEBIS)001974886', '(IDSSG)000177847', '(SGBN)000249023', '(SNL)vtls001203051', '(IDSLU)000164505', '(RERO)R243599160', '(VAUD)991016630449702852', '(ABN)000096920', '(Sz)001203051', '(RNV)002435991-41bculausa_network', '(RERO)002435991', 'R243599160', '(EXLNZ-41BCULAUSA_NETWORK)991020678209702851']
#
# Example pair 4
# slaves record ['(OCoLC)887157168', '(ABN)000223912']
# masters record ['(IDSBB)004654810', '(ABN)000223912']

# %%
for i in [sample_pair_1, sample_pair_2, sample_pair_3, sample_pair_4]:
    print('\npair------------------------------------->', i)
    print(goldstandard['slaves'].loc[i[0]], '\n')
    print(goldstandard['masters'].loc[i[1]])
# Out:
# pair-------------------------------------> [0, 85]
# docid                                                     000311049
# 035liste                         [(OCoLC)731635279, (ABN)000539983]
# isbn                                            [978-3-15-020008-7]
# ttlpart                                  {'245': ['Emma', 'Roman']}
# pubyear                                                    2009
# decade                                                         2009
# century                                                        2009
# exactDate                                                  2009uuuu
# edition
# part                                                          20008
# pages                                                      [600 S.]
# volumes                                                         600
# pubinit                                                 reclam jun.
# pubword                                               [Reclam jun.]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                               austenjane
# person_700                              grawechristian, graweursula
# person_245c       jane austen ; aus dem englischen übersetzt von...
# ttlfull_245                                             emma, roman
# ttlfull_246
# Name: 0, dtype: object
#
# docid                                                     504389793
# 035liste          [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# isbn                                            [978-3-15-020008-7]
# ttlpart                                           {'245': ['Emma']}
# pubyear                                                    2009
# decade                                                         2009
# century                                                        2009
# exactDate                                                  2009uuuu
# edition
# part                                                          20008
# pages                                                      [600 S.]
# volumes                                                         600
# pubinit                                                      reclam
# pubword                                                    [Reclam]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                               austenjane
# person_700
# person_245c       jane austen ; aus dem engl. übers. von ursula ...
# ttlfull_245                                                    emma
# ttlfull_246
# Name: 85, dtype: object
#
# pair-------------------------------------> [1, 145]
# docid                                                     00130724X
# 035liste                         [(OCoLC)808324878, (ABN)000155059]
# isbn                                                             []
# ttlpart           {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# pubyear                                                    2000
# decade                                                         2000
# century                                                        2000
# exactDate                                                  2000uuuu
# edition
# part
# pages                  [1 DVD-Video, DVD Region 0, 169 Min., farb.]
# volumes                                                     1 0 169
# pubinit                                         deutsche grammophon
# pubword                                       [Deutsche Grammophon]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     metropolitan opera orchestra, metropolitan ope...
# corporate_full    metropolitan opera orchestra, metropolitan ope...
# format_prefix                                                    vm
# format_postfix                                               010300
# person_100                                          levinejamesdir.
# person_700        mozartwolfgang amadeus, levinejames, schikaned...
# person_245c       w. a. mozart ; libretto: emanuel schikaneder ;...
# ttlfull_245                  die zauberflöte, oper in zwei aufzügen
# ttlfull_246
# Name: 1, dtype: object
#
# docid                                                     504390597
# 035liste          [(IDSBB)003690925, (NEBIS)005645758, (RERO)R00...
# isbn                                                             []
# ttlpart           {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# pubyear                                                    2000
# decade                                                         2000
# century                                                        2000
# exactDate                                                  2000uuuu
# edition
# part
# pages                                      [1 DVD-Video (169 Min.)]
# volumes                                                       1 169
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid                                                         073
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     metropolitan operaorchestra, metropolitan oper...
# corporate_full    metropolitan operaorchestra, metropolitan oper...
# format_prefix                                                    vm
# format_postfix                                               010300
# person_100                                   mozartwolfgang amadeus
# person_700            schikanederemanuel, hockneydavid, levinejames
# person_245c            w. a. mozart ; libretto: emanuel schikaneder
# ttlfull_245         die zauberflöte, oper in zwei aufzügen : kv 620
# ttlfull_246
# Name: 145, dtype: object
#
# pair-------------------------------------> [2, 119]
# docid                                                     001817272
# 035liste                         [(OCoLC)231772550, (ABN)000096920]
# isbn                                                [3-495-47879-5]
# ttlpart           {'245': ['Der moralische Status der Tiere', 'H...
# pubyear                                                    1999
# decade                                                         1999
# century                                                        1999
# exactDate                                                  1999uuuu
# edition
# part
# pages                                                      [316 S.]
# volumes                                                         316
# pubinit                                                       alber
# pubword                                                     [Alber]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                             fluryandreas
# person_700
# person_245c                                           andreas flury
# ttlfull_245       der moralische status der tiere, henry salt, p...
# ttlfull_246
# Name: 2, dtype: object
#
# docid                                                     50439018X
# 035liste          [(IDSBB)001651899, (NEBIS)001974886, (IDSSG)00...
# isbn                                                [3-495-47879-5]
# ttlpart           {'245': ['Der moralische Status der Tiere', 'H...
# pubyear                                                    1999
# decade                                                         1999
# century                                                        1999
# exactDate                                                  1999uuuu
# edition
# part                                                          57 57
# pages                                                      [316 S.]
# volumes                                                         316
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                             fluryandreas
# person_700
# person_245c                                           andreas flury
# ttlfull_245       der moralische status der tiere, henry salt, p...
# ttlfull_246
# Name: 119, dtype: object
#
# pair-------------------------------------> [3, 57]
# docid                                      00236865X
# 035liste          [(OCoLC)887157168, (ABN)000223912]
# isbn                                              []
# ttlpart                 {'245': ['Die Zauberflöte']}
# pubyear                                     uuuuuuuu
# decade                                          uuuu
# century                                         uuuu
# exactDate                                   uuuuuuuu
# edition
# part
# pages                                       [412 S.]
# volumes                                          412
# pubinit                              ernst eulenburg
# pubword                            [Ernst Eulenburg]
# scale
# coordinate                                        []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                     bk
# format_postfix                                020000
# person_100                    mozartwolfgang amadeus
# person_700
# person_245c
# ttlfull_245                          die zauberflöte
# ttlfull_246
# Name: 3, dtype: object
#
# docid                                                     504389513
# 035liste                         [(IDSBB)004654810, (ABN)000223912]
# isbn                                                             []
# ttlpart                                {'245': ['Die Zauberflöte']}
# pubyear                                                    1920
# decade                                                         1920
# century                                                        1920
# exactDate                                                  1920uuuu
# edition
# part
# pages                                                       [1 Bd.]
# volumes                                                           1
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                   mozartwolfgang amadeus
# person_700                                       schikanederemanuel
# person_245c       w. a. mozart ; oper in 2 akten v. emanuel schi...
# ttlfull_245                                         die zauberflöte
# ttlfull_246
# Name: 57, dtype: object

# %% [markdown]
# Record pairs with a relationship are pairs of duplicates of a bibliographical unit. This is according to the description in the first part of this chapter. To identify explicitly which slave record belongs to which master record, attribute $\texttt{035liste}$ will be used. The following function implements an algorithm that searches for each $\texttt{035liste}$ value of a slave record its same value in $\texttt{035liste}$ in the master records. If the record is found in one of the master records, the $\texttt{docid}$ of this master is stored in a new attribute $\texttt{masters}\_\texttt{docid}$ of the slave record. As there can be more than one element in attribute $\texttt{035liste}$, there may be several master relationships on a slave record. Therefore, attribute $\texttt{masters}\_\texttt{docid}$ is of type of a list.

# %%
def add_master_docid_to_slave (df_s, df_m):
    """Determine docid of master and store on slave."""
    # Initialize Foreign Key list
    df_s['masters_docid'] = [list() for x in range(len(df_s.index))]

    # Search for master of slave
    for i in range(len(df_s)):
        loc_li = list()
        for j in range(len(df_s['035liste'].loc[i])):
            master_index = df_m[df_m['035liste'].str.contains(
                df_s['035liste'].loc[i][j], regex=False
            )].index
            if len(master_index) > 0 : # Skip empty Series
                loc_li.append(df_m.docid[master_index].values[0])

        df_s['masters_docid'].loc[i] = loc_li
    
    return df_s

# %%
goldstandard['slaves'] = add_master_docid_to_slave(goldstandard['slaves'], goldstandard['masters'])

goldstandard['slaves'].masters_docid.sample(n=10)
# Out:
# 53                                           [50439018X]
# 96                                           [504389017]
# 427                                          [264853539]
# 26                                           [504389246]
# 397    [504388908, 504388908, 504388908, 504388908, 5...
# 223                                          [504389777]
# 71                                           [504390082]
# 1                                            [504390597]
# 418                                          [504390813]
# 310                               [504390120, 504390120]
# Name: masters_docid, dtype: object

# %% [markdown]
# Looking at the same samples as above, shows a new attribute $\texttt{masters}\_\texttt{docid}$ in the slaves record, which holds the docid value of its related master record. This is true for each pair of records, see below.

# %%
for i in [sample_pair_1, sample_pair_2, sample_pair_3, sample_pair_4]:
    print('\npair------------------------------------->', i)
    print(goldstandard['slaves'].loc[i[0]], '\n')
    print(goldstandard['masters'].loc[i[1]])
# Out:
# pair-------------------------------------> [0, 85]
# docid                                                     000311049
# 035liste                         [(OCoLC)731635279, (ABN)000539983]
# isbn                                            [978-3-15-020008-7]
# ttlpart                                  {'245': ['Emma', 'Roman']}
# pubyear                                                    2009
# decade                                                         2009
# century                                                        2009
# exactDate                                                  2009uuuu
# edition
# part                                                          20008
# pages                                                      [600 S.]
# volumes                                                         600
# pubinit                                                 reclam jun.
# pubword                                               [Reclam jun.]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                               austenjane
# person_700                              grawechristian, graweursula
# person_245c       jane austen ; aus dem englischen übersetzt von...
# ttlfull_245                                             emma, roman
# ttlfull_246
# masters_docid                                           [504389793]
# Name: 0, dtype: object
#
# docid                                                     504389793
# 035liste          [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# isbn                                            [978-3-15-020008-7]
# ttlpart                                           {'245': ['Emma']}
# pubyear                                                    2009
# decade                                                         2009
# century                                                        2009
# exactDate                                                  2009uuuu
# edition
# part                                                          20008
# pages                                                      [600 S.]
# volumes                                                         600
# pubinit                                                      reclam
# pubword                                                    [Reclam]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                               austenjane
# person_700
# person_245c       jane austen ; aus dem engl. übers. von ursula ...
# ttlfull_245                                                    emma
# ttlfull_246
# Name: 85, dtype: object
#
# pair-------------------------------------> [1, 145]
# docid                                                     00130724X
# 035liste                         [(OCoLC)808324878, (ABN)000155059]
# isbn                                                             []
# ttlpart           {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# pubyear                                                    2000
# decade                                                         2000
# century                                                        2000
# exactDate                                                  2000uuuu
# edition
# part
# pages                  [1 DVD-Video, DVD Region 0, 169 Min., farb.]
# volumes                                                     1 0 169
# pubinit                                         deutsche grammophon
# pubword                                       [Deutsche Grammophon]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     metropolitan opera orchestra, metropolitan ope...
# corporate_full    metropolitan opera orchestra, metropolitan ope...
# format_prefix                                                    vm
# format_postfix                                               010300
# person_100                                          levinejamesdir.
# person_700        mozartwolfgang amadeus, levinejames, schikaned...
# person_245c       w. a. mozart ; libretto: emanuel schikaneder ;...
# ttlfull_245                  die zauberflöte, oper in zwei aufzügen
# ttlfull_246
# masters_docid                                           [504390597]
# Name: 1, dtype: object
#
# docid                                                     504390597
# 035liste          [(IDSBB)003690925, (NEBIS)005645758, (RERO)R00...
# isbn                                                             []
# ttlpart           {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# pubyear                                                    2000
# decade                                                         2000
# century                                                        2000
# exactDate                                                  2000uuuu
# edition
# part
# pages                                      [1 DVD-Video (169 Min.)]
# volumes                                                       1 169
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid                                                         073
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     metropolitan operaorchestra, metropolitan oper...
# corporate_full    metropolitan operaorchestra, metropolitan oper...
# format_prefix                                                    vm
# format_postfix                                               010300
# person_100                                   mozartwolfgang amadeus
# person_700            schikanederemanuel, hockneydavid, levinejames
# person_245c            w. a. mozart ; libretto: emanuel schikaneder
# ttlfull_245         die zauberflöte, oper in zwei aufzügen : kv 620
# ttlfull_246
# Name: 145, dtype: object
#
# pair-------------------------------------> [2, 119]
# docid                                                     001817272
# 035liste                         [(OCoLC)231772550, (ABN)000096920]
# isbn                                                [3-495-47879-5]
# ttlpart           {'245': ['Der moralische Status der Tiere', 'H...
# pubyear                                                    1999
# decade                                                         1999
# century                                                        1999
# exactDate                                                  1999uuuu
# edition
# part
# pages                                                      [316 S.]
# volumes                                                         316
# pubinit                                                       alber
# pubword                                                     [Alber]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                             fluryandreas
# person_700
# person_245c                                           andreas flury
# ttlfull_245       der moralische status der tiere, henry salt, p...
# ttlfull_246
# masters_docid                                           [50439018X]
# Name: 2, dtype: object
#
# docid                                                     50439018X
# 035liste          [(IDSBB)001651899, (NEBIS)001974886, (IDSSG)00...
# isbn                                                [3-495-47879-5]
# ttlpart           {'245': ['Der moralische Status der Tiere', 'H...
# pubyear                                                    1999
# decade                                                         1999
# century                                                        1999
# exactDate                                                  1999uuuu
# edition
# part                                                          57 57
# pages                                                      [316 S.]
# volumes                                                         316
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                             fluryandreas
# person_700
# person_245c                                           andreas flury
# ttlfull_245       der moralische status der tiere, henry salt, p...
# ttlfull_246
# Name: 119, dtype: object
#
# pair-------------------------------------> [3, 57]
# docid                                      00236865X
# 035liste          [(OCoLC)887157168, (ABN)000223912]
# isbn                                              []
# ttlpart                 {'245': ['Die Zauberflöte']}
# pubyear                                     uuuuuuuu
# decade                                          uuuu
# century                                         uuuu
# exactDate                                   uuuuuuuu
# edition
# part
# pages                                       [412 S.]
# volumes                                          412
# pubinit                              ernst eulenburg
# pubword                            [Ernst Eulenburg]
# scale
# coordinate                                        []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                     bk
# format_postfix                                020000
# person_100                    mozartwolfgang amadeus
# person_700
# person_245c
# ttlfull_245                          die zauberflöte
# ttlfull_246
# masters_docid                            [504389513]
# Name: 3, dtype: object
#
# docid                                                     504389513
# 035liste                         [(IDSBB)004654810, (ABN)000223912]
# isbn                                                             []
# ttlpart                                {'245': ['Die Zauberflöte']}
# pubyear                                                    1920
# decade                                                         1920
# century                                                        1920
# exactDate                                                  1920uuuu
# edition
# part
# pages                                                       [1 Bd.]
# volumes                                                           1
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                   mozartwolfgang amadeus
# person_700                                       schikanederemanuel
# person_245c       w. a. mozart ; oper in 2 akten v. emanuel schi...
# ttlfull_245                                         die zauberflöte
# ttlfull_246
# Name: 57, dtype: object

# %%
goldstandard['slaves']['masters_docid'].sample(n=10)
# Out:
# 153                          [504389467]
# 52                           [504390694]
# 77     [504389823, 504389823, 504389823]
# 64                           [504388967]
# 135                          [504390694]
# 209                          [504389483]
# 246                          [504388940]
# 74                           [504390694]
# 224                          [504389076]
# 117                          [504390368]
# Name: masters_docid, dtype: object

# %% [markdown]
# As the records in the master file are uniques by themselves, for distinctly identifying whether a pair of slave records is a duplicate, the keys in $\texttt{masters}\_\texttt{docid}$ must be unique. In the samples shown above, some cases with more than one entry can be detected. On the other hand, the visual check reveals that they hold identical values. As a next step, all identical values in attribute $\texttt{masters}\_\texttt{docid}$ will be reduced to one single entry. This will lead to a list of distinct values.

# %%
# Proof that all docid_masters are unique...
goldstandard['slaves']['masters_docid'] = goldstandard['slaves']['masters_docid'].apply(lambda x : set(x))
goldstandard['slaves']['masters_docid'] = goldstandard['slaves']['masters_docid'].apply(lambda x : list(x))

for i in range(len(goldstandard['slaves'])):
    if len(goldstandard['slaves'].masters_docid.loc[i]) != 1 :
        print('STOP!', i)
        break

# %% [markdown]
# The silence of the code cell above demonstrates that after reducing the list of $\texttt{masters}\_\texttt{docid}$ to distinct entries, all slave records hold exactly one key reference to a master. This is the basis for joining the data.
#
# The list attribute $\texttt{masters}\_\texttt{docid}$ now holds exactly one single element. To remove the list data type and extract its contents to a single string value, the following line of code is executed.

# %%
goldstandard['slaves']['masters_docid'] = goldstandard['slaves']['masters_docid'].apply(lambda x : x[0])
goldstandard['slaves'].head()
# Out:
#        docid                            035liste                 isbn  \
# 0  000311049  [(OCoLC)731635279, (ABN)000539983]  [978-3-15-020008-7]
# 1  00130724X  [(OCoLC)808324878, (ABN)000155059]                   []
# 2  001817272  [(OCoLC)231772550, (ABN)000096920]      [3-495-47879-5]
# 3  00236865X  [(OCoLC)887157168, (ABN)000223912]                   []
# 4  00351031X  [(OCoLC)887324690, (ABN)000548154]  [978-1-4058-8214-9]
#
#                                              ttlpart   pubyear decade century  \
# 0                         {'245': ['Emma', 'Roman']}  2009       2009    2009
# 1  {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...  2000       2000    2000
# 2  {'245': ['Der moralische Status der Tiere', 'H...  1999       1999    1999
# 3                       {'245': ['Die Zauberflöte']}  uuuuuuuu   uuuu    uuuu
# 4                                  {'245': ['Emma']}  2008       2008    2008
#
#   exactDate edition   part                                         pages  ...  \
# 0  2009uuuu          20008                                      [600 S.]  ...
# 1  2000uuuu                 [1 DVD-Video, DVD Region 0, 169 Min., farb.]  ...
# 2  1999uuuu                                                     [316 S.]  ...
# 3  uuuuuuuu                                                     [412 S.]  ...
# 4  2008uuuu                                                      [64 S.]  ...
#
#   corporate_110                                      corporate_710  \
# 0
# 1                metropolitan opera orchestra, metropolitan ope...
# 2
# 3
# 4
#
#                                       corporate_full format_prefix  \
# 0                                                               bk
# 1  metropolitan opera orchestra, metropolitan ope...            vm
# 2                                                               bk
# 3                                                               bk
# 4                                                               bk
#
#   format_postfix              person_100  \
# 0         020000              austenjane
# 1         010300         levinejamesdir.
# 2         020000            fluryandreas
# 3         020000  mozartwolfgang amadeus
# 4         020000              austenjane
#
#                                           person_700  \
# 0                        grawechristian, graweursula
# 1  mozartwolfgang amadeus, levinejames, schikaned...
# 2
# 3
# 4                                      strangejoanna
#
#                                          person_245c  \
# 0  jane austen ; aus dem englischen übersetzt von...
# 1  w. a. mozart ; libretto: emanuel schikaneder ;...
# 2                                      andreas flury
# 3
# 4             jane austen ; retold by joanna strange
#
#                                          ttlfull_245 ttlfull_246 masters_docid
# 0                                        emma, roman                 504389793
# 1             die zauberflöte, oper in zwei aufzügen                 504390597
# 2  der moralische status der tiere, henry salt, p...                 50439018X
# 3                                    die zauberflöte                 504389513
# 4                                               emma                 504389823
#
# [5 rows x 32 columns]

# %% [markdown]
# Joining all slave records with all master records must result in a number of pairs that is equal to the number of master records, loaded at the beginning of this chapter.

# %%
slave_master = pd.merge(left=goldstandard['slaves'], right=goldstandard['masters'], how='inner',
                  left_on='masters_docid', right_on='docid')

print('Number of paired slave/master records', len(slave_master))

# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(slave_master)

slave_master.head()
# Out:
# Number of paired slave/master records 435
#      docid_x                            035liste_x               isbn_x  \
# 0  000311049    [(OCoLC)731635279, (ABN)000539983]  [978-3-15-020008-7]
# 1  196506476  [(OCoLC)731635279, (NEBIS)009587153]  [978-3-15-020008-7]
# 2  323173349  [(OCoLC)731635279, (LIBIB)000315536]  [978-3-15-020008-7]
# 3  00130724X    [(OCoLC)808324878, (ABN)000155059]                   []
# 4  116188030  [(OCoLC)884447694, (IDSBB)003690925]                   []
#
#                                            ttlpart_x pubyear_x decade_x  \
# 0                         {'245': ['Emma', 'Roman']}  2009         2009
# 1                                  {'245': ['Emma']}  2009         2009
# 2                         {'245': ['Emma', 'Roman']}  2009         2009
# 3  {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...  2000         2000
# 4  {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...  2000         2000
#
#   century_x exactDate_x edition_x part_x  \
# 0      2009    2009uuuu            20008
# 1      2009    2009uuuu            20008
# 2      2009    2009uuuu            20008
# 3      2000    2000uuuu
# 4      2000    2000uuuu
#
#                                         pages_x volumes_x  \
# 0                                      [600 S.]       600
# 1                                      [600 S.]       600
# 2                                      [600 S.]       600
# 3  [1 DVD-Video, DVD Region 0, 169 Min., farb.]   1 0 169
# 4                      [1 DVD-Video (169 Min.)]     1 169
#
#              pubinit_x              pubword_x scale_x coordinate_x doi_x  \
# 0          reclam jun.          [Reclam jun.]                   []
# 1               reclam               [Reclam]                   []
# 2               reclam               [Reclam]                   []
# 3  deutsche grammophon  [Deutsche Grammophon]                   []
# 4                                          []                   []
#
#   ismn_x musicid_x coordinate_E_x coordinate_N_x corporate_110_x  \
# 0
# 1
# 2
# 3
# 4              073
#
#                                      corporate_710_x  \
# 0
# 1
# 2
# 3  metropolitan opera orchestra, metropolitan ope...
# 4  metropolitan operaorchestra, metropolitan oper...
#
#                                     corporate_full_x format_prefix_x  \
# 0                                                                 bk
# 1                                                                 bk
# 2                                                                 bk
# 3  metropolitan opera orchestra, metropolitan ope...              vm
# 4  metropolitan operaorchestra, metropolitan oper...              vm
#
#   format_postfix_x            person_100_x  \
# 0           020000              austenjane
# 1           020000              austenjane
# 2           020000              austenjane
# 3           010300         levinejamesdir.
# 4           010300  mozartwolfgang amadeus
#
#                                         person_700_x  \
# 0                        grawechristian, graweursula
# 1
# 2
# 3  mozartwolfgang amadeus, levinejames, schikaned...
# 4      schikanederemanuel, hockneydavid, levinejames
#
#                                        person_245c_x  \
# 0  jane austen ; aus dem englischen übersetzt von...
# 1  jane austen ; aus dem engl. übers. von ursula ...
# 2                                        jane austen
# 3  w. a. mozart ; libretto: emanuel schikaneder ;...
# 4       w. a. mozart ; libretto: emanuel schikaneder
#
#                                      ttlfull_245_x ttlfull_246_x  \
# 0                                      emma, roman
# 1                                             emma
# 2                                      emma, roman
# 3           die zauberflöte, oper in zwei aufzügen
# 4  die zauberflöte, oper in zwei aufzügen : kv 620
#
#   masters_docid    docid_y                                         035liste_y  \
# 0     504389793  504389793  [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# 1     504389793  504389793  [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# 2     504389793  504389793  [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# 3     504390597  504390597  [(IDSBB)003690925, (NEBIS)005645758, (RERO)R00...
# 4     504390597  504390597  [(IDSBB)003690925, (NEBIS)005645758, (RERO)R00...
#
#                 isbn_y                                          ttlpart_y  \
# 0  [978-3-15-020008-7]                                  {'245': ['Emma']}
# 1  [978-3-15-020008-7]                                  {'245': ['Emma']}
# 2  [978-3-15-020008-7]                                  {'245': ['Emma']}
# 3                   []  {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# 4                   []  {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
#
#   pubyear_y decade_y century_y exactDate_y edition_y part_y  \
# 0  2009         2009      2009    2009uuuu            20008
# 1  2009         2009      2009    2009uuuu            20008
# 2  2009         2009      2009    2009uuuu            20008
# 3  2000         2000      2000    2000uuuu
# 4  2000         2000      2000    2000uuuu
#
#                     pages_y volumes_y pubinit_y pubword_y scale_y  \
# 0                  [600 S.]       600    reclam  [Reclam]
# 1                  [600 S.]       600    reclam  [Reclam]
# 2                  [600 S.]       600    reclam  [Reclam]
# 3  [1 DVD-Video (169 Min.)]     1 169                  []
# 4  [1 DVD-Video (169 Min.)]     1 169                  []
#
#   coordinate_y doi_y ismn_y musicid_y coordinate_E_y coordinate_N_y  \
# 0           []
# 1           []
# 2           []
# 3           []                    073
# 4           []                    073
#
#   corporate_110_y                                    corporate_710_y  \
# 0
# 1
# 2
# 3                  metropolitan operaorchestra, metropolitan oper...
# 4                  metropolitan operaorchestra, metropolitan oper...
#
#                                     corporate_full_y format_prefix_y  \
# 0                                                                 bk
# 1                                                                 bk
# 2                                                                 bk
# 3  metropolitan operaorchestra, metropolitan oper...              vm
# 4  metropolitan operaorchestra, metropolitan oper...              vm
#
#   format_postfix_y            person_100_y  \
# 0           020000              austenjane
# 1           020000              austenjane
# 2           020000              austenjane
# 3           010300  mozartwolfgang amadeus
# 4           010300  mozartwolfgang amadeus
#
#                                     person_700_y  \
# 0
# 1
# 2
# 3  schikanederemanuel, hockneydavid, levinejames
# 4  schikanederemanuel, hockneydavid, levinejames
#
#                                        person_245c_y  \
# 0  jane austen ; aus dem engl. übers. von ursula ...
# 1  jane austen ; aus dem engl. übers. von ursula ...
# 2  jane austen ; aus dem engl. übers. von ursula ...
# 3       w. a. mozart ; libretto: emanuel schikaneder
# 4       w. a. mozart ; libretto: emanuel schikaneder
#
#                                      ttlfull_245_y ttlfull_246_y
# 0                                             emma
# 1                                             emma
# 2                                             emma
# 3  die zauberflöte, oper in zwei aufzügen : kv 620
# 4  die zauberflöte, oper in zwei aufzügen : kv 620

# %% [markdown]
# Looking at the examples above, reveals that the slave/master record pairs are duplicates, indeed.

# %%
pd.options.display.max_rows = len(slave_master.columns)

for i in [sample_pair_1, sample_pair_2, sample_pair_3, sample_pair_4]:
    print('\npair------------------------------------->', i)
    print(slave_master.loc[i[0]], '\n')
    print('... and its master record ...')
    print(goldstandard['masters'].loc[i[1]])
# Out:
# pair-------------------------------------> [0, 85]
# docid_x                                                     000311049
# 035liste_x                         [(OCoLC)731635279, (ABN)000539983]
# isbn_x                                            [978-3-15-020008-7]
# ttlpart_x                                  {'245': ['Emma', 'Roman']}
# pubyear_x                                                    2009
# decade_x                                                         2009
# century_x                                                        2009
# exactDate_x                                                  2009uuuu
# edition_x
# part_x                                                          20008
# pages_x                                                      [600 S.]
# volumes_x                                                         600
# pubinit_x                                                 reclam jun.
# pubword_x                                               [Reclam jun.]
# scale_x
# coordinate_x                                                       []
# doi_x
# ismn_x
# musicid_x
# coordinate_E_x
# coordinate_N_x
# corporate_110_x
# corporate_710_x
# corporate_full_x
# format_prefix_x                                                    bk
# format_postfix_x                                               020000
# person_100_x                                               austenjane
# person_700_x                              grawechristian, graweursula
# person_245c_x       jane austen ; aus dem englischen übersetzt von...
# ttlfull_245_x                                             emma, roman
# ttlfull_246_x
# masters_docid                                               504389793
# docid_y                                                     504389793
# 035liste_y          [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# isbn_y                                            [978-3-15-020008-7]
# ttlpart_y                                           {'245': ['Emma']}
# pubyear_y                                                    2009
# decade_y                                                         2009
# century_y                                                        2009
# exactDate_y                                                  2009uuuu
# edition_y
# part_y                                                          20008
# pages_y                                                      [600 S.]
# volumes_y                                                         600
# pubinit_y                                                      reclam
# pubword_y                                                    [Reclam]
# scale_y
# coordinate_y                                                       []
# doi_y
# ismn_y
# musicid_y
# coordinate_E_y
# coordinate_N_y
# corporate_110_y
# corporate_710_y
# corporate_full_y
# format_prefix_y                                                    bk
# format_postfix_y                                               020000
# person_100_y                                               austenjane
# person_700_y
# person_245c_y       jane austen ; aus dem engl. übers. von ursula ...
# ttlfull_245_y                                                    emma
# ttlfull_246_y
# Name: 0, dtype: object
#
# ... and its master record ...
# docid                                                     504389793
# 035liste          [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# isbn                                            [978-3-15-020008-7]
# ttlpart                                           {'245': ['Emma']}
# pubyear                                                    2009
# decade                                                         2009
# century                                                        2009
# exactDate                                                  2009uuuu
# edition
# part                                                          20008
# pages                                                      [600 S.]
# volumes                                                         600
# pubinit                                                      reclam
# pubword                                                    [Reclam]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                               austenjane
# person_700
# person_245c       jane austen ; aus dem engl. übers. von ursula ...
# ttlfull_245                                                    emma
# ttlfull_246
# Name: 85, dtype: object
#
# pair-------------------------------------> [1, 145]
# docid_x                                                     196506476
# 035liste_x                       [(OCoLC)731635279, (NEBIS)009587153]
# isbn_x                                            [978-3-15-020008-7]
# ttlpart_x                                           {'245': ['Emma']}
# pubyear_x                                                    2009
# decade_x                                                         2009
# century_x                                                        2009
# exactDate_x                                                  2009uuuu
# edition_x
# part_x                                                          20008
# pages_x                                                      [600 S.]
# volumes_x                                                         600
# pubinit_x                                                      reclam
# pubword_x                                                    [Reclam]
# scale_x
# coordinate_x                                                       []
# doi_x
# ismn_x
# musicid_x
# coordinate_E_x
# coordinate_N_x
# corporate_110_x
# corporate_710_x
# corporate_full_x
# format_prefix_x                                                    bk
# format_postfix_x                                               020000
# person_100_x                                               austenjane
# person_700_x
# person_245c_x       jane austen ; aus dem engl. übers. von ursula ...
# ttlfull_245_x                                                    emma
# ttlfull_246_x
# masters_docid                                               504389793
# docid_y                                                     504389793
# 035liste_y          [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# isbn_y                                            [978-3-15-020008-7]
# ttlpart_y                                           {'245': ['Emma']}
# pubyear_y                                                    2009
# decade_y                                                         2009
# century_y                                                        2009
# exactDate_y                                                  2009uuuu
# edition_y
# part_y                                                          20008
# pages_y                                                      [600 S.]
# volumes_y                                                         600
# pubinit_y                                                      reclam
# pubword_y                                                    [Reclam]
# scale_y
# coordinate_y                                                       []
# doi_y
# ismn_y
# musicid_y
# coordinate_E_y
# coordinate_N_y
# corporate_110_y
# corporate_710_y
# corporate_full_y
# format_prefix_y                                                    bk
# format_postfix_y                                               020000
# person_100_y                                               austenjane
# person_700_y
# person_245c_y       jane austen ; aus dem engl. übers. von ursula ...
# ttlfull_245_y                                                    emma
# ttlfull_246_y
# Name: 1, dtype: object
#
# ... and its master record ...
# docid                                                     504390597
# 035liste          [(IDSBB)003690925, (NEBIS)005645758, (RERO)R00...
# isbn                                                             []
# ttlpart           {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# pubyear                                                    2000
# decade                                                         2000
# century                                                        2000
# exactDate                                                  2000uuuu
# edition
# part
# pages                                      [1 DVD-Video (169 Min.)]
# volumes                                                       1 169
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid                                                         073
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     metropolitan operaorchestra, metropolitan oper...
# corporate_full    metropolitan operaorchestra, metropolitan oper...
# format_prefix                                                    vm
# format_postfix                                               010300
# person_100                                   mozartwolfgang amadeus
# person_700            schikanederemanuel, hockneydavid, levinejames
# person_245c            w. a. mozart ; libretto: emanuel schikaneder
# ttlfull_245         die zauberflöte, oper in zwei aufzügen : kv 620
# ttlfull_246
# Name: 145, dtype: object
#
# pair-------------------------------------> [2, 119]
# docid_x                                                     323173349
# 035liste_x                       [(OCoLC)731635279, (LIBIB)000315536]
# isbn_x                                            [978-3-15-020008-7]
# ttlpart_x                                  {'245': ['Emma', 'Roman']}
# pubyear_x                                                    2009
# decade_x                                                         2009
# century_x                                                        2009
# exactDate_x                                                  2009uuuu
# edition_x
# part_x                                                          20008
# pages_x                                                      [600 S.]
# volumes_x                                                         600
# pubinit_x                                                      reclam
# pubword_x                                                    [Reclam]
# scale_x
# coordinate_x                                                       []
# doi_x
# ismn_x
# musicid_x
# coordinate_E_x
# coordinate_N_x
# corporate_110_x
# corporate_710_x
# corporate_full_x
# format_prefix_x                                                    bk
# format_postfix_x                                               020000
# person_100_x                                               austenjane
# person_700_x
# person_245c_x                                             jane austen
# ttlfull_245_x                                             emma, roman
# ttlfull_246_x
# masters_docid                                               504389793
# docid_y                                                     504389793
# 035liste_y          [(NEBIS)009587153, (LIBIB)000315536, (ABN)0005...
# isbn_y                                            [978-3-15-020008-7]
# ttlpart_y                                           {'245': ['Emma']}
# pubyear_y                                                    2009
# decade_y                                                         2009
# century_y                                                        2009
# exactDate_y                                                  2009uuuu
# edition_y
# part_y                                                          20008
# pages_y                                                      [600 S.]
# volumes_y                                                         600
# pubinit_y                                                      reclam
# pubword_y                                                    [Reclam]
# scale_y
# coordinate_y                                                       []
# doi_y
# ismn_y
# musicid_y
# coordinate_E_y
# coordinate_N_y
# corporate_110_y
# corporate_710_y
# corporate_full_y
# format_prefix_y                                                    bk
# format_postfix_y                                               020000
# person_100_y                                               austenjane
# person_700_y
# person_245c_y       jane austen ; aus dem engl. übers. von ursula ...
# ttlfull_245_y                                                    emma
# ttlfull_246_y
# Name: 2, dtype: object
#
# ... and its master record ...
# docid                                                     50439018X
# 035liste          [(IDSBB)001651899, (NEBIS)001974886, (IDSSG)00...
# isbn                                                [3-495-47879-5]
# ttlpart           {'245': ['Der moralische Status der Tiere', 'H...
# pubyear                                                    1999
# decade                                                         1999
# century                                                        1999
# exactDate                                                  1999uuuu
# edition
# part                                                          57 57
# pages                                                      [316 S.]
# volumes                                                         316
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                             fluryandreas
# person_700
# person_245c                                           andreas flury
# ttlfull_245       der moralische status der tiere, henry salt, p...
# ttlfull_246
# Name: 119, dtype: object
#
# pair-------------------------------------> [3, 57]
# docid_x                                                     00130724X
# 035liste_x                         [(OCoLC)808324878, (ABN)000155059]
# isbn_x                                                             []
# ttlpart_x           {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# pubyear_x                                                    2000
# decade_x                                                         2000
# century_x                                                        2000
# exactDate_x                                                  2000uuuu
# edition_x
# part_x
# pages_x                  [1 DVD-Video, DVD Region 0, 169 Min., farb.]
# volumes_x                                                     1 0 169
# pubinit_x                                         deutsche grammophon
# pubword_x                                       [Deutsche Grammophon]
# scale_x
# coordinate_x                                                       []
# doi_x
# ismn_x
# musicid_x
# coordinate_E_x
# coordinate_N_x
# corporate_110_x
# corporate_710_x     metropolitan opera orchestra, metropolitan ope...
# corporate_full_x    metropolitan opera orchestra, metropolitan ope...
# format_prefix_x                                                    vm
# format_postfix_x                                               010300
# person_100_x                                          levinejamesdir.
# person_700_x        mozartwolfgang amadeus, levinejames, schikaned...
# person_245c_x       w. a. mozart ; libretto: emanuel schikaneder ;...
# ttlfull_245_x                  die zauberflöte, oper in zwei aufzügen
# ttlfull_246_x
# masters_docid                                               504390597
# docid_y                                                     504390597
# 035liste_y          [(IDSBB)003690925, (NEBIS)005645758, (RERO)R00...
# isbn_y                                                             []
# ttlpart_y           {'245': ['Die Zauberflöte', 'Oper in zwei Aufz...
# pubyear_y                                                    2000
# decade_y                                                         2000
# century_y                                                        2000
# exactDate_y                                                  2000uuuu
# edition_y
# part_y
# pages_y                                      [1 DVD-Video (169 Min.)]
# volumes_y                                                       1 169
# pubinit_y
# pubword_y                                                          []
# scale_y
# coordinate_y                                                       []
# doi_y
# ismn_y
# musicid_y                                                         073
# coordinate_E_y
# coordinate_N_y
# corporate_110_y
# corporate_710_y     metropolitan operaorchestra, metropolitan oper...
# corporate_full_y    metropolitan operaorchestra, metropolitan oper...
# format_prefix_y                                                    vm
# format_postfix_y                                               010300
# person_100_y                                   mozartwolfgang amadeus
# person_700_y            schikanederemanuel, hockneydavid, levinejames
# person_245c_y            w. a. mozart ; libretto: emanuel schikaneder
# ttlfull_245_y         die zauberflöte, oper in zwei aufzügen : kv 620
# ttlfull_246_y
# Name: 3, dtype: object
#
# ... and its master record ...
# docid                                                     504389513
# 035liste                         [(IDSBB)004654810, (ABN)000223912]
# isbn                                                             []
# ttlpart                                {'245': ['Die Zauberflöte']}
# pubyear                                                    1920
# decade                                                         1920
# century                                                        1920
# exactDate                                                  1920uuuu
# edition
# part
# pages                                                       [1 Bd.]
# volumes                                                           1
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100                                   mozartwolfgang amadeus
# person_700                                       schikanederemanuel
# person_245c       w. a. mozart ; oper in 2 akten v. emanuel schi...
# ttlfull_245                                         die zauberflöte
# ttlfull_246
# Name: 57, dtype: object

# %% [markdown]
# ### Duplicates Rows Generation

# %% [markdown]
# The rows with pairs of duplicates can now be built joining each slave record with each slave record, with the condition of the same $\texttt{masters}\_\texttt{docid}$.

# %%
def build_duplicate_pairs (df):
    """Builds-up all duplicate pairs, even with itself."""
    
    return pd.merge(left=df, right=df, how='inner',
                    left_on='masters_docid', right_on='masters_docid')

# %% [markdown]
# The records of duplicates are marked as duplicates immediately after pairing.

# %%
duplicates = build_duplicate_pairs(goldstandard['slaves'])
duplicates['duplicates'] = 1

print('Number of duplicate rows {:,d}'.format(len(duplicates)))
# Out:
# Number of duplicate rows 1,473

# %%
import random as rand

pd.options.display.max_rows = len(duplicates.columns)

duplicates.loc[rand.randrange(len(duplicates))]
# Out:
# docid_x                                                     017467683
# 035liste_x                         [(OCoLC)254941323, (BGR)000336877]
# isbn_x                                                [3-8067-5097-1]
# ttlpart_x           {'245': ['Die Reise der Pinguine', '[das Buch ...
# pubyear_x                                                    2005
# decade_x                                                         2005
# century_x                                                        2005
# exactDate_x                                                  2005uuuu
# edition_x
# part_x
# pages_x                                                       [64 S.]
# volumes_x                                                          64
# pubinit_x                                                 gerstenberg
# pubword_x                                               [Gerstenberg]
# scale_x
# coordinate_x                                                       []
# doi_x
# ismn_x
# musicid_x
# coordinate_E_x
# coordinate_N_x
# corporate_110_x
# corporate_710_x
# corporate_full_x
# format_prefix_x                                                    bk
# format_postfix_x                                               020000
# person_100_x                                               jacquetluc
# person_700_x
# person_245c_x                                             luc jacquet
# ttlfull_245_x             die reise der pinguine, [das buch zum film]
# ttlfull_246_x
# masters_docid                                               504390368
# docid_y                                                     017467683
# 035liste_y                         [(OCoLC)254941323, (BGR)000336877]
# isbn_y                                                [3-8067-5097-1]
# ttlpart_y           {'245': ['Die Reise der Pinguine', '[das Buch ...
# pubyear_y                                                    2005
# decade_y                                                         2005
# century_y                                                        2005
# exactDate_y                                                  2005uuuu
# edition_y
# part_y
# pages_y                                                       [64 S.]
# volumes_y                                                          64
# pubinit_y                                                 gerstenberg
# pubword_y                                               [Gerstenberg]
# scale_y
# coordinate_y                                                       []
# doi_y
# ismn_y
# musicid_y
# coordinate_E_y
# coordinate_N_y
# corporate_110_y
# corporate_710_y
# corporate_full_y
# format_prefix_y                                                    bk
# format_postfix_y                                               020000
# person_100_y                                               jacquetluc
# person_700_y
# person_245c_y                                             luc jacquet
# ttlfull_245_y             die reise der pinguine, [das buch zum film]
# ttlfull_246_y
# duplicates                                                          1
# Name: 322, dtype: object

# %% [markdown]
# On joining the raw data to pairs, the column names have been duplicated and changed. This must be reflected in the metadata.

# %%
# Target is the first necessary column
columns_metadata_dict['columns_to_use'] = ['duplicates']

# After join with itself, the data has _x and _y attributes
for i in columns_metadata_dict['data_analysis_columns']:
    for j in ['_x', '_y']:
        columns_metadata_dict['columns_to_use'].append(i+j)

# %% [markdown]
# ## Build Pairs of Uniques

# %%
for i in range(len(goldstandard['uniques'])):
    if len(goldstandard['masters'][goldstandard['masters'].docid == goldstandard['uniques'].docid.loc[i]]) > 0 :
        print('STOP!')
        break

# %% [markdown]
# The silence of the code cell above shows that there is no record in file $\texttt{master.json}$ that has the same $\texttt{docid}$ like any record in file $\texttt{unique.json}$.

# %% [markdown]
# ### Masters Uniques Relationships

# %% [markdown]
# The investigations above have shown that relationships between records are expressed with the same value in attribute $\texttt{035liste}$. To find records of the uniques file that are duplicates of records of the masters file, the values of attributes $\texttt{035liste}$ have to be compared.

# %%
masters_uniques_duplicates = {'master' : [], 'unique' : [], 'slave' : {}}

for i in range(len(goldstandard['masters'])):
    for j in range(len(goldstandard['masters']['035liste'][i])):
        for k in range(len(goldstandard['uniques'])):
            if goldstandard['masters']['035liste'][i][j] in goldstandard['uniques']['035liste'][k]:
#                print('master', i, 'has relationship to unique', k)
                masters_uniques_duplicates['master'].append(i)
                masters_uniques_duplicates['unique'].append(k)
print()
for i in set(masters_uniques_duplicates['master']):
    masters_uniques_duplicates['slave'].update({i : []})
    for j in range(len(goldstandard['masters']['035liste'][i])):
        for k in range(len(goldstandard['slaves'])):
            if goldstandard['masters']['035liste'][i][j] in goldstandard['slaves']['035liste'][k]:
#                print('master', i, 'has relationship to slave', k)
                masters_uniques_duplicates['slave'][i].append(k)
                
masters_uniques_duplicates
# Out:
# {'master': [92, 121, 121],
#  'unique': [473, 458, 474],
#  'slave': {121: [358, 346, 345, 351, 346, 351],
#   92: [267, 272, 286, 303, 267, 267, 272, 303]}}

# %% [markdown]
# This result is surprising. The above code reveals that three unique records have relationships to a master record. Even worse but at least consistent, the affected master records also have relationships to some slave records. Is it true that they are duplicates?

# %%
pd.options.display.max_rows = len(slave_master.columns)

for i in range(len(masters_uniques_duplicates['master'])):
    print('\npair------------------------------------->', 
          masters_uniques_duplicates['master'][i], masters_uniques_duplicates['unique'][i]
         )
    print(goldstandard['masters'].loc[masters_uniques_duplicates['master'][i]], '\n')
    print('... and its master record ...')
    print(goldstandard['uniques'].loc[masters_uniques_duplicates['unique'][i]], '\n')
    print('... and its slave records ...')
    for j in masters_uniques_duplicates['slave'][masters_uniques_duplicates['master'][i]]:
        print(goldstandard['slaves'].loc[j], '\n')
# Out:
# pair-------------------------------------> 92 473
# docid                                                     504389866
# 035liste          [(IDSBB)006207118, (NEBIS)010150430, (RERO)R00...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                      [158 S.]
# volumes                                                         158
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# Name: 92, dtype: object
#
# ... and its master record ...
# docid                                                     404685048
# 035liste                       [(IDSLU)001264875, (OCoLC)871188367]
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                              [XI, 158 Seiten]
# volumes                                                         158
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# Name: 473, dtype: object
#
# ... and its slave records ...
# docid                                                     312073232
# 035liste          [(OCoLC)871188367, (IDSBB)006207118, (DE-599)D...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                      [158 S.]
# volumes                                                         158
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 267, dtype: object
#
# docid                                                     316725951
# 035liste          [(OCoLC)871188367, (NEBIS)010150430, (OCoLC)87...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                  [XI, 158 S.]
# volumes                                                         158
# pubinit                                                 springer vs
# pubword                                               [Springer VS]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 272, dtype: object
#
# docid                                                     333126866
# 035liste                                         [(RERO)R008122523]
# isbn                                            [978-3-642-41697-2]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                  [XI, 158 S.]
# volumes                                                         158
# pubinit                                                 springer vs
# pubword                                               [Springer VS]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 286, dtype: object
#
# docid                                                     341222542
# 035liste          [(OCoLC)871188367, (IDSSG)000839244, (OCoLC)87...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                  [XI, 158 S.]
# volumes                                                         158
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 303, dtype: object
#
# docid                                                     312073232
# 035liste          [(OCoLC)871188367, (IDSBB)006207118, (DE-599)D...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                      [158 S.]
# volumes                                                         158
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 267, dtype: object
#
# docid                                                     312073232
# 035liste          [(OCoLC)871188367, (IDSBB)006207118, (DE-599)D...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                      [158 S.]
# volumes                                                         158
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 267, dtype: object
#
# docid                                                     316725951
# 035liste          [(OCoLC)871188367, (NEBIS)010150430, (OCoLC)87...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                  [XI, 158 S.]
# volumes                                                         158
# pubinit                                                 springer vs
# pubword                                               [Springer VS]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 272, dtype: object
#
# docid                                                     341222542
# 035liste          [(OCoLC)871188367, (IDSSG)000839244, (OCoLC)87...
# isbn                             [978-3-642-41697-2, 3-642-41697-7]
# ttlpart           {'245': ['Empirische Bildungsforschung', 'aktu...
# pubyear                                                    2014
# decade                                                         2014
# century                                                        2014
# exactDate                                                  2014uuuu
# edition
# part
# pages                                                  [XI, 158 S.]
# volumes                                                         158
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                            spinathbirgit
# person_245c                                  birgit spinath (hrsg.)
# ttlfull_245       empirische bildungsforschung, aktuelle themen ...
# ttlfull_246
# masters_docid                                             504389866
# Name: 303, dtype: object
#
#
# pair-------------------------------------> 121 458
# docid                                                     504390201
# 035liste          [(RERO)R008499625, (NEBIS)010734165, (BGR)0006...
# isbn                             [3-290-20138-4, 978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     trägerverein 600 jahre niklaus von flüe 1417-2017
# corporate_full    trägerverein 600 jahre niklaus von flüe 1417-2017
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                            gröbliroland, achermannwalter
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# Name: 121, dtype: object
#
# ... and its master record ...
# docid                                                     366417150
# 035liste          [(OCoLC)951113986, (IDSBB)006619280, (OCoLC)95...
# isbn                             [978-3-290-20138-8, 3-290-20138-4]
# ttlpart           {'245': ['Mystiker - Mittler - Mensch', '600 J...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     bruder-klausen-stiftung, trägerverein 600 jahr...
# corporate_full    bruder-klausen-stiftung, trägerverein 600 jahr...
# format_prefix                                                    bk
# format_postfix                                               020400
# person_100
# person_700        gröbliroland, kronenbergheidi, riesmarkus, wal...
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker - mittler - mensch, 600 jahre niklaus...
# ttlfull_246
# Name: 458, dtype: object
#
# ... and its slave records ...
# docid                                                     404633099
# 035liste                                         [(RERO)R008499625]
# isbn                             [3-290-20138-4, 978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     trägerverein 600 jahre niklaus von flüe 1417-2017
# corporate_full    trägerverein 600 jahre niklaus von flüe 1417-2017
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                            gröbliroland, achermannwalter
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 358, dtype: object
#
# docid                                                     380205769
# 035liste          [(OCoLC)951113986, (NEBIS)010734165, (OCoLC)95...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker, Mittler, Mensch', '600 Jah...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700        gröbliroland, kronenbergheidi, riesmarkus, wal...
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker, mittler, mensch, 600 jahre niklaus v...
# ttlfull_246
# masters_docid                                             504390201
# Name: 346, dtype: object
#
# docid                                                     375482563
# 035liste                         [(OCoLC)964366899, (BGR)000660651]
# isbn                             [978-3-290-20138-8, 3-290-20138-4]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                      [388 S.]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                            gröbliroland, achermannwalter
# person_245c       roland gröbli ... [et al.] (hrsg.) ; mit beitr...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 345, dtype: object
#
# docid                                                     404109071
# 035liste          [(OCoLC)951113986, (ABN)000804056, (OCoLC)9511...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                      [388 S.]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                             gröbliroland
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 351, dtype: object
#
# docid                                                     380205769
# 035liste          [(OCoLC)951113986, (NEBIS)010734165, (OCoLC)95...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker, Mittler, Mensch', '600 Jah...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700        gröbliroland, kronenbergheidi, riesmarkus, wal...
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker, mittler, mensch, 600 jahre niklaus v...
# ttlfull_246
# masters_docid                                             504390201
# Name: 346, dtype: object
#
# docid                                                     404109071
# 035liste          [(OCoLC)951113986, (ABN)000804056, (OCoLC)9511...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                      [388 S.]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                             gröbliroland
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 351, dtype: object
#
#
# pair-------------------------------------> 121 474
# docid                                                     504390201
# 035liste          [(RERO)R008499625, (NEBIS)010734165, (BGR)0006...
# isbn                             [3-290-20138-4, 978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     trägerverein 600 jahre niklaus von flüe 1417-2017
# corporate_full    trägerverein 600 jahre niklaus von flüe 1417-2017
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                            gröbliroland, achermannwalter
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# Name: 121, dtype: object
#
# ... and its master record ...
# docid                                                     404845843
# 035liste          [(OCoLC)951113986, (SGBN)001375035, (OCoLC)951...
# isbn                             [978-3-290-20138-8, 3-290-20138-4]
# ttlpart           {'245': ['Mystiker, Mittler, Mensch', '600 Jah...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [280 Seiten]
# volumes                                                         280
# pubinit                            tvz, theologischer verlag zürich
# pubword                          [TVZ, Theologischer Verlag Zürich]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710             trägerverein «600 jahre niklaus von flüe»
# corporate_full            trägerverein «600 jahre niklaus von flüe»
# format_prefix                                                    bk
# format_postfix                                               020400
# person_100
# person_700                  gröbliroland, achermannwalter, nikolaus
# person_245c       hrsg. für den trägerverein 600 jahre nikolaus ...
# ttlfull_245       mystiker, mittler, mensch, 600 jahre niklaus v...
# ttlfull_246
# Name: 474, dtype: object
#
# ... and its slave records ...
# docid                                                     404633099
# 035liste                                         [(RERO)R008499625]
# isbn                             [3-290-20138-4, 978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710     trägerverein 600 jahre niklaus von flüe 1417-2017
# corporate_full    trägerverein 600 jahre niklaus von flüe 1417-2017
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                            gröbliroland, achermannwalter
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 358, dtype: object
#
# docid                                                     380205769
# 035liste          [(OCoLC)951113986, (NEBIS)010734165, (OCoLC)95...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker, Mittler, Mensch', '600 Jah...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700        gröbliroland, kronenbergheidi, riesmarkus, wal...
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker, mittler, mensch, 600 jahre niklaus v...
# ttlfull_246
# masters_docid                                             504390201
# Name: 346, dtype: object
#
# docid                                                     375482563
# 035liste                         [(OCoLC)964366899, (BGR)000660651]
# isbn                             [978-3-290-20138-8, 3-290-20138-4]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                      [388 S.]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                            gröbliroland, achermannwalter
# person_245c       roland gröbli ... [et al.] (hrsg.) ; mit beitr...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 345, dtype: object
#
# docid                                                     404109071
# 035liste          [(OCoLC)951113986, (ABN)000804056, (OCoLC)9511...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                      [388 S.]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                             gröbliroland
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 351, dtype: object
#
# docid                                                     380205769
# 035liste          [(OCoLC)951113986, (NEBIS)010734165, (OCoLC)95...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker, Mittler, Mensch', '600 Jah...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                  [388 Seiten]
# volumes                                                         388
# pubinit
# pubword                                                          []
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700        gröbliroland, kronenbergheidi, riesmarkus, wal...
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker, mittler, mensch, 600 jahre niklaus v...
# ttlfull_246
# masters_docid                                             504390201
# Name: 346, dtype: object
#
# docid                                                     404109071
# 035liste          [(OCoLC)951113986, (ABN)000804056, (OCoLC)9511...
# isbn                                            [978-3-290-20138-8]
# ttlpart           {'245': ['Mystiker Mittler Mensch', '600 Jahre...
# pubyear                                                    2016
# decade                                                         2016
# century                                                        2016
# exactDate                                                  2016uuuu
# edition
# part
# pages                                                      [388 S.]
# volumes                                                         388
# pubinit                                         edition nzn bei tvz
# pubword                                       [Edition NZN bei TVZ]
# scale
# coordinate                                                       []
# doi
# ismn
# musicid
# coordinate_E
# coordinate_N
# corporate_110
# corporate_710
# corporate_full
# format_prefix                                                    bk
# format_postfix                                               020000
# person_100
# person_700                                             gröbliroland
# person_245c       herausgegeben für den trägerverein 600 jahre n...
# ttlfull_245       mystiker mittler mensch, 600 jahre niklaus von...
# ttlfull_246
# masters_docid                                             504390201
# Name: 351, dtype: object

# %% [markdown]
# The visual check confirms that the status of duplicates are given for the pairs of records in uniques and slaves. Therefore, these records must be excluded from the pairing of rows to records of uniques.

# %% [markdown]
# ### Uniqes Rows Generation

# %% [markdown]
# To build pairs of uniques of the goldstandard, all records of slaves are joined with all records of uniques, except for the records that will produce duplicates shown in the previous subsection.

# %%
df_s_1 = goldstandard['slaves']
df_u_1 = goldstandard['uniques'].copy() # Do not modify original data.

# Exclude duplication candidates from above
df_u_1.drop(index=masters_uniques_duplicates['unique'], inplace=True)
#display(df_u_1.loc[masters_uniques_duplicates['unique']])

df_s_1['duplicates'] = 0
df_u_1['duplicates'] = 0
# Full join, Cartesian product
non_duplicates = pd.merge(df_s_1, df_u_1, on='duplicates')

print('Number of slave records : {:,d}, number of unique records : {:,d}, expected pairs : {:,d} = joined pairs : {:,d}'.format(
    len(df_s_1), len(df_u_1), len(df_s_1)*len(df_u_1), len(non_duplicates)))
# Out:
# Number of slave records : 435, number of unique records : 593, expected pairs : 257,955 = joined pairs : 257,955

# %%
pd.options.display.max_rows = len(non_duplicates.columns)

non_duplicates.loc[rand.randrange(len(non_duplicates))]
# Out:
# docid_x                                                     156459280
# 035liste_x                        [(OCoLC)82668726, (NEBIS)004325390]
# isbn_x                                                             []
# ttlpart_x           {'245': ['Die Zauberflöte', 'eine deutsche Ope...
# pubyear_x                                                    1970
# decade_x                                                         1970
# century_x                                                        1970
# exactDate_x                                                  1970uuuu
# edition_x
# part_x
# pages_x                                             [1 Klavierauszug]
# volumes_x                                                           1
# pubinit_x                                                 bärenreiter
# pubword_x                                               [Bärenreiter]
# scale_x
# coordinate_x                                                       []
# doi_x
# ismn_x
# musicid_x                                                        4553
# coordinate_E_x
# coordinate_N_x
# corporate_110_x
# corporate_710_x
# corporate_full_x
# format_prefix_x                                                    mu
# format_postfix_x                                               010200
# person_100_x                                   mozartwolfgang amadeus
# person_700_x             moehnheinz, schikanederemanuel, grubergernot
# person_245c_x       text von emanuel schikaneder ; [musik von] wol...
# ttlfull_245_x       die zauberflöte, eine deutsche oper in zwei au...
# ttlfull_246_x
# masters_docid                                               504389092
# duplicates                                                          0
# docid_y                                                     485323974
# 035liste_y                                         [(RERO)R008667898]
# isbn_y                                            [978-0-7294-1147-9]
# ttlpart_y           {'245': ['The complete works of Voltaire', 'Si...
# pubyear_y                                                    2017
# decade_y                                                         2017
# century_y                                                        2017
# exactDate_y                                                  2017uuuu
# edition_y
# part_y                                                             12
# pages_y                                                      [527 p.]
# volumes_y                                                         527
# pubinit_y                                         voltaire foundation
# pubword_y                                       [Voltaire Foundation]
# scale_y
# coordinate_y                                                       []
# doi_y
# ismn_y
# musicid_y
# coordinate_E_y
# coordinate_N_y
# corporate_110_y
# corporate_710_y
# corporate_full_y
# format_prefix_y                                                    bk
# format_postfix_y                                               020000
# person_100_y                                                 voltaire
# person_700_y                                           venturinodiego
# person_245c_y       sous la dir. de diego venturino = [les oeuvres...
# ttlfull_245_y       the complete works of voltaire, siècle de loui...
# ttlfull_246_y
# Name: 94209, dtype: object

# %% [markdown]
# The number of records of pairs of uniques shown above, is that big that no further records of pairs of uniques for training and testing purposes are needed. For this reason, joining the records of uniques with themselves will be ommitted and the pairs generated so far will be taken as they are.

# %% [markdown]
# ## Build Feature Base

# %% [markdown]
# The rows with pairs of duplicates and the rows with pairs of uniques resulting from above, can be concatenated to a DataFrame which will be the basis for further processing into the feature matrix.

# %%
df_feature_base = pd.concat([duplicates, non_duplicates], sort=True)
# Set unique values on index
df_feature_base.reset_index(inplace=True, drop=True)

print('Number of rows with pairs of uniques :\t\t{:,d}'.format(len(df_feature_base[df_feature_base.duplicates==0])))
print('Number of rows with pairs of duplicates :\t{:,d}'.format(len(df_feature_base[df_feature_base.duplicates==1])))
# Out:
# Number of rows with pairs of uniques :		257,955
# Number of rows with pairs of duplicates :	1,473

# %% [markdown]
# ## Summary

# %% [markdown]
# The result of this chapter is a deep understanding of Swissbib's goldstandard data and how to produce pairs of rows which represent duplicates and pairs of rows which represent uniques. After generating the pairs of duplicates and the pairs of uniques, the following ratio is in the data set that will be used for training the machine learning models.

# %%
print('ratio of uniques :\t{:.2f} %\nratio of duplicates :\t{:.2f} %'.format(
    df_feature_base.duplicates.value_counts(normalize=True).loc[0]*100,
    df_feature_base.duplicates.value_counts(normalize=True).loc[1]*100))
# Out:
# ratio of uniques :	99.43 %
# ratio of duplicates :	0.57 %

# %% [markdown]
# Besides the data with rows of uniques and duplicates, the metadata of the project have been updated. After this chapter, the metadata look like seen as the result of the following lines of code.

# %%
for k in columns_metadata_dict.keys():
    print(k, '\n', columns_metadata_dict[k], '\n')
# Out:
# data_analysis_columns
#  ['coordinate_E', 'coordinate_N', 'corporate_full', 'doi', 'edition', 'exactDate', 'format_prefix', 'format_postfix', 'isbn', 'ismn', 'musicid', 'part', 'person_100', 'person_700', 'person_245c', 'pubinit', 'scale', 'ttlfull_245', 'ttlfull_246', 'volumes']
#
# columns_to_use
#  ['duplicates', 'coordinate_E_x', 'coordinate_E_y', 'coordinate_N_x', 'coordinate_N_y', 'corporate_full_x', 'corporate_full_y', 'doi_x', 'doi_y', 'edition_x', 'edition_y', 'exactDate_x', 'exactDate_y', 'format_prefix_x', 'format_prefix_y', 'format_postfix_x', 'format_postfix_y', 'isbn_x', 'isbn_y', 'ismn_x', 'ismn_y', 'musicid_x', 'musicid_y', 'part_x', 'part_y', 'person_100_x', 'person_100_y', 'person_700_x', 'person_700_y', 'person_245c_x', 'person_245c_y', 'pubinit_x', 'pubinit_y', 'scale_x', 'scale_y', 'ttlfull_245_x', 'ttlfull_245_y', 'ttlfull_246_x', 'ttlfull_246_y', 'volumes_x', 'volumes_y']

# %% [markdown]
# The data handover for the next chapter still needs to done.

# %% [markdown]
# ### Goldstandard DataFrame Handover

# %% [markdown]
# For further processing in the next chapters, the metadata dictionary and the resulting feature base DataFrame of this chapter need to be persisted. Both will be restored and used in upcoming chapters. The DataFrame developped in this chapter is saved into a pickle file.

# %%
import pickle as pk

# Binary intermediary metadata file
with open(os.path.join(path_goldstandard,
                       'columns_metadata.pkl'), 'wb') as dict_output_file:
    pk.dump(columns_metadata_dict, dict_output_file)

# Binary intermediary DataFrame file for feature matrix generation
with open(os.path.join(path_goldstandard, 'feature_base_df.pkl'), 'wb') as df_output_file:
    pk.dump(df_feature_base, df_output_file)

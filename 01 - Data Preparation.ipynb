# %% [markdown]
# # Load data

# %%
import json
import pandas as pd

# %% [markdown]
# ## The file with big amount of data

# %% [markdown]
# Reading the data with pandas library, generates an error.

# %%
records = []
for line in open('./data/job7r4A1.json', 'r'):
    records.append(json.loads(line))

len(records)
# Out:
# 183407

# %%
records[0]
# Out:
# {'isbn': '',
#  'ttlfull': ['Die Feist von Kienberg',
#   'eine Wasenmeisterfamilie im Ancien Régime zwischen Ehrbarkeit und Delinquenz'],
#  'ttlpart': ['Die Feist von Kienberg',
#   'eine Wasenmeisterfamilie im Ancien Régime zwischen Ehrbarkeit und Delinquenz'],
#  'person': ['Schluchter', 'André', 'André Schluchter'],
#  'corporate': [],
#  'pubyear': '',
#  'decade': '12',
#  'century': '12',
#  'exactDate': '',
#  'edition': '',
#  'part': [],
#  'pages': [],
#  'volumes': 'S. 102-114',
#  'pubinit': '',
#  'pubword': [],
#  'scale': '',
#  'coordinate': [],
#  'doi': '',
#  'ismn': '',
#  'musicid': '',
#  'format': 'BK020000'}

# %%
df = pd.DataFrame(records)

# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(df.columns)

df.head()
# Out:
#    century coordinate corporate   decade doi edition exactDate    format isbn  \
# 0       12         []        []       12                        BK020000
# 1   123456         []        []   123456                        BK020000
# 2      123         []        []      123                        BK020000
# 3  1234567         []        []  1234567                        BK020000
# 4        1         []        []        1                        BK020000
#
#   ismn musicid pages part                                             person  \
# 0                 []   []              [Schluchter, André, André Schluchter]
# 1                 []   []              [Naegeli, Werner, von Werner Naegeli]
# 2                 []   []  [Kelly, M.V., Geniesse, J.B., M.V. Kelly et J....
# 3                 []   []                                [Wegelin, Walter, ]
# 4                 []   []  [Oberlin, Urs, Urs Oberlin ; translated from t...
#
#   pubinit pubword pubyear scale  \
# 0              []
# 1              []
# 2              []
# 3              []
# 4              []
#
#                                              ttlfull  \
# 0  [Die Feist von Kienberg, eine Wasenmeisterfami...
# 1                                       [Reimereien]
# 2  [Efficax antidotum ad matrimonia mixta praecav...
# 3  [Probleme der Inflationsbekämpfung, Referat vo...
# 4                                          [[Poems]]
#
#                                              ttlpart     volumes
# 0  [Die Feist von Kienberg, eine Wasenmeisterfami...  S. 102-114
# 1                                       [Reimereien]       43 S.
# 2  [Efficax antidotum ad matrimonia mixta praecav...       75 p.
# 3  [Probleme der Inflationsbekämpfung, Referat vo...       24 S.
# 4                                          [[Poems]]    p. 14-15

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## General functions

# %%
def information_filled (d, column_name, filled, empty):

    print('Number of records with filled {:s} {:d}, with missing {:s} {:d} => {:.1f}%'.format(
        column_name, len(filled), column_name, len(empty),
        100*len(filled)/(len(empty)+len(filled))
    ))

    if len(empty) > 0:
        print('\nEMPTY - index', empty[0], '\n')
        print(d.loc[empty[0]])
    else:
        print('\nEMPTY - None')
    print('\nFILLED - index', filled[0], '\n')
    print(d.loc[filled[0]])

    return

# %%
def find_empty_in_column (dataFrame, column_name):

    compare, anti_compare = comparison_logic(column_name)

    idx_filled = dataFrame[dataFrame[column_name].apply(compare)].index
    idx_empty = dataFrame[dataFrame[column_name].apply(anti_compare)].index

    information_filled(dataFrame, column_name, idx_filled, idx_empty)

    return idx_filled, idx_empty

# %%
# The dictionary of compare logics

list_columns = ['coordinate', 'corporate', 'pages', 'part', 'pubword',
                'ttlfull', 'ttlpart']
array_of_strings_columns = ['person']
strings_columns = ['century', 'doi', 'edition', 'exactDate', 'format', 'isbn',
                   'ismn', 'musicid', 'pubinit', 'pubyear', 'scale', 'volumes']

def comparison_logic (column_name):
    if column_name in (list_columns):
        # Lists
        compare = lambda col: col!=[]
        anti_compare = lambda col: col==[]
    elif column_name in (strings_columns):
        # Strings
        compare = lambda col: col!=''
        anti_compare = lambda col: col==''
    elif column_name in (array_of_strings_columns):
        # Array of Strings
        compare = lambda col: col!=['']
        anti_compare = lambda col: col==['']

    return compare, anti_compare

# %% [markdown]
# ## Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183407 entries, 0 to 183406
# Data columns (total 21 columns):
# century       183407 non-null object
# coordinate    183407 non-null object
# corporate     183407 non-null object
# decade        183407 non-null object
# doi           183407 non-null object
# edition       183407 non-null object
# exactDate     183407 non-null object
# format        183407 non-null object
# isbn          183407 non-null object
# ismn          183407 non-null object
# musicid       183407 non-null object
# pages         183407 non-null object
# part          183407 non-null object
# person        183407 non-null object
# pubinit       183407 non-null object
# pubword       183407 non-null object
# pubyear       183407 non-null object
# scale         183407 non-null object
# ttlfull       183407 non-null object
# ttlpart       183407 non-null object
# volumes       183407 non-null object
# dtypes: object(21)
# memory usage: 29.4+ MB

# %%
cols = df.columns
cols
# Out:
# Index(['century', 'coordinate', 'corporate', 'decade', 'doi', 'edition',
#        'exactDate', 'format', 'isbn', 'ismn', 'musicid', 'pages', 'part',
#        'person', 'pubinit', 'pubword', 'pubyear', 'scale', 'ttlfull',
#        'ttlpart', 'volumes'],
#       dtype='object')

# %% [markdown]
# ### Century

# %%
df.century.unique()
# Out:
# array(['12', '123456', '123', '1234567', '1', '', '12345', 'u', '1234',
#        '123456789', '12345678',
#        '123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu',
#        '2345678', '23', '23456789', '23456', '234', '2345', '234567', '2',
#        '23456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu'],
#       dtype=object)

# %%
idx_century_filled, idx_century_empty = find_empty_in_column(df, 'century')
# Out:
# Number of records with filled century 166478, with missing century 16929 => 90.8%
#
# EMPTY - index 6
#
# century
# coordinate                                                   []
# corporate              [Christkatholische Kirchgemeinde (Bern)]
# decade
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                                                       []
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Gedanken zur Jubiläumsfeier der Christkatholi...
# ttlpart       [Gedanken zur Jubiläumsfeier der Christkatholi...
# volumes                                                   48 S.
# Name: 6, dtype: object
#
# FILLED - index 0
#
# century                                                      12
# coordinate                                                   []
# corporate                                                    []
# decade                                                       12
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                    [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart       [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                              S. 102-114
# Name: 0, dtype: object

# %% [markdown]
# => Frage in OneNote.

# %% [markdown]
# ### Coordinate

# %%
idx_coordinate_filled, idx_coordinate_empty = find_empty_in_column(df, 'coordinate')
# Out:
# Number of records with filled coordinate 730, with missing coordinate 182677 => 0.4%
#
# EMPTY - index 0
#
# century                                                      12
# coordinate                                                   []
# corporate                                                    []
# decade                                                       12
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                    [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart       [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                              S. 102-114
# Name: 0, dtype: object
#
# FILLED - index 1801
#
# century                                                     123
# coordinate                                 [E0035400, N0532700]
# corporate                                                    []
# decade                                                      123
# doi
# edition                                               Facsimile
# exactDate                                                  1234
# format                                                 MP010300
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person        [Blaeu, Willem Janszoon, 1571-1638, (DE-588)11...
# pubinit
# pubword                                                      []
# pubyear                                                    1234
# scale                                                    400000
# ttlfull       [Nova descriptio Comitatus Hollandiæ, Niewe be...
# ttlpart       [Nova descriptio Comitatus Hollandiæ, Niewe be...
# volumes                                                 1 Karte
# Name: 1801, dtype: object

# %% [markdown]
# For $\texttt{df.volumes}$, see [Volumes](#volumes).

# %%
df.coordinate.loc[idx_coordinate_filled].str[0].str[0].unique()
# Out:
# array(['E', 'W'], dtype=object)

# %%
df.coordinate.loc[idx_coordinate_filled].str[1].str[0].unique()
# Out:
# array(['N', 'E', 'S'], dtype=object)

# %%
df.coordinate.loc[idx_coordinate_filled].str[2].str[0].unique()
# Out:
# array([nan, 'N', 'W', 'E'], dtype=object)

# %%
df.coordinate.loc[idx_coordinate_filled].str[3].str[0].unique()
# Out:
# array([nan, 'N'], dtype=object)

# %%
df.coordinate.loc[idx_coordinate_filled].str[4].str[0].unique()
# Out:
# array([nan, 'N'], dtype=object)

# %%
df.coordinate.loc[idx_coordinate_filled].str[5].str[0].unique()
# Out:
# array([nan, 'N'], dtype=object)

# %%
df.loc[idx_coordinate_filled][df.coordinate.loc[idx_coordinate_filled].str[5].str[0] == 'N']
# Out:
#        century                                         coordinate  \
# 104201  234567  [W1244400, E1722600, W1603200, N0492400, N0712...
# 136954       1  [E0083620, E0083624, E0083624, N0462105, N0462...
#
#                                         corporate  decade doi  \
# 104201         [Reise Know-How Verlag Peter Rump]  234567
# 136954  [Schweiz, Bundesamt für Landestopografie]       1
#
#                             edition exactDate    format           isbn ismn  \
# 104201                               23456789  MP010300
# 136954  Aggiornamento completo 1989            MP010300  3-302-01292-6
#
#        musicid                                              pages  \
# 104201                                                         []
# 136954          [f. 1292, ed. 1989, 1292,1991, 1292,1991, 1292...
#
#                                                      part person pubinit  \
# 104201                                                 []     []
# 136954  [f. 1292, ed. 1989, 1292,1991, 1292,1991, 1292...     []
#
#        pubword   pubyear                       scale   ttlfull   ttlpart  \
# 104201      []  23456789  50000012500002000000200000     [USA]     [USA]
# 136954      []                       250002500025000  [Maggia]  [Maggia]
#
#         volumes
# 104201   Karten
# 136954  1 Karte

# %% [markdown]
# ### Corporate<a id='corporate'></a>

# %%
df.corporate.head()
# Out:
# 0    []
# 1    []
# 2    []
# 3    []
# 4    []
# Name: corporate, dtype: object

# %%
idx_corporate_filled, idx_corporate_empty = find_empty_in_column(df, 'corporate')
# Out:
# Number of records with filled corporate 33166, with missing corporate 150241 => 18.1%
#
# EMPTY - index 0
#
# century                                                      12
# coordinate                                                   []
# corporate                                                    []
# decade                                                       12
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                    [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart       [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                              S. 102-114
# Name: 0, dtype: object
#
# FILLED - index 6
#
# century
# coordinate                                                   []
# corporate              [Christkatholische Kirchgemeinde (Bern)]
# decade
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                                                       []
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Gedanken zur Jubiläumsfeier der Christkatholi...
# ttlpart       [Gedanken zur Jubiläumsfeier der Christkatholi...
# volumes                                                   48 S.
# Name: 6, dtype: object

# %% [markdown]
# For $\texttt{df.person}$, see [Person](#person).

# %% [markdown]
# ### Decade

# %%
df.decade.unique()
# Out:
# array(['12', '123456', '123', '1234567', '1', '', '12345', 'u', '1234',
#        '123456789', '12345678',
#        '123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu',
#        '2345678', '23', '23456789', '23456', '234', '2345', '234567', '2',
#        '23456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu'],
#       dtype=object)

# %%
df[df.century != df.decade]
# Out:
# Empty DataFrame
# Columns: [century, coordinate, corporate, decade, doi, edition, exactDate, format, isbn, ismn, musicid, pages, part, person, pubinit, pubword, pubyear, scale, ttlfull, ttlpart, volumes]
# Index: []

# %% [markdown]
# ### Doi

# %%
df.doi[0]
# Out:
# ''

# %%
idx_doi_filled, idx_doi_empty = find_empty_in_column (df, 'doi')
# Out:
# Number of records with filled doi 19490, with missing doi 163917 => 10.6%
#
# EMPTY - index 0
#
# century                                                      12
# coordinate                                                   []
# corporate                                                    []
# decade                                                       12
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                    [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart       [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                              S. 102-114
# Name: 0, dtype: object
#
# FILLED - index 1791
#
# century                                                      23
# coordinate                                                   []
# corporate                                                    []
# decade                                                       23
# doi                                               9790201326702
# edition              Überarbeitete AuflagePartituur und Stimmen
# exactDate
# format                                                 MU010100
# isbn                             978-3-940069-36-83-940069-36-1
# ismn                                              9790201326702
# musicid                                                VHR 3840
# pages                                        [Streichorchester]
# part                                         [Streichorchester]
# person        [Holzer-Rhomberg, Andrea, 1970-, (DE-588)13540...
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Fiedel-Max, Besetzung: Violine 1, Violine 2, ...
# ttlpart       [Fiedel-Max, Besetzung: Violine 1, Violine 2, ...
# volumes                                  1 Partitur (20 Seiten)
# Name: 1791, dtype: object

# %%
df.doi.unique()
# Out:
# array(['', '9790201326702', 'M500173793', ...,
#        '10.5167/uzh-16927810.1080/03003930.2019.1584557',
#        '10.5167/uzh-169338', '10.1093/eurheartj/ehz068'], dtype=object)

# %% [markdown]
# ### Edition

# %%
df.edition[0]
# Out:
# ''

# %%
idx_edition_filled, idx_edition_empty = find_empty_in_column (df, 'edition')
# Out:
# Number of records with filled edition 25352, with missing edition 158055 => 13.8%
#
# EMPTY - index 0
#
# century                                                      12
# coordinate                                                   []
# corporate                                                    []
# decade                                                       12
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                    [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart       [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                              S. 102-114
# Name: 0, dtype: object
#
# FILLED - index 22
#
# century
# coordinate                                                   []
# corporate                                                    []
# decade
# doi
# edition                                                 2. Aufl
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person        [Weigl, Franz, Zinkl, Johann, Kozics, Ernst, [...
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull                        [Ein Bilderbuch vom Lieben Gott]
# ttlpart                        [Ein Bilderbuch vom Lieben Gott]
# volumes                                                 [8 Bl.]
# Name: 22, dtype: object

# %%
df.edition.unique()
# Out:
# array(['', '2. Aufl', '2.umgearb.Aufl', ..., '1. - 5. Tausend',
#        '3rd ed. 2018', 'First Savas Beatie edition'], dtype=object)

# %% [markdown]
# ### Exact Date

# %%
df.exactDate[0]
# Out:
# ''

# %%
idx_exactDate_filled, idx_exactDate_empty = find_empty_in_column (df, 'exactDate')
# Out:
# Number of records with filled exactDate 31010, with missing exactDate 152397 => 16.9%
#
# EMPTY - index 0
#
# century                                                      12
# coordinate                                                   []
# corporate                                                    []
# decade                                                       12
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                    [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart       [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                              S. 102-114
# Name: 0, dtype: object
#
# FILLED - index 12
#
# century                                         u
# coordinate                                     []
# corporate                                      []
# decade                                          u
# doi
# edition
# exactDate                                       u
# format                                   BK020000
# isbn
# ismn
# musicid
# pages                                          []
# part                                           []
# person                            [Jöhr, Adolf, ]
# pubinit
# pubword                                        []
# pubyear                                         u
# scale
# ttlfull       [Dr.Dr. h.c. Adolf Jöhr, 1878-1953]
# ttlpart       [Dr.Dr. h.c. Adolf Jöhr, 1878-1953]
# volumes                       33 S. 1 Portr.-Taf.
# Name: 12, dtype: object

# %%
df.exactDate.unique()
# Out:
# array(['', 'u', '12345', '123456789', '12345678', '1234', '1234567', '1',
#        '123456', '123', '2345678', '23456789',
#        '123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu',
#        '23456', '12', '234567', '23', '2345', '2', '234',
#        '23456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu'],
#       dtype=object)

# %% [markdown]
# ### Format

# %%
df.format.unique()
# Out:
# array(['BK020000', 'BK020800', 'BK020300', 'BK020400', 'MU040100',
#        'MU010100', 'VM010000', 'MP010300', 'BK020053', 'BK010000',
#        'CR030653', 'CR030300', 'BK020200', 'MU030100', 'BK020700',
#        'BK020353', 'MU010000', 'CL010000', 'VM010300', 'MU010100MU010000',
#        'MU010000MU010100', 'MU010200MU010000', 'VM010400',
#        'BK020000BK020400', 'MU040500', 'MU010200', 'MU010200MU010100',
#        'BK020000BK020200', 'BK020800BK020000', 'VM030100VM030000',
#        'BK020200BK020000', 'BK020400BK020000', 'BK020347',
#        'BK020300BK020000', 'VM010200', 'BK020000BK020800',
#        'MP010700MP010300', 'BK020000BK020300', 'VM030100',
#        'BK020500BK020000', 'BK020047', 'CF010000', 'VM030000', 'BK020100',
#        'BK020100BK020000', 'MP010300MP010300', 'BK020000BK020700',
#        'BK020000BK020100', 'CR030600CR030300', 'CR030600',
#        'MP010100MP010300', 'CF010100', 'MU010100MU010200', 'BK010053',
#        'MU030053', 'BK030000', 'VM020400', 'CL010053', 'VM020000',
#        'CR020153', 'CR020200', 'VM010253', 'MP020300', 'BK010800',
#        'VM030400', 'MU040000', 'CL050000', 'MU040600', 'BK010400',
#        'VM040400', 'BK020500', 'VM020500', 'VM040000', 'CL010800',
#        'BK020300BK020000BK020500', 'CR030300CR030600', 'CR030000',
#        'VM020300', 'BK020001', 'VM010353', 'CF010500', 'BK020847',
#        'VM020453', 'BK010453', 'CR020453', 'CR030553', 'BK020453',
#        'CR030300CR030000', 'MP010100', 'VM010153', 'CR030353', 'BK030300',
#        'BK020000BK020500', 'BK020700BK020000', 'CL020000', 'MU030600',
#        'VM010100', 'VM020353', 'BK020853', 'CR030053', 'BK020800BK020400',
#        'CR030653CR030053', 'MU030000', 'CR030600CR030700', '', 'VM020053',
#        'BK010300', 'BK020553', 'MP010200', 'BK020400BK020800', 'MP010700',
#        'BK010853', 'MU010153', 'VM030047VM030147', 'MU040053', 'CR010600',
#        'CR030500CR030600', 'CR030600CR030000', 'BK030053', 'BK030353',
#        'MU030500', 'BK020853BK020053', 'BK020053BK020853',
#        'BK020353BK020053', 'BK020053BK020453', 'BK020453BK020053',
#        'BK020053BK020353', 'VM030400VM030000', 'BK020053BK020153',
#        'CR030000CR030600', 'CR030700CR030600', 'CR030053CR030653',
#        'CR030000CR030300', 'MU010053', 'BK020753', 'VM030147VM030047',
#        'VM020600', 'BK010353', 'BK020753BK020053', 'BK020800BK020300',
#        'CR030647', 'MU020053', 'MU020153', 'VM030047', 'MU010300MU010000',
#        'BK010001', 'CR030047', 'BK020301', 'MU010101', 'CR020247',
#        'CR030700CR030300', 'CR030600CR030500', 'BK020300BK020800',
#        'BK020300BK020800BK020000', 'MU020100', 'CR030500', 'CR020000',
#        'MU020000', 'MP020700', 'BK030001', 'MU010300', 'BK020153',
#        'BK020600BK020000', 'CR030353CR030653', 'CR030347',
#        'BK020053BK020553', 'BK010800BK010000', 'VM020001',
#        'CR020453CR020153', 'BK020547', 'BK020547BK020047',
#        'CR030653CR030353', 'BK020000BK020600', 'BK020553BK020053',
#        'CF010200', 'BK020300BK020400', 'CR030700CR030000',
#        'BK010000BK010800', 'BK010000BK010400', 'MP020353',
#        'MP010300MP010100', 'BK020047BK020847', 'BK020801',
#        'CR030700CR030600CR030300', 'BK020800BK020400BK020000'],
#       dtype=object)

# %%
len(df.format.unique())
# Out:
# 185

# %%
idx_format_filled, idx_format_empty = find_empty_in_column (df, 'format')
# Out:
# Number of records with filled format 179688, with missing format 3719 => 98.0%
#
# EMPTY - index 25506
#
# century                                                23456789
# coordinate                                                   []
# corporate                                                    []
# decade                                                 23456789
# doi                                    10.3929/ethz-b-000283465
# edition
# exactDate
# format
# isbn
# ismn                                   10.3929/ethz-b-000283465
# musicid
# pages                                                        []
# part                                                         []
# person        [Hager, Pascal Alexander, [Pascal Alexander Ha...
# pubinit                                              ETH Zurich
# pubword                                            [ETH Zurich]
# pubyear
# scale
# ttlfull         [200 FPS Ultrafast Imaging with the LightProbe]
# ttlpart         [200 FPS Ultrafast Imaging with the LightProbe]
# volumes                                                 0.10 GB
# Name: 25506, dtype: object
#
# FILLED - index 0
#
# century                                                      12
# coordinate                                                   []
# corporate                                                    []
# decade                                                       12
# doi
# edition
# exactDate
# format                                                 BK020000
# isbn
# ismn
# musicid
# pages                                                        []
# part                                                         []
# person                    [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                      []
# pubyear
# scale
# ttlfull       [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart       [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                              S. 102-114
# Name: 0, dtype: object

# %%
df.format.str[:2].unique()
# Out:
# array(['BK', 'MU', 'VM', 'MP', 'CR', 'CL', 'CF', ''], dtype=object)

# %%
df['format_frst2'] = df.format.str[:2]
df[['volumes', 'format_frst2']].loc[idx_coordinate_filled].head()
# Out:
#       volumes format_frst2
# 1801  1 Karte           MP
# 1804  1 Karte           MP
# 1829  1 Karte           MP
# 1846  1 Karte           MP
# 1849  1 Karte           MP

# %%
df['format_frst2'].loc[idx_coordinate_filled].unique()
# Out:
# array(['MP', 'BK'], dtype=object)

# %%
df[['volumes', 'format_frst2']].loc[idx_coordinate_filled][
    df['format_frst2'].loc[idx_coordinate_filled]=='BK']
# Out:
#           volumes format_frst2
# 102432  9 Blätter           BK

# %%
df['volumes'][df.format_frst2=='CL'].head()
# Out:
# 1955                1 Mappe
# 15982    1 article en ligne
# 16276
# 16668                 35 p.
# 16669                 37 p.
# Name: volumes, dtype: object

# %% [markdown]
# ### ISBN

# %%
df.isbn[0]
# Out:
# ''

# %%
idx_isbn_filled, idx_isbn_empty = find_empty_in_column (df, 'isbn')
# Out:
# Number of records with filled isbn 80688, with missing isbn 102719 => 44.0%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 23
#
# century                                                         1
# coordinate                                                     []
# corporate                                                      []
# decade                                                          1
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn                                                3-7742-2429-3
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                              [Hofer, Rudolf, Rudolf Hofer]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Hofers Süsswasserfische-Kompass, Fische in Fl...
# ttlpart         [Hofers Süsswasserfische-Kompass, Fische in Fl...
# volumes                                                     79 S.
# format_frst2                                                   BK
# Name: 23, dtype: object

# %% [markdown]
# ### ISMN

# %%
df.ismn[0]
# Out:
# ''

# %%
idx_ismn_filled, idx_ismn_empty = find_empty_in_column (df, 'ismn')
# Out:
# Number of records with filled ismn 19490, with missing ismn 163917 => 10.6%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 1791
#
# century                                                        23
# coordinate                                                     []
# corporate                                                      []
# decade                                                         23
# doi                                                 9790201326702
# edition                Überarbeitete AuflagePartituur und Stimmen
# exactDate
# format                                                   MU010100
# isbn                               978-3-940069-36-83-940069-36-1
# ismn                                                9790201326702
# musicid                                                  VHR 3840
# pages                                          [Streichorchester]
# part                                           [Streichorchester]
# person          [Holzer-Rhomberg, Andrea, 1970-, (DE-588)13540...
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Fiedel-Max, Besetzung: Violine 1, Violine 2, ...
# ttlpart         [Fiedel-Max, Besetzung: Violine 1, Violine 2, ...
# volumes                                    1 Partitur (20 Seiten)
# format_frst2                                                   MU
# Name: 1791, dtype: object

# %% [markdown]
# ### MusicID

# %%
df.musicid[0]
# Out:
# ''

# %%
idx_musicid_filled, idx_musicid_empty = find_empty_in_column (df, 'musicid')
# Out:
# Number of records with filled musicid 13502, with missing musicid 169905 => 7.4%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 1788
#
# century                                                   2345678
# coordinate                                                     []
# corporate                                                      []
# decade                                                    2345678
# doi
# edition
# exactDate                                                 2345678
# format                                                   MU040100
# isbn
# ismn
# musicid                                                GCD 924201
# pages                                                          []
# part                                                           []
# person          [Brahms, Johannes, 1833-1897, (DE-588)11851425...
# pubinit
# pubword                                                        []
# pubyear                                                   2345678
# scale
# ttlfull                                          [Violin sonatas]
# ttlpart                                          [Violin sonatas]
# volumes                                              1 CD (69:42)
# format_frst2                                                   MU
# Name: 1788, dtype: object

# %% [markdown]
# ### Pages

# %%
df.pages[0]
# Out:
# []

# %%
idx_pages_filled, idx_pages_empty = find_empty_in_column (df, 'pages')
# Out:
# Number of records with filled pages 43116, with missing pages 140291 => 23.5%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 964
#
# century                                                        12
# coordinate                                                     []
# corporate                              [Zentralbibliothek Zürich]
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                         [1]
# part                                                          [1]
# person                                 [Mohlberg, Leo Cunibert, ]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Katalog der Handschriften der Zentralbiblioth...
# ttlpart         [Katalog der Handschriften der Zentralbiblioth...
# volumes                                                28, 637 S.
# format_frst2                                                   BK
# Name: 964, dtype: object

# %%
df['pages'].loc[idx_pages_filled]
# Out:
# 964                                                 [1]
# 967                                                 [1]
# 968                                                 [3]
# 969                                                 [5]
# 997                                                 [2]
# 1004                                                [2]
# 1005                                                [4]
# 1780                                              [4,1]
# 1786                                              [4,2]
# 1790                                         [[Band] 1]
# 1791                                 [Streichorchester]
# 1795                                             [2004]
# 1800                                          [1. Band]
# 1803                                             [[54]]
# 1808                                [Volume 2, Reprint]
# 1809                                        [volume 15]
# 1812       [37. Jahrgang, Heft 1+2 (2019), Seiten 8-17]
# 1814                                        [volume 20]
# 1815                                          [5. Band]
# 1816                                          [3. Band]
# 1817                                          [2. Band]
# 1818                                          [4. Band]
# 1819                                          [6. Band]
# 1820                                          [7. Band]
# 1821                                          [8. Band]
# 1822                                          [9. Band]
# 1823                                         [10. Band]
# 1824                                         [11. Band]
# 1826                                         [13. Band]
# 1827      [Heft 1 (1953), Seiten 11-17, Illustrationen]
#                               ...
# 183324                               [2009, S. 177-201]
# 183326                                            [528]
# 183327                                            [755]
# 183337                                            [276]
# 183339                               [1962, S. 279-284]
# 183340                                     [Band 87-88]
# 183347                                             [62]
# 183348                               [2009, S. 137-163]
# 183349                                             [50]
# 183350                                           [1100]
# 183352                               [1962, S. 305-310]
# 183355                                          [no. 2]
# 183359                                             [18]
# 183361                                            [484]
# 183365                                            [843]
# 183368                                            [842]
# 183373                                            [230]
# 183375                                            [102]
# 183382                                            [373]
# 183383                                             [13]
# 183389                                            [867]
# 183392                               [2009, S. 201-223]
# 183393                                     [Band 27-28]
# 183394                                            [191]
# 183396                                     [Band 75-76]
# 183397                                       [Band 1-2]
# 183398                                     [Band 79-80]
# 183400                                [1962, S. 92-106]
# 183401                                             [30]
# 183403                                              [9]
# Name: pages, Length: 43116, dtype: object

# %% [markdown]
# ### Part

# %%
df.part[0]
# Out:
# []

# %%
idx_part_filled, idx_part_empty = find_empty_in_column (df, 'part')
# Out:
# Number of records with filled part 43116, with missing part 140291 => 23.5%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 964
#
# century                                                        12
# coordinate                                                     []
# corporate                              [Zentralbibliothek Zürich]
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                         [1]
# part                                                          [1]
# person                                 [Mohlberg, Leo Cunibert, ]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Katalog der Handschriften der Zentralbiblioth...
# ttlpart         [Katalog der Handschriften der Zentralbiblioth...
# volumes                                                28, 637 S.
# format_frst2                                                   BK
# Name: 964, dtype: object

# %%
df[df.part != df.pages]
# Out:
# Empty DataFrame
# Columns: [century, coordinate, corporate, decade, doi, edition, exactDate, format, isbn, ismn, musicid, pages, part, person, pubinit, pubword, pubyear, scale, ttlfull, ttlpart, volumes, format_frst2]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Person<a id='person'></a>

# %%
df.person.head()
# Out:
# 0                [Schluchter, André, André Schluchter]
# 1                [Naegeli, Werner, von Werner Naegeli]
# 2    [Kelly, M.V., Geniesse, J.B., M.V. Kelly et J....
# 3                                  [Wegelin, Walter, ]
# 4    [Oberlin, Urs, Urs Oberlin ; translated from t...
# Name: person, dtype: object

# %%
idx_person_filled, idx_person_empty = find_empty_in_column(df, 'person')
# Out:
# Number of records with filled person 164691, with missing person 18716 => 89.8%
#
# EMPTY - index 6
#
# century
# coordinate                                                     []
# corporate                [Christkatholische Kirchgemeinde (Bern)]
# decade
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                                                         []
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Gedanken zur Jubiläumsfeier der Christkatholi...
# ttlpart         [Gedanken zur Jubiläumsfeier der Christkatholi...
# volumes                                                     48 S.
# format_frst2                                                   BK
# Name: 6, dtype: object
#
# FILLED - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object

# %% [markdown]
# For $\texttt{df.corporate}$, see [Corporate](#corporate).

# %%
cor_f_per_f = list(set(idx_corporate_filled) & set(idx_person_filled))
cor_f_per_e = list(set(idx_corporate_filled) & set(idx_person_empty))
cor_e_per_f = list(set(idx_corporate_empty) & set(idx_person_filled))
cor_e_per_e = list(set(idx_corporate_empty) & set(idx_person_empty))

print('corporate filled and person filled {:d} => {:.1f}%'.format(
      len(cor_f_per_f), 100*len(cor_f_per_f)/len(df))
     )
print('corporate filled and person empty {:d} => {:.1f}%'.format(
      len(cor_f_per_e), 100*len(cor_f_per_e)/len(df))
     )
print('corporate empty and person filled {:d} => {:.1f}%'.format(
      len(cor_e_per_f), 100*len(cor_e_per_f)/len(df))
     )
print('corporate empty and person empty {:d} => {:.1f}%'.format(
      len(cor_e_per_e), 100*len(cor_e_per_e)/len(df))
     )
# Out:
# corporate filled and person filled 28895 => 15.8%
# corporate filled and person empty 4271 => 2.3%
# corporate empty and person filled 135796 => 74.0%
# corporate empty and person empty 14445 => 7.9%

# %%
df.loc[cor_e_per_e[0]]
# Out:
# century                                                    234567
# coordinate                                                     []
# corporate                                                      []
# decade                                                     234567
# doi
# edition
# exactDate       23456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_...
# format                                                   BK020053
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                                                         []
# pubinit                                              AML Editions
# pubword                                            [AML Editions]
# pubyear         23456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_...
# scale
# ttlfull         [Dire et contre faire, Jean de Boschère, imagi...
# ttlpart         [Dire et contre faire, Jean de Boschère, imagi...
# volumes
# format_frst2                                                   BK
# Name: 32770, dtype: object

# %% [markdown]
# ### Pubinit

# %%
df.pubinit[0]
# Out:
# ''

# %%
idx_pubinit_filled, idx_pubinit_empty = find_empty_in_column(df, 'pubinit')
# Out:
# Number of records with filled pubinit 61462, with missing pubinit 121945 => 33.5%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 1976
#
# century
# coordinate                                                     []
# corporate                                                      []
# decade
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn                               978-3-8304-5419-93-8304-5419-8
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person          [Stöger, Adelheid, 1956-, (DE-588)140243321, A...
# pubinit                                        Hippokrates-Verlag
# pubword                                      [Hippokrates-Verlag]
# pubyear
# scale
# ttlfull                 [Chinesische Medizin bei Hautkrankheiten]
# ttlpart                 [Chinesische Medizin bei Hautkrankheiten]
# volumes                                                XI, 396 S.
# format_frst2                                                   BK
# Name: 1976, dtype: object

# %%
df.pubinit.unique()
# Out:
# array(['', 'Hippokrates-Verlag', 'Herder', ...,
#        'Consultants Bureau.Nauka/Interperiodica', 'en vente chez Paludan',
#        'AA-Verlag für Pädagogik'], dtype=object)

# %%
df.pubinit.loc[idx_pubinit_filled].head(10)
# Out:
# 1976       Hippokrates-Verlag
# 1977                   Herder
# 1981          Müller & Schade
# 1984                    Heyne
# 1986    Verbandsdruckerei AG.
# 1991                   Bitter
# 1994      Deutsche Grammophon
# 1998           Harmonia Mundi
# 1999              Schultheiss
# 2001       Breitkopf & Härtel
# Name: pubinit, dtype: object

# %% [markdown]
# ### Pubword

# %%
df.pubword[0]
# Out:
# []

# %%
idx_pubword_filled, idx_pubword_empty = find_empty_in_column(df, 'pubword')
# Out:
# Number of records with filled pubword 61462, with missing pubword 121945 => 33.5%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 1976
#
# century
# coordinate                                                     []
# corporate                                                      []
# decade
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn                               978-3-8304-5419-93-8304-5419-8
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person          [Stöger, Adelheid, 1956-, (DE-588)140243321, A...
# pubinit                                        Hippokrates-Verlag
# pubword                                      [Hippokrates-Verlag]
# pubyear
# scale
# ttlfull                 [Chinesische Medizin bei Hautkrankheiten]
# ttlpart                 [Chinesische Medizin bei Hautkrankheiten]
# volumes                                                XI, 396 S.
# format_frst2                                                   BK
# Name: 1976, dtype: object

# %%
init_f_word_f = list(set(idx_pubinit_filled) & set(idx_pubword_filled))
init_f_word_e = list(set(idx_pubinit_filled) & set(idx_pubword_empty))
init_e_word_f = list(set(idx_pubinit_empty) & set(idx_pubword_filled))
init_e_word_e = list(set(idx_pubinit_empty) & set(idx_pubword_empty))

print('corporate filled and person filled {:d} => {:.1f}%'.format(
      len(init_f_word_f), 100*len(init_f_word_f)/len(df))
     )
print('corporate filled and person empty {:d} => {:.1f}%'.format(
      len(init_f_word_e), 100*len(init_f_word_e)/len(df))
     )
print('corporate empty and person filled {:d} => {:.1f}%'.format(
      len(init_e_word_f), 100*len(init_e_word_f)/len(df))
     )
print('corporate empty and person empty {:d} => {:.1f}%'.format(
      len(init_e_word_e), 100*len(init_e_word_e)/len(df))
     )
# Out:
# corporate filled and person filled 61462 => 33.5%
# corporate filled and person empty 0 => 0.0%
# corporate empty and person filled 0 => 0.0%
# corporate empty and person empty 121945 => 66.5%

# %%
df['pubword'][df['pubinit'] != df['pubword'].str[0]].str[0].dropna().head()
# Out:
# 2131                                            Universal
# 2194    Bibliothèque cantonale et universitaire Lausan...
# 2281                                         Radio France
# 2502                                         Silva Screen
# 2524                                           Caduff, A.
# Name: pubword, dtype: object

# %%
df[['pubinit', 'pubword']].loc[2281]
# Out:
# pubinit        Radio FranceErato Disques
# pubword    [Radio France, Erato Disques]
# Name: 2281, dtype: object

# %% [markdown]
# ### Pubyear

# %%
df.pubyear[0]
# Out:
# ''

# %%
idx_pubyear_filled, idx_pubyear_empty = find_empty_in_column(df, 'pubyear')
# Out:
# Number of records with filled pubyear 31010, with missing pubyear 152397 => 16.9%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 12
#
# century                                           u
# coordinate                                       []
# corporate                                        []
# decade                                            u
# doi
# edition
# exactDate                                         u
# format                                     BK020000
# isbn
# ismn
# musicid
# pages                                            []
# part                                             []
# person                              [Jöhr, Adolf, ]
# pubinit
# pubword                                          []
# pubyear                                           u
# scale
# ttlfull         [Dr.Dr. h.c. Adolf Jöhr, 1878-1953]
# ttlpart         [Dr.Dr. h.c. Adolf Jöhr, 1878-1953]
# volumes                         33 S. 1 Portr.-Taf.
# format_frst2                                     BK
# Name: 12, dtype: object

# %%
df.pubyear.loc[idx_pubyear_filled].unique()
# Out:
# array(['u', '12345', '123456789', '12345678', '1234', '1234567', '1',
#        '123456', '123', '2345678', '23456789',
#        '123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu',
#        '23456', '12', '234567', '23', '2345', '2', '234',
#        '23456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstu'],
#       dtype=object)

# %%
df[df.pubyear != df.exactDate]
# Out:
# Empty DataFrame
# Columns: [century, coordinate, corporate, decade, doi, edition, exactDate, format, isbn, ismn, musicid, pages, part, person, pubinit, pubword, pubyear, scale, ttlfull, ttlpart, volumes, format_frst2]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Scale

# %%
df.scale[0]
# Out:
# ''

# %%
idx_scale_filled, idx_scale_empty = find_empty_in_column(df, 'scale')
# Out:
# Number of records with filled scale 793, with missing scale 182614 => 0.4%
#
# EMPTY - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object
#
# FILLED - index 1801
#
# century                                                       123
# coordinate                                   [E0035400, N0532700]
# corporate                                                      []
# decade                                                        123
# doi
# edition                                                 Facsimile
# exactDate                                                    1234
# format                                                   MP010300
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person          [Blaeu, Willem Janszoon, 1571-1638, (DE-588)11...
# pubinit
# pubword                                                        []
# pubyear                                                      1234
# scale                                                      400000
# ttlfull         [Nova descriptio Comitatus Hollandiæ, Niewe be...
# ttlpart         [Nova descriptio Comitatus Hollandiæ, Niewe be...
# volumes                                                   1 Karte
# format_frst2                                                   MP
# Name: 1801, dtype: object

# %%
df.scale.unique()
# Out:
# array(['', '400000', '3000000', '50000', '75000', '300000', '800000',
#        '10000', '5650', '1:400,000', '700000', '100000', '25000',
#        '275000', '500000500000', '301000', '15000', '16667',
#        'Echelle : 1:50 000', '1000000', '250000', '150000',
#        'Verschiedene Massstäbe', 'Echelle [ca. 1:440 000]', '5000050000',
#        '[Echelle non déterminée]', '200000', '118000', '1000010000',
#        '12500', 'Echelle 1:50.000', '5000', '500', 'Echelles diverses',
#        'Echelle 1:50 000', '1400000', '1600000', '550000', '1:50 000',
#        '1:60 000', '9117', '2000000', '20000100000', '1156015625', '8100',
#        '15700', '17400', '810011600', '16666', '500000', '70000',
#        'Echelle: 1:25.000', '1:25 000', '125000', '46000',
#        'Echelle 1:25.000 ; projection conforme cylindrique à axe oblique',
#        'Echelle 1:25.000', '300000700000', '850000', '2750', '1250000',
#        '1700000', '750000', '11000000', '17500', '250000250000',
#        '24000000', '3500000', '2500000', '240000', '60000', '650000',
#        '600000', '16000', '27000', '28000', '200000200000', '172000',
#        '24000', '2500065000', '56000', '40000', '35000', '1:18000',
#        '260000', '22500', '17000', '2600032000', '36000', '45000',
#        '2500040000', '20000', '30000', '275000275000', '15000000',
#        '2500033000', '490000', '1: 5 000 000', '120000', '37005000',
#        '56600', '16130', '1110023250', '126720', '2200000', '33000',
#        '7500', '6000060000', '11000', '10560', '13000', '160000', '18700',
#        '11450', '27600', '15500', '100', '10500', '1:35 000', '18500',
#        '2770000', '4000000', '150', '2000', '50000012500002000000200000',
#        '1100020000', '12000', 'Echelle : 1:100.000', '14000', '320000',
#        '9500000', '1:200 000', '5700000', '175000', '2700000', '3700000',
#        '4500000', '8000', '7700',
#        '850025 00010000 $d E0073010 $e E0073635 $f N0464638 $g N0464333',
#        '160009000', '5000000', '1875000', '2800000', '4000',
#        '1:8 000 000', '1:3 000 000', '38000', '1750049000',
#        '500000250000', '2670000', '2400000', '1960000', '2500025000',
#        '8500', '100000100000', '380000', '250002500025000', '13500',
#        '5500', '4500', '90000', 'Echelle 1:250 000'], dtype=object)

# %% [markdown]
# ### Ttlfull<a id='ttlfull'></a>

# %%
df.ttlfull[0]
# Out:
# ['Die Feist von Kienberg',
#  'eine Wasenmeisterfamilie im Ancien Régime zwischen Ehrbarkeit und Delinquenz']

# %%
idx_ttlfull_filled, idx_ttlfull_empty = find_empty_in_column(df, 'ttlfull')
# Out:
# Number of records with filled ttlfull 183407, with missing ttlfull 0 => 100.0%
#
# EMPTY - None
#
# FILLED - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object

# %% [markdown]
# ### Ttlpart

# %%
df.ttlpart[0]
# Out:
# ['Die Feist von Kienberg',
#  'eine Wasenmeisterfamilie im Ancien Régime zwischen Ehrbarkeit und Delinquenz']

# %%
idx_ttlpart_filled, idx_ttlpart_empty = find_empty_in_column(df, 'ttlpart')
# Out:
# Number of records with filled ttlpart 183407, with missing ttlpart 0 => 100.0%
#
# EMPTY - None
#
# FILLED - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object

# %%
df[['ttlfull', 'ttlpart']][df.ttlfull != df.ttlpart].head()
# Out:
#                                                ttlfull  \
# 38   [25 Jahre Micafil, 1918-1943 : Jubiläumsschrif...
# 73   [Katechismus der katholischen Religion, Kathol...
# 113  [Locorum ex iure Romano anteiustiniano ab ince...
# 138  [Die Stationen des heiligen Kreuzwegs, Fasten-...
# 152  [Cinquante-deux prones sur le décalogue, une t...
#
#                                                ttlpart
# 38    [25 Jahre Micafil, 1918-1943 : Jubiläumsschrift]
# 73             [Katechismus der katholischen Religion]
# 113  [Locorum ex iure Romano anteiustiniano ab ince...
# 138  [Die Stationen des heiligen Kreuzwegs, Fasten-...
# 152  [Cinquante-deux prones sur le décalogue, une t...

# %%
for i in range(len(df)):
    if len(df.ttlfull[i]) < len(df.ttlpart[i]):
        print(i)

# %% [markdown]
# [$\texttt{Ttlfull}$](#ttlfull) is always longer or equal to $\texttt{Ttlpart}$.

# %% [markdown]
# ### Volumes<a id='volumes'></a>

# %%
df.volumes.loc[idx_coordinate_filled].unique()
# Out:
# array(['1 Karte', '1 Panorama', '1 Karte in 3 Teilen', '1 Stadtplan',
#        '1 Atlas (XII, 136 S.)', '2 Karten auf 1 Bl.', '1 carte',
#        '1 Karte in 2 Teilen', '1 Karte in zwei Teilen',
#        '1 Karte in 2 Teilen auf 1 Blatt', '1 carta geografica',
#        '1 Handzeichnung', '1 Karte auf 4 Blättern',
#        '1 Atlas (XII, 128, 110 S.)', '1 Atlas', '1 atlas (IX, 400 p.)',
#        '2 Karten auf 1 Blatt', '1 Plan', '1 Atlas (303 Seiten)',
#        '2 Karten', '3 Karten auf 1 Blatt', '1 Atlas (230 Seiten)',
#        '1 Karte auf 2 Blättern', '1 Heft (48 Seiten, 1 Karte)',
#        '2 Karten in 3 Teilen auf 1 Blatt', '1 Atlas (186 Bl., 183 S.)',
#        '4 Karten auf 1 Blatt', '1 Atlas (262 S.)', '1 gefalt. Karte',
#        '1 Karte in 4 Teilen', '5 Karten auf 1 Blatt',
#        '6 Karten auf 1 Blatt', '1 map on 2 sheets',
#        '1 carte r°-v° plastifiée', '1 Vogelschaukarte',
#        '1 Karte auf 6 Blättern', '9 Blätter',
#        '1 Atlas (447 Seiten in verschiedenen Seitenzählungen)',
#        '1 Atlas (XV, 208 Seiten)', '1 Karte, 1 Satellitenbild', '',
#        'Karten', '2 cartes sur 1 feuille',
#        '1 Atlas (82 Seiten, [27 Blätter])',
#        '1 Atlas (76 Seiten, [20 Blätter])',
#        '1 Atlas (58 Seiten, [33] Blätter)',
#        '1 Atlas (72 Seiten, [31] Blätter)',
#        '1 Atlas (24 Seiten, 12 Blätter)',
#        '1 Atlas (76 Seiten, [30] Blätter)',
#        '1 Atlas (52 Seiten, [20] Blätter)',
#        '1 Atlas (56 Seiten, [22] Blätter)',
#        '1 Atlas ( 46 Seiten, [44] Blätter)', '2 Karten in je 9 Blättern',
#        '1 Atlas (76 Seiten, [24] Blätter)', '1 carta',
#        '1 Karte in 2 Teile', '2 cartes, 1 carte aérienne sur 1 feuille',
#        '1 Atlas (38 Blätter)',
#        '1 Karte und 1 Vogelschaukarte auf 1 Blatt',
#        '2 Karten, 1 Luftbildkarte', '1 Luftbildkarte',
#        '1 Atlas (335 Seiten)', '1 Karte auf 16 Blättern',
#        '1 Atlas (lose Bögen)', '23 Karten', '1 plan', '1 Mappe (14 Bl.)',
#        '2 Pläne auf 1 Blatt', '1 Manuskriptkarte', '1 Atlas (247 Seiten)',
#        '1 Atlas (113 Seiten)'], dtype=object)

# %%
res = [i for i in df.drop(index=idx_coordinate_filled).volumes.unique()
       if (('Karte' in i) or ('Atlas' in i))]
len(res)
# Out:
# 118

# %%
for j in range(len(res)):
    print(j, res[j])
# Out:
# 0 X, 458 S., 16 Taf., 1 Karte
# 1 LX, 188 S., 10 Taf. : 1 Karte
# 2 134 Taf. 6 Karten
# 3 119 S. 1 Karte
# 4 110, XV S. 657 Bl., S. 658-675, 2 Karten
# 5 IV, 104 S., 1 Karte
# 6 327 S. 1 Taf. 2 Karten
# 7 88 S. 3 Karten
# 8 20, 168 S. ill. 1 Portr.-Taf. 1 Karte
# 9 291 S. Kartenskizzen. 16 Taf.
# 10 62 S., 1 Karte
# 11 172 S. Kartenskizzen. 3 Karten.
# 12 1 Spiel (1 Regelheft, 1 Spielplan, 1 Schichtleitertableau, 39 Patientenkarten, 35 Karten "Vage Erinnerung", 35 Karten "Klare Erinnerung", 72 Szenariokarten, 10 Figuren, 24 Versorgungsmarker, 12 Stressmarker, 10 Fortschrittsmarker, 2 Verwarnungsmarker, 1 Telefonplättchen)
# 13 936, 4403-444 Seiten + 3 Karten
# 14 1 Karte
# 15 1 Spiel (42 Fragen-Karten, 27 ja!- und 27 nein!-Karten)
# 16 1 Mappe (5 gefaltete Plakate, 6 A3-Karten)
# 17 305 Seiten, 4 Seiten Karten
# 18 1 Karte auf 2 Blättern
# 19 1 Atlas (XVI, 352 Seiten)
# 20 32 Karten
# 21 55 Karten
# 22 1 Spiel (1 Anleitung, 1 Spielplan, 1 Würfel, 28 Piratenlager (je 7 pro Farbe), 28 Schiffe (je 7 pro Farbe), 1 Figur, 16 Coco-Karten, 90 Plättchen (je 18 Wolle, Holz, Ananas, Säbel und Gold), 4 Spieler-Tafeln)
# 23 1 Spiel (32 Karten, 1 Anleitung)
# 24 1 Schachtel (56 Karten, 1 Begleitbroschüre)
# 25 lx, 758 Seiten, 4 Seiten Karten, 43 Seiten Bildtafeln
# 26 120 Seiten + 1 Karte
# 27 1 Box (124 Karten, 1 booklet)
# 28 1 game (4 game boards/terrain Karten, 1 challenge booklet with 40 challenges, 3 erasable markers, 2 rovers and 2 stands, 4 charging station tokens, 3 data upload station tokens, 4 start/end tokens, 1 sample storage card and 2 plastic tabs, 1 solution booklet, 1 instruction manual)
# 29 1 Koffer mit 3 Schachteln (Gelbe Schachtel: 1 Handbuch, 10 Hefte, 1 Arbeitsbuch, 1 Poster, 1 Stickerbogen, 2 CDs, 2 Kartensets, 2 Zeigekartensets ; orange/rote Schachtel: 1 Handbuch, 8 Hefte, 2 Arbeitsbücher, 2 Poster, 1 Stickerbogen, 4 CDs, 3 Kartensets, 2 Zeigekartensets ; grüne Schachtel: 1 Handbuch, 4 Hefte, 1 Arbeitsbuch, 1 Poster, 1 Stickerbogen, 2 CDs, 1 Kartenset, 1 Zeigekartenset)
# 30 1 Spiel (120 Karten)
# 31 1 Spiel (1 Spielplan, 34 Gänge-Karten, 24 Schatzkarten, 24 Schätze, 24 Münzen, 1 Drachenhort, 1 Drache, 4 Abenteurer, 2 Wächter, 1 Duell-Würfel, 1 Drachen-Würfel, 1 Spielanleitung)
# 32 1 Box (Booklet mit 40 Seiten, 20 Geschichten Karten, 27 Bildkarten)
# 33 1 Atlas (nicht paginiert)
# 34 1 Box (56 Karten, 1 Heft)
# 35 1 Kartenset (40 Karten in Plastikbox)
# 36 1 Schachtel mit 200 Karten zu 10 Themen, 1 Spielanleitung
# 37 2 Kartenset
# 38 1 Medienpaket (36 A6 Karten, 112 A5 Karten, 1 Lehrer-Handbuch, 3 CDs)
# 39 [1] Bl., 82 S., 6 Karten
# 40 14, 362 S., 1 gef. Karte
# 41 XLII, 451 S., [1] Faltbl. Karte
# 42 144 Seiten + 1 Karte
# 43 68 Seiten (34 Karten)
# 44 27 Karten in Schuber
# 45 2 Theile u. Atlas
# 46 1 Schachtel (60 Karten, 1 Booklet)
# 47 1 Schachtel (40 Karten, 1 Anleitung)
# 48 1 Box (33 Karten, 1 Bbooklet)
# 49 52 Karteikarten in Spielkarten-Grösse
# 50 24 Karten (unpaginiert)
# 51 1 Spiel (224 Karten davon 9 Blankokarten für eigene Ideen, 1 Spielanleitung)
# 52 10 Karten in 1 Behältnis
# 53 128 S., Karte
# 54 25 Karten
# 55 12 Karten
# 56 Karten
# 57 1 Spiel (2 Kartenspiele in 1 Behältnis)
# 58 2 Bände, 1 Schuber mit 12 Karten mit Flurnamen
# 59 122 Karten in Faltschachtel
# 60 1 Box (21 + 9 + 3 Karten)
# 61 1 Spiel (1 Anleitung, 1 Spielplan, Figuren mit Aufstellern, 1 Würfel, Bewegungskarten, Berufekarten, 1 Kartenhalter mit Aufstellern, Gegenstandsplättchen)
# 62 1 Spiel (36 Karten, 6 Sichtschirme, 18 Spielfiguren, 54 Lupenmarker, 1 Anleitung)
# 63 1 Schachtel (66 Karten)
# 64 41 Karten
# 65 1 Karten
# 66 2 Kartenspiele
# 67 1 Mappe (28 Karteikarten, 1 Materialliste, 1 Beobachtungsbogen, 1 Begleitbroschüre)
# 68 1 Schachtel (122 Magnetzahlen und -zeichen, 32 Spielkarten, 1 Kartenset 3, 1 Kartenset 4, 1 Spielblock, 1 Anleitung, 1 Magnetfeld (am Deckel befestigt))
# 69 1 Manual (216 Seiten), 1 Box mit Karteikarten
# 70 8 Karten
# 71 1 Atlas (1393 Seiten)
# 72 1 Mappe (10 Karten)
# 73 1 Box (150 laminierte Karten, 1 Anleitung in Deutsch, Englisch, Spanisch, Französisch, Italienisch, Russisch)
# 74 1 Online-Ressource (xiii, 355 Seiten ; Illustrationen, Karten)
# 75 1 Mappe (13 Karten)
# 76 5 Karten
# 77 1 Kartenfächer
# 78 3 Schachteln mit je 24 x 4 Memo-Karten, je ein Artikelkreis
# 79 1 Band (64 Karten)
# 80 1 Spiel (108 Karten, 1 Stift, 1 Wertungsblock, Spielregeln)
# 81 1 Box (32 Karteikarten)
# 82 208 Seiten + 1 Karte
# 83 181 Seiten + 1 Karte
# 84 199 Seiten + 1 Karte
# 85 1 Schachtel (13 Staka-Ringe, 39 Karten, 1 Würfel, 1 Aufbewahrungssockel, 1 Metallstift, 1 mehrsprachige Anleitung, 2 Leinensäckchen)
# 86 1 Mappe (1 Heft, 6 A4-Karten, Sprechblasenvorlagen, 1 Leporello, 3 Domino (Schwierigkeitsgrad 1-3), 3 Memory (Schwierigkeitsgrad 1-3), 3 Puzzle (Schwierigkeitsgrad 1-3)
# 87 1 Mappe (1 Heft, 6 Bild-Karten A4, 6 A4-Karten, Sprechblasenvorlagen, 1 Leporello, 3 Domino (Schwierigkeitsgrad 1-3), 3 Memory (Schwierigkeitsgrad 1-3), 3 Puzzle (Schwierigkeitsgrad 1-3)
# 88 30 Karten
# 89 1 Box (32 Karten)
# 90 1 Faltbox (160 Karten)
# 91 1 Schachtel (20 A6 Karten, 108 A7 Karten, 48 Spielfiguren, 1 Anleitung)
# 92 214, 93-109Seiten + 3 Karten, 3 Portraits
# 93 380, 111-132 Seiten + 3 Karten + 2 Portraits + 1 Beilageheft + 1 Beilageheft ab Seite 849 mit Karte
# 94 3 Karten auf einem Blatt
# 95 30 Spielkarten, 3 Karten zur Anleitung
# 96 1 Spiel (32 Karten, 1 Anleitungskarte)
# 97 1 Behältnis (96 Karten)
# 98 Text und Atlas
# 99 1 Schachtel (70 Karten, 1 Begleitheft)
# 100 173 Seiten + 1 Karte
# 101 1 Spiel (66 farbige Karten = zwei vollständige Kartensets, 1 Spielanleitung)
# 102 250 Karteikarten
# 103 101 S., 42 Karten
# 104 1 Box, 72 Karten
# 105 1 Atlas (141 Seiten)
# 106 139 Seiten, 12 Karten, 26 Pläne
# 107 1 Spiel (145 Karten, 1 Anleitung)
# 108 1 Spiel (50 Karten, 1 Anleitung)
# 109 1 Spiel (56 Karten, 1 Anleitung)
# 110 1 Spiel (34 Karten)
# 111 1 Spiel (68 Karten, 12 Spielfiguren, 1 Spielplan 4-teilig, 1 Anleitung)
# 112 1 Spiel (175 Karten, 36 Maltafeln, 6 Stifte, 1 Tuch, 1 Sanduhr (1 Minute), 1 Anleitung)
# 113 1 Spiel (64 Karten, Spielregeln)
# 114 [34] lose Karten
# 115 Karten (z.T.farb.); 274 S. 1984.
# 116 Karten; 22 S.
# 117 Kartei

# %%
df.volumes[0]
# Out:
# 'S. 102-114'

# %%
idx_volumes_filled, idx_volumes_empty = find_empty_in_column(df, 'volumes')
# Out:
# Number of records with filled volumes 161471, with missing volumes 21936 => 88.0%
#
# EMPTY - index 1810
#
# century
# coordinate                                                     []
# corporate                                                      []
# decade
# doi
# edition                                               2nd edition
# exactDate
# format                                                   BK020000
# isbn                                            978-0-85702-829-7
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person          [Field, Andy, Graham, J. Jole, Andy Field, Gra...
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull                    [How to Design and Report Experiments]
# ttlpart                    [How to Design and Report Experiments]
# volumes
# format_frst2                                                   BK
# Name: 1810, dtype: object
#
# FILLED - index 0
#
# century                                                        12
# coordinate                                                     []
# corporate                                                      []
# decade                                                         12
# doi
# edition
# exactDate
# format                                                   BK020000
# isbn
# ismn
# musicid
# pages                                                          []
# part                                                           []
# person                      [Schluchter, André, André Schluchter]
# pubinit
# pubword                                                        []
# pubyear
# scale
# ttlfull         [Die Feist von Kienberg, eine Wasenmeisterfami...
# ttlpart         [Die Feist von Kienberg, eine Wasenmeisterfami...
# volumes                                                S. 102-114
# format_frst2                                                   BK
# Name: 0, dtype: object

# %% [markdown]
# ## Duplicates

# %%
for c in list_columns:
    target_string = c + '_string'
    print(c)
    df[target_string] = [', '.join(map(str, l)) for l in df[c]]
    
for c in array_of_strings_columns:
    target_string = c + '_string'
    print(c)
    df[target_string] = [', '.join(map(str, l)) for l in df[c]]
# Out:
# coordinate
# corporate
# pages
# part
# pubword
# ttlfull
# ttlpart
# person

# %%
df.corporate_string.loc[idx_corporate_filled].head()
# Out:
# 6                Christkatholische Kirchgemeinde (Bern)
# 7                               Milwaukee Public Museum
# 11    Jüdisches Museum der Schweiz, Museum für Völke...
# 14                                       Brugg (Aargau)
# 19                Sammlung für Völkerkunde Sankt Gallen
# Name: corporate_string, dtype: object

# %%
# Discard list columns
df_n = df.drop(columns=list_columns)
df_n = df_n.drop(columns=array_of_strings_columns)

# %%
df[df_n.duplicated(keep='first')]
# Out:
#           century coordinate                      corporate     decade doi  \
# 18352          12         []                             []         12
# 18388          12         []                             []         12
# 18930           1         []                             []          1
# 18937           1         []                             []          1
# 19462           u         []                             []          u
# 19903           u         []                             []          u
# 19912           u         []                             []          u
# 19916           u         []                             []          u
# 19919           u         []                             []          u
# 19920           u         []                             []          u
# 19922           u         []                             []          u
# 22366           u         []                             []          u
# 23157           u         []                             []          u
# 26693           1         []                             []          1
# 26694           1         []                             []          1
# 26699           1         []                             []          1
# 26710           1         []                             []          1
# 29419     2345678         []                             []    2345678
# 31321                     []                             []
# 32044     2345678         []                             []    2345678
# 32077           1         []                             []          1
# 33655           u         []                             []          u
# 35821     1234567         []                             []    1234567
# 35823       12345         []                             []      12345
# 35840                     []                             []
# 35871   123456789         []                             []  123456789
# 35902                     []                             []
# 35908                     []                             []
# 35912                     []                             []
# 48146                     []                             []
# ...           ...        ...                            ...        ...  ..
# 171723                    []  [Synnberg E. & R. v. Pfyffer]
# 171724                    []  [Synnberg E. & R. v. Pfyffer]
# 171725                    []  [Synnberg E. & R. v. Pfyffer]
# 171728                    []  [Synnberg E. & R. v. Pfyffer]
# 171730                    []  [Synnberg E. & R. v. Pfyffer]
# 171731                    []  [Synnberg E. & R. v. Pfyffer]
# 171732                    []  [Synnberg E. & R. v. Pfyffer]
# 171733                    []  [Synnberg E. & R. v. Pfyffer]
# 171735                    []  [Synnberg E. & R. v. Pfyffer]
# 171736                    []  [Synnberg E. & R. v. Pfyffer]
# 171737                    []  [Synnberg E. & R. v. Pfyffer]
# 171738                    []  [Synnberg E. & R. v. Pfyffer]
# 171739                    []  [Synnberg E. & R. v. Pfyffer]
# 171740                    []  [Synnberg E. & R. v. Pfyffer]
# 171741                    []  [Synnberg E. & R. v. Pfyffer]
# 171742                    []  [Synnberg E. & R. v. Pfyffer]
# 171743                    []  [Synnberg E. & R. v. Pfyffer]
# 171744                    []  [Synnberg E. & R. v. Pfyffer]
# 171745                    []  [Synnberg E. & R. v. Pfyffer]
# 171746                    []  [Synnberg E. & R. v. Pfyffer]
# 172275   23456789         []                             []   23456789
# 180410   23456789         []                             []   23456789
# 180924   23456789         []                             []   23456789
# 180960   23456789         []                             []   23456789
# 181172   23456789         []                             []   23456789
# 181173   23456789         []                             []   23456789
# 182880                    []                    [Wehrli AG]
# 182884                    []                    [Wehrli AG]
# 182885                    []                    [Wehrli AG]
# 182886                    []                    [Wehrli AG]
#
#            edition  exactDate    format  \
# 18352                 1234567  MP010300
# 18388                 1234567  MP010300
# 18930                          BK020300
# 18937                          BK020000
# 19462                       u  BK030000
# 19903                       u  MU010100
# 19912                       u  MU010100
# 19916                       u  MU010100
# 19919                       u  MU010100
# 19920                       u  MU010100
# 19922                       u  MU010100
# 22366                       u  BK030000
# 23157                       u  BK020000
# 26693                          BK020000
# 26694                          BK020000
# 26699                          BK020000
# 26710                          BK020000
# 29419                          MU030100
# 31321                          VM020400
# 32044                          BK020000
# 32077                          BK020000
# 33655                       u  MU010100
# 35821                          VM020300
# 35823                  123456  VM020300
# 35840                          VM020300
# 35871                          VM020300
# 35902                   12345  VM020300
# 35908                          VM020300
# 35912                          VM020300
# 48146               123456789  VM020300
# ...            ...        ...       ...
# 171723                         VM020300
# 171724                         VM020300
# 171725                         VM020300
# 171728                         VM020300
# 171730                         VM020300
# 171731                         VM020300
# 171732                         VM020300
# 171733                         VM020300
# 171735                         VM020300
# 171736                         VM020300
# 171737                         VM020300
# 171738                         VM020300
# 171739                         VM020300
# 171740                         VM020300
# 171741                         VM020300
# 171742                         VM020300
# 171743                         VM020300
# 171744                         VM020300
# 171745                         VM020300
# 171746                         VM020300
# 172275  1. Auflage             BK020000
# 180410                     23  BK020053
# 180924                      2  BK020053
# 180960                      2  BK020053
# 181172                     23  BK020053
# 181173                         BK020053
# 182880                         VM020300
# 182884                         VM020300
# 182885                         VM020300
# 182886                         VM020300
#
#                                                      isbn ismn  \
# 18352
# 18388
# 18930
# 18937
# 19462
# 19903
# 19912
# 19916
# 19919
# 19920
# 19922
# 22366
# 23157
# 26693
# 26694
# 26699
# 26710
# 29419
# 31321
# 32044   978-0-8101-3778-30-8101-3778-X978-0-8101-3779-...
# 32077
# 33655
# 35821
# 35823
# 35840
# 35871
# 35902
# 35908
# 35912
# 48146
# ...                                                   ...  ...
# 171723
# 171724
# 171725
# 171728
# 171730
# 171731
# 171732
# 171733
# 171735
# 171736
# 171737
# 171738
# 171739
# 171740
# 171741
# 171742
# 171743
# 171744
# 171745
# 171746
# 172275                     978-3-96093-324-33-96093-324-X
# 180410
# 180924
# 180960
# 181172
# 181173
# 182880
# 182884
# 182885
# 182886
#
#                               ...                          \
# 18352                         ...
# 18388                         ...
# 18930                         ...
# 18937                         ...
# 19462                         ...
# 19903                         ...
# 19912                         ...
# 19916                         ...
# 19919                         ...
# 19920                         ...
# 19922                         ...
# 22366                         ...
# 23157                         ...
# 26693                         ...
# 26694                         ...
# 26699                         ...
# 26710                         ...
# 29419                         ...
# 31321                         ...
# 32044                         ...
# 32077                         ...
# 33655                         ...
# 35821                         ...
# 35823                         ...
# 35840                         ...
# 35871                         ...
# 35902                         ...
# 35908                         ...
# 35912                         ...
# 48146                         ...
# ...                           ...
# 171723                        ...
# 171724                        ...
# 171725                        ...
# 171728                        ...
# 171730                        ...
# 171731                        ...
# 171732                        ...
# 171733                        ...
# 171735                        ...
# 171736                        ...
# 171737                        ...
# 171738                        ...
# 171739                        ...
# 171740                        ...
# 171741                        ...
# 171742                        ...
# 171743                        ...
# 171744                        ...
# 171745                        ...
# 171746                        ...
# 172275                        ...
# 180410                        ...
# 180924                        ...
# 180960                        ...
# 181172                        ...
# 181173                        ...
# 182880                        ...
# 182884                        ...
# 182885                        ...
# 182886                        ...
#
#                      volumes format_frst2 coordinate_string  \
# 18352                                  MP
# 18388                                  MP
# 18930   10 ungezählte Seiten           BK
# 18937   18 ungezählte Seiten           BK
# 19462                                  BK
# 19903            1 partition           MU
# 19912            1 partition           MU
# 19916            1 partition           MU
# 19919            1 partition           MU
# 19920            1 partition           MU
# 19922            1 partition           MU
# 22366                                  BK
# 23157                                  BK
# 26693              96 Seiten           BK
# 26694              96 Seiten           BK
# 26699              96 Seiten           BK
# 26710              96 Seiten           BK
# 29419       1 CD + 1 Booklet           MU
# 31321         1 photographie           VM
# 32044          x, 225 Seiten           BK
# 32077              96 Seiten           BK
# 33655            1 partition           MU
# 35821           1 Fotografie           VM
# 35823           1 Fotografie           VM
# 35840           1 Fotografie           VM
# 35871           1 Fotografie           VM
# 35902           1 Fotografie           VM
# 35908           1 Fotografie           VM
# 35912           1 Fotografie           VM
# 48146           1 Fotografie           VM
# ...                      ...          ...               ...
# 171723           1 Postkarte           VM
# 171724           1 Postkarte           VM
# 171725           1 Postkarte           VM
# 171728           1 Postkarte           VM
# 171730           1 Postkarte           VM
# 171731           1 Postkarte           VM
# 171732           1 Postkarte           VM
# 171733           1 Postkarte           VM
# 171735           1 Postkarte           VM
# 171736           1 Postkarte           VM
# 171737           1 Postkarte           VM
# 171738           1 Postkarte           VM
# 171739           1 Postkarte           VM
# 171740           1 Postkarte           VM
# 171741           1 Postkarte           VM
# 171742           1 Postkarte           VM
# 171743           1 Postkarte           VM
# 171744           1 Postkarte           VM
# 171745           1 Postkarte           VM
# 171746           1 Postkarte           VM
# 172275             64 Seiten           BK
# 180410  1 livre électronique           BK
# 180924  1 livre électronique           BK
# 180960  1 livre électronique           BK
# 181172  1 livre électronique           BK
# 181173  1 livre électronique           BK
# 182880           1 Postkarte           VM
# 182884           1 Postkarte           VM
# 182885           1 Postkarte           VM
# 182886           1 Postkarte           VM
#
#                    corporate_string pages_string part_string pubword_string  \
# 18352
# 18388
# 18930
# 18937
# 19462
# 19903                                                                [s.n.]
# 19912                                                                [s.n.]
# 19916                                                                [s.n.]
# 19919                                                                [s.n.]
# 19920                                                                [s.n.]
# 19922                                                                [s.n.]
# 22366
# 23157
# 26693
# 26694
# 26699
# 26710
# 29419                                                          Enja Records
# 31321
# 32044
# 32077
# 33655                                                                [s.n.]
# 35821
# 35823
# 35840
# 35871
# 35902
# 35908
# 35912
# 48146
# ...                             ...          ...         ...            ...
# 171723  Synnberg E. & R. v. Pfyffer
# 171724  Synnberg E. & R. v. Pfyffer
# 171725  Synnberg E. & R. v. Pfyffer
# 171728  Synnberg E. & R. v. Pfyffer
# 171730  Synnberg E. & R. v. Pfyffer
# 171731  Synnberg E. & R. v. Pfyffer
# 171732  Synnberg E. & R. v. Pfyffer
# 171733  Synnberg E. & R. v. Pfyffer
# 171735  Synnberg E. & R. v. Pfyffer
# 171736  Synnberg E. & R. v. Pfyffer
# 171737  Synnberg E. & R. v. Pfyffer
# 171738  Synnberg E. & R. v. Pfyffer
# 171739  Synnberg E. & R. v. Pfyffer
# 171740  Synnberg E. & R. v. Pfyffer
# 171741  Synnberg E. & R. v. Pfyffer
# 171742  Synnberg E. & R. v. Pfyffer
# 171743  Synnberg E. & R. v. Pfyffer
# 171744  Synnberg E. & R. v. Pfyffer
# 171745  Synnberg E. & R. v. Pfyffer
# 171746  Synnberg E. & R. v. Pfyffer
# 172275
# 180410
# 180924
# 180960
# 181172
# 181173
# 182880                    Wehrli AG
# 182884                    Wehrli AG
# 182885                    Wehrli AG
# 182886                    Wehrli AG
#
#                                            ttlfull_string  \
# 18352                       [Mappemonde d'Honoré d'Autun]
# 18388                     [Mappemonde de Gautier de Metz]
# 18930   Dissertatio academica de naturæ humanæ inclina...
# 18937   Vnser/ Der Dieneren vnd Lehreren des göttliche...
# 19462   Vivaldi : L'inganno trionfante in amore Vivald...
# 19903                     Danses hongroises, [pour piano]
# 19912                     Danses hongroises, [pour piano]
# 19916               La nativité du Seigneur, [pour orgue]
# 19919                     Danses Hongroises, [pour piano]
# 19920               La nativité du Seigneur, [pour orgue]
# 19922               La nativité du Seigneur, [pour orgue]
# 22366   MISCELLANEA :  Lettere, manifest ; narrationi ...
# 23157                                  Sammelband ETH-BIB
# 26693   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 26694   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 26699   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 26710   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 29419                                           Moosedays
# 31321   Saatzucht Sensebezirk Düdingen (Guin), culture...
# 32044   Theory's autoimmunity, skepticism, literature,...
# 32077   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 33655                    Méthode pour orgue, [pour orgue]
# 35821   [Dr. Franziskus von Streng (1884-1970), Bischo...
# 35823   [Josef Ambühl (1873-1936), Bischof von Basel u...
# 35840            [Hermann Obrecht (1882-1940), Bundesrat]
# 35871                 [Henri Guisan (1874-1960), General]
# 35902                       [Emil Zetter, Oberstleutnant]
# 35908                   [Peter Ludwig Zeltner, Gesandter]
# 35912                   [Peter Ludwig Zeltner, Gesandter]
# 48146                [Edmund Wyss (1867-1929), Komponist]
# ...                                                   ...
# 171723                Hochwasser in Luzern, 16. Juni 1910
# 171724                Hochwasser in Luzern, 16. Juni 1910
# 171725                Hochwasser in Luzern, 16. Juni 1910
# 171728                Hochwasser in Luzern, 16. Juni 1910
# 171730                Hochwasser in Luzern, 16. Juni 1910
# 171731                Hochwasser in Luzern, 16. Juni 1910
# 171732                Hochwasser in Luzern, 16. Juni 1910
# 171733                Hochwasser in Luzern, 16. Juni 1910
# 171735                Hochwasser in Luzern, 16. Juni 1910
# 171736                Hochwasser in Luzern, 16. Juni 1910
# 171737                Hochwasser in Luzern, 16. Juni 1910
# 171738                Hochwasser in Luzern, 16. Juni 1910
# 171739                Hochwasser in Luzern, 16. Juni 1910
# 171740                Hochwasser in Luzern, 16. Juni 1910
# 171741                Hochwasser in Luzern, 16. Juni 1910
# 171742                Hochwasser in Luzern, 16. Juni 1910
# 171743                Hochwasser in Luzern, 16. Juni 1910
# 171744                Hochwasser in Luzern, 16. Juni 1910
# 171745                Hochwasser in Luzern, 16. Juni 1910
# 171746                Hochwasser in Luzern, 16. Juni 1910
# 172275  Handlettering Ostern, frühlingsfrische Oster-P...
# 180410  The general delusion of Christians, touching t...
# 180924                         Poems on several occasions
# 180960  Probable reasons assigned for the Act of Indem...
# 181172                                      The spectator
# 181173                                      The spectator
# 182880                          Hochwasser in Luzern 1910
# 182884                          Hochwasser in Luzern 1910
# 182885                          Hochwasser in Luzern 1910
# 182886                          Hochwasser in Luzern 1910
#
#                                            ttlpart_string  \
# 18352                       [Mappemonde d'Honoré d'Autun]
# 18388                     [Mappemonde de Gautier de Metz]
# 18930   Dissertatio academica de naturæ humanæ inclina...
# 18937   Vnser/ Der Dieneren vnd Lehreren des göttliche...
# 19462   Vivaldi : L'inganno trionfante in amore Vivald...
# 19903                     Danses hongroises, [pour piano]
# 19912                     Danses hongroises, [pour piano]
# 19916               La nativité du Seigneur, [pour orgue]
# 19919                     Danses Hongroises, [pour piano]
# 19920               La nativité du Seigneur, [pour orgue]
# 19922               La nativité du Seigneur, [pour orgue]
# 22366   MISCELLANEA :  Lettere, manifest ; narrationi ...
# 23157                                  Sammelband ETH-BIB
# 26693   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 26694   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 26699   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 26710   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 29419                                           Moosedays
# 31321   Saatzucht Sensebezirk Düdingen (Guin), culture...
# 32044   Theory's autoimmunity, skepticism, literature,...
# 32077   Agend-Buch, Oder Christliche Kirchen-Gebraeuch...
# 33655                    Méthode pour orgue, [pour orgue]
# 35821   [Dr. Franziskus von Streng (1884-1970), Bischo...
# 35823   [Josef Ambühl (1873-1936), Bischof von Basel u...
# 35840            [Hermann Obrecht (1882-1940), Bundesrat]
# 35871                 [Henri Guisan (1874-1960), General]
# 35902                       [Emil Zetter, Oberstleutnant]
# 35908                   [Peter Ludwig Zeltner, Gesandter]
# 35912                   [Peter Ludwig Zeltner, Gesandter]
# 48146                [Edmund Wyss (1867-1929), Komponist]
# ...                                                   ...
# 171723                Hochwasser in Luzern, 16. Juni 1910
# 171724                Hochwasser in Luzern, 16. Juni 1910
# 171725                Hochwasser in Luzern, 16. Juni 1910
# 171728                Hochwasser in Luzern, 16. Juni 1910
# 171730                Hochwasser in Luzern, 16. Juni 1910
# 171731                Hochwasser in Luzern, 16. Juni 1910
# 171732                Hochwasser in Luzern, 16. Juni 1910
# 171733                Hochwasser in Luzern, 16. Juni 1910
# 171735                Hochwasser in Luzern, 16. Juni 1910
# 171736                Hochwasser in Luzern, 16. Juni 1910
# 171737                Hochwasser in Luzern, 16. Juni 1910
# 171738                Hochwasser in Luzern, 16. Juni 1910
# 171739                Hochwasser in Luzern, 16. Juni 1910
# 171740                Hochwasser in Luzern, 16. Juni 1910
# 171741                Hochwasser in Luzern, 16. Juni 1910
# 171742                Hochwasser in Luzern, 16. Juni 1910
# 171743                Hochwasser in Luzern, 16. Juni 1910
# 171744                Hochwasser in Luzern, 16. Juni 1910
# 171745                Hochwasser in Luzern, 16. Juni 1910
# 171746                Hochwasser in Luzern, 16. Juni 1910
# 172275  Handlettering Ostern, frühlingsfrische Oster-P...
# 180410  The general delusion of Christians, touching t...
# 180924                         Poems on several occasions
# 180960  Probable reasons assigned for the Act of Indem...
# 181172                                      The spectator
# 181173                                      The spectator
# 182880                          Hochwasser in Luzern 1910
# 182884                          Hochwasser in Luzern 1910
# 182885                          Hochwasser in Luzern 1910
# 182886                          Hochwasser in Luzern 1910
#
#                                             person_string
# 18352       Honorius, Augustodunensis, (RERO)A012323103,
# 18388               Gossouin, de Metz, (RERO)A000073443,
# 18930   Zwinger, Theodor, 1658-1724, (DE-588)118773321...
# 18937
# 19462
# 19903              Brahms, Johannes, 1833-1897, J. Brahms
# 19912              Brahms, Johannes, 1833-1897, J. Brahms
# 19916                 Messiaen, Olivier, Olivier Messiaen
# 19919        Brahms, Johannes, 1833-1897, Johannes Brahms
# 19920                 Messiaen, Olivier, Olivier Messiaen
# 19922                 Messiaen, Olivier, Olivier Messiaen
# 22366
# 23157
# 26693   Brandmüller, Johann, 1653-1710, (DE-588)103762...
# 26694   Brandmüller, Johann, 1653-1710, (DE-588)103762...
# 26699   Brandmüller, Johann, 1653-1710, (DE-588)103762...
# 26710   Brandmüller, Johann, 1653-1710, (DE-588)103762...
# 29419   Jost, Raphael, Musiker, Sänger, Instrumentalmu...
# 31321   Hilber, Leo, 1930-1986, (RERO)A003371105, cre,...
# 32044   Zalloua, Zahi Anbra, 1971-, (DE-588)140642250,...
# 32077   Brandmüller, Johann, 1653-1710, (DE-588)103762...
# 33655                              Merkel, Gustav, Merkel
# 35821
# 35823
# 35840
# 35871
# 35902
# 35908
# 35912
# 48146
# ...                                                   ...
# 171723
# 171724
# 171725
# 171728
# 171730
# 171731
# 171732
# 171733
# 171735
# 171736
# 171737
# 171738
# 171739
# 171740
# 171741
# 171742
# 171743
# 171744
# 171745
# 171746
# 172275  Schmiedicke, Katharina, (DE-588)1175249823, Ve...
# 180410         Lacy, John, 1664-, (RERO)A022773172, cre,
# 180924  Gay, John, 1685-1732, (RERO)A012320567, cre, B...
# 180960
# 181172
# 181173
# 182880
# 182884
# 182885
# 182886
#
# [248 rows x 30 columns]

# %% [markdown]
# There are 248 duplicated rows.

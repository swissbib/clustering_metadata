# %%
execution_mode = 'restricted'
factor = 0.1
exactDate_mode = 'xor'

# %% [markdown]
# # Feature Matrix Generation

# %% [markdown]
# In chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb), Swissbib's goldstandard data has been processed to form records of pairs of duplicate and pairs of unique records. These records are the starting point for the final feature matrix generation and that is the reason, why the DataFrame was called feature base. As described in [[JudACaps](./A_References.ipynb#judacaps)], the next step will be an attribute-wise comparison of each attribute pair of each record in the original feature base. This comparison will generate similarity values for each attribute pair. It will halve the number of attributes replacing each attribute pair with one value expressing their degree of similarity. The goal of this chapter is a DataFrame with the full and final feature attributes. The values of these feature attributes will be used for training and performance testing of the machine learning models in the chapters to follow.
#
# This chapter introduces similarity metrics for string comparisons. The metrics to be used for calculating its similarity will be decided for each attribute pair of the DataFrame built in the previous chapters.

# %% [markdown]
# ## Table of Contents
#
# - [Data Takeover](#Data-Takeover)
# - [Object Distance and Similarity](#Object-Distance-and-Similarity)
#     - [Mathematical Definitions](#Mathematical-Definitions)
#     - [Library TextDistance](#Library-TextDistance)
# - [Similarity Metrics on Attribute Level](#Similarity-Metrics-on-Attribute-Level)
#     - [Table of Contents of Attribute Similarities](#Table-of-Contents-of-Attribute-Similarities)
# - [DataFrame with Attributes and Similarity Features](#DataFrame-with-Attributes-and-Similarity-Features)
# - [Summary](#Summary)
#     - [Full Feature Matrix with Target Vector Handover](#Full-Feature-Matrix-with-Target-Vector-Handover)

# %% [markdown]
# ## Data Takeover

# %% [markdown]
# Swissbib's raw data of the goldstandard has been processed in chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb). As the first step of this chapter, this data is loaded for further processing to the feature matrix and target vector for the subsequent machine learning model chapters.

# %%
import os
import pandas as pd
import pickle as pk
import bz2
import _pickle as cPickle

path_goldstandard = './daten_goldstandard'

# Restore metadata so far
with open(os.path.join(path_goldstandard, 'columns_metadata.pkl'), 'rb') as handle:
    columns_metadata_dict = pk.load(handle)

# Restore DataFrame with features from compressed pickle file
with bz2.BZ2File((os.path.join(
    path_goldstandard, 'feature_base_df.pkl')), 'rb') as file:
    df_feature_base = cPickle.load(file)

# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(df_feature_base.columns)

df_feature_base.head()
# Out:
#                              035liste_x                            035liste_y  \
# 0    [(OCoLC)731635279, (ABN)000539983]    [(OCoLC)731635279, (ABN)000539983]
# 1    [(OCoLC)731635279, (ABN)000539983]  [(OCoLC)731635279, (NEBIS)009587153]
# 2    [(OCoLC)731635279, (ABN)000539983]  [(OCoLC)731635279, (LIBIB)000315536]
# 3  [(OCoLC)731635279, (NEBIS)009587153]    [(OCoLC)731635279, (ABN)000539983]
# 4  [(OCoLC)731635279, (NEBIS)009587153]  [(OCoLC)731635279, (NEBIS)009587153]
#
#   century_x century_y coordinate_E_x coordinate_E_y coordinate_N_x  \
# 0      2009      2009
# 1      2009      2009
# 2      2009      2009
# 3      2009      2009
# 4      2009      2009
#
#   coordinate_N_y coordinate_x coordinate_y corporate_110_x corporate_110_y  \
# 0                          []           []
# 1                          []           []
# 2                          []           []
# 3                          []           []
# 4                          []           []
#
#   corporate_710_x corporate_710_y corporate_full_x corporate_full_y decade_x  \
# 0                                                                       2009
# 1                                                                       2009
# 2                                                                       2009
# 3                                                                       2009
# 4                                                                       2009
#
#   decade_y    docid_x    docid_y doi_x doi_y  duplicates edition_x edition_y  \
# 0     2009  000311049  000311049                       1
# 1     2009  000311049  196506476                       1
# 2     2009  000311049  323173349                       1
# 3     2009  196506476  000311049                       1
# 4     2009  196506476  196506476                       1
#
#   exactDate_x exactDate_y format_postfix_x format_postfix_y format_prefix_x  \
# 0    2009uuuu    2009uuuu           020000           020000              bk
# 1    2009uuuu    2009uuuu           020000           020000              bk
# 2    2009uuuu    2009uuuu           020000           020000              bk
# 3    2009uuuu    2009uuuu           020000           020000              bk
# 4    2009uuuu    2009uuuu           020000           020000              bk
#
#   format_prefix_y               isbn_x               isbn_y ismn_x ismn_y  \
# 0              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 1              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 2              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 3              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
# 4              bk  [978-3-15-020008-7]  [978-3-15-020008-7]
#
#   masters_docid musicid_x musicid_y   pages_x   pages_y part_x part_y  \
# 0     504389793                      [600 S.]  [600 S.]  20008  20008
# 1     504389793                      [600 S.]  [600 S.]  20008  20008
# 2     504389793                      [600 S.]  [600 S.]  20008  20008
# 3     504389793                      [600 S.]  [600 S.]  20008  20008
# 4     504389793                      [600 S.]  [600 S.]  20008  20008
#
#   person_100_x person_100_y  \
# 0   austenjane   austenjane
# 1   austenjane   austenjane
# 2   austenjane   austenjane
# 3   austenjane   austenjane
# 4   austenjane   austenjane
#
#                                        person_245c_x  \
# 0  jane austen ; aus dem englischen übersetzt von...
# 1  jane austen ; aus dem englischen übersetzt von...
# 2  jane austen ; aus dem englischen übersetzt von...
# 3  jane austen ; aus dem engl. übers. von ursula ...
# 4  jane austen ; aus dem engl. übers. von ursula ...
#
#                                        person_245c_y  \
# 0  jane austen ; aus dem englischen übersetzt von...
# 1  jane austen ; aus dem engl. übers. von ursula ...
# 2                                        jane austen
# 3  jane austen ; aus dem englischen übersetzt von...
# 4  jane austen ; aus dem engl. übers. von ursula ...
#
#                   person_700_x                 person_700_y    pubinit_x  \
# 0  grawechristian, graweursula  grawechristian, graweursula  reclam jun.
# 1  grawechristian, graweursula                               reclam jun.
# 2  grawechristian, graweursula                               reclam jun.
# 3                               grawechristian, graweursula       reclam
# 4                                                                 reclam
#
#      pubinit_y      pubword_x      pubword_y pubyear_x pubyear_y scale_x  \
# 0  reclam jun.  [Reclam jun.]  [Reclam jun.]  2009      2009
# 1       reclam  [Reclam jun.]       [Reclam]  2009      2009
# 2       reclam  [Reclam jun.]       [Reclam]  2009      2009
# 3  reclam jun.       [Reclam]  [Reclam jun.]  2009      2009
# 4       reclam       [Reclam]       [Reclam]  2009      2009
#
#   scale_y ttlfull_245_x ttlfull_245_y ttlfull_246_x ttlfull_246_y  \
# 0           emma, roman   emma, roman
# 1           emma, roman          emma
# 2           emma, roman   emma, roman
# 3                  emma   emma, roman
# 4                  emma          emma
#
#                     ttlpart_x                   ttlpart_y volumes_x volumes_y
# 0  {'245': ['Emma', 'Roman']}  {'245': ['Emma', 'Roman']}       600       600
# 1  {'245': ['Emma', 'Roman']}           {'245': ['Emma']}       600       600
# 2  {'245': ['Emma', 'Roman']}  {'245': ['Emma', 'Roman']}       600       600
# 3           {'245': ['Emma']}  {'245': ['Emma', 'Roman']}       600       600
# 4           {'245': ['Emma']}           {'245': ['Emma']}       600       600

# %% [markdown]
# Chapter [Overview and Summary](./0_OverviewSummary.ipynb) assesses the predictions of the various models. One measure to analyse the results will be the resulting confusion matrix for a model prediction. The confusion matrix will reveal cases in the testing data that the model will predict opposite to the target values of the testing data. These predictions are called false positives and false negatives. To be able to analyse the original attribute values of the affected records in detail, columns $\texttt{035liste}\_\texttt{x}$, $\texttt{035liste}\_\texttt{y}$, $\texttt{docid}\_\texttt{x}$, and $\texttt{docid}\_\texttt{y}$ need to be restored. These four attributes will now be saved to a separate DataFrame to be reloaded in later chapters.

# %%
# Store docid's for fast identification of row pairs in model results
df_index_docids = df_feature_base[['035liste_x', '035liste_y', 'docid_x', 'docid_y']]
# The DataFrame of pairs with target information
df_feature_base = df_feature_base[columns_metadata_dict['columns_to_use']]

df_feature_base.sample(n=5)
# Out:
#         duplicates coordinate_E_x coordinate_E_y coordinate_N_x  \
# 258677           0                      e0074147
# 283238           1
# 314277           1
# 140784           0
# 211539           0
#
#        coordinate_N_y                   corporate_full_x  \
# 258677       n0460833
# 283238
# 314277
# 140784
# 211539                 schweizerische normen-vereinigung
#
#                         corporate_full_y doi_x doi_y edition_x edition_y  \
# 258677  eidgenössische landestopographie
# 283238
# 314277
# 140784
# 211539
#
#        exactDate_x exactDate_y format_prefix_x format_prefix_y  \
# 258677    2005uuuu    1943uuuu              vm              mp
# 283238    2003uuuu    2003uuuu              bk              bk
# 314277    19001950    19001950              mu              mu
# 140784    2005uuuu    1989uuuu              bk              bk
# 211539    2013uuuu    2010uuuu              bk              mu
#
#        format_postfix_x format_postfix_y               isbn_x  \
# 258677           010300           010300                   []
# 283238           020000           020000      [3-15-002620-2]
# 314277           010200           010200                   []
# 140784           020000           020053  [978-3-8067-5097-3]
# 211539           020053           030100                   []
#
#                              isbn_y ismn_x ismn_y musicid_x musicid_y  \
# 258677                           []
# 283238              [3-15-002620-2]
# 314277                           []                     245       245
# 140784  [978-3-598-31490-2 (print)]
# 211539          [978-1-85584-230-4]
#
#            part_x      part_y            person_100_x            person_100_y  \
# 258677             23 23 1943
# 283238  2620 2620   2620 2620  mozartwolfgang amadeus  mozartwolfgang amadeus
# 314277                         mozartwolfgang amadeus  mozartwolfgang amadeus
# 140784                  10 10              jacquetluc          mortzfeldpeter
# 211539                                                          steinerrudolf
#
#                                  person_700_x  \
# 258677                             jacquetluc
# 283238  kochhans-albrecht, schikanederemanuel
# 314277  kienzlwilhelm, mozartwolfgang amadeus
# 140784
# 211539
#
#                                     person_700_y  \
# 258677  dufourguillaume-henri, müllhauptheinrich
# 283238     kochhans-albrecht, schikanederemanuel
# 314277      kienzlwilhelm, mozartwlofgang amadus
# 140784                                 raabepaul
# 211539                            bridgmontpeter
#
#                                             person_245c_x  \
# 258677                           ein film von luc jacquet
# 283238  wolfgang amadeus mozart ; libretto von emanuel...
# 314277  von w.a. mozart ; klavierauszug neu rev. von w...
# 140784  luc jacquet ; übers. aus dem franz. von cornel...
# 211539
#
#                                             person_245c_y          pubinit_x  \
# 258677       g. h. dufour direxit ; h. müllhaupt sculpsit
# 283238  wolfgang amadeus mozart ; libretto von emanuel...          p. reclam
# 314277  von w.a. mozart ; klavierauszug neu rev. von w...  universal-edition
# 140784                      mortzfeld, peter; raabe, paul        gerstenberg
# 211539                                     rudolf steiner
#
#                         pubinit_y scale_x scale_y  \
# 258677  [eidg. landestopographie]          100000
# 283238                  p. reulam
# 314277          universa-ledltion
# 140784            de gruyter saur
# 211539
#
#                                             ttlfull_245_x  \
# 258677                             die reise der pinguine
# 283238  die zauberflöte, kv 620 : eine grosse oper in ...
# 314277  die zauberflöte, oper in zwei akten = il flaut...
# 140784                             die reise der pinguine
# 211539  informatique de santé - communication entre di...
#
#                                             ttlfull_245_y  \
# 258677                               domo d'ossola, arona
# 283238  die zauberflöte, kv 620 : eine grosse oper i n...
# 314277  die zauberflöte, oper inz wei akten = il flaut...
# 140784  katalog der graphischen porträts in der herzog...
# 211539               how do i find the christ?, a lecture
#
#                                             ttlfull_246_x  \
# 258677
# 283238
# 314277    die zauberflöte, ausgabe für gesang und klavier
# 140784
# 211539  medizinische informatik - kommunikation von ge...
#
#                                           ttlfull_246_y volumes_x volumes_y
# 258677                             [domodossola, arona]      1 82         2
# 283238                                                         90        90
# 314277  die zauberflöte, ausgabe für gesang und klaiver     1 167     1 167
# 140784                                                         64     1 406
# 211539                                                          1         1

# %%
print('Number of rows labelled as duplicates {:,d}'.format(len(df_feature_base[
    df_feature_base.duplicates==1])))
print('Number of rows labelled as uniques {:,d}'.format(len(df_feature_base[
    df_feature_base.duplicates==0])))
print('Total number of rows in DataFrame {:,d}'.format(df_feature_base.shape[0],
      'number of columns', df_feature_base.shape[1]))
# Out:
# Number of rows labelled as duplicates 67,158
# Number of rows labelled as uniques 257,955
# Total number of rows in DataFrame 325,113

# %%
print('Part of duplicates (1) on uniques (2) in units of [%]')
print(round(100*df_feature_base.duplicates.value_counts(normalize=True), 1))
# Out:
# Part of duplicates (1) on uniques (2) in units of [%]
# 0    79.3
# 1    20.7
# Name: duplicates, dtype: float64

# %% [markdown]
# DataFrame feature base is the starting point used for the further processing in this chapter.

# %% [markdown]
# ## Object Distance and Similarity

# %% [markdown]
# A mathematical idea of distance and similarity is needed for understanding object pair comparison. This section starts with a motivation for calculating similarities and afterwards gives a very basic definition of the two central terms, distance and similarity. The text of this section is a summary of [[Chri2012](./A_References.ipynb#chri2012)].

# %% [markdown]
# ### Mathematical Definitions

# %% [markdown]
# The attributes to be used for pair comparison may contain values of poor quality. The quality originates in the way the data has been entered at the very source. Manual data entry may suffer from mistyping, automatically scanned data may suffer from insufficiencies of the scanned base material or the recognition algorithm in the optical character recognition (OCR) processing. The basic step of a deduplication process is to identify the probability of two strings of a pair to be a pair of duplicates. This is done by calculating a similarity value between the two strings compared, rather than using an exact comparison function. Based on this common similarity value for an attribute pair, their being duplicates can be decided.

# %% [markdown]
# The term similarity is strongly coupled to the term of distance of two values of an attribute. Mathematically, a distance can be explained with the help of a distance function. A _distance function_ or _distance metric_ $dist(o_i, o_j)$ between two points or data objects $o_i$ and $o_j$ must fulfill four requirements.
#
# 1. $dist(o_i, o_i)=0$, the distance from an object to itself is zero.
# - $dist(o_i, o_j)\ge 0$, the distance between two objects is a non-negative number.
# - $dist(o_i, o_j)=dist(o_j, o_i)$, the distance between two objects is symmetric.
# - $dist(o_i, o_j)\le dist(o_i, o_k)+dist(o_k, o_j)$, the triangular inequality must hold. It states that the direct distance beween two objects is never larger than the combined distance when going through a third object.

# %% [markdown]
# A distance value expresses the dissimilarity $d$ of two objects [[HanK2012](./A_References.ipynb#hank2012)] and can therefore be converted into a similarity value $s$, calculating $s = \frac{1}{d}$, assuming $d\gt 0$. Alternatively, assuming the distance value is normalised $0\le d\le 1$, the similarity value can be calculated to $s = 1-d$. A _similarity function_ $sim(a_i, aj)$ between two attributes which can be strings, numbers, dates, geographic locations, text, XML documents, etc. fulfills the general requirements.
#
# 1. $sim(a_i, a_i)=1$, the result of comparing a value with itself is an exact similarity.
# - $sim(a_i, a_j)=0$, the similarity of values that are completely different from each other is 0. What accounts for 'complete different' depends upon the type of data that are compared.
# - $0\lt sim(a_i, a_j)\lt 1$, an approximate similarity between exact similarity and total dissimilarity is calculated if two attribute values are somewhat similar to each other. What accounts for 'somewhat different' depends upon the type of data that are compared.

# %% [markdown]
# The dissimilarity between two objects $o_i$ and $o_j$ can be computed based on the ratio of mismatches,
# $$
# d(o_i, o_j) = \frac{p-m}{p},
# $$
# where $m$ is the number of matching attributes and $p$ is the total number of attributes describing the objects [[HanK2012](./A_References.ipynb#hank2012)]. Thus the similarity between two objects can be computed as
# $$
# sim(o_i, o_j) = 1 - d(o_i, o_j) = \frac{m}{p}.
# $$

# %% [markdown]
# For data deduplication, a comparison function needs to be tailored to the type of underlying data. Although there is a correspondence between a similarity function and the mathematical concept of a distance function, not all known and implemented similarity comparison functions used for string pair comparison fulfill the requirements of a distance function. Some similarity functions are not symmetric, others do not fulfill the triangular inequality. Decision taking on the best similarity function for a string pair, will be based on the effect, a similarity function has for the purpose needed. In the case of this capstone project, this purpose is its capability to contribute to the prediction whether a pair of records is a pair duplicates or a pair of uniques.

# %% [markdown]
# ### Library TextDistance

# %% [markdown]
# An internet research on string distance calculation with Python has revealed libraries [[StSi](./A_References.ipynb#stsi)], [[TeDi](./A_References.ipynb#tedi)] and seperate code snippets for distinct algorithms. After trying the referenced libraries and a downloaded code snippet for a Smith Waterman similarity [[SmWa](./A_References.ipynb#smwa)], the text distance library [[TeDi](./A_References.ipynb#tedi)] has been decided to be the best decision for this capstone project. The decision is based on the GitHub statistics of stars and the date of the latest pull requests, indicating its popularity and maintenance activity of the library. A look at the API of the library, reveals the Python library to be a complete implementation (compared to suggestions of similarity metrics in [[Chri2012](./A_References.ipynb#chri2012)]) and easy to use.

# %%
# Install textdistance Python library - if not done, yet.
! pip install textdistance
# Out:
# Requirement already satisfied: textdistance in /Users/andreas/anaconda3/lib/python3.7/site-packages (4.1.5)

# %% [markdown]
# For using the library, see documentation in [[TeDi](./A_References.ipynb#tedi)]. For the purposes of this chapter, function $\texttt{.normalized}\_\texttt{similarity()}$ of an instantiated textdistance object will be used.

# %%
import textdistance as tedi

# %% [markdown]
# With the code line above, the library is imported for application in this chapter. In appendix [Comparison of Similarity Metrics](./B_CompareSimilarities.ipynb) the effects of the similarity metrics of the library are compared for better understanding of their specific behaviour. This comparison for each attribute is the basis of deciding the best similarity metric available for an attribute pair.

# %% [markdown]
# ## Similarity Metrics on Attribute Level

# %% [markdown]
# This section implements the decision for calculating the similarity metric for each attribute of the raw data based on appendix [Comparison of Similarity Metrics](./B_CompareSimilarities.ipynb). The implementation is applied on a pair of attributes of two records, resulting in a new attribute, the similarity value, of the final feature matrix. A general function $\texttt{build_delta_feature}$ is provided by the code file [data_preparation_funcs.py](./data_preparation_funcs.py) for transforming two attributes into their feature attribute holding their similarity value.

# %%
import data_preparation_funcs as dpf

# %% [markdown]
# ### Table of Contents of Attribute Similarities
#
# - [coordinate](#coordinate)
# - [corporate](#corporate)
# - [doi](#doi)
# - [edition](#edition)
# - [exactDate](#exactDate)
# - [format](#format)
# - [isbn](#isbn)
# - [ismn](#ismn)
# - [musicid](#musicid)
# - [part](#part)
# - [person](#person)
# - [pubinit](#pubinit)
# - [scale](#scale)
# - [ttlfull](#ttlfull)
# - [volumes](#volumes)

# %%
# These dictionary attributes will be filled in function dpf.build_delta_feature()
columns_metadata_dict['similarity_metrics'] = {}
columns_metadata_dict['features'] = []

# %% [markdown]
# ### coordinate

# %% [markdown]
# As discussed in chapter [Data Analysis](./1_DataAnalysis.ipynb), attribute $\texttt{coordinate}$ holds coordinates of maps. To decide whether a map covers the same geographical range, a metric will be chosen that compares the coordinate number digits from left to right. The more digits are found to be the equal, the higher the similarity value is calculated. The comparison stops with the first digit pair that differs. This algorithm is satisfyed by the LCS (Longest Common Substring comparison) algorithm and generates the wanted result, see appendix [Comparison of Similarity Metrics](./B_CompareSimilarities.ipynb).

# %%
attribute = 'coordinate'

columns_metadata_dict['similarity_metrics'][attribute+'_E'] = tedi.LCSStr()
columns_metadata_dict['similarity_metrics'][attribute+'_N'] = tedi.LCSStr()

ne_values = ['_E', '_N']

for ne in ne_values :
    df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
        df_feature_base, attribute+ne,
        columns_metadata_dict['similarity_metrics'][attribute+ne],
        columns_metadata_dict)

# %% [markdown]
# The length of attribute $\texttt{coordinate}$ is exactly eight digits. The distinct similarity values that may occurr form a discrete set of values with a distance of $\frac{1}{8}$ between adjacent values.

# %%
uniques, uniques_len = {}, {}

for ne in ne_values :
    uniques[attribute+ne], uniques_len[attribute+ne] = dpf.determine_similarity_values(
        df_feature_base, attribute+ne)
# Out:
# coordinate_E values range [0.    0.125 0.25  0.375 0.5   0.625 0.875 1.   ]
# coordinate_N values range [0.    0.375 0.5   0.625 0.75  0.875 1.   ]

# %% [markdown]
# Looking at some samples of the feature matrix reveals a good match to the expectations.

# %%
position = 3

for ne in ne_values :
    dpf.show_samples_interval(
        df_feature_base, attribute+ne,
        uniques[attribute+ne][uniques_len[attribute+ne]-position],
        uniques[attribute+ne][uniques_len[attribute+ne]-position+1]
    )
# Out:
#         duplicates  coordinate_E_delta coordinate_E_x coordinate_E_y
# 196658           0               0.625       e0055700       e0055009
# 854              1               0.875       e0080855       e0080851
# 182806           0               0.875       e0080855       e0080851
# 96166            0               0.625       e0080851       e0080900
# 863              1               0.875       e0080851       e0080855
# 0.625 <= coordinate_E_delta <= 0.875
#         duplicates  coordinate_N_delta coordinate_N_x coordinate_N_y
# 267550           1                0.75       n0460833       0n460833
# 54937            0                0.75       n0460826       n0460833
# 182777           0                0.75       n0460826       n0460833
# 318040           1                0.75       n0474800       0n474800
# 270949           1                0.75       n0460833       0n460833
# 0.75 <= coordinate_N_delta <= 0.875

# %% [markdown]
# The samples above show the wanted similarity behaviour for value ranges greater than 0. The metric has the weakness, though, that empty coordinate values, e.g. for bibliographical units other than maps, have each been calculated to a similarity of 0. Some samples for duplicates in the training data are shown below.

# %%
dpf.show_samples_interval(
    df_feature_base[df_feature_base.duplicates==1],
    attribute+'_E', uniques[attribute+'_E'][0], uniques[attribute+'_E'][1], 10)
# Out:
#         duplicates  coordinate_E_delta coordinate_E_x coordinate_E_y
# 272180           1               0.000
# 320755           1               0.000
# 284253           1               0.000
# 314881           1               0.000
# 299514           1               0.000
# 308352           1               0.000
# 262745           1               0.000
# 312262           1               0.000
# 296907           1               0.125       e0074147       n0460833
# 304992           1               0.000
# 0.0 <= coordinate_E_delta <= 0.125

# %% [markdown]
# This downside shall be avoided by marking pairs of missing coordinate values on both sides with a special negative value, which will point out to the models to be trained, the special case of missing information in a row. The implementation of this logic is done in function $\texttt{.mark}\_\texttt{missing}()$. The absolute value of this negative number is conrolled by a factor which is passed to the function as a parameter. The function handles explicitly two cases. The first one is missing information in both attributes (resulting in $-1*\texttt{factor}$) and the second one is missing information in only one of the two attributes (resulting in $-0.5*\texttt{factor}$).

# %%
for ne in ne_values :
    df_feature_base = dpf.mark_missing(df_feature_base, attribute+ne, factor)

# %% [markdown]
# ### corporate

# %% [markdown]
# Attribute $\texttt{corporate}$ is a collection of corporate names. The Monge-Elkan metric compares string tokens pairwise [[Chri2012](./A_References.ipynb#chri2012)] while the LCS metric searches for the longest common substring. Assessing the differences of these two metrics with the help of their values distribution in chapter [Features Discussion and Dummy Classifier Baseline](./5_FeatureDiscussionDummyBaseline.ipynb), reveals a better distribution behaviour for LCS. Therefore, the LCS metric will be chosen for this attribute.

# %%
attribute = 'corporate_full'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.LCSStr()
#tedi.StrCmp95()
#tedi.MongeElkan()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)
# Out:
# corporate_full values range [0.         0.01333333 0.01428571 0.01639344 0.01666667 0.01694915
#  0.01818182 0.01960784 0.02       0.02040816 0.0212766  0.02173913
#  0.02272727 0.02380952 0.025      0.02531646 0.02542373 0.02666667
#  0.02702703 0.02727273 0.02857143 0.03       0.03030303 0.03125
#  0.03225806 0.03278689 0.03333333 0.03389831 0.03448276 0.03571429
#  0.03636364 0.03773585 0.03797468 0.03846154 0.03921569 0.04
#  0.04081633 0.04166667 0.04237288 0.04255319 0.04285714 0.04347826
#  0.04444444 0.04545455 0.046875   0.04761905 0.04878049 0.04918033
#  0.05       0.05263158 0.05333333 0.05405405 0.05454545 0.05555556
#  0.05660377 0.05714286 0.05882353 0.05932203 0.06       0.06060606
#  0.06122449 0.0625     0.06329114 0.06363636 0.06382979 0.06451613
#  0.06521739 0.06557377 0.06666667 0.06779661 0.06818182 0.06896552
#  0.07       0.07142857 0.07272727 0.07317073 0.075      0.0754717
#  0.07594937 0.07627119 0.07692308 0.078125   0.07843137 0.07894737
#  0.08       0.08108108 0.08163265 0.08181818 0.08333333 0.08474576
#  0.08510638 0.08571429 0.08695652 0.08888889 0.09090909 0.09333333
#  0.09375    0.0952381  0.09677419 0.09756098 0.09803922 0.1
#  0.10126582 0.10169492 0.10204082 0.10344828 0.10526316 0.10666667
#  0.10810811 0.10869565 0.11111111 0.11428571 0.1147541  0.11538462
#  0.11666667 0.11764706 0.11904762 0.12       0.12121212 0.12195122
#  0.12244898 0.125      0.12727273 0.12765957 0.13043478 0.13157895
#  0.13207547 0.13513514 0.13636364 0.1372549  0.13793103 0.14285714
#  0.14634146 0.15       0.15217391 0.15384615 0.15555556 0.16326531
#  0.16981132 0.17241379 0.17391304 0.17647059 0.17777778 0.18181818
#  0.18421053 0.18666667 0.1875     0.18918919 0.19230769 0.19607843
#  0.19672131 0.2        0.20408163 0.21212121 0.21818182 0.24
#  0.24242424 0.25       0.25333333 0.26086957 0.26666667 0.27027027
#  0.27272727 0.275      0.28       0.28125    0.28181818 0.28571429
#  0.29090909 0.29166667 0.3        0.3030303  0.30434783 0.30612245
#  0.30769231 0.31111111 0.31147541 0.3125     0.31428571 0.31578947
#  0.31818182 0.31914894 0.32       0.3220339  0.32352941 0.32432432
#  0.3255814  0.32786885 0.33333333 0.33636364 0.34042553 0.34090909
#  0.34177215 0.34210526 0.34285714 0.34375    0.34482759 0.34545455
#  0.34615385 0.34693878 0.34782609 0.34883721 0.35       0.35135135
#  0.35294118 0.35483871 0.35555556 0.35714286 0.35849057 0.35897436
#  0.36       0.36065574 0.36111111 0.36231884 0.36363636 0.36585366
#  0.36666667 0.36842105 0.36956522 0.37142857 0.37254902 0.375
#  0.37777778 0.37837838 0.37931034 0.38       0.38095238 0.38235294
#  0.38333333 0.38461538 0.38571429 0.38666667 0.38709677 0.3877551
#  0.38888889 0.39       0.39130435 0.39215686 0.39285714 0.39344262
#  0.39393939 0.39473684 0.39534884 0.4        0.40425532 0.4047619
#  0.40540541 0.40625    0.40740741 0.40789474 0.40909091 0.40983607
#  0.41025641 0.41176471 0.41304348 0.41509434 0.41666667 0.41772152
#  0.41860465 0.42105263 0.42222222 0.42307692 0.42424242 0.425
#  0.42622951 0.42857143 0.43137255 0.43181818 0.43243243 0.43333333
#  0.43396226 0.43478261 0.43589744 0.43636364 0.4375     0.44
#  0.44117647 0.44230769 0.44262295 0.44285714 0.44303797 0.44444444
#  0.44545455 0.44642857 0.44736842 0.45       0.45070423 0.45098039
#  0.45238095 0.45283019 0.45454545 0.4556962  0.45652174 0.45833333
#  0.45901639 0.45945946 0.46       0.46153846 0.46341463 0.46363636
#  0.46376812 0.46428571 0.46478873 0.46666667 0.46808511 0.46835443
#  0.46875    0.46938776 0.47058824 0.47142857 0.47272727 0.47368421
#  0.47457627 0.475      0.47540984 0.47619048 0.47727273 0.47826087
#  0.47887324 0.4789916  0.47916667 0.48       0.48076923 0.48148148
#  0.48275862 0.48333333 0.48387097 0.48484848 0.48514851 0.48648649
#  0.48717949 0.48780488 0.48837209 0.48888889 0.4893617  0.48979592
#  0.49       0.49019608 0.49090909 0.49180328 0.49295775 0.49333333
#  0.49367089 0.4954955  0.5        0.50632911 0.50666667 0.50704225
#  0.50724638 0.50819672 0.50909091 0.50943396 0.50980392 0.51
#  0.51020408 0.5106383  0.51111111 0.51162791 0.51219512 0.5125
#  0.51260504 0.51282051 0.51315789 0.51351351 0.51428571 0.51515152
#  0.51612903 0.51666667 0.51694915 0.51724138 0.51818182 0.51851852
#  0.51923077 0.52       0.52173913 0.52272727 0.52380952 0.52459016
#  0.525      0.52542373 0.52631579 0.52727273 0.52830189 0.52857143
#  0.52941176 0.53061224 0.53125    0.53164557 0.53191489 0.53333333
#  0.53389831 0.53488372 0.53521127 0.53571429 0.53658537 0.53703704
#  0.53846154 0.53947368 0.54       0.54054054 0.54098361 0.54166667
#  0.54285714 0.54347826 0.54545455 0.54621849 0.54716981 0.54761905
#  0.54901961 0.55       0.55084746 0.55102041 0.55172414 0.55263158
#  0.55454545 0.55555556 0.55714286 0.55737705 0.55769231 0.55813953
#  0.55855856 0.55882353 0.56       0.56097561 0.5625     0.56410256
#  0.56521739 0.56603774 0.56666667 0.56756757 0.56818182 0.56862745
#  0.57142857 0.57333333 0.57377049 0.57446809 0.575      0.57575758
#  0.57657658 0.57692308 0.57777778 0.57894737 0.57971014 0.58
#  0.58064516 0.58139535 0.58181818 0.58227848 0.58333333 0.58490566
#  0.58536585 0.58571429 0.58666667 0.58695652 0.58823529 0.58974359
#  0.59       0.59016393 0.59090909 0.59183673 0.59210526 0.59259259
#  0.59322034 0.59375    0.5942029  0.59459459 0.59493671 0.5952381
#  0.59574468 0.59615385 0.6        0.60377358 0.6039604  0.60465116
#  0.60526316 0.60606061 0.60655738 0.60714286 0.60759494 0.60784314
#  0.60869565 0.60909091 0.6097561  0.61       0.61016949 0.61111111
#  0.6122449  0.61290323 0.61333333 0.61363636 0.61428571 0.61538462
#  0.61666667 0.61702128 0.61764706 0.61818182 0.61842105 0.61864407
#  0.61904762 0.61971831 0.62       0.62025316 0.62068966 0.62162162
#  0.62222222 0.62264151 0.62295082 0.62318841 0.62376238 0.625
#  0.62666667 0.62711864 0.62727273 0.62745098 0.62790698 0.62857143
#  0.62962963 0.63043478 0.63157895 0.63265306 0.63291139 0.63333333
#  0.63366337 0.63380282 0.63414634 0.63461538 0.63559322 0.63636364
#  0.6375     0.63829787 0.63888889 0.63934426 0.64       0.64102564
#  0.64150943 0.64285714 0.64444444 0.64473684 0.64516129 0.64545455
#  0.64705882 0.64864865 0.65       0.65116279 0.65217391 0.65306122
#  0.65333333 0.65384615 0.65454545 0.65517241 0.6557377  0.65625
#  0.65714286 0.65789474 0.65822785 0.65853659 0.65909091 0.65957447
#  0.66       0.66037736 0.66071429 0.66101695 0.66336634 0.66666667
#  0.66949153 0.67       0.67213115 0.67272727 0.67307692 0.67346939
#  0.67391304 0.6744186  0.675      0.67567568 0.67647059 0.67741935
#  0.6779661  0.67857143 0.68       0.68085106 0.68115942 0.68181818
#  0.68292683 0.68333333 0.6835443  0.68421053 0.68571429 0.68627451
#  0.6875     0.68852459 0.68888889 0.68965517 0.69       0.69014085
#  0.69047619 0.69090909 0.69230769 0.69333333 0.69369369 0.69387755
#  0.69444444 0.69491525 0.69565217 0.69620253 0.69642857 0.6969697
#  0.69736842 0.69767442 0.7        0.70212766 0.7027027  0.7037037
#  0.70491803 0.70588235 0.70731707 0.70833333 0.70909091 0.70967742
#  0.71       0.71014493 0.71052632 0.71111111 0.71153846 0.71171171
#  0.71428571 0.71666667 0.7173913  0.71818182 0.71830986 0.71875
#  0.72       0.72033898 0.72072072 0.72093023 0.72131148 0.72151899
#  0.72222222 0.72340426 0.72368421 0.72413793 0.72463768 0.725
#  0.7254902  0.72727273 0.72972973 0.73       0.73076923 0.73170732
#  0.73333333 0.73469388 0.73529412 0.73584906 0.73636364 0.73684211
#  0.73770492 0.73809524 0.73913043 0.74       0.74074074 0.74193548
#  0.74285714 0.74358974 0.74418605 0.74468085 0.74509804 0.74545455
#  0.74576271 0.74666667 0.74683544 0.75       0.75247525 0.75409836
#  0.75423729 0.75454545 0.75510204 0.75555556 0.75609756 0.75675676
#  0.75714286 0.75757576 0.75862069 0.76       0.76086957 0.76190476
#  0.7625     0.76271186 0.76315789 0.76363636 0.76470588 0.76576577
#  0.76595745 0.76666667 0.76744186 0.76811594 0.76923077 0.7704918
#  0.77118644 0.77142857 0.7721519  0.77272727 0.77333333 0.77358491
#  0.77419355 0.77477477 0.775      0.7755102  0.77631579 0.77777778
#  0.78       0.7804878  0.78125    0.78181818 0.78217822 0.7826087
#  0.78333333 0.78378378 0.78431373 0.78481013 0.78571429 0.78666667
#  0.78688525 0.78723404 0.78787879 0.78846154 0.78947368 0.78991597
#  0.79       0.79069767 0.79166667 0.79279279 0.79310345 0.79411765
#  0.79487179 0.79545455 0.79591837 0.79746835 0.79831933 0.8
#  0.80263158 0.80327869 0.80392157 0.80434783 0.80487805 0.80508475
#  0.80555556 0.80645161 0.80672269 0.80769231 0.80851064 0.80952381
#  0.81012658 0.81081081 0.81132075 0.8115942  0.8125     0.81395349
#  0.81428571 0.81481481 0.81578947 0.81632653 0.81666667 0.81690141
#  0.81818182 0.81967213 0.82       0.82051282 0.82142857 0.82222222
#  0.82352941 0.825      0.82608696 0.82666667 0.82758621 0.82857143
#  0.82882883 0.82926829 0.82978723 0.83018868 0.83168317 0.83333333
#  0.83544304 0.83606557 0.83636364 0.83673469 0.8372093  0.83783784
#  0.83870968 0.83898305 0.83928571 0.84       0.84057971 0.84090909
#  0.84210526 0.84285714 0.84313725 0.84375    0.84444444 0.84545455
#  0.84615385 0.84684685 0.84782609 0.84810127 0.84848485 0.8490566
#  0.85       0.85106383 0.85245902 0.85294118 0.85365854 0.8559322
#  0.85714286 0.86       0.86046512 0.86206897 0.8627451  0.86363636
#  0.86486486 0.86538462 0.86666667 0.86792453 0.86842105 0.86885246
#  0.86956522 0.87096774 0.87128713 0.87179487 0.87234043 0.87272727
#  0.87288136 0.875      0.87755102 0.87804878 0.87878788 0.88
#  0.88095238 0.88181818 0.88235294 0.88333333 0.88372093 0.88405797
#  0.88461538 0.8852459  0.88571429 0.88607595 0.88636364 0.88888889
#  0.88983051 0.89       0.89090909 0.89130435 0.89189189 0.89285714
#  0.89333333 0.89361702 0.89473684 0.89655172 0.89795918 0.89855072
#  0.89873418 0.9        0.90140845 0.90163934 0.90196078 0.90322581
#  0.90384615 0.9047619  0.90566038 0.90625    0.90666667 0.90677966
#  0.90697674 0.90909091 0.91       0.91111111 0.91139241 0.91176471
#  0.91304348 0.91428571 0.91666667 0.91803279 0.91818182 0.91836735
#  0.91891892 0.92       0.92105263 0.92156863 0.92307692 0.9245283
#  0.925      0.92592593 0.92682927 0.92727273 0.92792793 0.92857143
#  0.92957746 0.93       0.93023256 0.93103448 0.93181818 0.93220339
#  0.93333333 0.93421053 0.93442623 0.93478261 0.93548387 0.93617021
#  0.93636364 0.9375     0.93877551 0.93939394 0.94       0.94059406
#  0.94117647 0.94230769 0.94285714 0.94339623 0.94444444 0.94545455
#  0.94594595 0.94666667 0.94736842 0.94871795 0.95       0.95081967
#  0.95121951 0.95238095 0.95348837 0.95454545 0.95555556 0.95652174
#  0.95744681 0.95762712 0.95774648 0.95798319 0.95833333 0.95918367
#  0.96       0.96052632 0.96078431 0.96153846 0.96226415 0.9625
#  0.96296296 0.96363636 0.96396396 0.96428571 0.96551724 0.96638655
#  0.96666667 0.96721311 0.96774194 0.96875    0.96969697 0.97058824
#  0.97101449 0.97142857 0.97183099 0.97272727 0.97297297 0.97333333
#  0.97368421 0.97457627 0.975      0.97560976 0.97619048 0.97727273
#  0.97777778 0.97826087 0.97916667 0.97959184 0.98       0.98039216
#  0.98076923 0.98181818 0.98333333 0.98360656 0.98571429 0.98734177
#  0.99090909 1.        ]

# %% [markdown]
# Its $110$ part is sparsely filled and even its $710$ part comes along with a little more than $10\%$ of filling, only. The LCS metric generates a similarity of 1 for the cases where both strings of a pair are empty. Missing values on both sides may be an indicator for a pair of duplicates but due to the sparsely available information, it is a weak indicator. Therefore, the pairs with missing data on both sides of the pair, will be marked with the negative value.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, attribute, factor)

# %% [markdown]
# Some sample cases are shown below for both $\texttt{corporate}$ features.

# %%
dpf.show_samples_interval(
    df_feature_base[df_feature_base.duplicates==1],
    attribute, 0.0, 1.0, 20
)
# Out:
#         duplicates  corporate_full_delta  \
# 312672           1              1.000000
# 266618           1              1.000000
# 312733           1              0.606557
# 297161           1              1.000000
# 306006           1              1.000000
# 315010           1              1.000000
# 297354           1              0.666667
# 259590           1              0.666667
# 273398           1              0.866667
# 284267           1              0.500000
# 262414           1              1.000000
# 315255           1              1.000000
# 267231           1              0.729730
# 295004           1              1.000000
# 282195           1              0.508197
# 297131           1              1.000000
# 267515           1              1.000000
# 287805           1              1.000000
# 300100           1              1.000000
# 283375           1              1.000000
#
#                                          corporate_full_x  \
# 312672  interkantonale lehrmittelzentrale (rapperswil,...
# 266618                  interkantonale lehrmittelzentrale
# 312733  interkantonale lehrmittelzentrale (rapperswil,...
# 297161      schweizeidgenössisches topographisches bureau
# 306006                  schweizerische normen-vereinigung
# 315010                               les arts florissants
# 297354                   eidgenössische landestopographie
# 259590                              wiener philharmoniker
# 273398                                    bühnen kölnoper
# 284267  interkantonale lehrmittelzentrale (rapperswil,...
# 262414                                     quatre violons
# 315255  berliner philharmoniker, deutsche oper (berlin...
# 267231              eidgenssisches topographisches bureau
# 295004      schweizeidgenössisches topographisches bureau
# 282195  interkantonale lehrmittelzentrale (rapperswil,...
# 297131      schweizeidgenössisches topographisches bureau
# 267515              eidgenssisches topographisches bureau
# 287805  interkantonale lehrmittelzentrale (rapperswil,...
# 300100       uniwersytet im. adama mickiewicza w poznaniu
# 283375  interkantonale lehrmittelzentrale (rapperswil,...
#
#                                          corporate_full_y
# 312672  interkantonale lehrmittelzentrale (rapperswil,...
# 266618                  interkantonale lehrmittelzentrale
# 312733  interkantonale lehrmittelzentrale (raupperswli...
# 297161      schweizeidgenössisches topographisches bureau
# 306006                  schweizerische normen-vereinigung
# 315010                               les arts florissants
# 297354                  eidgevnösshsche landestopographie
# 259590                              wienerlphilharmoniker
# 273398                                    bühnen kölnopre
# 284267  interkantonale lehrmittelzentoale (rapperswil,...
# 262414                                     quatre violons
# 315255  berliner philharmoniker, deutsche oper (berlin...
# 267231              eigdenssisches topographisches iureau
# 295004      schweizeidgenössisches topographisches bureau
# 282195  interkantonale lehrmittelzentfrale (rapperswil...
# 297131      schweizeidgenössisches topographisches bureau
# 267515              eidgenssisches topographisches bureau
# 287805  interkantonale lehrmittelzentrale (rapperswil,...
# 300100       uniwersytet im. adama mickiewicza w poznaniu
# 283375  interkantonale lehrmittelzentrale (rapperswil,...
# 0.0 <= corporate_full_delta <= 1.0

# %%
position = uniques_len[attribute]//2 # Let's have a look in the middle range of the similarities.

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position],
    uniques[attribute][uniques_len[attribute]-position+2], 20)
# Out:
#         duplicates  corporate_full_delta  \
# 284262           1              0.616667
# 270914           1              0.615385
# 284444           1              0.616667
# 302246           1              0.615385
# 281782           1              0.616667
# 287815           1              0.616667
# 301638           1              0.616667
# 281680           1              0.616667
# 276489           1              0.614286
# 315222           1              0.615385
# 283047           1              0.616667
# 301272           1              0.616667
# 287655           1              0.616667
# 287825           1              0.616667
#
#                                          corporate_full_x  \
# 284262  interkantonale lehrmittelzentrale (rapperswil,...
# 270914             eidgenössisches topographisches bureau
# 284444  interkantonale lehrmittelzentrale (rapperswil,...
# 302246  opernhaus (zürich)orchester, opernhaus (zürich...
# 281782  interkantonale lehrmittelzentrale (rapperswil,...
# 287815  interkantonale lehrmittelzentrale (rapperswil,...
# 301638  interkantonale lehrmittelzentrale (rapperswil,...
# 281680  interkantonale lehrmittelzentrale (rapperswil,...
# 276489  interkantonale lehrmittelzentrale, staatlicher...
# 315222  berliner philharmoniker, deutsche oper (berlin...
# 283047  interkantonale lehrmittelzentrale (rapperswil,...
# 301272  interkantonale lehrmittelzentrale (rapperswil,...
# 287655  interkantonale lehrmittelzentrale (rapperswil,...
# 287825  interkantonale lehrmittelzentrale (rapperswil,...
#
#                                          corporate_full_y
# 284262  interkantonale lehrmitkelzentrale (rapperswil,...
# 270914            eidgenössisches topograpahisches bureau
# 284444  interkantonalel ehrmittelzentrale (rapperswil,...
# 302246  opernhaus (zürich)orchester, opevnhaus (zürich...
# 281782  interkantonale mlehrmittelzentrale (rapperswil...
# 287815  interkantonae lehrmittmelzentrale (rapperswil,...
# 301638  interkantonale lehrmitnelzentrale (rapperswil,...
# 281680  interkantonale lehrmittelzentrale (raiperswil,...
# 276489  interkantonale lehrmittelzentrale, staatlicehr...
# 315222  bverliner philharmoziker, deutsche oper (berli...
# 283047  interkantonale lehrmieelzentrale (rapperswil, ...
# 301272  interkantonale lehrmithelzentrale (rapperswil,...
# 287655  interkantonale lehrmittelzentrale (raiperswil,...
# 287825  interkantonale lehrmittelzentrale (racperswil,...
# 0.6142857142857143 <= corporate_full_delta <= 0.6166666666666667

# %% [markdown]
# ### doi

# %% [markdown]
# Swissbib uses an explicit $\texttt{doi}$ attribute for its deduplication implementation. In chapter [Goldstandard and Data Preparation](./2_GoldstandardDataPreparation.ipynb), the real doi identifier has been isolated with the help of a preprocessing function $\texttt{.reduce}\_\texttt{to}\_\texttt{doi}\_\texttt{element()}$, see [Data Analysis](./1_DataAnalysis.ipynb). Attribute $\texttt{doi}$ contains a single string value. The Identity metric will be used for comparing the string values of a pair in a row, calculating a similarity value of 1.0 or 0.0 for each pair. If one list is empty a value of 0 is returned.

# %%
attribute = 'doi'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.Identity()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

df_feature_base['doi_delta'].unique()
# Out:
# array([1., 0.])

# %% [markdown]
# Some sample cases are shown below for each category of $\texttt{doi}\_\texttt{delta}$.

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)

for doi_delta_value in df_feature_base['doi_delta'].unique():
    number_of_max_samples = min(
        10,
        len(df_feature_base[df_feature_base['doi_delta']==doi_delta_value])
    )

    dpf.show_samples_distinct(df_feature_base, 'doi', doi_delta_value, number_of_max_samples)
    print(f'doi_delta = {doi_delta_value}')
# Out:
# doi values range [0. 1.]
#         duplicates  doi_delta doi_x doi_y
# 46677            0        1.0
# 158078           0        1.0
# 28712            0        1.0
# 30232            0        1.0
# 143720           0        1.0
# 44436            0        1.0
# 41721            0        1.0
# 245413           0        1.0
# 30424            0        1.0
# 146825           0        1.0
# doi_delta = 1.0
#         duplicates  doi_delta                 doi_x                 doi_y
# 233119           0        0.0                        10.5169/seals-377251
# 14280            0        0.0                        10.5169/seals-376437
# 122307           0        0.0                        10.3931/e-rara-50903
# 21968            0        0.0                           10.5167/uzh-67756
# 120434           0        0.0                        10.5169/seals-376689
# 241450           0        0.0                        10.5169/seals-515356
# 88997            0        0.0                        10.5169/seals-376396
# 190222           0        0.0   10.1055/b-002-26639
# 202876           0        0.0                        10.5169/seals-377251
# 255352           0        0.0  10.1055/b-005-143650
# doi_delta = 0.0

# %%
# Let's have a look at some non-empty doi elements
df_doi_with_element = df_feature_base[df_feature_base.doi_x.apply(lambda x : len(x) > 0)]

for doi_delta_value in df_feature_base['doi_delta'].unique():
    number_of_max_samples = min(
        10,
        len(df_feature_base[df_feature_base['doi_delta']==doi_delta_value])
    )

    dpf.show_samples_distinct(df_doi_with_element, 'doi', doi_delta_value, number_of_max_samples)
    print(f'doi_delta = {doi_delta_value}')
# Out:
#         duplicates  doi_delta                      doi_x  \
# 290453           1        1.0       10.5169/seals-376510
# 319283           1        1.0  10.1007/978-3-642-41698-9
# 292577           1        1.0       10.5169/seals-377392
# 291419           1        1.0       10.5169/seals-376925
# 290640           1        1.0       10.5169/seals-376572
# 292705           1        1.0       10.5169/seals-377422
# 292046           1        1.0       10.5169/seals-377188
# 291245           1        1.0       10.5169/seals-376850
# 291491           1        1.0       10.5169/seals-376961
# 290524           1        1.0       10.5169/seals-376539
#
#                             doi_y
# 290453       10.5169/seals-376510
# 319283  10.1007/978-3-642-41698-9
# 292577       10.5169/seals-377392
# 291419       10.5169/seals-376925
# 290640       10.5169/seals-376572
# 292705       10.5169/seals-377422
# 292046       10.5169/seals-377188
# 291245       10.5169/seals-376850
# 291491       10.5169/seals-376961
# 290524       10.5169/seals-376539
# doi_delta = 1.0
#         duplicates  doi_delta                      doi_x                 doi_y
# 168034           0        0.0         10.1093/cid/ciu795
# 200480           0        0.0  10.1007/978-3-642-41698-9  10.5169/seals-376359
# 193508           0        0.0   10.5451/unibas-006499413
# 207370           0        0.0         10.1093/cid/ciu795
# 194206           0        0.0   10.5451/unibas-006503313
# 154814           0        0.0          10.5167/uzh-53042
# 194685           0        0.0   10.5451/unibas-006503313
# 162765           0        0.0  10.1007/978-3-642-41698-9
# 253151           0        0.0       10.1055/b-005-143650
# 255482           0        0.0       10.1055/b-005-143650
# doi_delta = 0.0

# %% [markdown]
# As can be seen above, a value of 1.0 is returned if both strings of a pair are empty. As the attribute filling of $\texttt{doi}$ is sparse, see chapter [Data Analysis](./1_DataAnalysis.ipynb), the $\texttt{doi}\_\texttt{delta}$ indicates strongly a pair of duplicates for most rows. To avoid such misleading identity indication, function $\texttt{.mark}\_\texttt{missing()}$ will be applyed to the attribute.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, attribute, factor)

# %% [markdown]
# ### edition

# %% [markdown]
# In its original form in Swissbib's raw data, the edition statement is a string value which may have several words. The modelling on this attribute has been tried with and without stripping letter characters from the string. The final decision for the best processing will be documented in chapter [Overview and Summary](./0_OverviewSummary.ipynb). A Jaccard similarity is tried for this attribute.

# %%
attribute = 'edition'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.Jaccard()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)

import numpy as np

edition_delta_uniques = np.sort(df_feature_base['edition_delta'].unique())
edition_delta_uniques_len = len(edition_delta_uniques)
print('edition values range', edition_delta_uniques[:30])
# Out:
# edition values range [0.         0.125      0.14285714 0.16666667 0.2        0.25
#  0.28571429 0.33333333 0.4        0.5        0.6        1.        ]
# edition values range [0.         0.125      0.14285714 0.16666667 0.2        0.25
#  0.28571429 0.33333333 0.4        0.5        0.6        1.        ]

# %% [markdown]
# The comparison results in a wide number of distinct similarity values for the goldstandard data set. Below, some examples are shown.

# %%
position = edition_delta_uniques_len

dpf.show_samples_interval(
    df_feature_base, 'edition',
    edition_delta_uniques[edition_delta_uniques_len-position-2],
    edition_delta_uniques[edition_delta_uniques_len-position-1], 10)
dpf.show_samples_interval(
    df_feature_base, 'edition',
    edition_delta_uniques[edition_delta_uniques_len-position],
    edition_delta_uniques[edition_delta_uniques_len-position+2], 10)

position = edition_delta_uniques_len//2

dpf.show_samples_interval(
    df_feature_base, 'edition',
    edition_delta_uniques[edition_delta_uniques_len-position-2],
    edition_delta_uniques[edition_delta_uniques_len-position-1], 10)
# Out:
#         duplicates  edition_delta edition_x edition_y
# 306961           1            1.0
# 7603             0            1.0
# 169190           0            1.0
# 88926            0            1.0
# 90888            0            1.0
# 103558           0            1.0
# 21850            0            1.0
# 85809            0            1.0
# 250349           0            1.0
# 320569           1            1.0
# 0.6 <= edition_delta <= 1.0
#         duplicates  edition_delta edition_x edition_y
# 141418           0            0.0                   3
# 177066           0            0.0                   4
# 73421            0            0.0                   2
# 166175           0            0.0                   6
# 126915           0            0.0                1994
# 181863           0            0.0         6
# 135117           0            0.0                   3
# 246635           0            0.0                   2
# 90681            0            0.0                   2
# 234935           0            0.0                1889
# 0.0 <= edition_delta <= 0.1428571428571428
#         duplicates  edition_delta edition_x edition_y
# 55265            0           0.25         1      1943
# 41807            0           0.20      1791        13
# 41919            0           0.20      1791        10
# 181843           0           0.25         6      1926
# 248220           0           0.20     10425         2
# 104748           0           0.25         8      1899
# 184459           0           0.20      1863        11
# 123136           0           0.25         2      1926
# 248419           0           0.20     10425         2
# 105112           0           0.25         8      1899
# 0.19999999999999996 <= edition_delta <= 0.25

# %% [markdown]
# Again, for $\texttt{edition}\_\texttt{delta} = 1$, many empty values of the $\texttt{edition}$ attribute can be observed. These will be marked with the special negative value in the data with the goal to distinguish them from the matching attribute pairs.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, 'edition', factor)

# %%
position = edition_delta_uniques_len

dpf.show_samples_interval(
    df_feature_base, 'edition',
    edition_delta_uniques[edition_delta_uniques_len-position-2],
    edition_delta_uniques[edition_delta_uniques_len-position-1], 10)
# Out:
#         duplicates  edition_delta edition_x edition_y
# 317821           1            1.0      1863      1863
# 294230           1            1.0         5         5
# 321238           1            1.0         8         8
# 264619           1            1.0         2         2
# 267405           1            1.0      1885      1885
# 289203           1            1.0        11        11
# 983              1            1.0         8         8
# 282850           1            1.0         1         1
# 317167           1            1.0         2         2
# 297227           1            1.0      1928      1928
# 0.6 <= edition_delta <= 1.0

# %% [markdown]
# ### exactDate

# %% [markdown]
# As discussed in chapter [Data Analysis](./1_DataAnalysis.ipynb), attribute $\texttt{exactDate}$ holds a year number stored in the first four digits. Letter 'u' is used as a placeholder for an unknown digit. The attribute may hold some month and day or a second year information in its second four digits, additionally.

# %% [markdown]
# The attribute will be kept as a string and will not be transformed to an integer. The feature attribute of the record pair to be compared will be calculated with a modified Hamming algorithm, see appendix [Comparison of Similarity Metrics](./B_CompareSimilarities.ipynb). The resulting similarity will be stored in a new attribute $\texttt{exactDate}\_\texttt{delta}$ which will be taken for the model calculation.
#
# As can be seen in chapter [Decision Tree Model](./6_DecisionTreeModel.ipynb), this attribute is important for prediction. Different ways of increasing the weight of the unknown status of a digit have been tried. The different ways can be seen in the implementations below. The algorithm decided for the final simulation will be documented in chapter [Overview and Summary](./0_OverviewSummary.ipynb).

# %%
import string

def no_xor (x_side, y_side) :
    number = 0
    for i in range(len(x_side)) :
        if ((x_side[i] in string.ascii_lowercase) | (y_side[i] in string.ascii_lowercase)) & (x_side[i] != y_side[i]) :
            number = number + 1
    return number

print('Example comparison results in a value of', no_xor ('202a0aaa', '1920uuuu'))
# Out:
# Example comparison results in a value of 5

# %%
attribute = 'exactDate'

# Replace letter 'u' with letter 'a' for one of the two strings.
#  As an effect, the resulting Hamming similarity for a letter
#  instead of a numerical digit in either string will add with an amount 0.
df_feature_base[attribute+'_x'] = df_feature_base.exactDate_x.str.replace('u', 'a')

# Compute Hamming similarity for century string pair.
columns_metadata_dict['similarity_metrics'][attribute] = tedi.Hamming()

unknown_share = 16

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

if exactDate_mode == 'added_u':
    # Add amount of 1/16 to Hamming similarity for every letter digit.
    #  But only maximum number of letter digits in both strings of a pair.
    df_feature_base[attribute+'_delta'] = df_feature_base[[
        attribute+'_x', attribute+'_y', attribute+'_delta']].apply(
        lambda x : x[attribute+'_delta'] + 
        max(x[attribute+'_x'].count('a'), x[attribute+'_y'].count('u'))/unknown_share, axis=1
    )
elif exactDate_mode == 'xor':
    # Add amount of 1/16 to Hamming similarity for every letter digit.
    #  But only number of position-wise xor-ed letter digits in the two strings of a pair.
    df_feature_base[attribute+'_delta'] = df_feature_base[[
        attribute+'_x', attribute+'_y', attribute+'_delta']].apply(
        lambda x : x[attribute+'_delta'] + 
        no_xor(x[attribute+'_x'], x[attribute+'_y'])/unknown_share, axis=1
    )

# %%
df_feature_base[['exactDate_x', 'exactDate_y', 'exactDate_delta']].sample(n=10)
# Out:
#        exactDate_x exactDate_y  exactDate_delta
# 265732    16001700    16001790            0.875
# 117616    1959aaaa    2017uuuu            0.250
# 178196    2005aaaa    19969999            0.250
# 193868    2016aaaa    1763uuuu            0.250
# 128808    1999aaaa    1870uuuu            0.375
# 75963     1960aaaa    1993uuuu            0.500
# 296559    2007aaaa    2007uuuu            0.750
# 48527     1979aaaa    uuuuuuuu            0.500
# 177       19791999    19791999            1.000
# 235262    1989aaaa    19952006            0.500

# %% [markdown]
# All resulting values of equal strings are equal to 1.

# %%
df_feature_base[['exactDate_x', 'exactDate_y', 'exactDate_delta']][
    df_feature_base.exactDate_x == df_feature_base.exactDate_y
].sort_values('exactDate_delta', ascending=False).head()
# Out:
#        exactDate_x exactDate_y  exactDate_delta
# 159       20022000    20022000              1.0
# 303973    20172016    20172016              1.0
# 303990    20172016    20172016              1.0
# 303989    20172016    20172016              1.0
# 303988    20172016    20172016              1.0

# %% [markdown]
# A discrete set of different similarity values can be found in the attribute deltas. Some sample records are shown below.

# %%
exactDate_deltas = np.sort(df_feature_base.exactDate_delta.unique())
exactDate_deltas
# Out:
# array([0.    , 0.125 , 0.25  , 0.3125, 0.375 , 0.4375, 0.5   , 0.5625,
#        0.625 , 0.6875, 0.75  , 0.8125, 0.875 , 1.    ])

# %%
sample_size = 5

for i in exactDate_deltas :
    dpf.show_samples_distinct(df_feature_base, 'exactDate', i, sample_size)
    print(f'exactDate_delta = {i}')
# Out:
#        duplicates  exactDate_delta exactDate_x exactDate_y
# 79314           0              0.0    20062005    19679999
# 26268           0              0.0    19791999    20002005
# 27743           0              0.0    20092005    19989999
# 43907           0              0.0    20091990    19282011
# 17425           0              0.0    19911990    20130627
# exactDate_delta = 0.0
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 186560           0            0.125    20151475    16001700
# 103601           0            0.125    20091991    18631869
# 121754           0            0.125    19911794    20121970
# 51356            0            0.125    19969999    16001700
# 154005           0            0.125    18501875    19669999
# exactDate_delta = 0.125
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 85525            0             0.25    2007aaaa    1889uuuu
# 172460           0             0.25    2015aaaa    1980uuuu
# 30794            0             0.25    20071990    1994uuuu
# 78767            0             0.25    2005aaaa    19972008
# 159001           0             0.25    2013aaaa    1994uuuu
# exactDate_delta = 0.25
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 12901            0           0.3125    2005aaaa    181uuuuu
# 143871           0           0.3125    1982aaaa    200uuuuu
# 166661           0           0.3125    2013aaaa    192uuuuu
# 251282           0           0.3125    183aaaaa    20022010
# 133278           0           0.3125    2000aaaa    193uuuuu
# exactDate_delta = 0.3125
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 135643           0            0.375    1764aaaa    1996uuuu
# 78608            0            0.375    2005aaaa    1995uuuu
# 155117           0            0.375    1970aaaa    1796uuuu
# 135616           0            0.375    1764aaaa    1979uuuu
# 234581           0            0.375    2009aaaa    1979uuuu
# exactDate_delta = 0.375
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 90054            0           0.4375    170aaaaa    1992uuuu
# 242256           0           0.4375    1763aaaa    189uuuuu
# 119048           0           0.4375    1987aaaa    181uuuuu
# 5056             0           0.4375    1988aaaa    189uuuuu
# 89921            0           0.4375    170aaaaa    1885uuuu
# exactDate_delta = 0.4375
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 69158            0              0.5    1963aaaa    1955uuuu
# 75488            0              0.5    1970aaaa    1992uuuu
# 144582           0              0.5    1982aaaa    1995uuuu
# 170740           0              0.5    1981aaaa    1999uuuu
# 237912           0              0.5    1999aaaa    1900uuuu
# exactDate_delta = 0.5
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 217066           0           0.5625    1970aaaa    192uuuuu
# 181230           0           0.5625    2014aaaa    200uuuuu
# 33061            0           0.5625    1999aaaa    193uuuuu
# 30096            0           0.5625    1999aaaa    193uuuuu
# 230530           0           0.5625    1987aaaa    193uuuuu
# exactDate_delta = 0.5625
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 144806           0            0.625    1982aaaa    1902uuuu
# 107312           0            0.625    2005aaaa    2004uuuu
# 23223            0            0.625    2010aaaa    2012uuuu
# 246731           0            0.625    2017aaaa    2013uuuu
# 108848           0            0.625    1982aaaa    1983uuuu
# exactDate_delta = 0.625
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 264759           1           0.6875    1980aaaa    198u0uuu
# 266244           1           0.6875    200aaaaa    200uuuuu
# 283129           1           0.6875    2003aaaa    200u3uuu
# 274166           1           0.6875    1970aaaa    197u0uuu
# 293037           1           0.6875    2014aaaa    201u4uuu
# exactDate_delta = 0.6875
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 297782           1             0.75    2015aaaa    2015uuuu
# 284059           1             0.75    1993aaaa    1993uuuu
# 265571           1             0.75    2010aaaa    2010uuuu
# 297824           1             0.75    2015aaaa    2015uuuu
# 282112           1             0.75    1998aaaa    1998uuuu
# exactDate_delta = 0.75
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 263006           1           0.8125    19aa9999    1u9u9999
# 262996           1           0.8125    19aa9999    19u9u999
# 263032           1           0.8125    19aa9999    19u9u999
# 263018           1           0.8125    19aa9999    1u9u9999
# 263007           1           0.8125    19aa9999    1u9u9999
# exactDate_delta = 0.8125
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 312718           1            0.875    19972002    19972006
# 311686           1            0.875    201310aa    201310uu
# 311631           1            0.875    201310aa    201310uu
# 263061           1            0.875    19aa9999    19uu9999
# 272636           1            0.875    200919aa    200919uu
# exactDate_delta = 0.875
#         duplicates  exactDate_delta exactDate_x exactDate_y
# 262315           1              1.0    19811995    19811995
# 271022           1              1.0    19809999    19809999
# 262091           1              1.0    19841992    19841992
# 262044           1              1.0    19841992    19841992
# 321446           1              1.0    19739999    19739999
# exactDate_delta = 1.0

# %% [markdown]
# ### format

# %% [markdown]
# Due to the discussion in chapter [Data Analysis](./1_DataAnalysis.ipynb), attribute $\texttt{format}$ has been split up into two new attributes $\texttt{format}\_\texttt{prefix}$ and $\texttt{format}\_\texttt{postfix}$ which will be compared by a different similarity metrics.
#
# - As the quality of $\texttt{format}\_\texttt{prefix}$ is expected to be high, an identity comparison should be sufficient.
# - Due to the observed structure of $\texttt{format}\_\texttt{postfix}$, a q-gram based comparison will be chosen.

# %%
attribute = 'format'

columns_metadata_dict['similarity_metrics'][attribute+'_prefix'] = tedi.Identity()
columns_metadata_dict['similarity_metrics'][attribute+'_postfix'] = tedi.Jaccard(qval=2)

pfix_values = ['_prefix', '_postfix']

for pf in pfix_values :
    df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
        df_feature_base, attribute+pf,
        columns_metadata_dict['similarity_metrics'][attribute+pf],
        columns_metadata_dict)

# %%
for i in df_feature_base.format_prefix_delta[
    df_feature_base.format_prefix_x != df_feature_base.format_prefix_y].unique():
    
    dpf.show_samples_distinct(df_feature_base, 'format_prefix', i)
    print(f'format_prefix_delta = {i}')
# Out:
#         duplicates  format_prefix_delta format_prefix_x format_prefix_y
# 93958            0                  0.0              mu              bk
# 158163           0                  0.0              vm              mu
# 172879           0                  0.0              bk              mu
# 194377           0                  0.0              bk              vm
# 67137            0                  0.0              bk              mp
# format_prefix_delta = 0.0

# %%
for i in df_feature_base.format_postfix_delta[
    df_feature_base.format_postfix_x != df_feature_base.format_postfix_y].unique():
    
    dpf.show_samples_distinct(df_feature_base, 'format_postfix', i)
    print(f'format_postfix_delta = {i}')
# Out:
#         duplicates  format_postfix_delta format_postfix_x format_postfix_y
# 102040           0              0.428571           010300           010200
# 193022           0              0.428571           020300           020000
# 157994           0              0.428571           020000           020053
# 192969           0              0.428571           020300           020053
# 246961           0              0.428571           020000           020053
# format_postfix_delta = 0.4285714285714286
#         duplicates  format_postfix_delta format_postfix_x format_postfix_y
# 33539            0              0.111111           030300           040100
# 97625            0              0.111111           010300           020000
# 213176           0              0.111111           020053           010000
# 5880             0              0.111111           010300           020000
# 149425           0              0.111111           040100           020000
# format_postfix_delta = 0.11111111111111116
#         duplicates  format_postfix_delta format_postfix_x format_postfix_y
# 248615           0                  0.25           010200           020353
# 181224           0                  0.25           020000           020353
# 76041            0                  0.25           010200           020347
# 40089            0                  0.25           020000           020353
# 92644            0                  0.25           020000           020353
# format_postfix_delta = 0.25
#         duplicates  format_postfix_delta format_postfix_x format_postfix_y
# 17390            0                   0.0           040100           030653
# 173908           0                   0.0           020000           030653
# 209111           0                   0.0           020000           010347
# 247267           0                   0.0           030653           020000
# 247492           0                   0.0           030653           010000
# format_postfix_delta = 0.0
#         duplicates  format_postfix_delta format_postfix_x format_postfix_y
# 313893           1                   1.0           010200           010200
# 313189           1                   1.0           010100           010100
# 272578           1                   1.0           010100           010100
# 288926           1                   1.0           010000           010000
# 322938           1                   1.0           020300           020300
# format_postfix_delta = 1.0
#         duplicates  format_postfix_delta format_postfix_x format_postfix_y
# 316551           1              0.666667           020000           200000
# 267710           1              0.666667           010300           100300
# 291464           1              0.666667           010053           100053
# 282442           1              0.666667           020000           200000
# 292399           1              0.666667           010053           100053
# format_postfix_delta = 0.6666666666666666

# %% [markdown]
# ### isbn

# %% [markdown]
# Swissbib uses each string element of the $\texttt{isbn}$ list separately for comparing with each string element of its comparison $\texttt{isbn}$ list. If two bibliographic units hold at least one element in common, this is interpreted as a strong indicator for duplicates [[WiCo2001](./A_References.ipynb#wico2001)].

# %% [markdown]
# This hard logic is used in a modified way in the context of this capstone project. A special comparison function $\texttt{.build}\_\texttt{delta}\_\texttt{isbn()}$ has been implemented that compares each list element of the left-hand side with each list element of the right-hand side of a pair. According to Swissbib's implementation, the Identity metric is used for string comparison, calculating a similarity value of 1.0 or 0.0 for each list element pair. For normalisation reasons, the sum of similarity values is divided by the number of elements of the smaller list. If both lists are empty a value of 1.0 is returned. If only one list is empty a value of 0.0 is returned.

# %%
attribute = 'isbn'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.Identity()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

df_feature_base[attribute+'_delta'].unique()
# Out:
# array([1. , 0. , 0.5])

# %% [markdown]
# Some sample cases are shown below for each category of $\texttt{isbn_delta}$.

# %%
for isbn_delta_value in df_feature_base['isbn_delta'].unique():
    number_of_max_samples = min(
        10,
        len(df_feature_base[df_feature_base['isbn_delta']==isbn_delta_value])
    )

    dpf.show_samples_distinct(df_feature_base, 'isbn', isbn_delta_value, number_of_max_samples)
    print(f'isbn_delta = {isbn_delta_value}')
# Out:
#         duplicates  isbn_delta  \
# 17541            0         1.0
# 293071           1         1.0
# 300854           1         1.0
# 300774           1         1.0
# 309336           1         1.0
# 1414             1         1.0
# 69451            0         1.0
# 21980            0         1.0
# 321747           1         1.0
# 10887            0         1.0
#
#                                                 isbn_x  \
# 17541                                               []
# 293071                             [978-3-944063-13-3]
# 300854                                              []
# 300774                                              []
# 309336  [978-3-598-31501-5 (print), 978-3-11-097003-6]
# 1414                                                []
# 69451                                               []
# 21980                                               []
# 321747              [978-3-495-48796-9, 3-495-48796-4]
# 10887                                               []
#
#                                                 isbn_y
# 17541                                               []
# 293071                             [978-3-944063-13-3]
# 300854                                              []
# 300774                                              []
# 309336  [978-3-598-31501-5 (print), 978-3-11-097003-6]
# 1414                                                []
# 69451                                               []
# 21980                                               []
# 321747              [978-3-495-48796-9, 3-495-48796-4]
# 10887                                               []
# isbn_delta = 1.0
#         duplicates  isbn_delta                                        isbn_x  \
# 157440           0         0.0  [978-3-13-127286-7, 978-3-13-150826-3 (PDF)]
# 216339           0         0.0                               [2-08-070552-0]
# 60917            0         0.0                                            []
# 55747            0         0.0                           [978-3-86772-104-2]
# 222140           0         0.0                           [978-2-07-046833-1]
# 159126           0         0.0                           [978-3-643-12370-1]
# 21483            0         0.0                               [3-499-17476-6]
# 41101            0         0.0                                            []
# 212576           0         0.0                                            []
# 165511           0         0.0                           [978-3-15-020008-7]
#
#                                                    isbn_y
# 157440                                [978-0-307-38684-7]
# 216339  [3-906721-51-5 (Livre de l'élève), 978-3-90672...
# 60917                                 [978-1-85584-230-4]
# 55747                                 [978-3-906721-38-5]
# 222140                                                 []
# 159126                                [978-0-7294-1151-6]
# 21483   [978-3-13-128546-1, 3-13-128546-X, 978-3-13-20...
# 41101                                 [978-2-01-322734-6]
# 212576                 [978-0-19-953552-1, 0-19-953552-3]
# 165511                                                 []
# isbn_delta = 0.0
#       duplicates  isbn_delta                                        isbn_x  \
# 1205           1         0.5            [978-3-13-127286-7, 3-13-127286-4]
# 1199           1         0.5  [978-3-13-127286-7, 978-3-13-150826-3 (PDF)]
# 1195           1         0.5            [978-3-13-127286-7, 3-13-127286-4]
# 1202           1         0.5  [978-3-13-127286-7, 978-3-13-150826-3 (PDF)]
# 1201           1         0.5  [978-3-13-127286-7, 978-3-13-150826-3 (PDF)]
# 1210           1         0.5            [978-3-13-127286-7, 3-13-127286-4]
#
#                                             isbn_y
# 1205  [978-3-13-127286-7, 978-3-13-150826-3 (PDF)]
# 1199            [978-3-13-127286-7, 3-13-127286-4]
# 1195  [978-3-13-127286-7, 978-3-13-150826-3 (PDF)]
# 1202            [978-3-13-127286-7, 3-13-127286-4]
# 1201            [978-3-13-127286-7, 3-13-127286-4]
# 1210  [978-3-13-127286-7, 978-3-13-150826-3 (PDF)]
# isbn_delta = 0.5

# %% [markdown]
# For attribute $\texttt{isbn}$, the special marking of missing values is omitted.

# %% [markdown]
# ### ismn

# %% [markdown]
# This attribute will be processed with the identity similarity metric. The reasoning for this decision is the same as for similar attributes above.

# %%
attribute = 'ismn'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.Identity()
#tedi.Jaccard()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)
# Out:
# ismn values range [0. 1.]

# %%
for ismn_delta_value in df_feature_base[attribute+'_delta'].unique():
    number_of_max_samples = min(
        10,
        len(df_feature_base[df_feature_base[attribute+'_delta']==ismn_delta_value])
    )

    dpf.show_samples_distinct(df_feature_base, 'ismn', ismn_delta_value, number_of_max_samples)
    print(f'ismn_delta = {ismn_delta_value}')
# Out:
#         duplicates  ismn_delta ismn_x ismn_y
# 319784           1         1.0
# 155951           0         1.0
# 58926            0         1.0
# 97119            0         1.0
# 86112            0         1.0
# 88048            0         1.0
# 310289           1         1.0
# 41264            0         1.0
# 322181           1         1.0
# 39780            0         1.0
# ismn_delta = 1.0
#         duplicates  ismn_delta                                   ismn_x  \
# 233676           0         0.0
# 79903            0         0.0                               m006546756
# 250981           0         0.0                               m006204687
# 79921            0         0.0                               m006546756
# 137162           0         0.0                               m006204687
# 79883            0         0.0                               m006546756
# 137258           0         0.0                               m006204687
# 250104           0         0.0                               m200205343
# 256384           0         0.0  m006546756 (kritischer bericht, leinen)
# 154156           0         0.0
#
#             ismn_y
# 233676  m008060205
# 79903
# 250981
# 79921
# 137162
# 79883
# 137258
# 250104
# 256384
# 154156  m006450510
# ismn_delta = 0.0

# %% [markdown]
# As can be seen in the previous chapters, attribute $\texttt{ismn}$ is filled sparsely. A lot of missing values calculate to a value of 1.0 in the chosen similarity metrics. To mark these cases specifically, they will be transformed to a negative value.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, attribute, factor)

# %% [markdown]
# ### musicid

# %% [markdown]
# Chapter [Data Analysis](./1_DataAnalysis.ipynb) shows that attribute $\texttt{musicid}$ is an identifyer for a music record. A Jaccard metric has been tested on this attribute, resulting in a distribution of many high similarity values on uniques. Comparing this result with the LCS metric, the latter has been decided.

# %%
attribute = 'musicid'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.LCSStr()
#tedi.Jaccard()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)
# Out:
# musicid values range [0.         0.125      0.14285714 0.16666667 0.2        0.25
#  0.28571429 0.33333333 0.375      0.4        0.42857143 0.44444444
#  0.5        0.55555556 0.57142857 0.6        0.625      0.66666667
#  0.71428571 0.75       0.77777778 0.8        0.83333333 0.85714286
#  0.875      1.        ]

# %%
position = uniques_len[attribute]

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position-2],
    uniques[attribute][uniques_len[attribute]-position-1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position],
    uniques[attribute][uniques_len[attribute]-position+2], 10)

position = uniques_len[attribute]//2

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position],
    uniques[attribute][uniques_len[attribute]-position+1], 10)
# Out:
#         duplicates  musicid_delta musicid_x musicid_y
# 1140             1            1.0       601       601
# 314047           1            1.0       245       245
# 314399           1            1.0      3714      3714
# 324431           1            1.0       134       134
# 287473           1            1.0      5714      5714
# 314567           1            1.0      4553      4553
# 323998           1            1.0    502023    502023
# 288196           1            1.0    502430    502430
# 314318           1            1.0       245       245
# 298696           1            1.0       172       172
# 0.875 <= musicid_delta <= 1.0
#         duplicates  musicid_delta musicid_x musicid_y
# 213025           0            0.0
# 24553            0            0.0      3714
# 185888           0            0.0
# 50068            0            0.0
# 21221            0            0.0
# 49461            0            0.0
# 242536           0            0.0
# 10801            0            0.0
# 38831            0            0.0
# 33390            0            0.0
# 0.0 <= musicid_delta <= 0.1428571428571429
#         duplicates  musicid_delta musicid_x musicid_y
# 271685           1       0.571429    134134   13m4134
# 271679           1       0.571429    134134   1341d34
# 260931           1       0.571429    502023   50c2023
# 322710           1       0.571429    501326   5013c26
# 268558           1       0.571429    901842   9018w42
# 321033           1       0.571429    502430   5024i30
# 304762           1       0.571429   4357412    437412
# 260961           1       0.571429    502023   50h2023
# 271692           1       0.571429    134134   1341s34
# 324067           1       0.571429    502023   50m2023
# 0.5555555555555556 <= musicid_delta <= 0.5714285714285714

# %%
dpf.show_samples_interval(
    df_feature_base[df_feature_base.duplicates==1], attribute,
    uniques[attribute][0],
    uniques[attribute][uniques_len[attribute]-1], 20)
# Out:
#         duplicates  musicid_delta musicid_x musicid_y
# 305360           1            0.0
# 274883           1            0.0
# 291261           1            0.0
# 262041           1            0.0
# 310499           1            0.0
# 321250           1            0.0
# 269176           1            0.0      4355
# 283366           1            0.0
# 282259           1            0.0
# 289655           1            0.0
# 276648           1            0.0
# 293660           1            0.0
# 267669           1            0.0
# 324404           1            1.0      4553      4553
# 319603           1            0.0
# 293451           1            0.0
# 288925           1            1.0      7918      7918
# 262878           1            0.0
# 268470           1            0.0
# 259835           1            0.0
# 0.0 <= musicid_delta <= 1.0

# %% [markdown]
# The attribute is filled with a degree of below $10\%$. The chosen metric for it results in a similarity value of 1.0 for empty value pairs. This effect can be adjusted with function $\texttt{.mark}\_\texttt{missing}()$ as above.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, 'musicid', factor)

# %% [markdown]
# ### part

# %% [markdown]
# Analogous to attribute $\texttt{edition}$ described above, the string value of this attribute can be stripped to pure number digits. Both ways, with and without letter stripping have been tried for modelling. The final decision for the best processing will be documented in chapter [Overview and Summary](./0_OverviewSummary.ipynb). Three different metrics have been tried for attribute $\texttt{part}$. Finally, metric Jaro will be used.

# %%
attribute = 'part'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.StrCmp95()
#tedi.Jaro()
#tedi.Hamming()
#tedi.LCSStr()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)
# Out:
# part values range [0.         0.27407407 0.28240741 0.29202279 0.30740741 0.31318681
#  0.31481481 0.32407407 0.32898551 0.33333333 0.33597884 0.33838384
#  0.33921569 0.34444444 0.3452381  0.35128205 0.35185185 0.35897436
#  0.36111111 0.36231884 0.36666667 0.37037037 0.37179487 0.37254902
#  0.37301587 0.37407407 0.375      0.37777778 0.38333333 0.38461538
#  0.38568376 0.38888889 0.38927739 0.39070048 0.39215686 0.39393939
#  0.3952381  0.3960114  0.39646465 0.39722222 0.39814815 0.4
#  0.4031746  0.4037037  0.40604575 0.40740741 0.40842491 0.40855763
#  0.41025641 0.41111111 0.41125541 0.41176471 0.41203704 0.41282051
#  0.41388889 0.41449275 0.41452991 0.41507937 0.41666667 0.4178744
#  0.41798942 0.41851852 0.41919192 0.42083333 0.42222222 0.42261905
#  0.42390289 0.4241453  0.42564103 0.42592593 0.42777778 0.42810458
#  0.42857143 0.42948718 0.43030303 0.43055556 0.43115942 0.43174603
#  0.43236715 0.43333333 0.43518519 0.43557423 0.43589744 0.43627451
#  0.43650794 0.43703704 0.4375     0.43813131 0.43888889 0.44017094
#  0.44166667 0.44200244 0.44230769 0.44358974 0.44444444 0.4469697
#  0.44761905 0.44814815 0.4484127  0.4494302  0.44949495 0.45
#  0.45098039 0.45138889 0.4537037  0.45555556 0.45598846 0.45726496
#  0.45764895 0.45833333 0.45868946 0.4589372  0.45970696 0.46068376
#  0.46111111 0.46296296 0.46367521 0.46405229 0.46428571 0.46470588
#  0.46481481 0.46507937 0.46527778 0.46570048 0.46581197 0.46666667
#  0.46709402 0.46794872 0.46801347 0.46851852 0.47008547 0.47222222
#  0.47222222 0.4724359  0.47301587 0.47407407 0.47463768 0.47466422
#  0.47474747 0.47584541 0.47619048 0.47777778 0.47777778 0.47985348
#  0.4807971  0.48096348 0.48104575 0.48148148 0.48232323 0.4832244
#  0.48333333 0.48366013 0.48412698 0.48589744 0.48611111 0.48636991
#  0.48888889 0.48917749 0.49007937 0.49047619 0.49074074 0.49130435
#  0.49166667 0.49175824 0.49206349 0.49230769 0.49358974 0.49487179
#  0.49509804 0.49565217 0.4957265  0.4984472  0.4991453  0.5
#  0.50071225 0.50092593 0.5015873  0.50181159 0.5021978  0.5026455
#  0.50326797 0.50362319 0.5037037  0.5040404  0.50404668 0.50505051
#  0.50529101 0.50555556 0.50588235 0.50637255 0.50653595 0.50757576
#  0.50793651 0.50833333 0.50917874 0.50925926 0.51055901 0.51068376
#  0.51111111 0.51176471 0.51190476 0.5125     0.51282051 0.51313131
#  0.51339031 0.51355311 0.51388889 0.51449275 0.51465201 0.51515152
#  0.51570048 0.51595442 0.51602564 0.51666667 0.51794872 0.51851852
#  0.51890756 0.51923077 0.51936027 0.51944444 0.51960784 0.51966874
#  0.52083333 0.52136752 0.52142857 0.52168746 0.52217554 0.52222222
#  0.52222222 0.52228327 0.52307692 0.52380952 0.52407407 0.52431562
#  0.525      0.5252588  0.52564103 0.52619048 0.52654753 0.52727273
#  0.52777778 0.52898551 0.52929293 0.52936508 0.53019324 0.53030303
#  0.5309057  0.53104575 0.53133903 0.53140097 0.53148148 0.53174603
#  0.53311966 0.53333333 0.53376068 0.53424908 0.53425926 0.53501401
#  0.53518519 0.53525641 0.53535354 0.53613445 0.53653846 0.53703704
#  0.53787879 0.53869048 0.53888889 0.53910256 0.53921569 0.53947904
#  0.53968254 0.53986928 0.54074074 0.54166667 0.54188034 0.5422619
#  0.54273504 0.54285714 0.54304029 0.54444444 0.5462963  0.54649758
#  0.54679487 0.54700855 0.54722222 0.54746377 0.54761905 0.54848485
#  0.5491453  0.54945055 0.54989107 0.55       0.5505698  0.55065359
#  0.55118473 0.55128205 0.5515873  0.55185185 0.55311355 0.55555556
#  0.55555556 0.55601852 0.55662393 0.55710956 0.55788656 0.55797101
#  0.55833333 0.55917874 0.55952381 0.55972222 0.56060606 0.56106443
#  0.56117216 0.56153846 0.56160969 0.56168831 0.56190476 0.5620915
#  0.56216931 0.56296296 0.56313131 0.56349206 0.56388889 0.56440781
#  0.5647343  0.56481481 0.56495726 0.56507937 0.56595442 0.56630037
#  0.56640212 0.56666667 0.56714976 0.56794872 0.56800446 0.56837607
#  0.56944444 0.57032428 0.57037037 0.57107023 0.57179487 0.57222222
#  0.57287785 0.57303922 0.57313797 0.57380952 0.57407407 0.57463768
#  0.57478632 0.57581699 0.57606838 0.57619048 0.57681159 0.57692308
#  0.57698413 0.57722567 0.5775641  0.57777778 0.57936508 0.57984608
#  0.58005698 0.58119658 0.58178054 0.58208458 0.58333333 0.58342624
#  0.58359213 0.58404558 0.58454106 0.58459596 0.58461538 0.58485958
#  0.58518519 0.58547009 0.58611111 0.58695652 0.58715359 0.58730159
#  0.58787879 0.58809524 0.58816425 0.58834724 0.58846154 0.58862434
#  0.58888889 0.58961039 0.58986928 0.59047619 0.59074074 0.59074074
#  0.59090909 0.59094203 0.59215686 0.592425   0.59259259 0.59343434
#  0.59351852 0.59401709 0.59477124 0.59483109 0.59489303 0.59509804
#  0.5952381  0.59583333 0.5970696  0.59722222 0.5973545  0.5974359
#  0.5982906  0.59880377 0.59880952 0.59890572 0.59903382 0.59915825
#  0.6        0.60105581 0.60119048 0.60133779 0.60245637 0.6025641
#  0.602657   0.60280112 0.60299145 0.60320513 0.6032967  0.603367
#  0.60365161 0.6040404  0.60441176 0.60470085 0.60555556 0.6057971
#  0.60598291 0.60622711 0.60683761 0.60714286 0.60793651 0.60833333
#  0.60868347 0.61020067 0.61025641 0.6110348  0.61111111 0.61111111
#  0.61114082 0.61165577 0.61177249 0.61202686 0.61253561 0.61344211
#  0.61388889 0.61402116 0.61437908 0.6147343  0.61481481 0.61507937
#  0.61616162 0.61666667 0.61851852 0.61904762 0.61923077 0.61950549
#  0.61982571 0.62037037 0.62049689 0.62057166 0.62075702 0.62121212
#  0.62179487 0.62222222 0.62270531 0.62307692 0.62328042 0.62328975
#  0.62424242 0.62451226 0.625      0.62558357 0.62606838 0.62637363
#  0.62651515 0.62681159 0.62698413 0.62777778 0.62908497 0.62946128
#  0.62946204 0.62962963 0.62970363 0.63095238 0.63121118 0.63137255
#  0.63151119 0.63162393 0.63186275 0.63247863 0.6326087  0.63290598
#  0.63296703 0.63333333 0.63427474 0.6346094  0.63461538 0.63467113
#  0.63472222 0.63492063 0.63571429 0.63689459 0.63703704 0.63787879
#  0.63888889 0.63969404 0.64057239 0.64102564 0.64130435 0.64159544
#  0.64166667 0.64215686 0.64245014 0.64251208 0.64285714 0.64365079
#  0.64444444 0.64444444 0.64466089 0.64468864 0.64542484 0.64583333
#  0.64613527 0.64642857 0.64646465 0.64672365 0.64722222 0.64793028
#  0.64795784 0.64814815 0.64843596 0.64869281 0.65       0.65079365
#  0.65128205 0.65196078 0.65248869 0.652657   0.65277778 0.65343915
#  0.65359278 0.65384615 0.6540404  0.65555556 0.65603865 0.65627706
#  0.65641026 0.65669516 0.65714286 0.6576087  0.65797101 0.65811966
#  0.65833333 0.65925926 0.65939153 0.65959596 0.65964591 0.65991577
#  0.66018519 0.66025641 0.66111111 0.66131423 0.66153846 0.66163004
#  0.66176471 0.66178266 0.66181422 0.66253561 0.66269841 0.66296296
#  0.66402116 0.66410256 0.66481481 0.66503268 0.66587302 0.66649908
#  0.66666667 0.66800446 0.66837607 0.66987179 0.67003367 0.67142857
#  0.67222222 0.67246377 0.67264957 0.67352941 0.67391304 0.67424242
#  0.67427536 0.67457265 0.67460317 0.67619048 0.67644352 0.67673108
#  0.67709706 0.67732268 0.67735043 0.67883023 0.67948718 0.67955574
#  0.67973856 0.68055556 0.68055556 0.68115942 0.68162393 0.68181818
#  0.68333333 0.68354978 0.68376068 0.68389581 0.68518519 0.68555679
#  0.68582202 0.68611111 0.68627451 0.6875     0.68849206 0.68883205
#  0.68888889 0.68974359 0.69000836 0.69047619 0.69179894 0.69230769
#  0.69262821 0.69404762 0.69426407 0.69444444 0.69444444 0.69565217
#  0.6969697  0.6984127  0.69852941 0.6985348  0.69927536 0.6996337
#  0.7        0.70025305 0.70233786 0.7025641  0.70299145 0.7032967
#  0.7037037  0.70588235 0.70687831 0.70688406 0.70701058 0.70714286
#  0.70726496 0.70740009 0.70780886 0.70826211 0.70833333 0.7084399
#  0.70924908 0.70940171 0.70959596 0.70985877 0.71014493 0.71111111
#  0.71111111 0.71309524 0.71349206 0.71419884 0.71428571 0.71464646
#  0.71595442 0.71666667 0.71733822 0.7173913  0.71794872 0.71851852
#  0.71901709 0.71915535 0.72121212 0.72179487 0.72222222 0.72222222
#  0.72294372 0.72420635 0.72446072 0.7254902  0.72619048 0.72727273
#  0.72777778 0.72817923 0.72820513 0.72916667 0.73015873 0.73116883
#  0.73131313 0.73333333 0.73770312 0.73809524 0.73811189 0.73861694
#  0.73888889 0.74002849 0.74074074 0.74094203 0.74166667 0.74285714
#  0.74358974 0.74509804 0.74615385 0.74679487 0.74814815 0.75
#  0.75091575 0.75151515 0.75213675 0.75250836 0.75277778 0.75555556
#  0.75661376 0.75714286 0.75757576 0.75793651 0.75833333 0.75848226
#  0.76068376 0.76111111 0.76161616 0.76190476 0.76309524 0.76346154
#  0.76349206 0.76666667 0.76923077 0.77142857 0.77380952 0.77706553
#  0.77777778 0.7797619  0.78055556 0.78333333 0.78431373 0.78518519
#  0.79047619 0.79166667 0.79487179 0.7962963  0.8        0.8008547
#  0.8047138  0.8047619  0.80512821 0.80555556 0.80555556 0.80833333
#  0.80952381 0.81282051 0.81349206 0.81481481 0.81818182 0.82051282
#  0.82222222 0.83244207 0.83333333 0.83682984 0.85185185 0.86111111
#  0.86324786 0.86410256 0.86666667 0.86713287 0.87307692 0.87382779
#  0.88888889 0.88888889 0.88985507 0.89277389 0.8974359  0.9047619
#  0.91666667 0.92094017 0.92156863 1.        ]

# %%
position = uniques_len[attribute]

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position-2],
    uniques[attribute][uniques_len[attribute]-position-1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position],
    uniques[attribute][uniques_len[attribute]-position+2], 10)

position = uniques_len[attribute]//7

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position-2],
    uniques[attribute][uniques_len[attribute]-position-1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position],
    uniques[attribute][uniques_len[attribute]-position+2], 10)
# Out:
#         duplicates  part_delta part_x part_y
# 201573           0         1.0
# 46142            0         1.0
# 313971           1         1.0
# 121724           0         1.0
# 45662            0         1.0
# 174332           0         1.0
# 110754           0         1.0
# 99577            0         1.0
# 288142           1         1.0
# 303176           1         1.0
# 0.9215686274509803 <= part_delta <= 1.0
#         duplicates  part_delta         part_x      part_y
# 135940           0         0.0                          9
# 136327           0         0.0                  2620 2620
# 148542           0         0.0                          2
# 209705           0         0.0                 24 23 1863
# 138546           0         0.0                 23 23 1869
# 219673           0         0.0                      20 20
# 219822           0         0.0          63 63           7
# 252699           0         0.0       313 2017
# 202032           0         0.0                          7
# 252030           0         0.0  2017 313 2017
# 0.0 <= part_delta <= 0.28240740740740744
#         duplicates  part_delta   part_x   part_y
# 35449            0    0.714286  552 552        2
# 257260           0    0.714286  23 1862        2
# 159635           0    0.714286        5  285 285
# 214466           0    0.714286  912 912        2
# 197341           0    0.714286  23 1862        3
# 121147           0    0.714286        2  241 319
# 35312            0    0.714286  552 552        2
# 216314           0    0.714286  552 552        2
# 123315           0    0.714286        5  552 552
# 197324           0    0.714286  23 1862        2
# 0.7142857142857143 <= part_delta <= 0.7146464646464646
#         duplicates  part_delta                part_x         part_y
# 197596           0    0.717338               23 1862  23 23 1870 23
# 257495           0    0.717338               23 1862  23 23 1889 23
# 166866           0    0.716667  28 10 2013 2421 2431            2 2
# 197570           0    0.717338               23 1862  23 23 1906 23
# 197585           0    0.717338               23 1862  23 23 1946 23
# 183896           0    0.716667       26 2000 26 2000       279 2000
# 197572           0    0.717338               23 1862  23 23 1870 23
# 257479           0    0.717338               23 1862  23 23 1988 23
# 183903           0    0.716667       26 2000 26 2000       286 2007
# 166702           0    0.716667  28 10 2013 2421 2431       282 2003
# 0.7159544159544161 <= part_delta <= 0.7173382173382173

# %% [markdown]
# In this attribute, too, moving pairs of empty values to negative values will result in a clearer distinction between pairs of uniques and duplicates, as will be seen in the graphical comparison of capter [Features Discussion and Dummy Classifier Baseline](./5_FeatureDiscussionDummyBaseline.ipynb).

# %%
df_feature_base = dpf.mark_missing(df_feature_base, 'part', factor)

# %% [markdown]
# ### person

# %% [markdown]
# As a result of chapter [Data Analysis](./1_DataAnalysis.ipynb), attribute $\texttt{person}$ has been split into three specific attributes. Attribute $\texttt{person}\_{100}$ and $\texttt{person}\_{700}$ hold strongly standardised string values. For comparing pure strings, a Levenshtein metric is recommended [[Chri2012](./A_References.ipynb#chri2012)]. Unfortunately, this metric shows a very long calculation time on the data of the capstone project. Comparing the similarity values of the Levenshtein metric with the similarity values of other metrics in appendix [Comparison of Similarity Metrics](./B_CompareSimilarities.ipynb), similarity metric StrCmp95 has been decided to use.

# %%
attribute = 'person'

columns_metadata_dict['similarity_metrics'][attribute+'_100'] = tedi.StrCmp95()
columns_metadata_dict['similarity_metrics'][attribute+'_700'] = tedi.StrCmp95()
#tedi.Levenshtein()

pe_values = ['_100', '_700']

for pe in pe_values :
    print('Calculating person'+pe)
    df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
        df_feature_base, attribute+pe,
        columns_metadata_dict['similarity_metrics'][attribute+pe],
        columns_metadata_dict)
# Out:
# Calculating person_100
# Calculating person_700

# %%
pe = '_100'

uniques[attribute+pe], uniques_len[attribute+pe] = dpf.determine_similarity_values(
    df_feature_base, attribute+pe)
# Out:
# person_100 values range [0.         0.31944444 0.32777778 ... 0.99090909 0.99130435 1.        ]

# %%
position = uniques_len[attribute+pe]

dpf.show_samples_interval(
    df_feature_base, attribute+pe,
    uniques[attribute+pe][uniques_len[attribute+pe]-position-2],
    uniques[attribute+pe][uniques_len[attribute+pe]-position-1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute+pe,
    uniques[attribute+pe][uniques_len[attribute+pe]-position],
    uniques[attribute+pe][uniques_len[attribute+pe]-position+2], 10)
# Out:
#         duplicates  person_100_delta            person_100_x  \
# 245726           0               1.0
# 281769           1               1.0
# 122492           0               1.0
# 301776           1               1.0
# 226638           0               1.0
# 323523           1               1.0                voltaire
# 17288            0               1.0  mozartwolfgang amadeus
# 110026           0               1.0  mozartwolfgang amadeus
# 295258           1               1.0
# 26073            0               1.0
#
#                   person_100_y
# 245726
# 281769
# 122492
# 301776
# 226638
# 323523                voltaire
# 17288   mozartwolfgang amadeus
# 110026  mozartwolfgang amadeus
# 295258
# 26073
# 0.9913043478260869 <= person_100_delta <= 1.0
#         duplicates  person_100_delta            person_100_x  \
# 168492           0               0.0
# 163121           0               0.0
# 234199           0               0.0               rosoffmeg
# 198452           0               0.0
# 35147            0               0.0                voltaire
# 113629           0               0.0
# 119862           0               0.0
# 35957            0               0.0  mozartwolfgang amadeus
# 93199            0               0.0
# 156703           0               0.0      trappehans-joachim
#
#                   person_100_y
# 168492  mozartwolfgang amadeus
# 163121            bührerwalter
# 234199
# 198452           schubertfranz
# 35147
# 113629              austenjane
# 119862            bührerwalter
# 35957
# 93199             bührerwalter
# 156703
# 0.0 <= person_100_delta <= 0.3277777777777777

# %% [markdown]
# For comparing person names, like in attribute $\texttt{person}\_{245c}$, a Jaro metric will be tested [[Chri2012](./A_References.ipynb#chri2012)].

# %%
pe = '_245c'

columns_metadata_dict['similarity_metrics'][attribute+pe] = tedi.Jaro()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute+pe,
    columns_metadata_dict['similarity_metrics'][attribute+pe],
    columns_metadata_dict)

# %%
uniques[attribute+pe], uniques_len[attribute+pe] = dpf.determine_similarity_values(
    df_feature_base, attribute+pe)
# Out:
# person_245c values range [0.         0.24632035 0.25462963 ... 0.99881797 0.99882214 1.        ]

# %%
position = uniques_len[attribute+pe]

dpf.show_samples_interval(
    df_feature_base, attribute+pe,
    uniques[attribute+pe][uniques_len[attribute+pe]-position-2],
    uniques[attribute+pe][uniques_len[attribute+pe]-position-1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute+pe,
    uniques[attribute+pe][uniques_len[attribute+pe]-position],
    uniques[attribute+pe][uniques_len[attribute+pe]-position+2], 10)
# Out:
#         duplicates  person_245c_delta  \
# 292041           1                1.0
# 49977            0                1.0
# 309031           1                1.0
# 312926           1                1.0
# 316623           1                1.0
# 292090           1                1.0
# 292236           1                1.0
# 273102           1                1.0
# 210280           0                1.0
# 280525           1                1.0
#
#                                             person_245c_x  \
# 292041                                    [walter bührer]
# 49977
# 309031                      mortzfeld, peter; raabe, paul
# 312926                                    von w.a. mozart
# 316623       hrsg. von attila csampai und dietmar holland
# 292090                                    [walter bührer]
# 292236                                    [walter bührer]
# 273102                        sigrid kessler ... [et al.]
# 210280
# 280525  voltaire ; introd., notes , bibliogr., chronol...
#
#                                             person_245c_y
# 292041                                    [walter bührer]
# 49977
# 309031                      mortzfeld, peter; raabe, paul
# 312926                                    von w.a. mozart
# 316623       hrsg. von attila csampai und dietmar holland
# 292090                                    [walter bührer]
# 292236                                    [walter bührer]
# 273102                        sigrid kessler ... [et al.]
# 210280
# 280525  voltaire ; introd., notes , bibliogr., chronol...
# 0.9988221436984688 <= person_245c_delta <= 1.0
#         duplicates  person_245c_delta  \
# 212668           0                0.0
# 233882           0                0.0
# 62684            0                0.0
# 234574           0                0.0
# 145909           0                0.0
# 210774           0                0.0
# 219825           0                0.0
# 165880           0                0.0
# 145813           0                0.0
# 114194           0                0.0
#
#                                             person_245c_x  \
# 212668
# 233882
# 62684
# 234574                                             mozart
# 145909
# 210774
# 219825                                     beatrice käser
# 165880  [a.u. scherrer, b. ledergerber, v. von wyl, j....
# 145813
# 114194  wolfgang amadeus mozart ; einf. und komm. von ...
#
#                                             person_245c_y
# 212668                                     rudolf steiner
# 233882                      mortzfeld, peter; raabe, paul
# 62684         g.h. dufour direxit ; h. müllhaupt sculpsit
# 234574
# 145909                                             mozart
# 210774                      mortzfeld, peter; raabe, paul
# 219825
# 165880
# 145813  sigrid kessler... [et al.] ; [hrsg.:] interkan...
# 114194
# 0.0 <= person_245c_delta <= 0.25462962962962954

# %% [markdown]
# The similarities of all three $\texttt{person}$ attributes are affected by empty values. These will be handled the same way as the attributes above.

# %%
pe_values = ['_100', '_245c', '_700']

for pe in pe_values :
    df_feature_base = dpf.mark_missing(df_feature_base, 'person'+pe, factor)

# %% [markdown]
# ### pubinit

# %% [markdown]
# This attribute holds publisher strings that have a similar representation as attribute $\texttt{person}$. A Jaro metric will be used.

# %%
attribute = 'pubinit'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.Jaro()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)
# Out:
# pubinit values range [0.         0.25132275 0.25303644 ... 0.9957265  0.99578059 1.        ]

# %%
position = uniques_len[attribute]//3

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position-1],
    uniques[attribute][uniques_len[attribute]-position], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-5],
    uniques[attribute][uniques_len[attribute]-1], 10)
# Out:
#         duplicates  pubinit_delta                            pubinit_x  \
# 139222           0       0.593651  kinowelt home entertainment arthaus
# 35564            0       0.593651                           flammarion
# 117991           0       0.593651                           flammarion
# 139390           0       0.593651  kinowelt home entertainment arthaus
# 216429           0       0.593651                           flammarion
# 139371           0       0.593651  kinowelt home entertainment arthaus
# 38877            0       0.593561                   theater st. gallen
# 139219           0       0.593651  kinowelt home entertainment arthaus
# 53702            0       0.593561                   theater st. gallen
#
#                                          pubinit_y
# 139222                                      peters
# 35564   w. goldmann, musikverlag b. schott's söhne
# 117991  w. goldmann, musikverlag b. schott's söhne
# 139390                                      peters
# 216429  w. goldmann, musikverlag b. schott's söhne
# 139371                                      peters
# 38877                    ed. del teatro alla scala
# 139219                                      peters
# 53702                    ed. del teatro alla scala
# 0.5935612535612536 <= pubinit_delta <= 0.5936507936507937
#         duplicates  pubinit_delta                     pubinit_x  \
# 314588           1            1.0
# 77240            0            1.0
# 233373           0            1.0
# 65038            0            1.0
# 311491           1            1.0
# 196935           0            1.0
# 312934           1            1.0
# 273204           1            1.0                           uam
# 79184            0            1.0
# 283359           1            1.0  staatlicher lehrmittelverlag
#
#                            pubinit_y
# 314588
# 77240
# 233373
# 65038
# 311491
# 196935
# 312934
# 273204                           uam
# 79184
# 283359  staatlicher lehrmittelverlag
# 0.9954337899543378 <= pubinit_delta <= 1.0

# %% [markdown]
# The similarities of $\texttt{pubinit}$ is affected by empty values. These will be transformed to negative values.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, attribute, factor)

# %% [markdown]
# ### scale

# %% [markdown]
# Comparing the similarity metrics of some sample value pairs of attribute $\texttt{scale}$ in appendix [Comparison of Similarity Metrics](./B_CompareSimilarities.ipynb), a Jaccard metrics has been identifyed to express the best matching behaviour for purely numerical values stored in the attribute.

# %%
attribute = 'scale'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.Jaccard()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)
# Out:
# scale values range [0.         0.17857143 0.21428571 0.57142857 1.        ]

# %%
position = uniques_len[attribute]

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position],
    uniques[attribute][uniques_len[attribute]-position+1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-3],
    uniques[attribute][uniques_len[attribute]-2], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-4],
    uniques[attribute][uniques_len[attribute]-3], 10)
# Out:
#         duplicates  scale_delta scale_x scale_y
# 103286           0          0.0          100000
# 134727           0          0.0          100000
# 253919           0          0.0          100000
# 19354            0          0.0          100000
# 38696            0          0.0          100000
# 128189           0          0.0          100000
# 34185            0          0.0          100000
# 13430            0          0.0          100000
# 238519           0          0.0          100000
# 69380            0          0.0   50000
# 0.0 <= scale_delta <= 0.1785714285714286
#         duplicates  scale_delta                       scale_x scale_y
# 69170            0     0.571429                         50000  100000
# 182434           0     0.571429                         50000  100000
# 227827           0     0.214286  50 000 8 10 8 35 45 55 46 05  100000
# 54932            0     0.571429                         50000  100000
# 69171            0     0.571429                         50000  100000
# 227503           0     0.214286  50 000 8 10 8 35 45 55 46 05  100000
# 196999           0     0.571429                        100000   50000
# 182746           0     0.571429                         50000  100000
# 55280            0     0.571429                         50000  100000
# 227838           0     0.214286  50 000 8 10 8 35 45 55 46 05  100000
# 0.2142857142857143 <= scale_delta <= 0.5714285714285714
#         duplicates  scale_delta                       scale_x  \
# 856              1     0.178571                         50000
# 227817           0     0.214286  50 000 8 10 8 35 45 55 46 05
# 227842           0     0.214286  50 000 8 10 8 35 45 55 46 05
# 861              1     0.178571                         50000
# 227496           0     0.214286  50 000 8 10 8 35 45 55 46 05
# 227500           0     0.214286  50 000 8 10 8 35 45 55 46 05
# 875              1     0.178571  50 000 8 10 8 35 45 55 46 05
# 227815           0     0.214286  50 000 8 10 8 35 45 55 46 05
# 227834           0     0.214286  50 000 8 10 8 35 45 55 46 05
# 227845           0     0.214286  50 000 8 10 8 35 45 55 46 05
#
#                              scale_y
# 856     50 000 8 10 8 35 45 55 46 05
# 227817                        100000
# 227842                        100000
# 861     50 000 8 10 8 35 45 55 46 05
# 227496                        100000
# 227500                        100000
# 875                            50000
# 227815                        100000
# 227834                        100000
# 227845                        100000
# 0.1785714285714286 <= scale_delta <= 0.2142857142857143

# %% [markdown]
# Attribute $\texttt{scale}$ is filled for maps, only. Due to its sparse filling, the similarities of the attribute are affected strongly by empty values. These empty values will be marked with a special negative value.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, attribute, factor)

# %% [markdown]
# ### ttlfull

# %% [markdown]
# Due to the discussion in chapter [Data Analysis](./1_DataAnalysis.ipynb), attribute $\texttt{ttlfull}$ has been split up into two new attributes $\texttt{ttlfull_245}$ and $\texttt{ttlfull_246}$ which will be compared by the same similarity metrics. A visual analysis of the values stored in the attribute, reveals a string of words, comparable to the strings in attribute $\texttt{person_245c}$, above. The same similarity metric will be used for both title attributes, therefore.

# %%
attribute = 'ttlfull'

columns_metadata_dict['similarity_metrics'][attribute+'_245'] = tedi.Jaro()
columns_metadata_dict['similarity_metrics'][attribute+'_246'] = tedi.Jaro()

tf_values = ['_245', '_246']

for tf in tf_values :
    df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
        df_feature_base, attribute+tf,
        columns_metadata_dict['similarity_metrics'][attribute+tf],
        columns_metadata_dict)

# %%
for tf in tf_values :
    uniques[attribute+tf], uniques_len[attribute+tf] = dpf.determine_similarity_values(
        df_feature_base, attribute+tf)
# Out:
# ttlfull_245 values range [0.         0.24175824 0.24358974 ... 0.99947257 0.99947341 1.        ]
# ttlfull_246 values range [0.         0.27407407 0.35555556 ... 0.99944072 0.99945085 1.        ]

# %%
tf = '_245'
position = uniques_len[attribute+tf]

dpf.show_samples_interval(
    df_feature_base, attribute+tf,
    uniques[attribute+tf][uniques_len[attribute+tf]-position],
    uniques[attribute+tf][uniques_len[attribute+tf]-position+1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute+tf,
    uniques[attribute+tf][uniques_len[attribute+tf]-3],
    uniques[attribute+tf][uniques_len[attribute+tf]-2], 10)
dpf.show_samples_interval(
    df_feature_base, attribute+tf,
    uniques[attribute+tf][uniques_len[attribute+tf]-4],
    uniques[attribute+tf][uniques_len[attribute+tf]-3], 10)
# Out:
#         duplicates  ttlfull_245_delta                         ttlfull_245_x  \
# 115815           0                0.0  bildungsforschung und bildungspraxis
# 107982           0                0.0                                  emma
# 137622           0                0.0                                  emma
# 107986           0                0.0                                  emma
# 33564            0                0.0                                  arts
# 33850            0                0.0                                  arts
# 137640           0                0.0                                  emma
# 4249             0                0.0                                  emma
# 186251           0                0.0                                  emma
# 33852            0                0.0                                  arts
#
#             ttlfull_245_y
# 115815               emma
# 107982  blick in die welt
# 137622  blick in die welt
# 107986  blick in die welt
# 33564   blick in die welt
# 33850   blick in die welt
# 137640  blick in die welt
# 4249    blick in die welt
# 186251  blick in die welt
# 33852   blick in die welt
# 0.0 <= ttlfull_245_delta <= 0.2417582417582418
#         duplicates  ttlfull_245_delta  \
# 320293           1           0.999473
# 320326           1           0.999473
# 320327           1           0.999473
# 320268           1           0.999473
# 320321           1           0.999473
# 320284           1           0.999473
# 320296           1           0.999473
# 320255           1           0.999473
# 320313           1           0.999473
# 320300           1           0.999473
#
#                                             ttlfull_245_x  \
# 320293  health informatics - personal health device co...
# 320326  health informatics - personal health device co...
# 320327  health informatics - personal health device co...
# 320268  health informatics - personal health device co...
# 320321  health informatics - personal health device co...
# 320284  health informatics - personal health device co...
# 320296  health informatics - personal health device co...
# 320255  health informatics - personal health device co...
# 320313  health informatics - personal health device co...
# 320300  health informatics - personal health device co...
#
#                                             ttlfull_245_y
# 320293  health informatics - personal health device co...
# 320326  health ifnormatics - personal health device co...
# 320327  health informatics - personal health device co...
# 320268  health informatics - personal health device co...
# 320321  health informatics - personal health edvice co...
# 320284  health informatics - personal health device co...
# 320296  health informatics - personal health device co...
# 320255  health informatics - personal health device co...
# 320313  health informatics - personal health device co...
# 320300  health informatics - personal health device co...
# 0.9994725738396625 <= ttlfull_245_delta <= 0.9994734070563455
#         duplicates  ttlfull_245_delta  \
# 320327           1           0.999473
# 320255           1           0.999473
# 320268           1           0.999473
# 320317           1           0.999473
# 319795           1           0.999463
# 319758           1           0.999463
# 320321           1           0.999473
# 320296           1           0.999473
# 320326           1           0.999473
# 320300           1           0.999473
#
#                                             ttlfull_245_x  \
# 320327  health informatics - personal health device co...
# 320255  health informatics - personal health device co...
# 320268  health informatics - personal health device co...
# 320317  health informatics - personal health device co...
# 319795  health informatics - personal health device co...
# 319758  health informatics - personal health device co...
# 320321  health informatics - personal health device co...
# 320296  health informatics - personal health device co...
# 320326  health informatics - personal health device co...
# 320300  health informatics - personal health device co...
#
#                                             ttlfull_245_y
# 320327  health informatics - personal health device co...
# 320255  health informatics - personal health device co...
# 320268  health informatics - personal health device co...
# 320317  health informatics - personal health device co...
# 319795  health informatics - personal health device co...
# 319758  health informatics - personal health device co...
# 320321  health informatics - personal health edvice co...
# 320296  health informatics - personal health device co...
# 320326  health ifnormatics - personal health device co...
# 320300  health informatics - personal health device co...
# 0.9994632313472893 <= ttlfull_245_delta <= 0.9994725738396625

# %% [markdown]
# Attribute $\texttt{ttlfull}\_\texttt{245}$ is filled for all data rows of Swissbib's raw data as can be seen in chapter [Data Analysis](./1_DataAnalysis.ipynb). For attribute $\texttt{ttlfull}\_\texttt{245}$, the filling is below $10\%$. The data pairs with missing values will be marked with a negative value as has been done for similar cases above.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, attribute+'_246', factor)

# %% [markdown]
# ### volumes

# %% [markdown]
# This attribute is described in chapter [Data Analysis](./1_DataAnalysis.ipynb) to hold a kind of contents that resembles the contents of attribute $\texttt{part}$. The same similarity metrics will be used for attribute $\texttt{volumes}$ as for attribute $\texttt{part}$, therefore.

# %%
attribute = 'volumes'

columns_metadata_dict['similarity_metrics'][attribute] = tedi.StrCmp95()
#tedi.Jaro()
#tedi.LCSSeq()
#tedi.MongeElkan()

df_feature_base, columns_metadata_dict = dpf.build_delta_feature(
    df_feature_base, attribute,
    columns_metadata_dict['similarity_metrics'][attribute],
    columns_metadata_dict)

# %%
uniques[attribute], uniques_len[attribute] = dpf.determine_similarity_values(
    df_feature_base, attribute)
# Out:
# volumes values range [0.         0.31318681 0.32222222 0.32905983 0.35128205 0.37301587
#  0.37407407 0.38333333 0.38461538 0.3952381  0.40740741 0.41111111
#  0.41666667 0.41737892 0.42857143 0.43650794 0.43703704 0.44017094
#  0.44166667 0.44200244 0.44230769 0.44761905 0.4537037  0.45555556
#  0.45833333 0.46296296 0.46428571 0.46581197 0.46666667 0.47008547
#  0.47222222 0.47619048 0.47777778 0.48148148 0.48333333 0.48412698
#  0.48611111 0.48888889 0.49007937 0.49145299 0.49206349 0.49365079
#  0.4991453  0.5        0.50793651 0.51111111 0.51190476 0.52222222
#  0.52380952 0.52564103 0.52777778 0.53333333 0.53653846 0.53703704
#  0.53968254 0.54074074 0.54166667 0.54304029 0.54401709 0.54722222
#  0.54761905 0.5491453  0.55       0.55128205 0.55555556 0.56031746
#  0.56111111 0.56190476 0.56507937 0.56630037 0.56666667 0.56944444
#  0.57407407 0.57478632 0.57777778 0.58148148 0.58333333 0.58730159
#  0.58862434 0.58888889 0.59444444 0.5952381  0.59722222 0.5982906
#  0.6        0.60119048 0.60320513 0.60683761 0.60714286 0.61025641
#  0.61111111 0.61507937 0.61666667 0.61904762 0.61923077 0.62037037
#  0.62222222 0.62380952 0.625      0.62637363 0.62777778 0.62962963
#  0.63095238 0.63247863 0.63296703 0.63333333 0.63888889 0.64285714
#  0.64444444 0.65079365 0.65555556 0.65833333 0.66018519 0.66178266
#  0.66269841 0.66481481 0.66666667 0.66987179 0.67195767 0.67264957
#  0.67619048 0.67777778 0.68055556 0.68333333 0.68589744 0.68611111
#  0.68888889 0.69047619 0.69230769 0.69444444 0.6984127  0.7
#  0.7037037  0.70714286 0.70833333 0.70940171 0.71111111 0.71309524
#  0.71428571 0.71794872 0.71851852 0.72222222 0.72222222 0.72619048
#  0.72685185 0.72820513 0.72962963 0.73148148 0.73333333 0.73888889
#  0.74074074 0.74358974 0.74814815 0.75       0.75277778 0.76190476
#  0.76666667 0.77142857 0.77207977 0.77289377 0.77380952 0.77777778
#  0.78333333 0.78518519 0.79047619 0.79166667 0.8        0.80555556
#  0.80952381 0.81944444 0.82222222 0.83333333 0.83809524 0.84920635
#  0.85       0.85714286 0.86666667 0.875      0.87777778 0.88888889
#  0.9047619  0.91666667 0.93333333 1.        ]

# %%
position = uniques_len[attribute]

dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-position],
    uniques[attribute][uniques_len[attribute]-position+1], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-3],
    uniques[attribute][uniques_len[attribute]-2], 10)
dpf.show_samples_interval(
    df_feature_base, attribute,
    uniques[attribute][uniques_len[attribute]-4],
    uniques[attribute][uniques_len[attribute]-3], 10)
# Out:
#         duplicates  volumes_delta volumes_x volumes_y
# 159710           0            0.0       675         1
# 88431            0            0.0       3 1
# 250336           0            0.0      1 32       600
# 235795           0            0.0       475        58
# 6147             0            0.0         2      1 56
# 61169            0            0.0         1       600
# 11134            0            0.0   3 64 71         1
# 167185           0            0.0         1       3 1
# 238545           0            0.0       135
# 161071           0            0.0         1       249
# 0.0 <= volumes_delta <= 0.3131868131868132
#         duplicates  volumes_delta volumes_x volumes_y
# 54818            0       0.933333      1 36     1 346
# 247561           0       0.933333      1 45     1 245
# 247463           0       0.916667      1 45       145
# 193148           0       0.933333     1 166      1 16
# 93524            0       0.933333     1 167      1 16
# 100431           0       0.916667      1 82       1 2
# 258762           0       0.916667      1 82       1 2
# 251050           0       0.933333     1 379      1 39
# 80266            0       0.933333     1 379      1 39
# 250334           0       0.916667      1 32      1 23
# 0.9166666666666666 <= volumes_delta <= 0.9333333333333332
#         duplicates  volumes_delta volumes_x volumes_y
# 258760           0       0.916667      1 82       1 2
# 320              1       0.904762     1 169   1 0 169
# 13               1       0.904762     1 169   1 0 169
# 247463           0       0.916667      1 45       145
# 2114             0       0.904762   1 0 169     1 169
# 165068           0       0.916667      1 82       1 2
# 10889            0       0.916667      1 82       1 2
# 107548           0       0.916667      1 82       1 2
# 23932            0       0.916667      1 82       1 2
# 86200            0       0.916667      1 82       1 2
# 0.9047619047619048 <= volumes_delta <= 0.9166666666666666

# %% [markdown]
# Attribute $\texttt{volumes}$ holds rows with missing data. The data pairs with missing values will be marked with a special negative value.

# %%
df_feature_base = dpf.mark_missing(df_feature_base, attribute, factor)

# %% [markdown]
# ## DataFrame with Attributes and Similarity Features

# %% [markdown]
# The metric for each attribute of the feature DataFrame has been decided and the similarity features have been calculated. In this last step, the columns of the DataFrame are reordered in order to place the $\_\texttt{delta}$ columns close to their input origins $\_\texttt{x}$ and $\_\texttt{y}$ and some sample records are shown.

# %%
# Take _x, _y, and _delta columns together
fb_col_list = df_feature_base.columns.tolist()
fb_col_list.sort()
# Move target column to first place
fb_col_list.insert(0, fb_col_list.pop(fb_col_list.index('duplicates')))
# Reorder DataFrame columns
df_attribute_with_sim_feature = pd.DataFrame(df_feature_base, columns=fb_col_list)

# Extend display to number of columns of DataFrame
pd.options.display.max_columns = len(df_attribute_with_sim_feature.columns)

class_label = ['uniques', 'duplicate']

for i in class_label:
    display(df_attribute_with_sim_feature[df_attribute_with_sim_feature.duplicates==class_label.index(i)].sample(n=10))
    print(i)
# Out:
#         duplicates  coordinate_E_delta coordinate_E_x coordinate_E_y  \
# 127939           0               -0.10
# 202790           0               -0.10
# 101968           0               -0.10
# 251748           0               -0.10
# 208253           0               -0.05                      e0074147
# 113690           0               -0.10
# 6188             0               -0.10
# 60227            0               -0.10
# 30470            0               -0.10
# 207489           0               -0.10
#
#         coordinate_N_delta coordinate_N_x coordinate_N_y  \
# 127939               -0.10
# 202790               -0.10
# 101968               -0.10
# 251748               -0.10
# 208253               -0.05                      n0460833
# 113690               -0.10
# 6188                 -0.10
# 60227                -0.10
# 30470                -0.10
# 207489               -0.10
#
#         corporate_full_delta  \
# 127939                 -0.10
# 202790                 -0.05
# 101968                 -0.05
# 251748                 -0.10
# 208253                 -0.05
# 113690                 -0.10
# 6188                   -0.05
# 60227                  -0.10
# 30470                  -0.10
# 207489                 -0.10
#
#                                          corporate_full_x  \
# 127939
# 202790                  schweizerische normen-vereinigung
# 101968  metropolitan operaorchestra, metropolitan oper...
# 251748
# 208253
# 113690
# 6188                           opernhaus orchester zürich
# 60227
# 30470
# 207489
#
#                         corporate_full_y  doi_delta               doi_x doi_y  \
# 127939                                        -0.10
# 202790                                        -0.10
# 101968                                        -0.10
# 251748                                        -0.10
# 208253  eidgenössische landestopographie      -0.05  10.1093/cid/cir669
# 113690                                        -0.10
# 6188                                          -0.10
# 60227                                         -0.10
# 30470                                         -0.10
# 207489                                        -0.05  10.1093/cid/ciu795
#
#         edition_delta edition_x edition_y  exactDate_delta exactDate_x  \
# 127939          -0.10                                0.375    19001950
# 202790          -0.10                                0.250    2011aaaa
# 101968          -0.10                                0.500    2000aaaa
# 251748          -0.10                                0.250    2017aaaa
# 208253          -0.10                                0.250    20111201
# 113690          -0.10                                0.250    20071990
# 6188            -0.10                                0.625    2002aaaa
# 60227           -0.10                                0.500    1959aaaa
# 30470           -0.05                   2            0.250    1999aaaa
# 207489          -0.10                                0.250    20150201
#
#        exactDate_y  format_postfix_delta format_postfix_x format_postfix_y  \
# 127939    19819999              0.428571           010200           030100
# 202790    1979uuuu              0.428571           020053           020000
# 101968    19001950              0.428571           010300           010100
# 251748    1970uuuu              0.428571           010000           010100
# 208253    1926uuuu              0.428571           010053           010300
# 113690    1835uuuu              0.428571           010300           010200
# 6188      2007uuuu              0.111111           010300           020053
# 60227     uuuuuuuu              0.428571           020000           010200
# 30470     2016uuuu              0.428571           020000           020053
# 207489    1982uuuu              0.111111           010053           020000
#
#         format_prefix_delta format_prefix_x format_prefix_y  isbn_delta  \
# 127939                  0.0              mu              vm         1.0
# 202790                  1.0              bk              bk         0.0
# 101968                  0.0              vm              mu         1.0
# 251748                  0.0              bk              mu         1.0
# 208253                  0.0              bk              mp         1.0
# 113690                  0.0              vm              mu         1.0
# 6188                    0.0              vm              bk         0.0
# 60227                   0.0              bk              vm         1.0
# 30470                   1.0              bk              bk         0.0
# 207489                  1.0              bk              bk         1.0
#
#                  isbn_x                                          isbn_y  \
# 127939               []                                              []
# 202790               []                                 [3-442-33001-7]
# 101968               []                                              []
# 251748               []                                              []
# 208253               []                                              []
# 113690               []                                              []
# 6188                 []  [978-3-598-31805-4 (print), 978-3-11-096274-1]
# 60227                []                                              []
# 30470   [3-495-47879-5]                             [978-3-495-81796-4]
# 207489               []                                              []
#
#         ismn_delta ismn_x ismn_y  musicid_delta musicid_x musicid_y  \
# 127939        -0.1                    -0.050000       245
# 202790        -0.1                    -0.050000               33001
# 101968        -0.1                     0.000000       073       226
# 251748        -0.1                    -0.050000                4553
# 208253        -0.1                    -0.100000
# 113690        -0.1                     0.166667    502023    134134
# 6188          -0.1                    -0.100000
# 60227         -0.1                    -0.100000
# 30470         -0.1                    -0.100000
# 207489        -0.1                    -0.100000
#
#         part_delta                      part_x              part_y  \
# 127939   -0.100000
# 202790   -0.050000                                     33001 33001
# 101968   -0.100000
# 251748    0.525641               2017 313 2017                  19
# 208253    0.526548  53 11 2011 12 01 1143 1152  23 1926 23 1926 23
# 113690   -0.100000
# 6188     -0.050000                                           45 45
# 60227    -0.050000                        2620
# 30470     1.000000                          57                  57
# 207489   -0.050000     60 3 2015 02 01 432 437
#
#         person_100_delta            person_100_x            person_100_y  \
# 127939         -0.050000  mozartwolfgang amadeus
# 202790         -0.050000                          mozartwolfgang amadeus
# 101968          1.000000  mozartwolfgang amadeus  mozartwolfgang amadeus
# 251748         -0.050000                          mozartwolfgang amadeus
# 208253         -0.100000
# 113690         -0.050000                          mozartwolfgang amadeus
# 6188            0.633285  mozartwolfgang amadeus          mortzfeldpeter
# 60227          -0.050000  mozartwolfgang amadeus
# 30470           1.000000            fluryandreas            fluryandreas
# 207489         -0.100000
#
#         person_245c_delta                                      person_245c_x  \
# 127939           0.543241  von w.a. mozart ; klavierauszug neu rev. von w...
# 202790          -0.050000
# 101968           0.593254         w.a. mozart ; libretto emanuel schikaneder
# 251748          -0.050000
# 208253           0.525329  [alexandra u. scherrer, bruno ledergerber, vik...
# 113690           0.538050  regie: volker schlöndorff ; drehbuch: volker s...
# 6188            -0.050000
# 60227            0.715058  wolfgang amadeus mozart ; dichtung von emanuel...
# 30470            1.000000                                      andreas flury
# 207489           0.590560  [virginie rozot, amelio patrizia, selena vigan...
#
#                                             person_245c_y  person_700_delta  \
# 127939                        sigrid kessler ... [et al.]          0.506324
# 202790  wolfgang amadeus mozart ; dieser opernführer w...         -0.050000
# 101968                                   von w. a. mozart          0.513964
# 251748  wolfgang amadeus mozart ; vorgelegt von gernot...         -0.100000
# 208253       g. h. dufour direxit ; h. müllhaupt sculpsit          0.543723
# 113690  von w.a. mozart ; clavier-auszug mit ital. u. ...         -0.050000
# 6188                        mortzfeld, peter; raabe, paul         -0.050000
# 60227                 wolfgang amadeus mozart, rens groot          0.591246
# 30470                                       andreas flury         -0.100000
# 207489  heidy binder... [et al.] ; [éd.:] interkantona...         -0.050000
#
#                                              person_700_x  \
# 127939              kienzlwilhelm, mozartwolfgang amadeus
# 202790
# 101968  schikanederemanuel, hockneydavid, coxjohn, lev...
# 251748
# 208253  scherreralexandra u., ledergerberbruno, von wy...
# 113690  schlöndorffvolker, wurlitzerrudy, frischmax, m...
# 6188
# 60227                  schikanederemanuel, zentnerwilhelm
# 30470
# 207489  rozotvirginie, patriziaamelio, viganoselena, m...
#
#                                     person_700_y  pubinit_delta  \
# 127939                             kesslersigrid      -0.050000
# 202790                                pahlenkurt       0.496337
# 101968                    mozartwolfgang amadeus       0.489352
# 251748                                                -0.100000
# 208253  dufourguillaume-henri, müllhauptheinrich      -0.050000
# 113690                                                -0.050000
# 6188                                   raabepaul       0.642735
# 60227          grootrens, mozartwolfgang amadeus      -0.050000
# 30470                                                 -0.100000
# 207489                                                -0.050000
#
#                                       pubinit_x  \
# 127939                        universal-edition
# 202790  schweizerische normen-vereinigung (snv)
# 101968         deutsche grammophon gesellschaft
# 251748
# 208253
# 113690              kinowelt home entertainment
# 6188                 tdk recording media europe
# 60227
# 30470
# 207489
#
#                                          pubinit_y  scale_delta scale_x  \
# 127939                                                    -0.10
# 202790  w. goldmann, musikverlag b. schott's söhne        -0.10
# 101968                          breitkopf & härtel        -0.10
# 251748                                                    -0.10
# 208253                   [eidg. landestopographie]        -0.05
# 113690                                                    -0.10
# 6188                               de gruyter saur        -0.10
# 60227                                      philips        -0.10
# 30470                                                     -0.10
# 207489                 staatlicher lehrmittelverl.        -0.10
#
#        scale_y  ttlfull_245_delta  \
# 127939                   0.585522
# 202790                   0.497999
# 101968                   0.719367
# 251748                   0.506323
# 208253  100000           0.505947
# 113690                   0.480952
# 6188                     0.533119
# 60227                    0.611643
# 30470                    1.000000
# 207489                   0.587057
#
#                                             ttlfull_245_x  \
# 127939  die zauberflöte, oper in zwei akten = il flaut...
# 202790  health informatics - personal health device co...
# 101968    die zauberflöte, oper in zwei aufzügen : kv 620
# 251748  alles wissen dieser welt, warum bibliotheken n...
# 208253  improved virological outcome in white patients...
# 113690                                         homo faber
# 6188                                      die zauberflöte
# 60227              die zauberflöte, oper in zwei aufzügen
# 30470   der moralische status der tiere, henry salt, p...
# 207489  combined use of mycobacterium tuberculosis-spe...
#
#                                             ttlfull_245_y  ttlfull_246_delta  \
# 127939  bonne chance, cours de langue française, deuxi...              -0.10
# 202790                   die zauberflöte, originalausgabe              -0.05
# 101968  die zauberflöte, deutsche oper in 2 acten : kö...              -0.10
# 251748                          die zauberflöte, [kv 620]              -0.05
# 208253                               domo d'ossola, arona              -0.05
# 113690  die zauberflöte, grosse oper in zwei aufzügen ...              -0.10
# 6188    katalog der graphischen porträts in der herzog...              -0.10
# 60227                                         zauberflöte              -0.10
# 30470   der moralische status der tiere, henry salt, p...              -0.10
# 207489  bonne chance!, cours de langue française, prem...              -0.10
#
#                                             ttlfull_246_x  \
# 127939
# 202790  medizinische informatik - kommunikation von ge...
# 101968
# 251748                                       bibliotheken
# 208253
# 113690
# 6188
# 60227
# 30470
# 207489
#
#                ttlfull_246_y  volumes_delta volumes_x volumes_y
# 127939                            -0.050000     1 167
# 202790                            -0.050000                 252
# 101968                             0.783333     1 169      1 26
# 251748                             0.000000        74       379
# 208253  [domodossola, arona]      -0.050000                   1
# 113690                             0.600000     2 109     1 127
# 6188                               0.000000         2     1 417
# 60227                              0.000000        71         1
# 30470                              0.000000       316         1
# 207489                            -0.050000                  72
# uniques
#         duplicates  coordinate_E_delta coordinate_E_x coordinate_E_y  \
# 281752           1                -0.1
# 263688           1                -0.1
# 285703           1                -0.1
# 259757           1                -0.1
# 266249           1                -0.1
# 282246           1                -0.1
# 267002           1                -0.1
# 292475           1                -0.1
# 287886           1                -0.1
# 280654           1                -0.1
#
#         coordinate_N_delta coordinate_N_x coordinate_N_y  \
# 281752                -0.1
# 263688                -0.1
# 285703                -0.1
# 259757                -0.1
# 266249                -0.1
# 282246                -0.1
# 267002                -0.1
# 292475                -0.1
# 287886                -0.1
# 280654                -0.1
#
#         corporate_full_delta  \
# 281752                   1.0
# 263688                  -0.1
# 285703                  -0.1
# 259757                  -0.1
# 266249                  -0.1
# 282246                  -0.1
# 267002                  -0.1
# 292475                  -0.1
# 287886                  -0.1
# 280654                  -0.1
#
#                                          corporate_full_x  \
# 281752  interkantonale lehrmittelzentrale (rapperswil,...
# 263688
# 285703
# 259757
# 266249
# 282246
# 267002
# 292475
# 287886
# 280654
#
#                                          corporate_full_y  doi_delta  \
# 281752  interkantonale lehrmittelzentrale (rapperswil,...       -0.1
# 263688                                                          -0.1
# 285703                                                          -0.1
# 259757                                                          -0.1
# 266249                                                          -0.1
# 282246                                                          -0.1
# 267002                                                          -0.1
# 292475                                                           1.0
# 287886                                                          -0.1
# 280654                                                          -0.1
#
#                        doi_x                 doi_y  edition_delta edition_x  \
# 281752                                                        1.0         2
# 263688                                                       -0.1
# 285703                                                       -0.1
# 259757                                                       -0.1
# 266249                                                       -0.1
# 282246                                                       -0.1
# 267002                                                       -0.1
# 292475  10.5169/seals-377332  10.5169/seals-377332           -0.1
# 287886                                                       -0.1
# 280654                                                       -0.1
#
#        edition_y  exactDate_delta exactDate_x exactDate_y  \
# 281752         2           0.7500    1999aaaa    1999uuuu
# 263688                     0.7500    2003aaaa    2003uuuu
# 285703                     0.7500    1998aaaa    1998uuuu
# 259757                     0.7500    2000aaaa    2000uuuu
# 266249                     0.6875    200aaaaa    200uuuuu
# 282246                     0.7500    1999aaaa    19997uuu
# 267002                     0.7500    2006aaaa    2006uuuu
# 292475                     0.7500    2007aaaa    2007uuuu
# 287886                     1.0000    19001950    19001950
# 280654                     0.7500    1998aaaa    1998uuuu
#
#         format_postfix_delta format_postfix_x format_postfix_y  \
# 281752                   1.0           020000           020000
# 263688                   1.0           010300           010300
# 285703                   1.0           020000           020000
# 259757                   1.0           020047           020047
# 266249                   1.0           020000           020000
# 282246                   1.0           020000           020000
# 267002                   1.0           020000           020000
# 292475                   1.0           010053           010053
# 287886                   1.0           010100           010100
# 280654                   1.0           020000           020000
#
#         format_prefix_delta format_prefix_x format_prefix_y  isbn_delta  \
# 281752                  1.0              bk              bk         1.0
# 263688                  1.0              vm              vm         1.0
# 285703                  1.0              bk              bk         1.0
# 259757                  1.0              bk              bk         1.0
# 266249                  1.0              bk              bk         1.0
# 282246                  1.0              bk              bk         1.0
# 267002                  1.0              bk              bk         1.0
# 292475                  1.0              bk              bk         1.0
# 287886                  1.0              mu              mu         1.0
# 280654                  1.0              bk              bk         1.0
#
#                                     isbn_x  \
# 281752                     [3-906721-48-5]
# 263688                                  []
# 285703                                  []
# 259757                     [3-932992-42-3]
# 266249                 [978-0-14-062010-8]
# 282246                     [0-7294-0706-3]
# 267002  [978-1-85584-193-2, 1-85584-193-2]
# 292475                                  []
# 287886                                  []
# 280654                     [3-15-002620-2]
#
#                                     isbn_y  ismn_delta ismn_x ismn_y  \
# 281752                     [3-906721-48-5]        -0.1
# 263688                                  []        -0.1
# 285703                                  []        -0.1
# 259757                     [3-932992-42-3]        -0.1
# 266249                 [978-0-14-062010-8]        -0.1
# 282246                     [0-7294-0706-3]        -0.1
# 267002  [978-1-85584-193-2, 1-85584-193-2]        -0.1
# 292475                                  []        -0.1
# 287886                                  []        -0.1
# 280654                     [3-15-002620-2]        -0.1
#
#         musicid_delta musicid_x musicid_y  part_delta     part_x     part_y  \
# 281752           -0.1                            -0.1
# 263688           -0.1                            -0.1
# 285703           -0.1                            -0.1
# 259757           -0.1                            -0.1
# 266249           -0.1                            -0.1
# 282246           -0.1                            -0.1
# 267002           -0.1                            -0.1
# 292475           -0.1                             1.0   286 2007   286 2007
# 287886           -0.1                            -0.1
# 280654           -0.1                             1.0  2620 2620  2620 2620
#
#         person_100_delta            person_100_x            person_100_y  \
# 281752         -0.100000
# 263688         -0.100000
# 285703          0.943162           kesslersigrid            keslersigrid
# 259757         -0.100000
# 266249          0.980000              austenjane               austenjan
# 282246          0.977778                voltaire               voltaifre
# 267002          1.000000           steinerrudolf           steinerrudolf
# 292475          0.946970            bührerwalter             bührewaltre
# 287886          0.990909  mozartwolfgang amadeus   mozarwolfgang amadeus
# 280654          0.981818  mozartwolfgang amadeus  mozarjwolfgang amadeus
#
#         person_245c_delta                                      person_245c_x  \
# 281752           0.994326  sigrid kessler... [et al.] ; [hrsg.:] interkan...
# 263688           1.000000           w.a. mozart ; video director brian large
# 285703           1.000000                              sigrid kessler [u.a.]
# 259757           0.981481                                  max frisch (u.a.)
# 266249           1.000000                                        jane austen
# 282246           1.000000       voltaire ; introd. et notes par john renwick
# 267002           0.952381                                     rudolf steiner
# 292475           0.955556                                    [walter bührer]
# 287886           0.998148  von emanuel schikaneder ; musik von w. a. moza...
# 280654           0.996255  wolfgang amadeus mozart ; libretto von emanuel...
#
#                                             person_245c_y  person_700_delta  \
# 281752  sigrid kessler..j. [et al.] ;[ hrsg.:] interka...          0.852293
# 263688           w.a. mozart ; video director brian large          0.988235
# 285703                              sigrid kessler [u.a.]         -0.100000
# 259757                                 max frisfch (u.a.)          0.977778
# 266249                                        jane austen         -0.100000
# 282246       voltaire ; introd. et notes par john renwick          0.945455
# 267002                                     erdolf steiner         -0.100000
# 292475                                    mwalter bührer]         -0.100000
# 287886  von emanuel schikaneder ; musik von w. a. mzoa...          1.000000
# 280654  wolfgang amadeus mozart ; libretto von emanuel...          0.994595
#
#                                              person_700_x  \
# 281752                        kesslersigrid, hubercharles
# 263688                 mozartwolfgang amadeus, largebrian
# 285703
# 259757                                          frischmax
# 266249
# 282246                                        renwickjohn
# 267002
# 292475
# 287886  aberthermann, schikanederemanuel, mozartwolfga...
# 280654              kochhans-albrecht, schikanederemanuel
#
#                                              person_700_y  pubinit_delta  \
# 281752                       rkesslersigrid, hubercharles       0.976190
# 263688                 mozartwolfgang amadeus, largebrimn       0.884259
# 285703                                                          0.928982
# 259757                                           frishmax       0.888889
# 266249                                                          0.948718
# 282246                                        raenwicjohn       1.000000
# 267002                                                          1.000000
# 292475                                                         -0.100000
# 287886  aberthermann, schikanederemanuel, mozartwolfga...       0.944444
# 280654              kochhans-albrceht, schikanederemanuel       1.000000
#
#                            pubinit_x                      pubinit_y  \
# 281752  staatlicher lehrmittelverlag   staatlichear lehrmittelerlag
# 263688                     del prado                       del rayo
# 285703  staatlicher lehrmittelverlag  staatliciher lehrmittelverlag
# 259757                        terzio                         terzao
# 266249                 penguin books                  penguin boofk
# 282246           voltaire foundation            voltaire foundation
# 267002                  sophia books                   sophia books
# 292475
# 287886                  e. eulenburg                   e.peulenburg
# 280654                p. reclam jun.                 p. reclam jun.
#
#         scale_delta scale_x scale_y  ttlfull_245_delta  \
# 281752         -0.1                           0.974155
# 263688         -0.1                           0.931746
# 285703         -0.1                           1.000000
# 259757         -0.1                           0.901122
# 266249         -0.1                           0.933333
# 282246         -0.1                           1.000000
# 267002         -0.1                           0.986667
# 292475         -0.1                           0.919118
# 287886         -0.1                           0.961345
# 280654         -0.1                           0.942018
#
#                                             ttlfull_245_x  \
# 281752  bonne chance!, cours de langue française, 3, c...
# 263688                                    die zauberflöte
# 285703  bonne chance!, cours de langue française, nouv...
# 259757  homo faber, originaltext, interpretation, biog...
# 266249                                               emma
# 282246                            traité sur la tolérance
# 267002                          how do i find the christ?
# 292475                                  blick in die welt
# 287886                die zauberflöte, eine deutsche oper
# 280654  die zauberflöte, kv 620 : eine grosse oper in ...
#
#                                             ttlfull_245_y  ttlfull_246_delta  \
# 281752  bonn echance!, cours de langul française, 3, c...               -0.1
# 263688                                    dei zauberfyöte               -0.1
# 285703  bonne chance!, cours de langue française, nouv...               -0.1
# 259757  homo faber, originalext, interpretation, biogr...               -0.1
# 266249                                              embma               -0.1
# 282246                            traité sur la tolérance               -0.1
# 267002                          how do i findt he christ?               -0.1
# 292475                                  blick mn die welt               -0.1
# 287886                die zauberflöte, eine deutscheroper               -0.1
# 280654  ide zauberflöte, kv 620g: eine grosse opr in z...               -0.1
#
#        ttlfull_246_x ttlfull_246_y  volumes_delta volumes_x volumes_y
# 281752                                        1.0       181       181
# 263688                                        1.0     1 169     1 169
# 285703                                        1.0       107       107
# 259757                                        1.0         1         1
# 266249                                        1.0       367       367
# 282246                                        1.0       142       142
# 267002                                        1.0        58        58
# 292475                                       -0.1
# 287886                                        1.0     1 412     1 412
# 280654                                        1.0        90        90
# duplicate

# %% [markdown]
# ## Summary

# %% [markdown]
# This chapter covers the central area of feature construction. The features of the feature matrix have been generated for each attribute of Swissbib's raw data, deciding on its similarity metric. With these metric values, the feature base DataFrame has been extended and a new DataFrame with the attribute values of the pairs together with their calculated similarity value have been generated. The similarity values will be the final features for training and performance testing of the models, compare [[JudACaps](./A_References.ipynb#judacaps)].

# %%
columns_metadata_dict['similarity_metrics']
# Out:
# {'coordinate_E': LCSStr({'qval': 1, 'external': True}),
#  'coordinate_N': LCSStr({'qval': 1, 'external': True}),
#  'corporate_full': LCSStr({'qval': 1, 'external': True}),
#  'doi': Identity({'qval': 1, 'external': True}),
#  'edition': Jaccard({'qval': 1, 'as_set': False, 'external': True}),
#  'exactDate': Hamming({'qval': 1, 'test_func': <function Base._ident at 0x10b7c2950>, 'truncate': False, 'external': True}),
#  'format_prefix': Identity({'qval': 1, 'external': True}),
#  'format_postfix': Jaccard({'qval': 2, 'as_set': False, 'external': True}),
#  'isbn': Identity({'qval': 1, 'external': True}),
#  'ismn': Identity({'qval': 1, 'external': True}),
#  'musicid': LCSStr({'qval': 1, 'external': True}),
#  'part': StrCmp95({'long_strings': False, 'external': True}),
#  'person_100': StrCmp95({'long_strings': False, 'external': True}),
#  'person_700': StrCmp95({'long_strings': False, 'external': True}),
#  'person_245c': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}),
#  'pubinit': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}),
#  'scale': Jaccard({'qval': 1, 'as_set': False, 'external': True}),
#  'ttlfull_245': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}),
#  'ttlfull_246': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}),
#  'volumes': StrCmp95({'long_strings': False, 'external': True})}

# %% [markdown]
# The similarity metric decided for each attribute has been added as an additional kind of information to the columns metadata dictionary. The following table gives this summary in a structured form and lists the metric used for each attribute. Attributes with the same font color indicate similar types of values (description column) for better orientation.

# %% [markdown]
# | attribute     | subtype | description | similarity metric |
# | ------------- |:--------|:------------|:------------------|
# |<font color='red'>[coordinate](#coordinate)</font>|<font color='red'>\_E</font>|<font color='red'>Code(9)</font>|<font color='red'>LCSStr</font>|
# |               |<font color='red'>\_N</font>|<font color='red'>Code(9)</font>|<font color='red'>LCSStr</font>|
# |<font color='blue'>[corporate](#corporate)</font>|<font color='blue'>\_full</font>|<font color='blue'>Name</font>|<font color='blue'>LCSStr</font>|
# |<font color='green'>[doi](#doi)</font>|         |<font color='green'>Identifier</font>|<font color='green'>Identity</font>|
# |<font color='orange'>[edition](#edition)</font>|         |<font color='orange'>Number</font>|<font color='orange'>Jaccard</font>|
# |<font color='black'>[exactDate](#exactDate)</font>|         |<font color='black'>Date</font>|<font color='black'>Hamming</font>|
# |<font color='red'>[format](#format)</font>|<font color='red'>\_prefix</font>|<font color='red'>Code(2)</font>|<font color='red'>Identity</font>|
# |               |<font color='red'>\_postfix</font>|<font color='red'>Code(6)</font>|<font color='red'>Jaccard (qval=2)</font>|
# |<font color='green'>[isbn](#isbn)</font>|         |<font color='green'>Identifier</font>|<font color='green'>Identity</font>|
# |<font color='green'>[ismn](#ismn)</font>|         |<font color='green'>Identifier</font>|<font color='green'>Identity</font>|
# |<font color='green'>[musicid](#musicid)</font>|         |<font color='green'>Identifier</font>|<font color='green'>LCSStr</font>|
# |<font color='orange'>[part](#part)</font>|         |<font color='orange'>Number</font>|<font color='orange'>StrCmp95</font>|
# |<font color='blue'>[person](#person)</font>|<font color='blue'>\_100</font>|<font color='blue'>Name</font>|<font color='blue'>StrCmp95</font>|
# |               |<font color='blue'>\_700</font>|<font color='blue'>Name</font>|<font color='blue'>StrCmp95</font>|
# |               |<font color='blue'>\_245c</font>|<font color='blue'>Name</font>|<font color='blue'>Jaro</font>|
# |<font color='blue'>[pubinit](#pubinit)</font>|         |<font color='blue'>Name</font>|<font color='blue'>Jaro</font>|
# |<font color='orange'>[scale](#scale)</font>|         |<font color='orange'>Number</font>|<font color='orange'>Jaccard</font>|
# |<font color='blue'>[ttlfull](#ttlfull)</font>|<font color='blue'>\_245</font>|<font color='blue'>String</font>|<font color='blue'>Jaro</font>|
# |               |<font color='blue'>\_246</font>|<font color='blue'>String</font>|<font color='blue'>Jaro</font>|
# |<font color='orange'>[volumes](#volumes)</font>|         |<font color='orange'>Number</font>|<font color='orange'>StrCmp95</font>|

# %% [markdown]
# ### Full Feature Matrix with Target Vector Handover

# %% [markdown]
# To hand over the resulting DataFrame of this chapter, the DataFrame is saved into a pickle file that will be read in the next chapters [Features Discussion and Dummy Classifier Baseline](./5_FeatureDiscussionDummyBaseline.ipynb) as input.

# %%
# Store into compressed intermediary file
with bz2.BZ2File(os.path.join(path_goldstandard,
                       'labelled_feature_matrix_full.pkl'), 'w') as df_output_file:
    pk.dump(df_attribute_with_sim_feature, df_output_file)
    
# Binary intermediary DataFrame file for docid's
with open(os.path.join(path_goldstandard, 'index_docids_df.pkl'), 'wb') as df_output_file:
    pk.dump(df_index_docids, df_output_file)

# %% [markdown]
# The full metadata dictionary is to be persisted for handover to subsequent chapters.

# %%
# The target is still needed for the feature matrix
columns_metadata_dict['features'].append('duplicates')

for k in columns_metadata_dict.keys():
    print(k, '\n', columns_metadata_dict[k], '\n')
# Out:
# data_analysis_columns
#  ['coordinate_E', 'coordinate_N', 'corporate_full', 'doi', 'edition', 'exactDate', 'format_prefix', 'format_postfix', 'isbn', 'ismn', 'musicid', 'part', 'person_100', 'person_700', 'person_245c', 'pubinit', 'scale', 'ttlfull_245', 'ttlfull_246', 'volumes']
#
# columns_to_use
#  ['duplicates', 'coordinate_E_x', 'coordinate_E_y', 'coordinate_N_x', 'coordinate_N_y', 'corporate_full_x', 'corporate_full_y', 'doi_x', 'doi_y', 'edition_x', 'edition_y', 'exactDate_x', 'exactDate_y', 'format_prefix_x', 'format_prefix_y', 'format_postfix_x', 'format_postfix_y', 'isbn_x', 'isbn_y', 'ismn_x', 'ismn_y', 'musicid_x', 'musicid_y', 'part_x', 'part_y', 'person_100_x', 'person_100_y', 'person_700_x', 'person_700_y', 'person_245c_x', 'person_245c_y', 'pubinit_x', 'pubinit_y', 'scale_x', 'scale_y', 'ttlfull_245_x', 'ttlfull_245_y', 'ttlfull_246_x', 'ttlfull_246_y', 'volumes_x', 'volumes_y']
#
# similarity_metrics
#  {'coordinate_E': LCSStr({'qval': 1, 'external': True}), 'coordinate_N': LCSStr({'qval': 1, 'external': True}), 'corporate_full': LCSStr({'qval': 1, 'external': True}), 'doi': Identity({'qval': 1, 'external': True}), 'edition': Jaccard({'qval': 1, 'as_set': False, 'external': True}), 'exactDate': Hamming({'qval': 1, 'test_func': <function Base._ident at 0x10b7c2950>, 'truncate': False, 'external': True}), 'format_prefix': Identity({'qval': 1, 'external': True}), 'format_postfix': Jaccard({'qval': 2, 'as_set': False, 'external': True}), 'isbn': Identity({'qval': 1, 'external': True}), 'ismn': Identity({'qval': 1, 'external': True}), 'musicid': LCSStr({'qval': 1, 'external': True}), 'part': StrCmp95({'long_strings': False, 'external': True}), 'person_100': StrCmp95({'long_strings': False, 'external': True}), 'person_700': StrCmp95({'long_strings': False, 'external': True}), 'person_245c': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'pubinit': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'scale': Jaccard({'qval': 1, 'as_set': False, 'external': True}), 'ttlfull_245': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'ttlfull_246': Jaro({'qval': 1, 'long_tolerance': False, 'winklerize': False, 'external': True}), 'volumes': StrCmp95({'long_strings': False, 'external': True})}
#
# features
#  ['coordinate_E_delta', 'coordinate_N_delta', 'corporate_full_delta', 'doi_delta', 'edition_delta', 'exactDate_delta', 'format_prefix_delta', 'format_postfix_delta', 'isbn_delta', 'ismn_delta', 'musicid_delta', 'part_delta', 'person_100_delta', 'person_700_delta', 'person_245c_delta', 'pubinit_delta', 'scale_delta', 'ttlfull_245_delta', 'ttlfull_246_delta', 'volumes_delta', 'duplicates']

# %%
# Binary intermediary metadata file
with open(os.path.join(path_goldstandard,
                       'columns_metadata.pkl'), 'wb') as dict_output_file:
    pk.dump(columns_metadata_dict, dict_output_file)
